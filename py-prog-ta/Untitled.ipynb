# %%
import pandas as pd
import numpy as np

# %%
def open_csv(file=None,header=6):
    if file:
        #open csv pakai pandas
        data = pd.read_csv(file, header=header)
        #ganti nama header
        data.columns = [
                        "Nama Panggilan", 
                        "Asal Sekolah", 
                        "Jurusan Sekolah", 
                        "Jenis Sekolah",
                        "Jenis Kelas", 
                        "Akreditasi Sekolah", 
                        "Prestasi Sekolah", 
                        "Alumni Sekolah", 
                        "PTN Pilihan I", 
                        "Jurusan Pilihan I di PTN Pilihan I" ,
                        "Jurusan Pilihan II di PTN Pilihan I", 
                        "PTN Pilihan II", 
                        "Jurusan Pilihan I di PTN Pilihan II" ,
                        "Jurusan Pilihan II di PTN Pilihan II", 
                        "Jurusan Diterima", "PTN Diterima", 
                        "Matematika Semester 1", 
                        "Matematika Semester 2", 
                        "Matematika Semester 3", 
                        "Matematika Semester 4", 
                        "Matematika Semester 5", 
                        "Inggris Semester 1", 
                        "Inggris Semester 2", 
                        "Inggris Semester 3", 
                        "Inggris Semester 4", 
                        "Inggris Semester 5",
                        "Indonesia Semester 1",
                        "Indonesia Semester 2",
                        "Indonesia Semester 3",
                        "Indonesia Semester 4",
                        "Indonesia Semester 5",
                        "Fisika Semester 1",
                        "Fisika Semester 2",
                        "Fisika Semester 3",
                        "Fisika Semester 4",
                        "Fisika Semester 5",
                        "Kimia Semester 1",
                        "Kimia Semester 2",
                        "Kimia Semester 3",
                        "Kimia Semester 4",
                        "Kimia Semester 5",
                        "Biologi Semester 1",
                        "Biologi Semester 2",
                        "Biologi Semester 3",
                        "Biologi Semester 4",
                        "Biologi Semester 5",
                        "Ekonomi Semester 1",
                        "Ekonomi Semester 2",
                        "Ekonomi Semester 3",
                        "Ekonomi Semester 4",
                        "Ekonomi Semester 5",
                        "Geografi Semester 1",
                        "Geografi Semester 2",
                        "Geografi Semester 3",
                        "Geografi Semester 4",
                        "Geografi Semester 5",
                        "Sosiologi Semester 1",
                        "Sosiologi Semester 2",
                        "Sosiologi Semester 3",
                        "Sosiologi Semester 4",
                        "Sosiologi Semester 5",
                        "Sejarah Semester 1",
                        "Sejarah Semester 2",
                        "Sejarah Semester 3",
                        "Sejarah Semester 4",
                        "Sejarah Semester 5",
                        "Komputer Semester 1",
                        "Komputer Semester 2",
                        "Komputer Semester 3",
                        "Komputer Semester 4",
                        "Komputer Semester 5",
                        "Peringkat Kelas Semester 1",
                        "Peringkat Kelas Semester 2",
                        "Peringkat Kelas Semester 3",
                        "Peringkat Kelas Semester 4",
                        "Peringkat Kelas Semester 5",
                        "Nilai UN", 
                        "Saran",
                        "Prestasi Lain"
                    ]
        #drop column yang gak digunain
        data = data.drop([
            "Asal Sekolah", 
            "Jenis Kelas",
            "Akreditasi Sekolah", 
            "Prestasi Sekolah", 
            "Alumni Sekolah", 
            "Komputer Semester 1",
            "Komputer Semester 2",
            "Komputer Semester 3",
            "Komputer Semester 4",
            "Komputer Semester 5",
            "Peringkat Kelas Semester 1",
            "Peringkat Kelas Semester 2",
            "Peringkat Kelas Semester 3",
            "Peringkat Kelas Semester 4",
            "Peringkat Kelas Semester 5",
            "Nilai UN", 
            "Saran",
            "Prestasi Lain",
            "Sejarah Semester 1",
            "Sejarah Semester 2",
            "Sejarah Semester 3",
            "Sejarah Semester 4",
            "Sejarah Semester 5",
        ], axis = 1)

        #hapus row jika nama panggilan dan jurusan diterima NaN
        data = data.dropna(subset=["Nama Panggilan"])
    else:
        data = None

    return data

# %%
getMapel = lambda columns: {column.split(" Semester ")[0] for column in columns if "Semester" in column}

# %%
avg = lambda list_nilai: sum(list_nilai) / len(list_nilai)

# %%
def gantiPakeMedian(data):
    #mengambil nilai tengah dari tiap nilai
    data = data.replace("<70", 34.5)
    data = data.replace("71 - 75", 73)
    data = data.replace("76 - 80", 78)
    data = data.replace("81 - 85", 83)
    data = data.replace("86 - 90", 88)
    data = data.replace("91 - 95", 93)
    data = data.replace("> 95", 98)
    data = data.replace("No data", np.NaN)
    
    return data

# %%
def getMeanLimaSemester(data, mata_pelajaran, index=0):
    #isi value untuk fillna
    values = dict()
    for i in range(1, 6):
        rata2_per_pelajaran = data[f"{mata_pelajaran} Semester {i}"].mean()
        values[f"{mata_pelajaran} Semester {i}"] = rata2_per_pelajaran

    #isi NaN dengan rata2 semester
    data = data.fillna(value=values)

    #itung rata2 nilai 5 semester
    nilai_siswa_5_semester_list = [data[f"{mata_pelajaran} Semester {idx}"][index] for idx in range(1,6)]
    rata2_nilai_siswa_5_semester = avg(nilai_siswa_5_semester_list)
            
    return rata2_nilai_siswa_5_semester

# %%
def getJurusanDiterima(jurusan_diterima):
    if "administrasi" in jurusan_diterima.casefold()\
    or "sosial" in jurusan_diterima.casefold()\
    or "ekonomi" in jurusan_diterima.casefold()\
    or "hi" in jurusan_diterima.casefold()\
    or "hukum" in jurusan_diterima.casefold()\
    or "komunikasi" in jurusan_diterima.casefold()\
    or "politik" in jurusan_diterima.casefold()\
    or "sosiologi" in jurusan_diterima.casefold()\
    or "fsrd" in jurusan_diterima.casefold()\
    or "sbm" in jurusan_diterima.casefold()\
    or "akuntansi" in jurusan_diterima.casefold()\
    or "manajemen" in jurusan_diterima.casefold()\
    or "psdk" in jurusan_diterima.casefold()\
    or "fiskal" in jurusan_diterima.casefold()\
    or ("hubungan" in jurusan_diterima.casefold() and "internasional" in jurusan_diterima.casefold())\
    or "kriminologi" in jurusan_diterima.casefold()\
    or "psikologi" in jurusan_diterima.casefold()\
    or "bisnis" in jurusan_diterima.casefold()\
    or "filsafat" in jurusan_diterima.casefold()\
    or "jurnalistik" in jurusan_diterima.casefold()\
    or "humas" in jurusan_diterima.casefold()\
    or "desain" in jurusan_diterima.casefold()\
    or "film" in jurusan_diterima.casefold()\
    or "antropologi" in jurusan_diterima.casefold()\
    or "keluarga" in jurusan_diterima.casefold()\
    or "konsumen" in jurusan_diterima.casefold()\
    or "sejarah" in jurusan_diterima.casefold()\
    or "menejemen" in jurusan_diterima.casefold()\
    or "arkeologi" in jurusan_diterima.casefold()\
    or ("hubungan" in jurusan_diterima.casefold() and "masyarakat" in jurusan_diterima.casefold())\
    or "akutansi" in jurusan_diterima.casefold():
        jurusan_diterima = f"{jurusan_diterima} (IPS)"
    else:
        jurusan_diterima = f"{jurusan_diterima} (IPA)"

    return jurusan_diterima

# %%
def getDictionary(data, mata_pelajaran):
    df = dict()
    df_train_test = dict()
    list_jurusan = set()
    indeks = 0
    for i, row in data.iterrows():
        #dapetin nama jurusan
        jrs = row["Jurusan Diterima"].strip()
        fkl = row["PTN Diterima"].strip()
        jurusan_diterima = f"{jrs} - {fkl}".upper()
        
        #dapetin nama jurusan
        jurusan_diterima = getJurusanDiterima(jurusan_diterima)
        
        if "sastra" not in jurusan_diterima.casefold()\
        and "bahasa" not in jurusan_diterima.casefold()\
        and "perpustakaan" not in jurusan_diterima.casefold()\
        and "ugm" not in jurusan_diterima.casefold():
            list_jurusan.add(jurusan_diterima)
            #masukkin nama panggilan
            if "Nama Panggilan" not in df_train_test:
                df_train_test["Nama Panggilan"] = [row["Nama Panggilan"]]
            else:
                df_train_test["Nama Panggilan"].append(row["Nama Panggilan"])
                
            #masukkin jurusan sekolah
            if "Jurusan Sekolah" not in df_train_test:
                df_train_test["Jurusan Sekolah"] = [row["Jurusan Sekolah"]]
            else:
                df_train_test["Jurusan Sekolah"].append(row["Jurusan Sekolah"])
            
            #masukkin pilihan
            if not pd.isnull(row["PTN Pilihan I"]) and row["PTN Pilihan I"].casefold() != "kosong":
                if "Pilihan I" not in df_train_test:
                    if not pd.isnull(row["Jurusan Pilihan I di PTN Pilihan I"]):
                        if row["Jurusan Pilihan I di PTN Pilihan I"].casefold() != "kosong" and row["Jurusan Pilihan I di PTN Pilihan I"].casefold() != "-":
                            pilihan = getJurusanDiterima(f"{row['Jurusan Pilihan I di PTN Pilihan I'].strip()} - {row['PTN Pilihan I'].strip()}")
                            df_train_test["Pilihan I"] = [pilihan.upper()]
                else:
                    if not pd.isnull(row["Jurusan Pilihan I di PTN Pilihan I"]):
                        if row["Jurusan Pilihan I di PTN Pilihan I"].casefold() != "kosong" and row["Jurusan Pilihan I di PTN Pilihan I"].casefold() != "-":
                            pilihan = getJurusanDiterima(f"{row['Jurusan Pilihan I di PTN Pilihan I'].strip()} - {row['PTN Pilihan I'].strip()}")
                            df_train_test["Pilihan I"].append(pilihan.upper())
                                                          
                if "Pilihan II" not in df_train_test:
                    if not pd.isnull(row["Jurusan Pilihan II di PTN Pilihan I"]):
                        if row["Jurusan Pilihan II di PTN Pilihan I"].casefold() != "kosong" and row["Jurusan Pilihan II di PTN Pilihan I"].casefold() != "-":
                            pilihan = getJurusanDiterima(f"{row['Jurusan Pilihan II di PTN Pilihan I'].strip()} - {row['PTN Pilihan I'].strip()}")
                            df_train_test["Pilihan II"] = [pilihan.upper()]
                        else:
                            df_train_test["Pilihan II"] = ["KOSONG"]
                    else:
                        if not pd.isnull(row["PTN Pilihan II"]):
                            if row["PTN Pilihan II"].casefold() != "kosong":
                                if not pd.isnull(row["Jurusan Pilihan I di PTN Pilihan II"]):
                                    if row["Jurusan Pilihan I di PTN Pilihan II"].casefold() != "kosong" and row["Jurusan Pilihan I di PTN Pilihan II"].casefold() != "-":
                                        pilihan = getJurusanDiterima(f'{row["Jurusan Pilihan I di PTN Pilihan II"].strip()} - {row["PTN Pilihan II"].strip()}')
                                        df_train_test["Pilihan II"] = [pilihan.upper()]
                                    else:
                                        df_train_test["Pilihan II"] = ["KOSONG"]
                                else:
                                    df_train_test["Pilihan II"] = ["KOSONG"]
                            else:
                                df_train_test["Pilihan II"] = ["KOSONG"]
                        else:
                            df_train_test["Pilihan II"] = ["KOSONG"]
                else:
                    if not pd.isnull(row["Jurusan Pilihan II di PTN Pilihan I"]):
                        if row["Jurusan Pilihan II di PTN Pilihan I"].casefold() != "kosong" and row["Jurusan Pilihan II di PTN Pilihan I"].casefold() != "-":
                            pilihan = getJurusanDiterima(f"{row['Jurusan Pilihan II di PTN Pilihan I'].strip()} - {row['PTN Pilihan I'].strip()}")
                            df_train_test["Pilihan II"].append(pilihan.upper())
                        else:
                            df_train_test["Pilihan II"].append("KOSONG")
                    else:
                        if not pd.isnull(row["PTN Pilihan II"]):
                            if row["PTN Pilihan II"].casefold() != "kosong" or row["PTN Pilihan II"].casefold() != "-":
                                if not pd.isnull(row["Jurusan Pilihan I di PTN Pilihan II"]):
                                    if row["Jurusan Pilihan I di PTN Pilihan II"].casefold() != "kosong" and row["Jurusan Pilihan I di PTN Pilihan II"].casefold() != "-":
                                        pilihan = getJurusanDiterima(f'{row["Jurusan Pilihan I di PTN Pilihan II"].strip()} - {row["PTN Pilihan II"].strip()}')
                                        df_train_test["Pilihan II"].append(pilihan.upper())
                                    else:
                                        df_train_test["Pilihan II"].append("KOSONG")
                                else:
                                    df_train_test["Pilihan II"].append("KOSONG")
                            else:
                                df_train_test["Pilihan II"].append("KOSONG")
                        else:
                            df_train_test["Pilihan II"].append("KOSONG")
                        
            if "Pilihan III" not in df_train_test:
                if not pd.isnull(row["PTN Pilihan II"]):
                    if row["PTN Pilihan II"].casefold() != "kosong" or row["PTN Pilihan II"].casefold() != "-":
                        if df_train_test["Pilihan II"][indeks].casefold() != getJurusanDiterima(f'{row["Jurusan Pilihan I di PTN Pilihan II"]} - {row["PTN Pilihan II"]}').casefold():
                            if not pd.isnull(row["Jurusan Pilihan I di PTN Pilihan II"]):
                                if row["Jurusan Pilihan I di PTN Pilihan II"].casefold() != "kosong" and row["Jurusan Pilihan I di PTN Pilihan II"].casefold() != "-":
                                    pilihan = getJurusanDiterima(f'{row["Jurusan Pilihan I di PTN Pilihan II"].strip()} - {row["PTN Pilihan II"].strip()}')
                                    df_train_test["Pilihan III"] = [pilihan.upper()]
                                else:
                                    df_train_test["Pilihan III"] = ["KOSONG"]
                            else:
                                df_train_test["Pilihan III"] = ["KOSONG"]
                        else:
                            if not pd.isnull(row["Jurusan Pilihan II di PTN Pilihan II"]):
                                if row["Jurusan Pilihan II di PTN Pilihan II"].casefold() != "kosong" and row["Jurusan Pilihan II di PTN Pilihan II"].casefold() != "-":
                                    pilihan = getJurusanDiterma(f'{row["Jurusan Pilihan II di PTN Pilihan II"].strip()} - {row["PTN Pilihan II"].strip()}')
                                    df_train_test["Pilihan III"] = [pilihan.upper()]
                                else:
                                    df_train_test["Pilihan III"] = ["KOSONG"]
                            else:
                                df_train_test["Pilihan III"] = ["KOSONG"]
                    else:
                        df_train_test["Pilihan III"] = ["KOSONG"]
                else:
                    df_train_test["Pilihan III"] = ["KOSONG"]
            else:
                if not pd.isnull(row["PTN Pilihan II"]):
                    if row["PTN Pilihan II"].casefold() != "kosong" or row["PTN Pilihan II"].casefold() != "-":
                        if df_train_test["Pilihan II"][indeks].casefold() != getJurusanDiterima(f'{row["Jurusan Pilihan I di PTN Pilihan II"]} - {row["PTN Pilihan II"]}').casefold():
                            if not pd.isnull(row["Jurusan Pilihan I di PTN Pilihan II"]):
                                if row["Jurusan Pilihan I di PTN Pilihan II"].casefold() != "kosong" and row["Jurusan Pilihan I di PTN Pilihan II"].casefold() != "-":
                                    pilihan = getJurusanDiterima(f'{row["Jurusan Pilihan I di PTN Pilihan II"].strip()} - {row["PTN Pilihan II"].strip()}')
                                    df_train_test["Pilihan III"].append(pilihan.upper())
                                else:
                                    df_train_test["Pilihan III"].append("KOSONG")
                            else:
                                df_train_test["Pilihan III"].append("KOSONG")
                        else:
                            if not pd.isnull(row["Jurusan Pilihan II di PTN Pilihan II"]):
                                if row["Jurusan Pilihan II di PTN Pilihan II"].casefold() != "kosong" and row["Jurusan Pilihan II di PTN Pilihan II"].casefold() != "-":
                                    pilihan = getJurusanDiterima(f'{row["Jurusan Pilihan II di PTN Pilihan II"].strip()} - {row["PTN Pilihan II"].strip()}')
                                    df_train_test["Pilihan III"].append(pilihan.upper())
                                else:
                                    df_train_test["Pilihan III"].append("KOSONG")
                            else:
                                df_train_test["Pilihan III"].append("KOSONG")
                    else:
                        df_train_test["Pilihan III"].append("KOSONG")
                else:
                    df_train_test["Pilihan III"].append("KOSONG")
            
            indeks += 1
                                                                        
            #masukkin jurusan diterima
            if "Jurusan Diterima" not in df_train_test:
                df_train_test["Jurusan Diterima"] = [jurusan_diterima]
            else:
                df_train_test["Jurusan Diterima"].append(jurusan_diterima)
        
            #bikin dictionary untuk data frame
            mean_list_temp = list()
            for item in mata_pelajaran:
                #masukkin mata pelajaran
                if item not in df_train_test:
                    df_train_test[item] = [getMeanLimaSemester(data, item, i)]
                else: 
                    df_train_test[item].append(getMeanLimaSemester(data, item, i))
                    
                if jurusan_diterima not in df:
                    df[jurusan_diterima] = [[getMeanLimaSemester(data, item, i)]]
                else:
                    if len(df[jurusan_diterima][0]) >= 9:
                        mean_list_temp.append(getMeanLimaSemester(data, item, i))
                        if len(mean_list_temp) >= 9:
                            df[jurusan_diterima].append(mean_list_temp)
                            del mean_list_temp
                    else:
                        df[jurusan_diterima][0].append(getMeanLimaSemester(data, item, i))

    #rata2in value di dictionary
    for item in list_jurusan:
        if len(df[item]) > 1:
            df[item] = [sum(x)/len(df[item]) for x in zip(*df[item])]
        else:
            df[item] = df[item][0]
    
                                                                            
    return [df, df_train_test]

# %%
data = open_csv("data/Data SNMPTN 2016 ITB by @halokampus.csv")

# %%
data
# Out:
#    Nama Panggilan Jurusan Sekolah Jenis Sekolah PTN Pilihan I  \
# 0          Nadija             IPA           SMA           ITB
# 1            Diah             IPA           SMA           ITB
# 2           Ihsan             IPA           SMA           ITB
# 3           Riana             IPA           SMA           ITB
# 4          Nisrin             IPA           SMA           ITB
# 5    Safira, fira             IPA           SMA           ITB
# 6          Satrio             IPA           SMA           ITB
# 7             Ari             IPA           SMA           ITB
# 8           Resty             IPA           SMA           ITB
# 9          Choiza             IPA           SMA           ITB
# 10            Iky             IPA           SMA           ITB
# 11    Li atau Nel             IPA           SMA           ITB
# 12         Raihan             IPA           SMA           ITB
# 13         Sodiko             IPA           SMA           ITB
# 14            Ica             IPA           SMA           ITB
# 15           Boti             IPA           SMA           Itb
# 16           Alif             IPA           SMA           ITB
# 17          Nanda             IPA           SMA           ITB
# 18          Syams             IPA           SMA           Itb
# 19           Oji              IPA           SMA           ITB
# 20          Dinan             IPA           SMA           ITB
# 21         Debora             IPA           SMA           ITB
# 22           Dito             IPA           SMA           ITB
# 23          Grace             IPA           SMA           ITB
# 24          Nasya             IPA           SMA           ITB
# 25           Lean             IPA           SMA           ITB
# 26            Iim             IPA           SMA           ITB
# 27           Ardi             IPA           SMA           ITB
# 28         Oktada             IPA           SMA           ITB
# 29            Aji             IPA           SMA           ITB
# 30         Mayang             IPA           SMA           ITB
# 31         Sheila             IPA           SMA           ITB
# 32         Kelvin             IPA           SMA           ITB
# 33            Edo             IPA           SMA           ITB
# 34           Fara             IPA           SMA           ITB
# 35          Gerry             IPA           SMA           ITB
# 36          Adita             IPA           SMA           ITB
# 37         Athira             IPA           SMA           ITB
# 38        Refanie             IPA           SMA           ITB
# 39         Muthia             IPA           SMA           ITB
# 40           Niel             IPA           SMA           ITB
# 41          Dicta             IPA           SMA           ITB
# 42        Luthfan             IPA           SMA           ITB
# 43          Kevin             IPA           SMA           ITB
# 44           Faiz             IPA           SMA           ITB
# 45          Arina             IPA           SMA           Itb
# 46          Marha             IPA           SMA           ITB
# 47           Iffa             IPA           SMA           ITB
# 48         Junius             IPA           SMA           ITB
# 49          Jacob             IPA           SMA           Itb
# 50         Erlien             IPA           SMA           Itb
# 51          Rifia             IPA           SMA           ITB
#
#                    Jurusan Pilihan I di PTN Pilihan I  \
# 0                                                STEI
# 1                            Fakultas Teknik Industri
# 2                                                FITB
# 3                                          SITH-Sains
# 4           Fakultas teknik industri - kampus ganesha
# 5                                                FSRD
# 6                                                FITB
# 7                                               FMIPA
# 8                                               FMIPA
# 9                                                FTI
# 10                                            FTI - G
# 11                                               STEI
# 12                                               STEI
# 13                         Sekolah Bisnis & Manajemen
# 14                                              fmipa
# 15                                              Fmipa
# 16                                       Teknik Mesin
# 17                                              FMIPA
# 18                                               Ftsl
# 19                                              SAPPK
# 20                                              SAPPK
# 21                                              FMIPA
# 22                                                FTI
# 23  Matematika (Fak. Matematika & Ilmu Pengetahuan...
# 24                                               FTTM
# 25                                               FTTM
# 26                                              FMIPA
# 27                                                FTI
# 28                                               FTTM
# 29               Fakultas Ilmu dan Teknologi Kebumian
# 30  SAPPK - Peminatan Perencanaan Wilayah Kota Kel...
# 31                                              FMIPA
# 32                                              FMIPA
# 33                                                FTI
# 34                                               FITB
# 35                                              FMIPA
# 36                 Sekolah Bisnis dan Manajemen (SBM)
# 37                                                FTI
# 38                        Fakultas Teknologi Industri
# 39                              SITH-Program Rekayasa
# 40                                               FTMD
# 41                                               FTTM
# 42                                              FMIPA
# 43                                              FMIPA
# 44                                                SBM
# 45                                         Arsitektur
# 46                                          FTI - MRI
# 47                                               STEI
# 48                                               FTMD
# 49                                               Ftsl
# 50                                            Elektro
# 51               Fakultas Teknik Sipil dan Lingkungan
#
#                   Jurusan Pilihan II di PTN Pilihan I PTN Pilihan II  \
# 0                                              kosong         kosong
# 1                                                 NaN         KOSONG
# 2                                                FTTM         KOSONG
# 3                                       SITH-Rekayasa            ITS
# 4                Fakultas teknik mesin dan dirgantara         KOSONG
# 5                                              Kosong         Kosong
# 6                                        FTSL-Ganesha         KOSONG
# 7                                                 NaN         KOSONG
# 8                                                 NaN         KOSONG
# 9                                        TEKNIK KIMIA            UGM
# 10                                               FTSL            ITB
# 11                                              FMIPA         Kosong
# 12                                              SAPPK         KOSONG
# 13                                                NaN         KOSONG
# 14                                                NaN         KOSONG
# 15                                                NaN         KOSONG
# 16                                                NaN         KOSONG
# 17                                                NaN            ITS
# 18                                              Fmipa          Unpad
# 19                                               SITH            USU
# 20                                                NaN         KOSONG
# 21                                                NaN         KOSONG
# 22                                              FMIPA         KOSONG
# 23                                             kosong         kosong
# 24                       Perencanaan Wilayah dan Kota         KOSONG
# 25                                    Teknik Industri            UNS
# 26                                             SITH-R            ITS
# 27                                               FTTM             UI
# 28                                               FTMD         KOSONG
# 29  Sekolah Arsitektur Perencanaan dan Pengembanga...            ITS
# 30                                               FITB         KOSONG
# 31                                                 SF         kosong
# 32                                                NaN          UNPAD
# 33                                                NaN         KOSONG
# 34                                              FMIPA             UB
# 35                                               FTSL         KOSONG
# 36      Sekolah Teknik Elektro dan Informatika (STEI)             UI
# 37                                             Kosong         Kosong
# 38                                    Sekolah Farmasi             UI
# 39                                             Kosong            IPB
# 40                                              SAPPK         KOSONG
# 41                                                NaN         KOSONG
# 42                                             Kosong         Kosong
# 43                                                NaN         KOSONG
# 44                                               SITH         KOSONG
# 45                                                Sbm         KOSONG
# 46                                                 SF         KOSONG
# 47                                               FTTM             UI
# 48                                             FTSL-G             UI
# 49                            Fakultas teknik arsitek             Ui
# 50                                            Geologi             Ui
# 51  Sekolah Arsitektur Perencanaan dan Pengembanga...         KOSONG
#
#    Jurusan Pilihan I di PTN Pilihan II Jurusan Pilihan II di PTN Pilihan II  \
# 0                               kosong                               kosong
# 1                                  NaN                                  NaN
# 2                                  NaN                                  NaN
# 3                    Teknik Lingkungan                                  NaN
# 4                                  NaN                                  NaN
# 5                               Kosong                               Kosong
# 6                                  NaN                                  NaN
# 7                                  NaN                                  NaN
# 8                                  NaN                                  NaN
# 9                         TEKNIK MESIN                        TEKNIK FISIKA
# 10                                 NaN                                  NaN
# 11                              Kosong                               Kosong
# 12                                 NaN                                  NaN
# 13                                 NaN                                  NaN
# 14                                 NaN                                  NaN
# 15                                 NaN                                  NaN
# 16                                 NaN                                  NaN
# 17                          Matematika                           Statistika
# 18                          Matematika                                  NaN
# 19                           Akuntansi                                    -
# 20                                 NaN                                  NaN
# 21                                 NaN                                  NaN
# 22                                 NaN                                  NaN
# 23                              kosong                               kosong
# 24                                 NaN                                  NaN
# 25                          Kedokteran                                  NaN
# 26                          Statistika                                  NaN
# 27                        Teknik Kimia                               Kosong
# 28                                 NaN                                  NaN
# 29                    Teknik Geomatika                               Kosong
# 30                                 NaN                                  NaN
# 31                              kosong                               kosong
# 32                              Fisika                                  NaN
# 33                                 NaN                                  NaN
# 34                           ILMU GIZI                                  NaN
# 35                                 NaN                                  NaN
# 36                           Manajemen                                  NaN
# 37                              Kosong                               Kosong
# 38                             Farmasi                               Kosong
# 39                     Manajemen Hutan                               Kosong
# 40                                 NaN                                  NaN
# 41                                 NaN                                  NaN
# 42                              Kosong                               Kosong
# 43                                 NaN                                  NaN
# 44                                 NaN                                  NaN
# 45                                 NaN                                  NaN
# 46                                 NaN                                  NaN
# 47                    Sistem informasi                               kosong
# 48                             Farmasi                                    -
# 49                        Teknik sipil                               Kosong
# 50                     Teknik industri                       Teknik elektro
# 51                                 NaN                                  NaN
#
#                                      Jurusan Diterima  ...  \
# 0                                                STEI  ...
# 1                            Fakultas Teknik Industri  ...
# 2                                                FITB  ...
# 3                                          SITH-Sains  ...
# 4                Fakultas teknik mesin dan dirgantara  ...
# 5                                                FSRD  ...
# 6                                                FITB  ...
# 7                                               FMIPA  ...
# 8                                               FMIPA  ...
# 9                                                FTI   ...
# 10                                            FTI - G  ...
# 11                                               STEI  ...
# 12                                               STEI  ...
# 13                         Sekolah Bisnis & Manajemen  ...
# 14                                              fmipa  ...
# 15                                              Fmipa  ...
# 16                                                  0  ...
# 17                                              FMIPA  ...
# 18                                               Ftsl  ...
# 19                                              SAPPK  ...
# 20                                              SAPPK  ...
# 21                                              FMIPA  ...
# 22                                              FMIPA  ...
# 23  Matematika (Fak. Matematika & Ilmu Pengetahuan...  ...
# 24                                               FTTM  ...
# 25                                               FTTM  ...
# 26                                              FMIPA  ...
# 27                                                FTI  ...
# 28                                               FTTM  ...
# 29               Fakultas Ilmu dan Teknologi Kebumian  ...
# 30  SAPPK - Peminatan Perencanaan Wilayah Kota Kel...  ...
# 31                                              FMIPA  ...
# 32                                              FMIPA  ...
# 33                                                FTI  ...
# 34                                               FITB  ...
# 35                                              FMIPA  ...
# 36                 Sekolah Bisnis dan Manajemen (SBM)  ...
# 37                                                FTI  ...
# 38                        Fakultas Teknologi Industri  ...
# 39                              SITH-Program Rekayasa  ...
# 40                                               FTMD  ...
# 41                                               FTTM  ...
# 42                                              FMIPA  ...
# 43                                              FMIPA  ...
# 44                                                SBM  ...
# 45                                         Arsitektur  ...
# 46                                                 SF  ...
# 47                                               STEI  ...
# 48                                               FTMD  ...
# 49                                               Ftsl  ...
# 50                                            Elektro  ...
# 51               Fakultas Teknik Sipil dan Lingkungan  ...
#
#    Geografi Semester 1 Geografi Semester 2 Geografi Semester 3  \
# 0              No data             No data             No data
# 1                  NaN                 NaN                 NaN
# 2              No data             No data             No data
# 3                  NaN                 NaN                 NaN
# 4              No data             No data             No data
# 5                  NaN                 NaN                 NaN
# 6              No data             No data             No data
# 7              No data             No data             No data
# 8                  NaN                 NaN                 NaN
# 9                  NaN                 NaN                 NaN
# 10                 NaN                 NaN                 NaN
# 11             No data             No data             No data
# 12             No data             No data             No data
# 13             No data             No data             No data
# 14                 NaN                 NaN                 NaN
# 15                 NaN                 NaN                 NaN
# 16                 NaN                 NaN                 NaN
# 17                 NaN                 NaN                 NaN
# 18                 NaN                 NaN                 NaN
# 19             No data             No data             No data
# 20                 NaN                 NaN                 NaN
# 21                 NaN                 NaN                 NaN
# 22                 NaN                 NaN                 NaN
# 23             71 - 75             81 - 85             No data
# 24                 NaN                 NaN                 NaN
# 25             No data             No data             No data
# 26             No data             No data             No data
# 27                 NaN                 NaN                 NaN
# 28                 NaN                 NaN                 NaN
# 29             No data             No data             No data
# 30                 NaN                 NaN                 NaN
# 31             81 - 85             81 - 85             71 - 75
# 32                 NaN                 NaN                 NaN
# 33             86 - 90             86 - 90             86 - 90
# 34                 NaN                 NaN                 NaN
# 35             No data             No data             No data
# 36             No data             No data             No data
# 37                 NaN                 NaN                 NaN
# 38             81 - 85             91 - 95             91 - 95
# 39             No data             No data             No data
# 40                 NaN                 NaN                 NaN
# 41                 NaN                 NaN                 NaN
# 42             81 - 85             76 - 80             No data
# 43             No data             No data             No data
# 44                 NaN                 NaN                 NaN
# 45                 NaN                 NaN                 NaN
# 46                 NaN                 NaN                 NaN
# 47                 NaN                 NaN                 NaN
# 48             No data             No data             No data
# 49             No data             No data             No data
# 50             86 - 90             86 - 90             86 - 90
# 51             No data             No data             No data
#
#    Geografi Semester 4 Geografi Semester 5 Sosiologi Semester 1  \
# 0              No data             No data              No data
# 1                  NaN                 NaN                  NaN
# 2              No data             No data              No data
# 3                  NaN                 NaN                  NaN
# 4              No data             No data              81 - 85
# 5                  NaN                 NaN                  NaN
# 6              No data             No data              No data
# 7              No data             No data              No data
# 8                  NaN                 NaN                  NaN
# 9                  NaN                 NaN                  NaN
# 10                 NaN                 NaN                  NaN
# 11             No data             No data              No data
# 12             No data             No data              No data
# 13             No data             No data              No data
# 14                 NaN                 NaN                  NaN
# 15                 NaN                 NaN                  NaN
# 16                 NaN                 NaN                  NaN
# 17                 NaN                 NaN              No data
# 18                 NaN                 NaN                  NaN
# 19             No data             No data              No data
# 20                 NaN                 NaN                  NaN
# 21                 NaN                 NaN                  NaN
# 22                 NaN                 NaN                  NaN
# 23             No data             No data              81 - 85
# 24                 NaN                 NaN                  NaN
# 25             No data             No data              No data
# 26             No data             No data              No data
# 27                 NaN                 NaN                  NaN
# 28                 NaN                 NaN                  NaN
# 29             No data             No data              No data
# 30                 NaN                 NaN                  NaN
# 31             71 - 75             71 - 75              86 - 90
# 32                 NaN                 NaN                  NaN
# 33             91 - 95                > 95              No data
# 34                 NaN                 NaN                  NaN
# 35             No data             No data              No data
# 36             No data             No data              No data
# 37                 NaN                 NaN                  NaN
# 38             86 - 90             81 - 85              No data
# 39             No data             No data              No data
# 40                 NaN                 NaN                  NaN
# 41                 NaN                 NaN                  NaN
# 42             No data             No data              76 - 80
# 43             No data             No data              No data
# 44                 NaN                 NaN                  NaN
# 45                 NaN                 NaN                  NaN
# 46                 NaN                 NaN                  NaN
# 47                 NaN                 NaN                  NaN
# 48             No data             No data              No data
# 49             No data             No data              No data
# 50             86 - 90             86 - 90                  NaN
# 51             No data             No data              No data
#
#    Sosiologi Semester 2 Sosiologi Semester 3 Sosiologi Semester 4  \
# 0               No data              No data              No data
# 1                   NaN                  NaN                  NaN
# 2               No data              No data              No data
# 3                   NaN                  NaN                  NaN
# 4               86 - 90              No data              No data
# 5                   NaN                  NaN                  NaN
# 6               No data              No data              No data
# 7               No data              No data              No data
# 8                   NaN                  NaN                  NaN
# 9                   NaN                  NaN                  NaN
# 10                  NaN                  NaN                  NaN
# 11              No data              No data              No data
# 12              No data              No data              No data
# 13              No data              No data              No data
# 14                  NaN                  NaN                  NaN
# 15                  NaN                  NaN                  NaN
# 16                  NaN                  NaN                  NaN
# 17              No data              No data              No data
# 18                  NaN                  NaN                  NaN
# 19              No data              No data              No data
# 20                  NaN                  NaN                  NaN
# 21                  NaN                  NaN                  NaN
# 22                  NaN                  NaN                  NaN
# 23              86 - 90              No data              No data
# 24                  NaN                  NaN                  NaN
# 25              No data              No data              No data
# 26              No data              No data              No data
# 27                  NaN                  NaN                  NaN
# 28                  NaN                  NaN                  NaN
# 29              No data              No data              No data
# 30                  NaN                  NaN                  NaN
# 31              86 - 90              No data              No data
# 32                  NaN                  NaN                  NaN
# 33              No data              No data              No data
# 34                  NaN                  NaN                  NaN
# 35              No data              No data              No data
# 36              No data              No data              No data
# 37                  NaN                  NaN                  NaN
# 38              No data              No data              No data
# 39              No data              No data              No data
# 40                  NaN                  NaN                  NaN
# 41                  NaN                  NaN                  NaN
# 42              76 - 80              No data              No data
# 43              No data              No data              No data
# 44                  NaN                  NaN                  NaN
# 45                  NaN                  NaN                  NaN
# 46                  NaN                  NaN                  NaN
# 47                  NaN                  NaN                  NaN
# 48              No data              No data              No data
# 49              No data              No data              No data
# 50                  NaN                  NaN                  NaN
# 51              No data              No data              No data
#
#    Sosiologi Semester 5
# 0               No data
# 1                   NaN
# 2               No data
# 3                   NaN
# 4               No data
# 5                   NaN
# 6               No data
# 7               No data
# 8                   NaN
# 9                   NaN
# 10                  NaN
# 11              No data
# 12              No data
# 13              No data
# 14                  NaN
# 15                  NaN
# 16                  NaN
# 17              No data
# 18                  NaN
# 19              No data
# 20                  NaN
# 21                  NaN
# 22                  NaN
# 23              No data
# 24                  NaN
# 25              No data
# 26              No data
# 27                  NaN
# 28                  NaN
# 29              No data
# 30                  NaN
# 31              No data
# 32                  NaN
# 33              No data
# 34                  NaN
# 35              No data
# 36              No data
# 37                  NaN
# 38              No data
# 39              No data
# 40                  NaN
# 41                  NaN
# 42              No data
# 43              No data
# 44                  NaN
# 45                  NaN
# 46                  NaN
# 47                  NaN
# 48              No data
# 49              No data
# 50                  NaN
# 51              No data
#
# [52 rows x 56 columns]

# %%
data = gantiPakeMedian(data)

# %%
data
# Out:
#    Nama Panggilan Jurusan Sekolah Jenis Sekolah PTN Pilihan I  \
# 0          Nadija             IPA           SMA           ITB
# 1            Diah             IPA           SMA           ITB
# 2           Ihsan             IPA           SMA           ITB
# 3           Riana             IPA           SMA           ITB
# 4          Nisrin             IPA           SMA           ITB
# 5    Safira, fira             IPA           SMA           ITB
# 6          Satrio             IPA           SMA           ITB
# 7             Ari             IPA           SMA           ITB
# 8           Resty             IPA           SMA           ITB
# 9          Choiza             IPA           SMA           ITB
# 10            Iky             IPA           SMA           ITB
# 11    Li atau Nel             IPA           SMA           ITB
# 12         Raihan             IPA           SMA           ITB
# 13         Sodiko             IPA           SMA           ITB
# 14            Ica             IPA           SMA           ITB
# 15           Boti             IPA           SMA           Itb
# 16           Alif             IPA           SMA           ITB
# 17          Nanda             IPA           SMA           ITB
# 18          Syams             IPA           SMA           Itb
# 19           Oji              IPA           SMA           ITB
# 20          Dinan             IPA           SMA           ITB
# 21         Debora             IPA           SMA           ITB
# 22           Dito             IPA           SMA           ITB
# 23          Grace             IPA           SMA           ITB
# 24          Nasya             IPA           SMA           ITB
# 25           Lean             IPA           SMA           ITB
# 26            Iim             IPA           SMA           ITB
# 27           Ardi             IPA           SMA           ITB
# 28         Oktada             IPA           SMA           ITB
# 29            Aji             IPA           SMA           ITB
# 30         Mayang             IPA           SMA           ITB
# 31         Sheila             IPA           SMA           ITB
# 32         Kelvin             IPA           SMA           ITB
# 33            Edo             IPA           SMA           ITB
# 34           Fara             IPA           SMA           ITB
# 35          Gerry             IPA           SMA           ITB
# 36          Adita             IPA           SMA           ITB
# 37         Athira             IPA           SMA           ITB
# 38        Refanie             IPA           SMA           ITB
# 39         Muthia             IPA           SMA           ITB
# 40           Niel             IPA           SMA           ITB
# 41          Dicta             IPA           SMA           ITB
# 42        Luthfan             IPA           SMA           ITB
# 43          Kevin             IPA           SMA           ITB
# 44           Faiz             IPA           SMA           ITB
# 45          Arina             IPA           SMA           Itb
# 46          Marha             IPA           SMA           ITB
# 47           Iffa             IPA           SMA           ITB
# 48         Junius             IPA           SMA           ITB
# 49          Jacob             IPA           SMA           Itb
# 50         Erlien             IPA           SMA           Itb
# 51          Rifia             IPA           SMA           ITB
#
#                    Jurusan Pilihan I di PTN Pilihan I  \
# 0                                                STEI
# 1                            Fakultas Teknik Industri
# 2                                                FITB
# 3                                          SITH-Sains
# 4           Fakultas teknik industri - kampus ganesha
# 5                                                FSRD
# 6                                                FITB
# 7                                               FMIPA
# 8                                               FMIPA
# 9                                                FTI
# 10                                            FTI - G
# 11                                               STEI
# 12                                               STEI
# 13                         Sekolah Bisnis & Manajemen
# 14                                              fmipa
# 15                                              Fmipa
# 16                                       Teknik Mesin
# 17                                              FMIPA
# 18                                               Ftsl
# 19                                              SAPPK
# 20                                              SAPPK
# 21                                              FMIPA
# 22                                                FTI
# 23  Matematika (Fak. Matematika & Ilmu Pengetahuan...
# 24                                               FTTM
# 25                                               FTTM
# 26                                              FMIPA
# 27                                                FTI
# 28                                               FTTM
# 29               Fakultas Ilmu dan Teknologi Kebumian
# 30  SAPPK - Peminatan Perencanaan Wilayah Kota Kel...
# 31                                              FMIPA
# 32                                              FMIPA
# 33                                                FTI
# 34                                               FITB
# 35                                              FMIPA
# 36                 Sekolah Bisnis dan Manajemen (SBM)
# 37                                                FTI
# 38                        Fakultas Teknologi Industri
# 39                              SITH-Program Rekayasa
# 40                                               FTMD
# 41                                               FTTM
# 42                                              FMIPA
# 43                                              FMIPA
# 44                                                SBM
# 45                                         Arsitektur
# 46                                          FTI - MRI
# 47                                               STEI
# 48                                               FTMD
# 49                                               Ftsl
# 50                                            Elektro
# 51               Fakultas Teknik Sipil dan Lingkungan
#
#                   Jurusan Pilihan II di PTN Pilihan I PTN Pilihan II  \
# 0                                              kosong         kosong
# 1                                                 NaN         KOSONG
# 2                                                FTTM         KOSONG
# 3                                       SITH-Rekayasa            ITS
# 4                Fakultas teknik mesin dan dirgantara         KOSONG
# 5                                              Kosong         Kosong
# 6                                        FTSL-Ganesha         KOSONG
# 7                                                 NaN         KOSONG
# 8                                                 NaN         KOSONG
# 9                                        TEKNIK KIMIA            UGM
# 10                                               FTSL            ITB
# 11                                              FMIPA         Kosong
# 12                                              SAPPK         KOSONG
# 13                                                NaN         KOSONG
# 14                                                NaN         KOSONG
# 15                                                NaN         KOSONG
# 16                                                NaN         KOSONG
# 17                                                NaN            ITS
# 18                                              Fmipa          Unpad
# 19                                               SITH            USU
# 20                                                NaN         KOSONG
# 21                                                NaN         KOSONG
# 22                                              FMIPA         KOSONG
# 23                                             kosong         kosong
# 24                       Perencanaan Wilayah dan Kota         KOSONG
# 25                                    Teknik Industri            UNS
# 26                                             SITH-R            ITS
# 27                                               FTTM             UI
# 28                                               FTMD         KOSONG
# 29  Sekolah Arsitektur Perencanaan dan Pengembanga...            ITS
# 30                                               FITB         KOSONG
# 31                                                 SF         kosong
# 32                                                NaN          UNPAD
# 33                                                NaN         KOSONG
# 34                                              FMIPA             UB
# 35                                               FTSL         KOSONG
# 36      Sekolah Teknik Elektro dan Informatika (STEI)             UI
# 37                                             Kosong         Kosong
# 38                                    Sekolah Farmasi             UI
# 39                                             Kosong            IPB
# 40                                              SAPPK         KOSONG
# 41                                                NaN         KOSONG
# 42                                             Kosong         Kosong
# 43                                                NaN         KOSONG
# 44                                               SITH         KOSONG
# 45                                                Sbm         KOSONG
# 46                                                 SF         KOSONG
# 47                                               FTTM             UI
# 48                                             FTSL-G             UI
# 49                            Fakultas teknik arsitek             Ui
# 50                                            Geologi             Ui
# 51  Sekolah Arsitektur Perencanaan dan Pengembanga...         KOSONG
#
#    Jurusan Pilihan I di PTN Pilihan II Jurusan Pilihan II di PTN Pilihan II  \
# 0                               kosong                               kosong
# 1                                  NaN                                  NaN
# 2                                  NaN                                  NaN
# 3                    Teknik Lingkungan                                  NaN
# 4                                  NaN                                  NaN
# 5                               Kosong                               Kosong
# 6                                  NaN                                  NaN
# 7                                  NaN                                  NaN
# 8                                  NaN                                  NaN
# 9                         TEKNIK MESIN                        TEKNIK FISIKA
# 10                                 NaN                                  NaN
# 11                              Kosong                               Kosong
# 12                                 NaN                                  NaN
# 13                                 NaN                                  NaN
# 14                                 NaN                                  NaN
# 15                                 NaN                                  NaN
# 16                                 NaN                                  NaN
# 17                          Matematika                           Statistika
# 18                          Matematika                                  NaN
# 19                           Akuntansi                                    -
# 20                                 NaN                                  NaN
# 21                                 NaN                                  NaN
# 22                                 NaN                                  NaN
# 23                              kosong                               kosong
# 24                                 NaN                                  NaN
# 25                          Kedokteran                                  NaN
# 26                          Statistika                                  NaN
# 27                        Teknik Kimia                               Kosong
# 28                                 NaN                                  NaN
# 29                    Teknik Geomatika                               Kosong
# 30                                 NaN                                  NaN
# 31                              kosong                               kosong
# 32                              Fisika                                  NaN
# 33                                 NaN                                  NaN
# 34                           ILMU GIZI                                  NaN
# 35                                 NaN                                  NaN
# 36                           Manajemen                                  NaN
# 37                              Kosong                               Kosong
# 38                             Farmasi                               Kosong
# 39                     Manajemen Hutan                               Kosong
# 40                                 NaN                                  NaN
# 41                                 NaN                                  NaN
# 42                              Kosong                               Kosong
# 43                                 NaN                                  NaN
# 44                                 NaN                                  NaN
# 45                                 NaN                                  NaN
# 46                                 NaN                                  NaN
# 47                    Sistem informasi                               kosong
# 48                             Farmasi                                    -
# 49                        Teknik sipil                               Kosong
# 50                     Teknik industri                       Teknik elektro
# 51                                 NaN                                  NaN
#
#                                      Jurusan Diterima  ...  \
# 0                                                STEI  ...
# 1                            Fakultas Teknik Industri  ...
# 2                                                FITB  ...
# 3                                          SITH-Sains  ...
# 4                Fakultas teknik mesin dan dirgantara  ...
# 5                                                FSRD  ...
# 6                                                FITB  ...
# 7                                               FMIPA  ...
# 8                                               FMIPA  ...
# 9                                                FTI   ...
# 10                                            FTI - G  ...
# 11                                               STEI  ...
# 12                                               STEI  ...
# 13                         Sekolah Bisnis & Manajemen  ...
# 14                                              fmipa  ...
# 15                                              Fmipa  ...
# 16                                                  0  ...
# 17                                              FMIPA  ...
# 18                                               Ftsl  ...
# 19                                              SAPPK  ...
# 20                                              SAPPK  ...
# 21                                              FMIPA  ...
# 22                                              FMIPA  ...
# 23  Matematika (Fak. Matematika & Ilmu Pengetahuan...  ...
# 24                                               FTTM  ...
# 25                                               FTTM  ...
# 26                                              FMIPA  ...
# 27                                                FTI  ...
# 28                                               FTTM  ...
# 29               Fakultas Ilmu dan Teknologi Kebumian  ...
# 30  SAPPK - Peminatan Perencanaan Wilayah Kota Kel...  ...
# 31                                              FMIPA  ...
# 32                                              FMIPA  ...
# 33                                                FTI  ...
# 34                                               FITB  ...
# 35                                              FMIPA  ...
# 36                 Sekolah Bisnis dan Manajemen (SBM)  ...
# 37                                                FTI  ...
# 38                        Fakultas Teknologi Industri  ...
# 39                              SITH-Program Rekayasa  ...
# 40                                               FTMD  ...
# 41                                               FTTM  ...
# 42                                              FMIPA  ...
# 43                                              FMIPA  ...
# 44                                                SBM  ...
# 45                                         Arsitektur  ...
# 46                                                 SF  ...
# 47                                               STEI  ...
# 48                                               FTMD  ...
# 49                                               Ftsl  ...
# 50                                            Elektro  ...
# 51               Fakultas Teknik Sipil dan Lingkungan  ...
#
#    Geografi Semester 1  Geografi Semester 2  Geografi Semester 3  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
# 5                  NaN                  NaN                  NaN
# 6                  NaN                  NaN                  NaN
# 7                  NaN                  NaN                  NaN
# 8                  NaN                  NaN                  NaN
# 9                  NaN                  NaN                  NaN
# 10                 NaN                  NaN                  NaN
# 11                 NaN                  NaN                  NaN
# 12                 NaN                  NaN                  NaN
# 13                 NaN                  NaN                  NaN
# 14                 NaN                  NaN                  NaN
# 15                 NaN                  NaN                  NaN
# 16                 NaN                  NaN                  NaN
# 17                 NaN                  NaN                  NaN
# 18                 NaN                  NaN                  NaN
# 19                 NaN                  NaN                  NaN
# 20                 NaN                  NaN                  NaN
# 21                 NaN                  NaN                  NaN
# 22                 NaN                  NaN                  NaN
# 23                73.0                 83.0                  NaN
# 24                 NaN                  NaN                  NaN
# 25                 NaN                  NaN                  NaN
# 26                 NaN                  NaN                  NaN
# 27                 NaN                  NaN                  NaN
# 28                 NaN                  NaN                  NaN
# 29                 NaN                  NaN                  NaN
# 30                 NaN                  NaN                  NaN
# 31                83.0                 83.0                 73.0
# 32                 NaN                  NaN                  NaN
# 33                88.0                 88.0                 88.0
# 34                 NaN                  NaN                  NaN
# 35                 NaN                  NaN                  NaN
# 36                 NaN                  NaN                  NaN
# 37                 NaN                  NaN                  NaN
# 38                83.0                 93.0                 93.0
# 39                 NaN                  NaN                  NaN
# 40                 NaN                  NaN                  NaN
# 41                 NaN                  NaN                  NaN
# 42                83.0                 78.0                  NaN
# 43                 NaN                  NaN                  NaN
# 44                 NaN                  NaN                  NaN
# 45                 NaN                  NaN                  NaN
# 46                 NaN                  NaN                  NaN
# 47                 NaN                  NaN                  NaN
# 48                 NaN                  NaN                  NaN
# 49                 NaN                  NaN                  NaN
# 50                88.0                 88.0                 88.0
# 51                 NaN                  NaN                  NaN
#
#     Geografi Semester 4  Geografi Semester 5  Sosiologi Semester 1  \
# 0                   NaN                  NaN                   NaN
# 1                   NaN                  NaN                   NaN
# 2                   NaN                  NaN                   NaN
# 3                   NaN                  NaN                   NaN
# 4                   NaN                  NaN                  83.0
# 5                   NaN                  NaN                   NaN
# 6                   NaN                  NaN                   NaN
# 7                   NaN                  NaN                   NaN
# 8                   NaN                  NaN                   NaN
# 9                   NaN                  NaN                   NaN
# 10                  NaN                  NaN                   NaN
# 11                  NaN                  NaN                   NaN
# 12                  NaN                  NaN                   NaN
# 13                  NaN                  NaN                   NaN
# 14                  NaN                  NaN                   NaN
# 15                  NaN                  NaN                   NaN
# 16                  NaN                  NaN                   NaN
# 17                  NaN                  NaN                   NaN
# 18                  NaN                  NaN                   NaN
# 19                  NaN                  NaN                   NaN
# 20                  NaN                  NaN                   NaN
# 21                  NaN                  NaN                   NaN
# 22                  NaN                  NaN                   NaN
# 23                  NaN                  NaN                  83.0
# 24                  NaN                  NaN                   NaN
# 25                  NaN                  NaN                   NaN
# 26                  NaN                  NaN                   NaN
# 27                  NaN                  NaN                   NaN
# 28                  NaN                  NaN                   NaN
# 29                  NaN                  NaN                   NaN
# 30                  NaN                  NaN                   NaN
# 31                 73.0                 73.0                  88.0
# 32                  NaN                  NaN                   NaN
# 33                 93.0                 98.0                   NaN
# 34                  NaN                  NaN                   NaN
# 35                  NaN                  NaN                   NaN
# 36                  NaN                  NaN                   NaN
# 37                  NaN                  NaN                   NaN
# 38                 88.0                 83.0                   NaN
# 39                  NaN                  NaN                   NaN
# 40                  NaN                  NaN                   NaN
# 41                  NaN                  NaN                   NaN
# 42                  NaN                  NaN                  78.0
# 43                  NaN                  NaN                   NaN
# 44                  NaN                  NaN                   NaN
# 45                  NaN                  NaN                   NaN
# 46                  NaN                  NaN                   NaN
# 47                  NaN                  NaN                   NaN
# 48                  NaN                  NaN                   NaN
# 49                  NaN                  NaN                   NaN
# 50                 88.0                 88.0                   NaN
# 51                  NaN                  NaN                   NaN
#
#     Sosiologi Semester 2  Sosiologi Semester 3  Sosiologi Semester 4  \
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3                    NaN                   NaN                   NaN
# 4                   88.0                   NaN                   NaN
# 5                    NaN                   NaN                   NaN
# 6                    NaN                   NaN                   NaN
# 7                    NaN                   NaN                   NaN
# 8                    NaN                   NaN                   NaN
# 9                    NaN                   NaN                   NaN
# 10                   NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12                   NaN                   NaN                   NaN
# 13                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
# 15                   NaN                   NaN                   NaN
# 16                   NaN                   NaN                   NaN
# 17                   NaN                   NaN                   NaN
# 18                   NaN                   NaN                   NaN
# 19                   NaN                   NaN                   NaN
# 20                   NaN                   NaN                   NaN
# 21                   NaN                   NaN                   NaN
# 22                   NaN                   NaN                   NaN
# 23                  88.0                   NaN                   NaN
# 24                   NaN                   NaN                   NaN
# 25                   NaN                   NaN                   NaN
# 26                   NaN                   NaN                   NaN
# 27                   NaN                   NaN                   NaN
# 28                   NaN                   NaN                   NaN
# 29                   NaN                   NaN                   NaN
# 30                   NaN                   NaN                   NaN
# 31                  88.0                   NaN                   NaN
# 32                   NaN                   NaN                   NaN
# 33                   NaN                   NaN                   NaN
# 34                   NaN                   NaN                   NaN
# 35                   NaN                   NaN                   NaN
# 36                   NaN                   NaN                   NaN
# 37                   NaN                   NaN                   NaN
# 38                   NaN                   NaN                   NaN
# 39                   NaN                   NaN                   NaN
# 40                   NaN                   NaN                   NaN
# 41                   NaN                   NaN                   NaN
# 42                  78.0                   NaN                   NaN
# 43                   NaN                   NaN                   NaN
# 44                   NaN                   NaN                   NaN
# 45                   NaN                   NaN                   NaN
# 46                   NaN                   NaN                   NaN
# 47                   NaN                   NaN                   NaN
# 48                   NaN                   NaN                   NaN
# 49                   NaN                   NaN                   NaN
# 50                   NaN                   NaN                   NaN
# 51                   NaN                   NaN                   NaN
#
#     Sosiologi Semester 5
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
# 6                    NaN
# 7                    NaN
# 8                    NaN
# 9                    NaN
# 10                   NaN
# 11                   NaN
# 12                   NaN
# 13                   NaN
# 14                   NaN
# 15                   NaN
# 16                   NaN
# 17                   NaN
# 18                   NaN
# 19                   NaN
# 20                   NaN
# 21                   NaN
# 22                   NaN
# 23                   NaN
# 24                   NaN
# 25                   NaN
# 26                   NaN
# 27                   NaN
# 28                   NaN
# 29                   NaN
# 30                   NaN
# 31                   NaN
# 32                   NaN
# 33                   NaN
# 34                   NaN
# 35                   NaN
# 36                   NaN
# 37                   NaN
# 38                   NaN
# 39                   NaN
# 40                   NaN
# 41                   NaN
# 42                   NaN
# 43                   NaN
# 44                   NaN
# 45                   NaN
# 46                   NaN
# 47                   NaN
# 48                   NaN
# 49                   NaN
# 50                   NaN
# 51                   NaN
#
# [52 rows x 56 columns]

# %%
mata_pelajaran = getMapel(data)

# %%
df_table = getDictionary(data, mata_pelajaran)[0]

# %%
df_test_train = getDictionary(data, mata_pelajaran)[1]

# %%
table_alternatif = pd.DataFrame(df_table, list(mata_pelajaran))

# %%
table_alternatif
# Out:
#             STEI - ITB (IPA)  FAKULTAS TEKNIK INDUSTRI - ITB (IPA)  \
# Biologi            88.250000                             84.703232
# Ekonomi            84.060065                             84.655844
# Inggris            89.250000                             84.080000
# Sosiologi                NaN                                   NaN
# Fisika             87.500000                             86.538782
# Geografi           85.000000                             85.000000
# Indonesia          87.000000                             85.207317
# Kimia              90.000000                             87.548780
# Matematika         89.000000                             86.995122
#
#             FITB - ITB (IPA)  SITH-SAINS - ITB (IPA)  \
# Biologi            85.000000               87.000000
# Ekonomi            84.655844               84.655844
# Inggris            86.666667               96.000000
# Sosiologi                NaN                     NaN
# Fisika             87.333333               87.000000
# Geografi           85.000000               85.000000
# Indonesia          89.000000               83.000000
# Kimia              85.666667               90.000000
# Matematika         88.000000               84.000000
#
#             FAKULTAS TEKNIK MESIN DAN DIRGANTARA - ITB (IPA)  \
# Biologi                                                 85.0
# Ekonomi                                                 88.0
# Inggris                                                 82.0
# Sosiologi                                                NaN
# Fisika                                                  85.0
# Geografi                                                85.0
# Indonesia                                               90.0
# Kimia                                                   88.0
# Matematika                                              91.0
#
#             FSRD - ITB (IPS)  FMIPA - ITB (IPA)  FTI - ITB (IPA)  \
# Biologi            84.703232          81.354592        88.175808
# Ekonomi            84.655844          84.570430        85.474026
# Inggris            86.648293          82.853321        91.162073
# Sosiologi                NaN                NaN              NaN
# Fisika             86.538782          84.701257        92.634696
# Geografi           85.000000          84.269231        86.500000
# Indonesia          85.207317          81.393996        86.301829
# Kimia              87.548780          86.549719        93.387195
# Matematika         77.000000          85.883114        91.748780
#
#             FTI - G - ITB (IPA)  SEKOLAH BISNIS & MANAJEMEN - ITB (IPS)  ...  \
# Biologi               82.000000                                    81.0  ...
# Ekonomi               84.655844                                    85.0  ...
# Inggris               79.000000                                    85.0  ...
# Sosiologi                   NaN                                     NaN  ...
# Fisika                87.000000                                    84.0  ...
# Geografi              85.000000                                    85.0  ...
# Indonesia             83.000000                                    78.0  ...
# Kimia                 91.000000                                    78.0  ...
# Matematika            87.000000                                    87.0  ...
#
#             SAPPK - PEMINATAN PERENCANAAN WILAYAH KOTA KELAS GANESHA - ITB (IPA)  \
# Biologi                                             90.000000
# Ekonomi                                             84.655844
# Inggris                                             91.000000
# Sosiologi                                                 NaN
# Fisika                                              86.538782
# Geografi                                            85.000000
# Indonesia                                           85.000000
# Kimia                                               86.000000
# Matematika                                          79.000000
#
#             SEKOLAH BISNIS DAN MANAJEMEN (SBM) - ITB (IPS)  \
# Biologi                                          83.000000
# Ekonomi                                          84.655844
# Inggris                                          86.000000
# Sosiologi                                              NaN
# Fisika                                           85.000000
# Geografi                                         85.000000
# Indonesia                                        85.000000
# Kimia                                            85.000000
# Matematika                                       93.000000
#
#             FAKULTAS TEKNOLOGI INDUSTRI - ITB (IPA)  \
# Biologi                                   90.000000
# Ekonomi                                   84.655844
# Inggris                                   86.000000
# Sosiologi                                       NaN
# Fisika                                    95.000000
# Geografi                                  88.000000
# Indonesia                                 86.000000
# Kimia                                     85.000000
# Matematika                                86.000000
#
#             SITH-PROGRAM REKAYASA - ITB (IPA)  FTMD - ITB (IPA)  \
# Biologi                                  88.0         92.000000
# Ekonomi                                  90.0         84.655844
# Inggris                                  87.0         92.500000
# Sosiologi                                 NaN               NaN
# Fisika                                   91.0         93.500000
# Geografi                                 85.0         85.000000
# Indonesia                                90.0         88.500000
# Kimia                                    91.0         92.500000
# Matematika                               89.0         92.000000
#
#             SBM - ITB (IPS)  ARSITEKTUR - ITB (IPA)  SF - ITB (IPA)  \
# Biologi           84.703232               86.000000       90.000000
# Ekonomi           84.655844               84.655844       84.655844
# Inggris           86.648293               90.000000       93.000000
# Sosiologi               NaN                     NaN             NaN
# Fisika            86.538782               86.000000       86.000000
# Geografi          85.000000               85.000000       85.000000
# Indonesia         85.207317               91.000000       92.000000
# Kimia             87.548780               88.000000       86.000000
# Matematika        86.995122               89.000000       81.000000
#
#             ELEKTRO - ITB (IPA)  \
# Biologi               87.000000
# Ekonomi               84.655844
# Inggris               91.000000
# Sosiologi                   NaN
# Fisika                84.000000
# Geografi              88.000000
# Indonesia             86.000000
# Kimia                 85.000000
# Matematika            85.000000
#
#             FAKULTAS TEKNIK SIPIL DAN LINGKUNGAN - ITB (IPA)
# Biologi                                            85.000000
# Ekonomi                                            84.655844
# Inggris                                            90.000000
# Sosiologi                                                NaN
# Fisika                                             87.451282
# Geografi                                           85.000000
# Indonesia                                          87.000000
# Kimia                                              88.000000
# Matematika                                         88.000000
#
# [9 rows x 26 columns]

# %%
train = pd.DataFrame(df_test_train)

# %%
train
# Out:
#    Nama Panggilan Jurusan Sekolah  \
# 0          Nadija             IPA
# 1            Diah             IPA
# 2           Ihsan             IPA
# 3           Riana             IPA
# 4          Nisrin             IPA
# 5    Safira, fira             IPA
# 6          Satrio             IPA
# 7             Ari             IPA
# 8           Resty             IPA
# 9          Choiza             IPA
# 10            Iky             IPA
# 11    Li atau Nel             IPA
# 12         Raihan             IPA
# 13         Sodiko             IPA
# 14            Ica             IPA
# 15           Boti             IPA
# 16           Alif             IPA
# 17          Nanda             IPA
# 18          Syams             IPA
# 19           Oji              IPA
# 20          Dinan             IPA
# 21         Debora             IPA
# 22           Dito             IPA
# 23          Grace             IPA
# 24          Nasya             IPA
# 25           Lean             IPA
# 26            Iim             IPA
# 27           Ardi             IPA
# 28         Oktada             IPA
# 29            Aji             IPA
# 30         Mayang             IPA
# 31         Sheila             IPA
# 32         Kelvin             IPA
# 33            Edo             IPA
# 34           Fara             IPA
# 35          Gerry             IPA
# 36          Adita             IPA
# 37         Athira             IPA
# 38        Refanie             IPA
# 39         Muthia             IPA
# 40           Niel             IPA
# 41          Dicta             IPA
# 42        Luthfan             IPA
# 43          Kevin             IPA
# 44           Faiz             IPA
# 45          Arina             IPA
# 46          Marha             IPA
# 47           Iffa             IPA
# 48         Junius             IPA
# 49          Jacob             IPA
# 50         Erlien             IPA
# 51          Rifia             IPA
#
#                                             Pilihan I  \
# 0                                    STEI - ITB (IPA)
# 1                FAKULTAS TEKNIK INDUSTRI - ITB (IPA)
# 2                                    FITB - ITB (IPA)
# 3                              SITH-SAINS - ITB (IPA)
# 4   FAKULTAS TEKNIK INDUSTRI - KAMPUS GANESHA - IT...
# 5                                    FSRD - ITB (IPS)
# 6                                    FITB - ITB (IPA)
# 7                                   FMIPA - ITB (IPA)
# 8                                   FMIPA - ITB (IPA)
# 9                                     FTI - ITB (IPA)
# 10                                FTI - G - ITB (IPA)
# 11                                   STEI - ITB (IPA)
# 12                                   STEI - ITB (IPA)
# 13             SEKOLAH BISNIS & MANAJEMEN - ITB (IPS)
# 14                                  FMIPA - ITB (IPA)
# 15                                  FMIPA - ITB (IPA)
# 16                           TEKNIK MESIN - ITB (IPA)
# 17                                  FMIPA - ITB (IPA)
# 18                                   FTSL - ITB (IPA)
# 19                                  SAPPK - ITB (IPA)
# 20                                  SAPPK - ITB (IPA)
# 21                                  FMIPA - ITB (IPA)
# 22                                    FTI - ITB (IPA)
# 23  MATEMATIKA (FAK. MATEMATIKA & ILMU PENGETAHUAN...
# 24                                   FTTM - ITB (IPA)
# 25                                   FTTM - ITB (IPA)
# 26                                  FMIPA - ITB (IPA)
# 27                                    FTI - ITB (IPA)
# 28                                   FTTM - ITB (IPA)
# 29   FAKULTAS ILMU DAN TEKNOLOGI KEBUMIAN - ITB (IPA)
# 30  SAPPK - PEMINATAN PERENCANAAN WILAYAH KOTA KEL...
# 31                                  FMIPA - ITB (IPA)
# 32                                  FMIPA - ITB (IPA)
# 33                                    FTI - ITB (IPA)
# 34                                   FITB - ITB (IPA)
# 35                                  FMIPA - ITB (IPA)
# 36     SEKOLAH BISNIS DAN MANAJEMEN (SBM) - ITB (IPS)
# 37                                    FTI - ITB (IPA)
# 38            FAKULTAS TEKNOLOGI INDUSTRI - ITB (IPA)
# 39                  SITH-PROGRAM REKAYASA - ITB (IPA)
# 40                                   FTMD - ITB (IPA)
# 41                                   FTTM - ITB (IPA)
# 42                                  FMIPA - ITB (IPA)
# 43                                  FMIPA - ITB (IPA)
# 44                                    SBM - ITB (IPS)
# 45                             ARSITEKTUR - ITB (IPA)
# 46                              FTI - MRI - ITB (IPA)
# 47                                   STEI - ITB (IPA)
# 48                                   FTMD - ITB (IPA)
# 49                                   FTSL - ITB (IPA)
# 50                                ELEKTRO - ITB (IPA)
# 51   FAKULTAS TEKNIK SIPIL DAN LINGKUNGAN - ITB (IPA)
#
#                                            Pilihan II  \
# 0                                              KOSONG
# 1                                              KOSONG
# 2                                    FTTM - ITB (IPA)
# 3                           SITH-REKAYASA - ITB (IPA)
# 4    FAKULTAS TEKNIK MESIN DAN DIRGANTARA - ITB (IPA)
# 5                                              KOSONG
# 6                            FTSL-GANESHA - ITB (IPA)
# 7                                              KOSONG
# 8                                              KOSONG
# 9                            TEKNIK KIMIA - ITB (IPA)
# 10                                   FTSL - ITB (IPA)
# 11                                  FMIPA - ITB (IPA)
# 12                                  SAPPK - ITB (IPA)
# 13                                             KOSONG
# 14                                             KOSONG
# 15                                             KOSONG
# 16                                             KOSONG
# 17                             MATEMATIKA - ITS (IPA)
# 18                                  FMIPA - ITB (IPA)
# 19                                   SITH - ITB (IPA)
# 20                                             KOSONG
# 21                                             KOSONG
# 22                                  FMIPA - ITB (IPA)
# 23                                             KOSONG
# 24           PERENCANAAN WILAYAH DAN KOTA - ITB (IPA)
# 25                        TEKNIK INDUSTRI - ITB (IPA)
# 26                                 SITH-R - ITB (IPA)
# 27                                   FTTM - ITB (IPA)
# 28                                   FTMD - ITB (IPA)
# 29  SEKOLAH ARSITEKTUR PERENCANAAN DAN PENGEMBANGA...
# 30                                   FITB - ITB (IPA)
# 31                                     SF - ITB (IPA)
# 32                               FISIKA - UNPAD (IPA)
# 33                                             KOSONG
# 34                                  FMIPA - ITB (IPA)
# 35                                   FTSL - ITB (IPA)
# 36  SEKOLAH TEKNIK ELEKTRO DAN INFORMATIKA (STEI) ...
# 37                                             KOSONG
# 38                        SEKOLAH FARMASI - ITB (IPA)
# 39                                             KOSONG
# 40                                  SAPPK - ITB (IPA)
# 41                                             KOSONG
# 42                                             KOSONG
# 43                                             KOSONG
# 44                                   SITH - ITB (IPA)
# 45                                    SBM - ITB (IPS)
# 46                                     SF - ITB (IPA)
# 47                                   FTTM - ITB (IPA)
# 48                                 FTSL-G - ITB (IPA)
# 49                FAKULTAS TEKNIK ARSITEK - ITB (IPA)
# 50                                GEOLOGI - ITB (IPA)
# 51  SEKOLAH ARSITEKTUR PERENCANAAN DAN PENGEMBANGA...
#
#                       Pilihan III  \
# 0                          KOSONG
# 1                          KOSONG
# 2                          KOSONG
# 3   TEKNIK LINGKUNGAN - ITS (IPA)
# 4                          KOSONG
# 5                          KOSONG
# 6                          KOSONG
# 7                          KOSONG
# 8                          KOSONG
# 9        TEKNIK MESIN - UGM (IPA)
# 10                         KOSONG
# 11                         KOSONG
# 12                         KOSONG
# 13                         KOSONG
# 14                         KOSONG
# 15                         KOSONG
# 16                         KOSONG
# 17         STATISTIKA - ITS (IPA)
# 18       MATEMATIKA - UNPAD (IPA)
# 19          AKUNTANSI - USU (IPS)
# 20                         KOSONG
# 21                         KOSONG
# 22                         KOSONG
# 23                         KOSONG
# 24                         KOSONG
# 25         KEDOKTERAN - UNS (IPA)
# 26         STATISTIKA - ITS (IPA)
# 27        TEKNIK KIMIA - UI (IPA)
# 28                         KOSONG
# 29   TEKNIK GEOMATIKA - ITS (IPA)
# 30                         KOSONG
# 31                         KOSONG
# 32                         KOSONG
# 33                         KOSONG
# 34           ILMU GIZI - UB (IPA)
# 35                         KOSONG
# 36           MANAJEMEN - UI (IPS)
# 37                         KOSONG
# 38             FARMASI - UI (IPA)
# 39    MANAJEMEN HUTAN - IPB (IPS)
# 40                         KOSONG
# 41                         KOSONG
# 42                         KOSONG
# 43                         KOSONG
# 44                         KOSONG
# 45                         KOSONG
# 46                         KOSONG
# 47    SISTEM INFORMASI - UI (IPA)
# 48             FARMASI - UI (IPA)
# 49        TEKNIK SIPIL - UI (IPA)
# 50     TEKNIK INDUSTRI - UI (IPA)
# 51                         KOSONG
#
#                                      Jurusan Diterima    Biologi    Ekonomi  \
# 0                                    STEI - ITB (IPA)  85.000000  84.655844
# 1                FAKULTAS TEKNIK INDUSTRI - ITB (IPA)  84.703232  84.655844
# 2                                    FITB - ITB (IPA)  81.000000  84.655844
# 3                              SITH-SAINS - ITB (IPA)  87.000000  84.655844
# 4    FAKULTAS TEKNIK MESIN DAN DIRGANTARA - ITB (IPA)  85.000000  88.000000
# 5                                    FSRD - ITB (IPS)  84.703232  84.655844
# 6                                    FITB - ITB (IPA)  86.000000  84.655844
# 7                                   FMIPA - ITB (IPA)  91.000000  87.928571
# 8                                   FMIPA - ITB (IPA)  34.500000  84.655844
# 9                                     FTI - ITB (IPA)  91.000000  84.655844
# 10                                FTI - G - ITB (IPA)  82.000000  84.655844
# 11                                   STEI - ITB (IPA)  93.000000  81.000000
# 12                                   STEI - ITB (IPA)  88.000000  85.928571
# 13             SEKOLAH BISNIS & MANAJEMEN - ITB (IPS)  81.000000  85.000000
# 14                                  FMIPA - ITB (IPA)  84.703232  84.655844
# 15                                  FMIPA - ITB (IPA)  76.000000  84.655844
# 16                                      0 - ITB (IPA)  84.703232  84.655844
# 17                                  FMIPA - ITB (IPA)  84.703232  84.655844
# 18                                   FTSL - ITB (IPA)  86.732500  84.655844
# 19                                  SAPPK - ITB (IPA)  91.000000  84.655844
# 20                                  SAPPK - ITB (IPA)  89.000000  84.655844
# 21                                  FMIPA - ITB (IPA)  89.000000  84.655844
# 22                                  FMIPA - ITB (IPA)  84.703232  84.655844
# 23  MATEMATIKA (FAK. MATEMATIKA & ILMU PENGETAHUAN...  85.000000  83.500000
# 24                                   FTTM - ITB (IPA)  84.703232  84.655844
# 25                                   FTTM - ITB (IPA)  84.000000  77.000000
# 26                                  FMIPA - ITB (IPA)  87.000000  84.655844
# 27                                    FTI - ITB (IPA)  87.000000  84.655844
# 28                                   FTTM - ITB (IPA)  84.703232  84.655844
# 29   FAKULTAS ILMU DAN TEKNOLOGI KEBUMIAN - ITB (IPA)  84.703232  84.655844
# 30  SAPPK - PEMINATAN PERENCANAAN WILAYAH KOTA KEL...  90.000000  84.655844
# 31                                  FMIPA - ITB (IPA)  82.000000  82.000000
# 32                                  FMIPA - ITB (IPA)  86.000000  84.655844
# 33                                    FTI - ITB (IPA)  90.000000  87.928571
# 34                                   FITB - ITB (IPA)  88.000000  84.655844
# 35                                  FMIPA - ITB (IPA)  84.000000  84.655844
# 36     SEKOLAH BISNIS DAN MANAJEMEN (SBM) - ITB (IPS)  83.000000  84.655844
# 37                                    FTI - ITB (IPA)  84.703232  84.655844
# 38            FAKULTAS TEKNOLOGI INDUSTRI - ITB (IPA)  90.000000  84.655844
# 39                  SITH-PROGRAM REKAYASA - ITB (IPA)  88.000000  90.000000
# 40                                   FTMD - ITB (IPA)  93.000000  84.655844
# 41                                   FTTM - ITB (IPA)  78.000000  84.655844
# 42                                  FMIPA - ITB (IPA)  88.000000  82.928571
# 43                                  FMIPA - ITB (IPA)  86.000000  84.655844
# 44                                    SBM - ITB (IPS)  84.703232  84.655844
# 45                             ARSITEKTUR - ITB (IPA)  86.000000  84.655844
# 46                                     SF - ITB (IPA)  90.000000  84.655844
# 47                                   STEI - ITB (IPA)  87.000000  84.655844
# 48                                   FTMD - ITB (IPA)  91.000000  84.655844
# 49                                   FTSL - ITB (IPA)  61.600000  84.655844
# 50                                ELEKTRO - ITB (IPA)  87.000000  84.655844
# 51   FAKULTAS TEKNIK SIPIL DAN LINGKUNGAN - ITB (IPA)  85.000000  84.655844
#
#       Inggris  Sosiologi     Fisika  Geografi  Indonesia     Kimia  Matematika
# 0   90.000000        NaN  87.000000      85.0  85.000000  92.00000   92.000000
# 1   84.080000        NaN  86.538782      85.0  85.207317  87.54878   86.995122
# 2   87.000000        NaN  89.000000      85.0  89.000000  83.00000   93.000000
# 3   96.000000        NaN  87.000000      85.0  83.000000  90.00000   84.000000
# 4   82.000000        NaN  85.000000      85.0  90.000000  88.00000   91.000000
# 5   86.648293        NaN  86.538782      85.0  85.207317  87.54878   77.000000
# 6   83.000000        NaN  85.000000      85.0  85.000000  86.00000   87.000000
# 7   86.648293        NaN  93.000000      85.0  93.000000  98.00000   93.000000
# 8   34.500000        NaN  34.500000      85.0  34.500000  34.50000   34.500000
# 9   97.000000        NaN  97.000000      85.0  84.000000  98.00000   92.000000
# 10  79.000000        NaN  87.000000      85.0  83.000000  91.00000   87.000000
# 11  93.000000        NaN  93.000000      85.0  88.000000  95.00000   92.000000
# 12  89.000000        NaN  88.000000      85.0  85.000000  85.00000   91.000000
# 13  85.000000        NaN  84.000000      85.0  78.000000  78.00000   87.000000
# 14  86.648293        NaN  86.538782      85.0  85.207317  87.54878   86.995122
# 15  81.000000        NaN  85.000000      85.0  78.000000  95.00000   84.000000
# 16  86.648293        NaN  86.538782      85.0  85.207317  87.54878   86.995122
# 17  86.648293        NaN  86.538782      85.0  85.207317  87.54878   86.995122
# 18  91.000000        NaN  90.000000      85.0  90.000000  87.00000   93.000000
# 19  88.000000        NaN  81.000000      85.0  92.000000  89.00000   85.000000
# 20  89.000000        NaN  82.000000      85.0  87.000000  85.00000   86.000000
# 21  85.000000        NaN  89.000000      85.0  84.000000  88.00000   93.000000
# 22  86.648293        NaN  86.538782      85.0  85.207317  87.54878   86.995122
# 23  87.000000        NaN  90.000000      82.5  82.000000  88.00000   90.000000
# 24  86.648293        NaN  86.538782      85.0  85.207317  87.54878   86.995122
# 25  85.000000        NaN  93.000000      85.0  86.000000  88.00000   89.000000
# 26  90.000000        NaN  90.000000      85.0  93.000000  93.00000   90.000000
# 27  89.000000        NaN  89.000000      85.0  89.000000  96.00000   96.000000
# 28  86.648293        NaN  86.538782      85.0  85.207317  87.54878   86.995122
# 29  86.648293        NaN  86.538782      85.0  85.207317  87.54878   86.995122
# 30  91.000000        NaN  86.538782      85.0  85.000000  86.00000   79.000000
# 31  89.000000        NaN  94.000000      77.0  87.000000  91.00000   95.000000
# 32  90.000000        NaN  91.000000      85.0  86.000000  94.00000   86.995122
# 33  92.000000        NaN  98.000000      91.0  87.000000  92.00000   92.000000
# 34  90.000000        NaN  88.000000      85.0  93.000000  88.00000   84.000000
# 35  88.000000        NaN  91.000000      85.0  83.000000  92.00000   93.000000
# 36  86.000000        NaN  85.000000      85.0  85.000000  85.00000   93.000000
# 37  86.648293        NaN  86.538782      85.0  85.207317  87.54878   86.995122
# 38  86.000000        NaN  95.000000      88.0  86.000000  85.00000   86.000000
# 39  87.000000        NaN  91.000000      85.0  90.000000  91.00000   89.000000
# 40  92.000000        NaN  94.000000      85.0  91.000000  95.00000   93.000000
# 41  81.000000        NaN  80.000000      85.0  88.000000  79.00000   81.000000
# 42  89.000000        NaN  81.000000      83.5  85.000000  86.00000   93.000000
# 43  84.000000        NaN  93.000000      85.0  79.000000  91.00000   93.000000
# 44  86.648293        NaN  86.538782      85.0  85.207317  87.54878   86.995122
# 45  90.000000        NaN  86.000000      85.0  91.000000  88.00000   89.000000
# 46  93.000000        NaN  86.000000      85.0  92.000000  86.00000   81.000000
# 47  85.000000        NaN  82.000000      85.0  90.000000  88.00000   81.000000
# 48  93.000000        NaN  93.000000      85.0  86.000000  90.00000   91.000000
# 49  81.000000        NaN  63.600000      85.0  78.000000  82.00000   74.300000
# 50  91.000000        NaN  84.000000      88.0  86.000000  85.00000   85.000000
# 51  90.000000        NaN  87.451282      85.0  87.000000  88.00000   88.000000
