# %%
import pandas as pd
import math
import numpy as np

# %% [markdown]
# # Open File
#
# Membuka file dataset dengan ekstensi **csv**. Setelah itu merename nama-nama header. Baru kemudian men-drop column-column yang tidak akan digunakan.

# %%
def open_file(file):
    #read dataset
    raw_data = pd.read_csv(file, header=6)

    #ganti nama header
    raw_data.columns = [
                        "Nama Panggilan", 
                        "Asal Sekolah", 
                        "Jurusan Sekolah", 
                        "Jenis Sekolah",
                        "Jenis Kelas", 
                        "Akreditasi Sekolah", 
                        "Prestasi Sekolah", 
                        "Alumni Sekolah", 
                        "PTN Pilihan I", 
                        "Jurusan Pilihan I di PTN Pilihan I" ,
                        "Jurusan Pilihan II di PTN Pilihan I", 
                        "PTN Pilihan II", 
                        "Jurusan Pilihan I di PTN Pilihan II" ,
                        "Jurusan Pilihan II di PTN Pilihan II", 
                        "Jurusan Diterima", "PTN Diterima", 
                        "Matematika Semester 1", 
                        "Matematika Semester 2", 
                        "Matematika Semester 3", 
                        "Matematika Semester 4", 
                        "Matematika Semester 5", 
                        "Inggris Semester 1", 
                        "Inggris Semester 2", 
                        "Inggris Semester 3", 
                        "Inggris Semester 4", 
                        "Inggris Semester 5",
                        "Indonesia Semester 1",
                        "Indonesia Semester 2",
                        "Indonesia Semester 3",
                        "Indonesia Semester 4",
                        "Indonesia Semester 5",
                        "Fisika Semester 1",
                        "Fisika Semester 2",
                        "Fisika Semester 3",
                        "Fisika Semester 4",
                        "Fisika Semester 5",
                        "Kimia Semester 1",
                        "Kimia Semester 2",
                        "Kimia Semester 3",
                        "Kimia Semester 4",
                        "Kimia Semester 5",
                        "Biologi Semester 1",
                        "Biologi Semester 2",
                        "Biologi Semester 3",
                        "Biologi Semester 4",
                        "Biologi Semester 5",
                        "Ekonomi Semester 1",
                        "Ekonomi Semester 2",
                        "Ekonomi Semester 3",
                        "Ekonomi Semester 4",
                        "Ekonomi Semester 5",
                        "Geografi Semester 1",
                        "Geografi Semester 2",
                        "Geografi Semester 3",
                        "Geografi Semester 4",
                        "Geografi Semester 5",
                        "Sosiologi Semester 1",
                        "Sosiologi Semester 2",
                        "Sosiologi Semester 3",
                        "Sosiologi Semester 4",
                        "Sosiologi Semester 5",
                        "Sejarah Semester 1",
                        "Sejarah Semester 2",
                        "Sejarah Semester 3",
                        "Sejarah Semester 4",
                        "Sejarah Semester 5",
                        "Komputer Semester 1",
                        "Komputer Semester 2",
                        "Komputer Semester 3",
                        "Komputer Semester 4",
                        "Komputer Semester 5",
                        "Peringkat Kelas Semester 1",
                        "Peringkat Kelas Semester 2",
                        "Peringkat Kelas Semester 3",
                        "Peringkat Kelas Semester 4",
                        "Peringkat Kelas Semester 5",
                        "Nilai UN", 
                        "Saran",
                        "Prestasi Lain"
                    ]
    
    #drop column yang tidak digunakan
    data = raw_data.drop([
                "Jenis Kelas",
                "Akreditasi Sekolah", 
                "Prestasi Sekolah", 
                "Alumni Sekolah", 
                "Komputer Semester 1",
                "Komputer Semester 2",
                "Komputer Semester 3",
                "Komputer Semester 4",
                "Komputer Semester 5",
                "Peringkat Kelas Semester 1",
                "Peringkat Kelas Semester 2",
                "Peringkat Kelas Semester 3",
                "Peringkat Kelas Semester 4",
                "Peringkat Kelas Semester 5",
                "Nilai UN", 
                "Saran",
                "Prestasi Lain"
        ],axis=1)
    
    return data

# %% [markdown]
# # Cleaning Nilai
#
# Proses cleaning nilai terdiri dari beberapa langkah:
#
# 1. Mengambil nilai tengah dari tiap mata pelajaran
# 2. Mengganti setiap NaN/null data dengan mean per mata pelajaran

# %%
def cleaning_nilai(data):

    #Mengambil nilai tengah dari tiap nilai
    data = data.replace("<70", 34.5)
    data = data.replace("71 - 75", 73)
    data = data.replace("76 - 80", 78)
    data = data.replace("81 - 85", 83)
    data = data.replace("86 - 90", 88)
    data = data.replace("91 - 95", 93)
    data = data.replace("> 95", 98)
    data = data.replace("No data", np.NaN)

    return data

# %%
def replace_zero_w_mean(data, mata_pelajaran):
    
    #mencari rata-rata dari per mata pelajaran
    rata2 = (data[f"{mata_pelajaran} Semester 1"].mean() 
            + data[f"{mata_pelajaran} Semester 2"].mean() 
            + data[f"{mata_pelajaran} Semester 3"].mean()
            + data[f"{mata_pelajaran} Semester 4"].mean()
            + data[f"{mata_pelajaran} Semester 5"].mean())/5
    
    #mengganti NaN value dengan nilai rata-rata
    values = {
        f"{mata_pelajaran} Semester 1": rata2,
        f"{mata_pelajaran} Semester 2": rata2,
        f"{mata_pelajaran} Semester 3": rata2,
        f"{mata_pelajaran} Semester 4": rata2,
        f"{mata_pelajaran} Semester 5": rata2,
    }
    data = data.fillna(value=values)
                    
    return data

# %% [markdown]
# # Menghitung Rata-Rata Per 5 Semester
#
# Dari nilai-nilai yang telah di-clean kemudian akan dicari rata-rata tiap mata pelajarannya per semester

# %%
def rata2_mp_semester(data, mata_pelajaran):
    data_rata2 = {}
    
    #drop column tiap mata pelajaran untuk digantikan dengan rata-rata semester
    mapel = []
    for i in range(1,6):
        mapel.append(f"{mata_pelajaran} Semester {i}")

    data_drop = data.drop(mapel, axis=1)
    
    
    for column in data_drop:
        isi = []
        for i in range(len(data)):
            isi.append(data[column][i])
        data_rata2[column] = isi

    #menghitung rata-rata nilai 5 semester
    mean = []
    for i in range(len(data)):
        jumlah_nilai = 0
        jumlah_nilai += data[f"{mata_pelajaran} Semester 1"][i] + data[f"{mata_pelajaran} Semester 2"][i] + data[f"{mata_pelajaran} Semester 3"][i] + data[f"{mata_pelajaran} Semester 4"][i] + data[f"{mata_pelajaran} Semester 5"][i]
        mean.append(jumlah_nilai/5)

    #memasukkan column rata-rata 5 semester tiap mata pelajaran ke dataframe
    data_rata2[f"Rata-rata {mata_pelajaran}"] = mean

    data_rata2_frame = pd.DataFrame(data=data_rata2)
    
    return data_rata2_frame

# %% [markdown]
# # Menghapus NaN
#
# Proses ini akan menghapus tiap rows yang memiliki NaN value yang ada pada column Jurusan Diterima

# %%
def remove_nan(data):
    drop_index = []

    #menghapus NaN value
    for i in range(len(data)):
        try:
            float(data["Jurusan Diterima"][i])
        except ValueError:
            pass
        else:
            if math.isnan(float(data["Jurusan Diterima"][i])) or int(data["Jurusan Diterima"][i]) == 0:
                drop_index.append(i)
        finally:
            if math.isnan(float(data["Rata-rata Sosiologi"][i])):
                drop_index.append(i)

    data = data.drop(drop_index)
        
    return data

# %%
def clean_jurusan_ptn(data):
    for i in range(len(data)):
        for column in data:
            if column == "Jurusan Diterima"  or column == "Jurusan Pilihan I di PTN Pilihan I" or column == "Jurusan Pilihan II di PTN Pilihan I" or column == "Jurusan Pilihan I di PTN Pilihan II" or column == "Jurusan Pilihan II di PTN Pilihan II":
                if isinstance(data[column][i], float):
                    pass
                else:
                    data[column][i] = data[column][i].title()
            elif column == "PTN Diterima" or column == "PTN Pilihan I" or column == "PTN Pilihan II":
                if isinstance(data[column][i], float):
                    pass
                else:
                    data[column][i] = data[column][i].upper()
    
    return data

# %%
def clean(files):
    cleanned_data = []
    
    for file in files:
        data = open_file(file)

        data = cleaning_nilai(data)

        matpel = ["Matematika", "Inggris", "Indonesia", "Fisika", "Kimia", "Biologi", "Ekonomi", "Geografi", "Sosiologi","Sejarah"]

        for item in matpel:
            data = replace_zero_w_mean(data, item)
            data = rata2_mp_semester(data, item)
                    
        data = remove_nan(data)
        
        cleanned_data.append(data)
        
        data_merge = pd.concat(cleanned_data, ignore_index=True)
        
        result = clean_jurusan_ptn(data_merge)
        
    #Split data test - data train
    test = result.sample(frac=0.3, replace=True)
    test.to_csv("Splitted Test.csv", encoding="utf-8")
    
#     rest_of_data = result.drop(test.index).reset_index()
    
    train = result.drop([
            "Nama Panggilan", 
            "Asal Sekolah", 
            "PTN Pilihan I", 
            "Jurusan Pilihan I di PTN Pilihan I" ,
            "Jurusan Pilihan II di PTN Pilihan I", 
            "PTN Pilihan II", 
            "Jurusan Pilihan I di PTN Pilihan II" ,
            "Jurusan Pilihan II di PTN Pilihan II", 
            "Rata-rata Sejarah",
        ],axis=1)
    
    train.to_csv("Splitted Train.csv", encoding="utf-8")
    
#     train = train_w_index.drop(["index"],axis=1)

    return train

# %%
def sort_data(data):
    data_sort = data.sort_values(by=['Jurusan Diterima', 'PTN Diterima'])
    
    data_sort.reset_index(inplace = True)

    data_sort = data_sort.drop(["index"], axis=1)

    return data_sort

# %%
def get_jurusan_ptn(data):
    temp_jurusan = ""
    temp_ptn = ""
    list_jurusan_ptn = []
    for i in range(len(data)):
        if data["Jurusan Diterima"][i] != temp_jurusan and data["PTN Diterima"][i] != temp_ptn:
            temp_jurusan = data["Jurusan Diterima"][i]
            temp_ptn = data["PTN Diterima"][i]
            list_jurusan_ptn.append((temp_jurusan, temp_ptn))
        else:
            pass

    return list_jurusan_ptn

# %%
def get_tabel_alternatif(data, list_jurusan_ptn):
    frame = {}
    for j in range(len(list_jurusan_ptn)):
        list_nilai = []
        for column in data:
            jum = 0
            byk = 0
            for i in data.index:
                if data["Jurusan Diterima"][i] == list_jurusan_ptn[j][0] and data["PTN Diterima"][i] == list_jurusan_ptn[j][1]:
    #                 print(data_sort["Jurusan Diterima"][i], data_sort["PTN Diterima"][i])
                    temp_jurusan = data["Jurusan Diterima"][i]
                    temp_ptn = data["PTN Diterima"][i]
                    try:
                        float(data[column][i])
                    except ValueError:
                        break
                    else:
                        jum += data[column][i]
                        byk += 1
                else:
                    pass
            try:
    #             print(column, jum/byk)
                list_nilai.append(jum/byk)
            except ZeroDivisionError:
                continue
        nama_alternatif = f"{temp_jurusan} - {temp_ptn}"
        if "administrasi" in temp_jurusan.casefold().split()\
        or "sosial" in temp_jurusan.casefold().split()\
        or "ekonomi" in temp_jurusan.casefold().split()\
        or "hi" in temp_jurusan.casefold().split()\
        or "hukum" in temp_jurusan.casefold().split()\
        or "komunikasi" in temp_jurusan.casefold().split()\
        or "politik" in temp_jurusan.casefold().split()\
        or "sosiologi" in temp_jurusan.casefold().split()\
        or "fsrd" in temp_jurusan.casefold().split()\
        or "sbm" in temp_jurusan.casefold().split()\
        or "akuntansi" in temp_jurusan.casefold().split()\
        or "manajemen" in temp_jurusan.casefold().split()\
        or "psdk" in temp_jurusan.casefold().split()\
        or "fiskal" in temp_jurusan.casefold().split()\
        or ("hubungan" in temp_jurusan.casefold().split() and "internasional" in temp_jurusan.casefold().split())\
        or "kriminologi" in temp_jurusan.casefold().split()\
        or "psikologi" in temp_jurusan.casefold().split()\
        or "bisnis" in temp_jurusan.casefold().split()\
        or "filsafat" in temp_jurusan.casefold().split()\
        or "jurnalistik" in temp_jurusan.casefold().split()\
        or "humas" in temp_jurusan.casefold().split()\
        or "desain" in temp_jurusan.casefold().split()\
        or "film" in temp_jurusan.casefold().split()\
        or "antropologi" in temp_jurusan.casefold().split()\
        or "keluarga" in temp_jurusan.casefold().split()\
        or "konsumen" in temp_jurusan.casefold().split()\
        or "sejarah" in temp_jurusan.casefold().split()\
        or "menejemen" in temp_jurusan.casefold().split()\
        or "arkeologi" in temp_jurusan.casefold().split()\
        or ("hubungan" in temp_jurusan.casefold().split() and "masyarakat" in temp_jurusan.casefold().split())\
        or "akutansi" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "sastra" in temp_jurusan.casefold().split()\
        or "bahasa" in temp_jurusan.casefold().split()\
        or "perpustakaan" in temp_jurusan.casefold().split()\
        or "ugm" in temp_jurusan.casefold().split():
            continue
        
        if "(IPS)" not in nama_alternatif.split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPA)"
        
#         if len(list_nilai) == 11:
#             del list_nilai[0]
#         elif len(list_nilai) == 13:
#             del list_nilai[0:3]
#         elif len(list_nilai) == 12:
#             del list_nilai[0:2]
            
        frame[nama_alternatif] = list_nilai

    tabel = pd.DataFrame(frame, index=["Matematika", "Inggris", "Indonesia", "Fisika", "Kimia", "Biologi", "Ekonomi", "Geografi", "Sosiologi"])

    return tabel

# %%
datasets = ["Data SNMPTN 2016 IPB by @halokampus.csv",
            "Data SNMPTN 2016 ITB by @halokampus.csv",
            "Data SNMPTN 2016 ITS by @halokampus.csv",
            "Data SNMPTN 2016 UB by @halokampus.csv",
            "Data SNMPTN 2016 UGM by @halokampus.csv",
            "Data SNMPTN 2016 UI by @halokampus.csv",
            "Data SNMPTN 2016 Unair by @halokampus.csv",
            "Data SNMPTN 2016 Undip by @halokampus.csv",
            "Data SNMPTN 2016 Unpad by @halokampus.csv",
            "Data SNMPTN 2017 IPB by @halokampus.csv",
            "Data SNMPTN 2017 ITB by @halokampus.csv",
            "Data SNMPTN 2017 ITS by @halokampus.csv",
            "Data SNMPTN 2017 UGM by @halokampus.csv",
            "Data SNMPTN 2017 UI by @halokampus.csv",
            "Data SNMPTN 2017 Unair by @halokampus.csv",
            "Data SNMPTN 2017 Unpad by @halokampus.csv",]

# %%
result = clean(datasets)

result
# Out:
# C:\Users\jamal\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Users\jamal\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     Jurusan Sekolah Jenis Sekolah          Jurusan Diterima PTN Diterima  \
# 0               IPA           SMA                Mipa Kimia           UB
# 1               IPA           SMA        Teknik Informatika           UB
# 2               IPS           SMA        Antropologi Sosial           UB
# 3               IPS           SMA  Ilmu Administrasi Publik           UB
# 4               IPA           SMA         Pendidikan Dokter           UB
# ..              ...           ...                       ...          ...
# 746             IPA           SMA                    Kimia        UNPAD
# 747             IPS           SMA             Ekonomi Islam        UNPAD
# 748             IPA           SMA        Teknik Informatika        UNPAD
# 749             IPA           SMA                   Kimia,         UNPAD
# 750             IPS           SMA                Komunikasi        UNPAD
#
#      Rata-rata Matematika  Rata-rata Inggris  Rata-rata Indonesia  \
# 0               89.000000          83.000000            82.000000
# 1               82.408571          83.918889            84.351667
# 2               77.000000          81.000000            80.000000
# 3               82.408571          83.918889            84.351667
# 4               91.000000          92.000000            95.000000
# ..                    ...                ...                  ...
# 746             84.000000          90.000000            91.000000
# 747             88.000000          84.880013            85.361743
# 748             93.000000          89.000000            89.000000
# 749             82.237153          84.880013            85.361743
# 750             34.500000          88.000000            98.000000
#
#      Rata-rata Fisika  Rata-rata Kimia  Rata-rata Biologi  Rata-rata Ekonomi  \
# 0           88.000000        93.000000          79.000000          84.210714
# 1           81.956615        82.397782          82.827536          84.210714
# 2           73.000000        73.000000          73.000000          79.000000
# 3           81.956615        82.397782          82.827536          84.210714
# 4           84.000000        94.000000          96.000000          84.210714
# ..                ...              ...                ...                ...
# 746         83.000000        86.000000          86.000000          83.968929
# 747         84.584430        84.592411          83.879942          83.968929
# 748         88.000000        91.000000          89.000000          92.000000
# 749         84.584430        84.592411          83.879942          83.968929
# 750         88.000000        78.000000          78.000000          83.000000
#
#      Rata-rata Geografi  Rata-rata Sosiologi
# 0             84.808608             84.85000
# 1             84.808608             84.85000
# 2             77.000000             83.00000
# 3             84.808608             84.85000
# 4             84.808608             84.85000
# ..                  ...                  ...
# 746           84.283138             85.10347
# 747           84.283138             85.10347
# 748           85.769883             85.10347
# 749           84.283138             85.10347
# 750           83.000000             88.00000
#
# [751 rows x 13 columns]

# %%
data_sort = sort_data(result)

data_sort
# Out:
#     Jurusan Sekolah Jenis Sekolah     Jurusan Diterima PTN Diterima  \
# 0               IPA           SMA  Administrasi Fiskal           UI
# 1               IPS           SMA  Administrasi Negara           UI
# 2               IPS           SMA  Administrasi Negara        UNPAD
# 3               IPS           SMA  Administrasi Negara        UNPAD
# 4               IPS           SMA   Administrasi Niaga           UI
# ..              ...           ...                  ...          ...
# 746             IPA           SMA                 Tphp          UGM
# 747             IPS           SMA            Tv & Film        UNPAD
# 748             IPS           SMA       Tv & Perfilman        UNPAD
# 749             IPS           SMA         Tv Dan Film         UNPAD
# 750             IPA           SMA                  Ugm          UGM
#
#      Rata-rata Matematika  Rata-rata Inggris  Rata-rata Indonesia  \
# 0               84.000000          84.000000            84.000000
# 1               88.000000          86.000000            87.000000
# 2               87.000000          83.000000            91.000000
# 3               90.000000          78.000000            88.000000
# 4               85.465625          83.888667            85.246032
# ..                    ...                ...                  ...
# 746             86.000000          90.000000            91.000000
# 747             85.000000          85.000000            84.000000
# 748             84.000000          91.000000            88.000000
# 749             83.000000          77.000000            82.000000
# 750             93.000000          89.000000            97.000000
#
#      Rata-rata Fisika  Rata-rata Kimia  Rata-rata Biologi  Rata-rata Ekonomi  \
# 0           82.000000        81.000000          83.000000          86.145714
# 1           85.458673        85.232000          84.774154          92.000000
# 2           84.584430        84.592411          83.879942          85.000000
# 3           84.584430        84.592411          83.879942          93.000000
# 4           84.493016        85.297674          84.182558          86.145714
# ..                ...              ...                ...                ...
# 746         88.000000        89.000000          90.000000          89.837895
# 747         84.584430        84.592411          83.879942          86.000000
# 748         84.584430        84.592411          83.879942          87.000000
# 749         84.584430        84.592411          83.879942          83.000000
# 750         89.000000        94.000000          93.000000          89.837895
#
#      Rata-rata Geografi  Rata-rata Sosiologi
# 0             85.512727            86.930877
# 1             92.000000            89.000000
# 2             90.000000            84.000000
# 3             85.000000            87.000000
# 4             85.512727            86.930877
# ..                  ...                  ...
# 746           88.094322            90.363636
# 747           87.000000            85.000000
# 748           87.000000            90.000000
# 749           85.000000            87.000000
# 750           88.094322            90.363636
#
# [751 rows x 13 columns]

# %%
list_jurusan_ptn = get_jurusan_ptn(data_sort)

list_jurusan_ptn
# Out:
# [('Administrasi Fiskal', 'UI'),
#  ('Administrasi Negara', 'UNPAD'),
#  ('Administrasi Niaga', 'UI'),
#  ('Administrasi Perpajakan', 'UB'),
#  ('Agribisnis', 'UNDIP'),
#  ('Agroekoteknologi', 'UB'),
#  ('Agroteknologi', 'UNPAD'),
#  ('Akuntansi', 'UGM'),
#  ('Akutansi', 'UI'),
#  ('Antropologi', 'UNAIR'),
#  ('Antropologi Sosial', 'UB'),
#  ('Apoteker', 'UNAIR'),
#  ('Arkeologi', 'UI'),
#  ('Arsitektur', 'ITS'),
#  ('Astronomi', 'ITB'),
#  ('Bahasa Dan Kebudayaan Korea', 'UI'),
#  ('Bahasa Korea', 'UGM'),
#  ('Biologi', 'ITS'),
#  ('Budidaya Perairan', 'UNAIR'),
#  ('Desain Interior', 'ITS'),
#  ('Ekonomi Islam', 'UB'),
#  ('Ekonomi Islam ', 'UNPAD'),
#  ('Ekonomi Pembangunan', 'UB'),
#  ('Fakultas Ilmu Dan Teknologi Kebumian', 'ITB'),
#  ('Fakultas Kedokteran Gigi', 'UNAIR'),
#  ('Fakultas Teknik Sipil & Lingkungan', 'ITB'),
#  ('Farmasi', 'UI'),
#  ('Fisika', 'ITS'),
#  ('Fiskal', 'UI'),
#  ('Fitb', 'ITB'),
#  ('Fkg', 'UGM'),
#  ('Fmipa', 'ITB'),
#  ('Fmipa Fisika', 'UB'),
#  ('Fmipa- Ilmu Kimia', 'UNPAD'),
#  ('Fti', 'ITB'),
#  ('Geofisika', 'UGM'),
#  ('Geofisika ', 'UI'),
#  ('Gizi', 'UGM'),
#  ('Hi', 'UB'),
#  ('Hubungan Internasional', 'UGM'),
#  ('Hubungan Masyarakat', 'UNPAD'),
#  ('Hukum', 'UB'),
#  ('Humas', 'UNPAD'),
#  ('Ilmu Adm. Fiskal', 'UI'),
#  ('Ilmu Administrasi Bisnis', 'UNPAD'),
#  ('Ilmu Administrasi Negara', 'UI'),
#  ('Ilmu Administrasi Publik', 'UB'),
#  ('Ilmu Ekonomi', 'UGM'),
#  ('Ilmu Ekonomi Islam', 'UI'),
#  ('Ilmu Filsafat', 'UGM'),
#  ('Ilmu Gizi', 'UI'),
#  ('Ilmu Hub. Internasional', 'UNPAD'),
#  ('Ilmu Hubungan Internasional', 'UI'),
#  ('Ilmu Hukum', 'UB'),
#  ('Ilmu Informasi Dan Perpustakaan ', 'UNPAD'),
#  ('Ilmu Kelautan', 'UNDIP'),
#  ('Ilmu Keperawatan', 'UI'),
#  ('Ilmu Keperawatan ', 'UNPAD '),
#  ('Ilmu Kesehatan Masyarakat', 'UI'),
#  ('Ilmu Komputer', 'UGM'),
#  ('Ilmu Komunikasi', 'UB'),
#  ('Ilmu Perpustakaan', 'UI'),
#  ('Ilmu Peternakan', 'UNPAD'),
#  ('Ilmu Politik', 'UB'),
#  ('Ilmu Sejarah', 'UI'),
#  ('Ilmu Sosiologi', 'UNPAD'),
#  ('Itb - Sithr', 'ITB'),
#  ('Jurnalistik', 'UNPAD'),
#  ('Kedokteran', 'UI'),
#  ('Kedokteran ', 'UNAIR'),
#  ('Kedokteran Gigi', 'UGM'),
#  ('Kedokteran Hewan', 'UNAIR'),
#  ('Kehutanan', 'UGM'),
#  ('Kesehatan Masyarakat', 'UI'),
#  ('Kesehatan Masyarakat (Pdd Banyuwangi)', 'UNAIR'),
#  ('Kesejahteraan Sosial', 'UI'),
#  ('Kimia', 'ITS'),
#  ('Kimia ', 'UI'),
#  ('Kimia, ', 'UNPAD'),
#  ('Komunikasi', 'UI'),
#  ('Manajemen', 'ITB'),
#  ('Manajemen Bisnis', 'ITS'),
#  ('Manajemen Dan Kebijakan Publik (An)', 'UGM'),
#  ('Manajemen Komunikasi', 'UNPAD'),
#  ('Manajemen Sd Perairan', 'UNDIP'),
#  ('Matematika', 'ITS'),
#  ('Matematika ', 'UI'),
#  ('Matematika Aktuaria', 'ITB'),
#  ('Menejemen', 'UNAIR '),
#  ('Mipa Geologi', 'UI'),
#  ('Mipa Kimia', 'UB'),
#  ('Oceanografi', 'UNDIP'),
#  ('Pembangunan Wilayah', 'UGM'),
#  ('Pend. Apoteker', 'UNAIR'),
#  ('Pendidikan Dokter', 'UB'),
#  ('Pendidikan Dokter Gigi', 'UNAIR'),
#  ('Perencanaan Wilayah & Kota', 'UB'),
#  ('Perikanan', 'UNPAD'),
#  ('Peternakan', 'UB'),
#  ('Psdk', 'UGM'),
#  ('Psikologi', 'UI'),
#  ('Psikologi ', 'UGM'),
#  ('S-1 Teknik Informatika', 'ITS'),
#  ('Sappk', 'ITB'),
#  ('Sastra', 'UI'),
#  ('Sastra Arab', 'UGM'),
#  ('Sastra Belanda', 'UI'),
#  ('Sastra Indonesia', 'UNPAD'),
#  ('Sastra Inggris', 'UI'),
#  ('Sastra Inggris ', 'UNAIR'),
#  ('Sastra Jawa', 'UI'),
#  ('Sastra Jepang', 'UB'),
#  ('Sastra Jerman', 'UI'),
#  ('Sastra Jerman ', 'UNPAD'),
#  ('Sastra Perancis', 'UI'),
#  ('School Of Business And Management ', 'ITB'),
#  ('Sistem Informasi', 'UB'),
#  ('Sith - Rekayasa', 'ITB'),
#  ('Sosial Ekonomi Pertanian (Agrobisnis)', 'UGM'),
#  ('Sosiologi', 'UB'),
#  ('Sosiologi Murni', 'UNAIR'),
#  ('Statistika', 'ITS'),
#  ('Stei', 'ITB'),
#  ('Tehnik Sipil', 'UGM'),
#  ('Teknik Elektro', 'ITS'),
#  ('Teknik Fisika', 'UGM'),
#  ('Teknik Geodesi', 'UNDIP'),
#  ('Teknik Geologi', 'UGM'),
#  ('Teknik Geologi ', 'UNPAD'),
#  ('Teknik Industri', 'ITB'),
#  ('Teknik Industri Pertanian', 'UGM'),
#  ('Teknik Informatika', 'ITS'),
#  ('Teknik Kimia', 'ITB'),
#  ('Teknik Komputer', 'ITS'),
#  ('Teknik Lingkungan', 'UB'),
#  ('Teknik Mesin', 'ITS'),
#  ('Teknik Metalurgi & Material', 'UI'),
#  ('Teknik Nuklir', 'UGM'),
#  ('Teknik Pengairan', 'UB'),
#  ('Teknik Perkapalan', 'ITS'),
#  ('Teknik Pertanian', 'UGM'),
#  ('Teknik Sipil', 'ITB'),
#  ('Teknik Sistem Perkapalan', 'ITS'),
#  ('Teknobiomedik', 'UNAIR'),
#  ('Teknologi Bioproses', 'UI'),
#  ('Teknologi Hasil Perikanan', 'UB'),
#  ('Teknologi Industri Hasil Perikanan', 'UNAIR'),
#  ('Teknologi Industri Pertanian', 'UGM'),
#  ('Teknologi Pangan', 'UB'),
#  ('Televisi & Film', 'UNPAD'),
#  ('Tip', 'UGM'),
#  ('Tv & Film', 'UNPAD'),
#  ('Ugm', 'UGM')]

# %%
tabel_alternatif = get_tabel_alternatif(data_sort, list_jurusan_ptn)

tabel_alternatif
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1694         blocks = form_blocks(arrays, names, axes)
# -> 1695         mgr = BlockManager(blocks, axes)
#    1696         mgr._consolidate_inplace()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\managers.py in __init__(self, blocks, axes, do_integrity_check)
#     142         if do_integrity_check:
# --> 143             self._verify_integrity()
#     144
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\managers.py in _verify_integrity(self)
#     344             if block._verify_integrity and block.shape[1:] != mgr_shape[1:]:
# --> 345                 construction_error(tot_items, block.shape[1:], self.axes)
#     346         if len(self.items) != tot_items:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\managers.py in construction_error(tot_items, block_shape, axes, e)
#    1718     raise ValueError(
# -> 1719         "Shape of passed values is {0}, indices imply {1}".format(passed, implied)
#    1720     )
#
# ValueError: Shape of passed values is (9, 137), indices imply (10, 137)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-3f90dcb490f2> in <module>
# ----> 1 tabel_alternatif = get_tabel_alternatif(data_sort, list_jurusan_ptn)
#       2
#       3 tabel_alternatif
#
# <ipython-input-11-c50c1c819179> in get_tabel_alternatif(data, list_jurusan_ptn)
#      76         frame[nama_alternatif] = list_nilai
#      77
# ---> 78     tabel = pd.DataFrame(frame, index=["Matematika", "Inggris", "Indonesia", "Fisika", "Kimia", "Biologi", "Ekonomi", "Geografi", "Sosiologi", "Sejarah"])
#      79
#      80     return tabel
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     409             )
#     410         elif isinstance(data, dict):
# --> 411             mgr = init_dict(data, index, columns, dtype=dtype)
#     412         elif isinstance(data, ma.MaskedArray):
#     413             import numpy.ma.mrecords as mrecords
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     255             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     256         ]
# --> 257     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     258
#     259
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      85     axes = [ensure_index(columns), index]
#      86
# ---> 87     return create_block_manager_from_arrays(arrays, arr_names, axes)
#      88
#      89
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1697         return mgr
#    1698     except ValueError as e:
# -> 1699         construction_error(len(arrays), arrays[0].shape, axes, e)
#    1700
#    1701
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\managers.py in construction_error(tot_items, block_shape, axes, e)
#    1717         raise ValueError("Empty data passed with indices specified.")
#    1718     raise ValueError(
# -> 1719         "Shape of passed values is {0}, indices imply {1}".format(passed, implied)
#    1720     )
#    1721
#
# ValueError: Shape of passed values is (9, 137), indices imply (10, 137)

# %%
tabel_alternatif.to_csv("Tabel Alternatif.csv", encoding="utf-8")
