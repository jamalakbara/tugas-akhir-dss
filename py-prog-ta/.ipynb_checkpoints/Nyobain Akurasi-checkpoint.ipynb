# %%
# %run Weighting.ipynb
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-watson-data-lab/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.1.18</span>
#         </div>

# %%
nilai_test = pd.read_csv("Splitted Test.csv", index_col = 0)

nilai_test
# Out:
#     Nama Panggilan                     Asal Sekolah Jurusan Sekolah  \
# 254         Ayunda        SMAS Al-Irsyad Padalarang             IPS
# 245           Irma                   SMAN 1 Sindang             IPS
# 460          Zanky               SMA Negeri 3 Tegal             IPA
# 614           WITA                     SMAN 1 TAMAN             IPS
# 305           Erde               SMA Negeri 9 Bogor             IPA
# ..             ...                              ...             ...
# 263          Fikri             SMA NEGERI 1O PADANG             IPA
# 598           Nova                  SMAN 1 Surabaya             IPA
# 449          Anggi              SMA Negeri 1 Klaten             IPS
# 238          karin  sma al-azhar bumi serpong damai             IPA
# 69          Ashila               SMA N 1 Pekalongan             IPS
#
#     Jenis Sekolah PTN Pilihan I Jurusan Pilihan I di PTN Pilihan I  \
# 254           SMA         UNPAD                              Hukum
# 245           SMA         UNPAD                              Hukum
# 460           SMA           UGM                      Ilmu Filsafat
# 614           SMA         UNAIR                       Ilmu Politik
# 305           SMA           ITB                             Sith-R
# ..            ...           ...                                ...
# 263           SMA         UNPAD                 Teknik Informatika
# 598           SMA         UNAIR                          Akuntansi
# 449           SMA           UGM                          Psikologi
# 238           SMA         UNPAD                         Statistika
# 69            SMA           UGM                          Psikologi
#
#     Jurusan Pilihan II di PTN Pilihan I PTN Pilihan II  \
# 254                              Kosong         KOSONG
# 245                                   U         KOSONG
# 460                               Kimia         KOSONG
# 614                                 NaN          UNESA
# 305                               Fti-J         KOSONG
# ..                                  ...            ...
# 263                                 NaN          UNAND
# 598                           Manajemen      UPN JATIM
# 449                          Ilmu Hukum            UNS
# 238                                 NaN         KOSONG
# 69                           Ilmu Hukum          UNDIP
#
#     Jurusan Pilihan I di PTN Pilihan II Jurusan Pilihan II di PTN Pilihan II  \
# 254                              Kosong                               Kosong
# 245                              Unsoed                           Komunikasi
# 460                                 NaN                                  NaN
# 614                           Sosiologi                   Pendidikan Ekonomi
# 305                                 NaN                                  NaN
# ..                                  ...                                  ...
# 263                      Teknik Elektro                    Teknik Lingkungan
# 598                 Administrasi Negara                               Kosong
# 449                          Ilmu Hukum                                  NaN
# 238                                 NaN                                  NaN
# 69                            Psikologi                               Kosong
#
#      ... Rata-rata Matematika Rata-rata Inggris  Rata-rata Indonesia  \
# 254  ...            82.796296         84.277778            83.648148
# 245  ...            82.796296         84.277778            83.648148
# 460  ...            82.000000         88.547569            87.000000
# 614  ...            81.000000         81.000000            83.000000
# 305  ...            86.000000         88.000000            88.000000
# ..   ...                  ...               ...                  ...
# 263  ...            86.000000         91.000000            88.000000
# 598  ...            98.000000         90.000000            88.000000
# 449  ...            88.617137         88.547569            88.740000
# 238  ...            79.000000         80.000000            83.000000
# 69   ...            82.000000         80.000000            86.000000
#
#      Rata-rata Fisika  Rata-rata Kimia  Rata-rata Biologi  Rata-rata Ekonomi  \
# 254         83.198246        85.673434          84.964912          81.561183
# 245         83.198246        85.673434          84.964912          81.561183
# 460         83.000000        84.000000          82.000000          82.000000
# 614         84.646720        85.035214          86.206897          90.000000
# 305         85.000000        85.000000          89.000000          87.917424
# ..                ...              ...                ...                ...
# 263         86.000000        91.000000          89.000000          89.000000
# 598         88.000000        93.000000          83.000000          93.000000
# 449         87.828571        87.628571          88.502521          89.837895
# 238         81.000000        81.000000          83.000000          80.136710
# 69          86.843464        87.843137          87.058824          91.000000
#
#      Rata-rata Geografi  Rata-rata Sosiologi  Rata-rata Sejarah
# 254           79.336154            77.450278          81.832680
# 245           79.336154            77.450278          81.832680
# 460           72.300000            90.363636          87.000000
# 614           85.000000            81.000000          83.000000
# 305           85.858929            89.898990          87.000000
# ..                  ...                  ...                ...
# 263           83.801692            77.450278          86.000000
# 598           84.793706            85.695971          85.000000
# 449           88.094322            90.363636          88.650538
# 238           79.336154            77.450278          81.000000
# 69            91.000000            89.000000          80.000000
#
# [225 rows x 22 columns]

# %%
tabel_alternatif = open_tabel("Tabel Alternatif.csv")

tabel_alternatif
# Out:
#             Administrasi Fiskal - UI (IPS)  Administrasi Negara - UNPAD (IPS)  \
# Matematika                       84.000000                          88.500000
# Inggris                          84.000000                          80.500000
# Indonesia                        84.000000                          89.500000
# Fisika                           82.000000                          84.584430
# Kimia                            81.000000                          84.592411
# Biologi                          83.000000                          83.879942
# Ekonomi                          86.145714                          89.000000
# Geografi                         85.512727                          87.500000
# Sosiologi                        86.930877                          85.500000
#
#             Administrasi Niaga - UI (IPS)  Administrasi Perpajakan - UB (IPS)  \
# Matematika                      85.465625                           92.000000
# Inggris                         83.888667                           86.000000
# Indonesia                       85.246032                           89.000000
# Fisika                          84.493016                           81.956615
# Kimia                           85.297674                           82.397782
# Biologi                         84.182558                           82.827536
# Ekonomi                         86.145714                           91.242143
# Geografi                        85.512727                           91.000000
# Sosiologi                       86.930877                           91.000000
#
#             Agribisnis - UNDIP (IPA)  Agroekoteknologi - UB (IPA)  \
# Matematika                 86.250000                    81.852143
# Inggris                    85.500000                    84.729722
# Indonesia                  87.833333                    85.837917
# Fisika                     83.360000                    81.739154
# Kimia                      85.100000                    82.349446
# Biologi                    86.172727                    83.706884
# Ekonomi                    87.271429                    83.726429
# Geografi                   87.500000                    84.627747
# Sosiologi                  87.000000                    85.702500
#
#             Agroteknologi - UNPAD (IPA)  Akuntansi - UGM (IPS)  \
# Matematika                    82.500000              91.625000
# Inggris                       82.750000              90.875000
# Indonesia                     84.000000              89.875000
# Fisika                        80.500000              89.437576
# Kimia                         81.500000              88.716106
# Biologi                       83.250000              89.695798
# Ekonomi                       82.062045              92.250000
# Geografi                      81.926031              88.959803
# Sosiologi                     81.331846              91.872475
#
#             Akutansi - UI (IPS)  Antropologi - UNAIR (IPS)  ...  \
# Matematika            44.693125                  84.576004  ...
# Inggris               54.255467                  85.307966  ...
# Indonesia             85.000000                  85.970128  ...
# Fisika                87.000000                  84.646720  ...
# Kimia                 74.300000                  85.035214  ...
# Biologi               83.000000                  86.206897  ...
# Ekonomi               86.145714                  85.211111  ...
# Geografi              85.512727                  84.793706  ...
# Sosiologi             86.930877                  85.695971  ...
#
#             Teknik Sistem Perkapalan - ITS (IPA)  Teknobiomedik - UNAIR (IPA)  \
# Matematika                             90.000000                    86.154669
# Inggris                                87.000000                    86.153983
# Indonesia                              88.000000                    86.651731
# Fisika                                 88.500000                    85.048360
# Kimia                                  89.500000                    85.286546
# Biologi                                92.000000                    86.364812
# Ekonomi                                87.839744                    85.654365
# Geografi                               84.333333                    85.363520
# Sosiologi                              84.666667                    85.531319
#
#             Teknologi Bioproses - UI (IPA)  \
# Matematika                       85.465625
# Inggris                          83.888667
# Indonesia                        85.246032
# Fisika                           84.493016
# Kimia                            85.297674
# Biologi                          84.182558
# Ekonomi                          86.145714
# Geografi                         85.512727
# Sosiologi                        86.930877
#
#             Teknologi Hasil Perikanan - UB (IPA)  \
# Matematika                             82.000000
# Inggris                                91.000000
# Indonesia                              89.000000
# Fisika                                 80.000000
# Kimia                                  79.000000
# Biologi                                83.000000
# Ekonomi                                88.726429
# Geografi                               84.808608
# Sosiologi                              84.850000
#
#             Teknologi Industri Hasil Perikanan - UNAIR (IPA)  \
# Matematika                                         85.000000
# Inggris                                            84.000000
# Indonesia                                          86.000000
# Fisika                                             83.000000
# Kimia                                              81.000000
# Biologi                                            86.000000
# Ekonomi                                            85.211111
# Geografi                                           84.793706
# Sosiologi                                          85.695971
#
#             Teknologi Industri Pertanian - UGM (IPA)  \
# Matematika                                 86.506173
# Inggris                                    86.859259
# Indonesia                                  86.982716
# Fisika                                     85.562309
# Kimia                                      86.895425
# Biologi                                    87.039216
# Ekonomi                                    87.864219
# Geografi                                   88.470835
# Sosiologi                                  91.380471
#
#             Teknologi Pangan - UB (IPA)  Televisi & Film - UNPAD (IPS)  \
# Matematika                    82.408571                      85.000000
# Inggris                       83.918889                      85.500000
# Indonesia                     84.351667                      86.500000
# Fisika                        81.956615                      84.584430
# Kimia                         82.397782                      84.592411
# Biologi                       82.827536                      83.879942
# Ekonomi                       84.210714                      86.000000
# Geografi                      84.808608                      86.500000
# Sosiologi                     84.850000                      85.500000
#
#             Tip - UGM (IPA)  Tv & Film - UNPAD (IPS)
# Matematika        87.000000                85.000000
# Inggris           94.000000                85.000000
# Indonesia         80.000000                84.000000
# Fisika            86.000000                84.584430
# Kimia             87.000000                84.592411
# Biologi           86.000000                83.879942
# Ekonomi           89.837895                86.000000
# Geografi          88.094322                87.000000
# Sosiologi         90.363636                85.000000
#
# [9 rows x 137 columns]

# %%
pilihan_jurusan = get_jurusan(tabel_alternatif)

pilihan_jurusan
# Out:
# ['Administrasi Fiskal - UI (IPS)',
#  'Administrasi Negara - UNPAD (IPS)',
#  'Administrasi Niaga - UI (IPS)',
#  'Administrasi Perpajakan - UB (IPS)',
#  'Agribisnis - UNDIP (IPA)',
#  'Agroekoteknologi - UB (IPA)',
#  'Agroteknologi - UNPAD (IPA)',
#  'Akuntansi - UGM (IPS)',
#  'Akutansi - UI (IPS)',
#  'Antropologi - UNAIR (IPS)',
#  'Antropologi Sosial - UB (IPS)',
#  'Apoteker - UNAIR (IPA)',
#  'Arkeologi - UI (IPS)',
#  'Arsitektur - ITS (IPA)',
#  'Astronomi - ITB (IPA)',
#  'Biologi - ITS (IPA)',
#  'Budidaya Perairan - UNAIR (IPA)',
#  'Desain Interior - ITS (IPS)',
#  'Ekonomi Islam - UB (IPS)',
#  'Ekonomi Islam  - UNPAD (IPS)',
#  'Ekonomi Pembangunan - UB (IPS)',
#  'Fakultas Ilmu Dan Teknologi Kebumian - ITB (IPA)',
#  'Fakultas Kedokteran Gigi - UNAIR (IPA)',
#  'Fakultas Teknik Sipil & Lingkungan - ITB (IPA)',
#  'Farmasi - UI (IPA)',
#  'Fisika - ITS (IPA)',
#  'Fiskal - UI (IPS)',
#  'Fitb - ITB (IPA)',
#  'Fkg - UGM (IPA)',
#  'Fmipa - ITB (IPA)',
#  'Fmipa Fisika - UB (IPA)',
#  'Fmipa- Ilmu Kimia - UNPAD (IPA)',
#  'Fti - ITB (IPA)',
#  'Geofisika - UGM (IPA)',
#  'Geofisika  - UI (IPA)',
#  'Gizi - UGM (IPA)',
#  'Hi - UB (IPS)',
#  'Hubungan Internasional - UGM (IPS)',
#  'Hubungan Masyarakat - UNPAD (IPS)',
#  'Hukum - UB (IPS)',
#  'Humas - UNPAD (IPS)',
#  'Ilmu Adm. Fiskal - UI (IPS)',
#  'Ilmu Administrasi Bisnis - UNPAD (IPS)',
#  'Ilmu Administrasi Negara - UI (IPS)',
#  'Ilmu Administrasi Publik - UB (IPS)',
#  'Ilmu Ekonomi - UGM (IPS)',
#  'Ilmu Ekonomi Islam - UI (IPS)',
#  'Ilmu Filsafat - UGM (IPS)',
#  'Ilmu Gizi - UI (IPA)',
#  'Ilmu Hub. Internasional - UNPAD (IPA)',
#  'Ilmu Hubungan Internasional - UI (IPS)',
#  'Ilmu Hukum - UB (IPS)',
#  'Ilmu Kelautan - UNDIP (IPA)',
#  'Ilmu Keperawatan - UI (IPA)',
#  'Ilmu Keperawatan  - UNPAD  (IPA)',
#  'Ilmu Kesehatan Masyarakat - UI (IPA)',
#  'Ilmu Komputer - UGM (IPA)',
#  'Ilmu Komunikasi - UB (IPS)',
#  'Ilmu Peternakan - UNPAD (IPA)',
#  'Ilmu Politik - UB (IPS)',
#  'Ilmu Sejarah - UI (IPS)',
#  'Ilmu Sosiologi - UNPAD (IPS)',
#  'Itb - Sithr - ITB (IPA)',
#  'Jurnalistik - UNPAD (IPS)',
#  'Kedokteran - UI (IPA)',
#  'Kedokteran  - UNAIR (IPA)',
#  'Kedokteran Gigi - UGM (IPA)',
#  'Kedokteran Hewan - UNAIR (IPA)',
#  'Kehutanan - UGM (IPA)',
#  'Kesehatan Masyarakat - UI (IPA)',
#  'Kesehatan Masyarakat (Pdd Banyuwangi) - UNAIR (IPA)',
#  'Kesejahteraan Sosial - UI (IPS)',
#  'Kimia - ITS (IPA)',
#  'Kimia  - UI (IPA)',
#  'Kimia,  - UNPAD (IPA)',
#  'Komunikasi - UI (IPS)',
#  'Manajemen - ITB (IPS)',
#  'Manajemen Bisnis - ITS (IPS)',
#  'Manajemen Dan Kebijakan Publik (An) - UGM (IPS)',
#  'Manajemen Komunikasi - UNPAD (IPS)',
#  'Manajemen Sd Perairan - UNDIP (IPS)',
#  'Matematika - ITS (IPA)',
#  'Matematika  - UI (IPA)',
#  'Matematika Aktuaria - ITB (IPA)',
#  'Menejemen - UNAIR  (IPS)',
#  'Mipa Geologi - UI (IPA)',
#  'Mipa Kimia - UB (IPA)',
#  'Oceanografi - UNDIP (IPA)',
#  'Pembangunan Wilayah - UGM (IPA)',
#  'Pend. Apoteker - UNAIR (IPA)',
#  'Pendidikan Dokter - UB (IPA)',
#  'Pendidikan Dokter Gigi - UNAIR (IPA)',
#  'Perencanaan Wilayah & Kota - UB (IPA)',
#  'Perikanan - UNPAD (IPA)',
#  'Peternakan - UB (IPA)',
#  'Psdk - UGM (IPS)',
#  'Psikologi - UI (IPS)',
#  'Psikologi  - UGM (IPS)',
#  'S-1 Teknik Informatika - ITS (IPA)',
#  'Sappk - ITB (IPA)',
#  'School Of Business And Management  - ITB (IPA)',
#  'Sistem Informasi - UB (IPA)',
#  'Sith - Rekayasa - ITB (IPA)',
#  'Sosial Ekonomi Pertanian (Agrobisnis) - UGM (IPS)',
#  'Sosiologi - UB (IPS)',
#  'Sosiologi Murni - UNAIR (IPS)',
#  'Statistika - ITS (IPA)',
#  'Stei - ITB (IPA)',
#  'Tehnik Sipil - UGM (IPA)',
#  'Teknik Elektro - ITS (IPA)',
#  'Teknik Fisika - UGM (IPA)',
#  'Teknik Geodesi - UNDIP (IPA)',
#  'Teknik Geologi - UGM (IPA)',
#  'Teknik Geologi  - UNPAD (IPA)',
#  'Teknik Industri - ITB (IPA)',
#  'Teknik Industri Pertanian - UGM (IPA)',
#  'Teknik Informatika - ITS (IPA)',
#  'Teknik Kimia - ITB (IPA)',
#  'Teknik Komputer - ITS (IPA)',
#  'Teknik Lingkungan - UB (IPA)',
#  'Teknik Mesin - ITS (IPA)',
#  'Teknik Metalurgi & Material - UI (IPA)',
#  'Teknik Nuklir - UGM (IPA)',
#  'Teknik Pengairan - UB (IPA)',
#  'Teknik Perkapalan - ITS (IPA)',
#  'Teknik Pertanian - UGM (IPA)',
#  'Teknik Sipil - ITB (IPA)',
#  'Teknik Sistem Perkapalan - ITS (IPA)',
#  'Teknobiomedik - UNAIR (IPA)',
#  'Teknologi Bioproses - UI (IPA)',
#  'Teknologi Hasil Perikanan - UB (IPA)',
#  'Teknologi Industri Hasil Perikanan - UNAIR (IPA)',
#  'Teknologi Industri Pertanian - UGM (IPA)',
#  'Teknologi Pangan - UB (IPA)',
#  'Televisi & Film - UNPAD (IPS)',
#  'Tip - UGM (IPA)',
#  'Tv & Film - UNPAD (IPS)']

# %%
mean = get_mean(tabel_alternatif)
std = get_std(tabel_alternatif)

# %%
bener = 0
aw = list()
for test_index in nilai_test.index:
#assign nilai IPA/IPS
    try:
        if nilai_test["Jurusan Sekolah"][test_index].casefold() == "ipa":
            nilai = [
                nilai_test["Rata-rata Matematika"][test_index],
                nilai_test["Rata-rata Inggris"][test_index],
                nilai_test["Rata-rata Indonesia"][test_index],
                nilai_test["Rata-rata Fisika"][test_index],
                nilai_test["Rata-rata Kimia"][test_index],
                nilai_test["Rata-rata Biologi"][test_index],
                0,
                0,
                0,
            ]
        elif nilai_test["Jurusan Sekolah"][test_index].casefold() == "ips":
            nilai = [
                0,
                nilai_test["Rata-rata Inggris"][test_index],
                nilai_test["Rata-rata Indonesia"][test_index],
                0,
                0,
                0,
                nilai_test["Rata-rata Ekonomi"][test_index],
                nilai_test["Rata-rata Geografi"][test_index],
                nilai_test["Rata-rata Sosiologi"][test_index],
            ]
    except AttributeError:
        continue

    #Mendapatkan nilai2 parameter yang hendak digunakan
    params = get_params(mean, nilai, std)

    #Menambahkan kolom parameter ke tabel_alternatif
    tabel_alternatif = add_parameter(params, tabel_alternatif)

    #Mencari nilai fungsi preferensi gaussian
    fp_gaussian = fungsi_preferensi_gaussian(tabel_alternatif)

    #Menghitung index preferensi global
    index_preferensi_global = idx_pref_global1(fp_gaussian, f'{nilai_test["Jurusan Diterima"][test_index]} - {nilai_test["PTN Diterima"][test_index]}',weight)

    #Menghitung entering flow
    e_flow = entering_flow(pilihan_jurusan, index_preferensi_global)

    #Menghitung leaving flow
    l_flow = leaving_flow(pilihan_jurusan, index_preferensi_global)

    #Menghitung net flow
    n_flow = net_flow(pilihan_jurusan, e_flow, l_flow)

    #Mendapatkan Hasil Outrank
    hasil_outrank = sorted(n_flow.items(), key = lambda kv:(kv[1], kv[0]), reverse = True)

    tab = dict()

    rank = list()
    jurusan = list()
    net = list()

    for i in range(len(hasil_outrank)):
        rank.append(i+1)
        jurusan.append(hasil_outrank[i][0])
        net.append(hasil_outrank[i][1])

    tab["Jurusan"] = jurusan
    tab["Net Flow"] = net

    tabel_hasil = pd.DataFrame(tab, index=rank)
#     aw.append((tabel_hasil["Jurusan"][1], tabel_hasil["Jurusan"][2], tabel_hasil["Jurusan"][3], tabel_hasil["Jurusan"][4], tabel_hasil["Jurusan"][5], tabel_hasil["Jurusan"][6], tabel_hasil["Jurusan"][7], tabel_hasil["Jurusan"][8], tabel_hasil["Jurusan"][9], tabel_hasil["Jurusan"][10], f'{nilai_test["Jurusan Diterima"][test_index]} - {nilai_test["PTN Diterima"][test_index]}'))
    aw.append(
        [tabel_hasil["Jurusan"][i] for i in range(1,10)]
    )
    aw[-1].insert(len(aw[-1]), f'{nilai_test["Jurusan Diterima"][test_index]} - {nilai_test["PTN Diterima"][test_index]}')

# %%
dictHasil = dict()
for i in range(1,len(aw[0])+1):
    if i != len(aw[0]):
        dictHasil[f"tebakan {i}"] = [aw[idx][i-1] for idx in range(len(aw))]
    else:
         dictHasil[f"asli"] = [aw[idx][i-1] for idx in range(len(aw))]

dfHasil = pd.DataFrame(dictHasil)

dfHasil.to_csv(f"Hasil Prediksi {len(aw[0])} rank unk.csv")

# %%
hasil = open_tabel(f"Hasil Prediksi {len(aw[0])} rank unk.csv")
hasilBenar = list()

for i in hasil.index:
    for col in hasil.columns:
        asl = hasil["asli"][i].split()
        s = " "
        aseli = s.join(asl)
        if col != "asli":
            hsl = hasil[col][i].split()
            try:
                hsl.remove("(IPA)")
            except ValueError:
                hsl.remove("(IPS)")
            finally:
                s = " "
                if s.join(hsl) == aseli:
                    hasilBenar.append([hasil[col][i], aseli])

# %%
dictBenar = {
        "tebakan": [hasilBenar[i][0] for i in range(len(hasilBenar))],
        "asli": [hasilBenar[i][1] for i in range(len(hasilBenar))],
    }

dfBenar = pd.DataFrame(dictBenar)

dfBenar.to_csv("Hasil Prediksi Benar.csv")

# %%
idiw = pd.read_csv("Hasil Prediksi 10 rank unk.csv")

idiw
# Out:
#      Unnamed: 0                           tebakan 1              tebakan 2  \
# 0             0  S-1 Teknik Informatika - ITS (IPA)  Geofisika  - UI (IPA)
# 1             1           Ilmu Filsafat - UGM (IPS)  Geofisika  - UI (IPA)
# 2             2  S-1 Teknik Informatika - ITS (IPA)  Geofisika  - UI (IPA)
# 3             3  S-1 Teknik Informatika - ITS (IPA)  Geofisika  - UI (IPA)
# 4             4  S-1 Teknik Informatika - ITS (IPA)  Geofisika  - UI (IPA)
# ..          ...                                 ...                    ...
# 164         164  S-1 Teknik Informatika - ITS (IPA)  Geofisika  - UI (IPA)
# 165         165  S-1 Teknik Informatika - ITS (IPA)  Geofisika  - UI (IPA)
# 166         166  S-1 Teknik Informatika - ITS (IPA)  Geofisika  - UI (IPA)
# 167         167  S-1 Teknik Informatika - ITS (IPA)  Geofisika  - UI (IPA)
# 168         168  S-1 Teknik Informatika - ITS (IPA)  Geofisika  - UI (IPA)
#
#                         tebakan 3                           tebakan 4  \
# 0    Pend. Apoteker - UNAIR (IPA)             Fmipa Fisika - UB (IPA)
# 1    Pend. Apoteker - UNAIR (IPA)  S-1 Teknik Informatika - ITS (IPA)
# 2    Pend. Apoteker - UNAIR (IPA)             Fmipa Fisika - UB (IPA)
# 3    Pend. Apoteker - UNAIR (IPA)             Fmipa Fisika - UB (IPA)
# 4    Pend. Apoteker - UNAIR (IPA)             Fmipa Fisika - UB (IPA)
# ..                            ...                                 ...
# 164  Pend. Apoteker - UNAIR (IPA)             Fmipa Fisika - UB (IPA)
# 165  Pend. Apoteker - UNAIR (IPA)             Fmipa Fisika - UB (IPA)
# 166  Pend. Apoteker - UNAIR (IPA)             Fmipa Fisika - UB (IPA)
# 167  Pend. Apoteker - UNAIR (IPA)             Fmipa Fisika - UB (IPA)
# 168  Pend. Apoteker - UNAIR (IPA)             Fmipa Fisika - UB (IPA)
#
#              tebakan 5                tebakan 6                     tebakan 7  \
# 0    Sappk - ITB (IPA)          Fti - ITB (IPA)  Pendidikan Dokter - UB (IPA)
# 1    Sappk - ITB (IPA)  Fmipa Fisika - UB (IPA)               Fti - ITB (IPA)
# 2    Sappk - ITB (IPA)          Fti - ITB (IPA)  Pendidikan Dokter - UB (IPA)
# 3    Sappk - ITB (IPA)          Fti - ITB (IPA)  Pendidikan Dokter - UB (IPA)
# 4    Sappk - ITB (IPA)          Fti - ITB (IPA)  Pendidikan Dokter - UB (IPA)
# ..                 ...                      ...                           ...
# 164  Sappk - ITB (IPA)          Fti - ITB (IPA)  Pendidikan Dokter - UB (IPA)
# 165  Sappk - ITB (IPA)          Fti - ITB (IPA)  Pendidikan Dokter - UB (IPA)
# 166  Sappk - ITB (IPA)          Fti - ITB (IPA)  Pendidikan Dokter - UB (IPA)
# 167  Sappk - ITB (IPA)          Fti - ITB (IPA)  Pendidikan Dokter - UB (IPA)
# 168  Sappk - ITB (IPA)          Fti - ITB (IPA)  Pendidikan Dokter - UB (IPA)
#
#                   tebakan 8         tebakan 9                        asli
# 0    Matematika  - UI (IPA)  Stei - ITB (IPA)               Hukum - UNPAD
# 1    Matematika  - UI (IPA)  Stei - ITB (IPA)         Ilmu Filsafat - UGM
# 2    Matematika  - UI (IPA)  Stei - ITB (IPA)        Ilmu Politik - UNAIR
# 3    Matematika  - UI (IPA)  Stei - ITB (IPA)                Sith-R - ITB
# 4    Matematika  - UI (IPA)  Stei - ITB (IPA)          Ilmu Hukum - UNAIR
# ..                      ...               ...                         ...
# 164  Matematika  - UI (IPA)  Stei - ITB (IPA)  Teknik Informatika - UNPAD
# 165  Matematika  - UI (IPA)  Stei - ITB (IPA)           Akuntansi - UNAIR
# 166  Matematika  - UI (IPA)  Stei - ITB (IPA)             Psikologi - UGM
# 167  Matematika  - UI (IPA)  Stei - ITB (IPA)          Statistika - UNPAD
# 168  Matematika  - UI (IPA)  Stei - ITB (IPA)             Psikologi - UGM
#
# [169 rows x 11 columns]

# %%
adaw = pd.read_csv("Hasil Prediksi Benar.csv")

adaw
# Out:
#     Unnamed: 0                                            tebakan  \
# 0            0                          Ilmu Filsafat - UGM (IPS)
# 1            1                               Psikologi - UI (IPS)
# 2            2               Teknologi Hasil Perikanan - UB (IPA)
# 3            3                              Akuntansi - UGM (IPS)
# 4            4                       Pendidikan Dokter - UB (IPA)
# 5            5                                  Fmipa - ITB (IPA)
# 6            6                    Budidaya Perairan - UNAIR (IPA)
# 7            7                                   Fitb - ITB (IPA)
# 8            8                             Matematika  - UI (IPA)
# 9            9                        Ilmu Keperawatan - UI (IPA)
# 10          10                             Matematika  - UI (IPA)
# 11          11                             Matematika  - UI (IPA)
# 12          12                  Hubungan Masyarakat - UNPAD (IPS)
# 13          13                              Geofisika - UGM (IPA)
# 14          14                                   Gizi - UGM (IPA)
# 15          15                 Manajemen Komunikasi - UNPAD (IPS)
# 16          16                               Arkeologi - UI (IPS)
# 17          17                     Teknik Informatika - ITS (IPA)
# 18          18                                   Fitb - ITB (IPA)
# 19          19                             Matematika  - UI (IPA)
# 20          20  Sosial Ekonomi Pertanian (Agrobisnis) - UGM (IPS)
# 21          21                    Budidaya Perairan - UNAIR (IPA)
# 22          22                 Manajemen Komunikasi - UNPAD (IPS)
# 23          23                                  Kimia - ITS (IPA)
# 24          24                        Agroekoteknologi - UB (IPA)
# 25          25                                    Fti - ITB (IPA)
# 26          26                    Kesehatan Masyarakat - UI (IPA)
# 27          27                                 Fisika - ITS (IPA)
# 28          28                              Geofisika - UGM (IPA)
# 29          29                       Pendidikan Dokter - UB (IPA)
# 30          30                                   Fitb - ITB (IPA)
# 31          31                              Astronomi - ITB (IPA)
# 32          32                    Kesehatan Masyarakat - UI (IPA)
# 33          33                 Manajemen Komunikasi - UNPAD (IPS)
# 34          34                            Itb - Sithr - ITB (IPA)
# 35          35              Ilmu Hub. Internasional - UNPAD (IPA)
# 36          36                                   Fitb - ITB (IPA)
# 37          37                                      Hi - UB (IPS)
# 38          38                        Agroekoteknologi - UB (IPA)
# 39          39                       Pend. Apoteker - UNAIR (IPA)
# 40          40                                   Fitb - ITB (IPA)
# 41          41                    Budidaya Perairan - UNAIR (IPA)
# 42          42                  Hubungan Masyarakat - UNPAD (IPS)
# 43          43                              Akuntansi - UGM (IPS)
# 44          44               Teknik Sistem Perkapalan - ITS (IPA)
# 45          45                                  Fmipa - ITB (IPA)
# 46          46                              Peternakan - UB (IPA)
# 47          47                              Akuntansi - UGM (IPS)
# 48          48                     Kedokteran Hewan - UNAIR (IPA)
# 49          49                      Ilmu Peternakan - UNPAD (IPA)
# 50          50                          Jurnalistik - UNPAD (IPS)
# 51          51                                   Fitb - ITB (IPA)
# 52          52                             Statistika - ITS (IPA)
# 53          53                 Hubungan Internasional - UGM (IPS)
# 54          54                   Ilmu Keperawatan  - UNPAD  (IPA)
# 55          55                             Matematika  - UI (IPA)
#
#                                            asli
# 0                           Ilmu Filsafat - UGM
# 1                                Psikologi - UI
# 2                Teknologi Hasil Perikanan - UB
# 3                               Akuntansi - UGM
# 4                        Pendidikan Dokter - UB
# 5                                   Fmipa - ITB
# 6                     Budidaya Perairan - UNAIR
# 7                                    Fitb - ITB
# 8                               Matematika - UI
# 9                         Ilmu Keperawatan - UI
# 10                              Matematika - UI
# 11                              Matematika - UI
# 12                  Hubungan Masyarakat - UNPAD
# 13                              Geofisika - UGM
# 14                                   Gizi - UGM
# 15                 Manajemen Komunikasi - UNPAD
# 16                               Arkeologi - UI
# 17                     Teknik Informatika - ITS
# 18                                   Fitb - ITB
# 19                              Matematika - UI
# 20  Sosial Ekonomi Pertanian (Agrobisnis) - UGM
# 21                    Budidaya Perairan - UNAIR
# 22                 Manajemen Komunikasi - UNPAD
# 23                                  Kimia - ITS
# 24                        Agroekoteknologi - UB
# 25                                    Fti - ITB
# 26                    Kesehatan Masyarakat - UI
# 27                                 Fisika - ITS
# 28                              Geofisika - UGM
# 29                       Pendidikan Dokter - UB
# 30                                   Fitb - ITB
# 31                              Astronomi - ITB
# 32                    Kesehatan Masyarakat - UI
# 33                 Manajemen Komunikasi - UNPAD
# 34                            Itb - Sithr - ITB
# 35              Ilmu Hub. Internasional - UNPAD
# 36                                   Fitb - ITB
# 37                                      Hi - UB
# 38                        Agroekoteknologi - UB
# 39                       Pend. Apoteker - UNAIR
# 40                                   Fitb - ITB
# 41                    Budidaya Perairan - UNAIR
# 42                  Hubungan Masyarakat - UNPAD
# 43                              Akuntansi - UGM
# 44               Teknik Sistem Perkapalan - ITS
# 45                                  Fmipa - ITB
# 46                              Peternakan - UB
# 47                              Akuntansi - UGM
# 48                     Kedokteran Hewan - UNAIR
# 49                      Ilmu Peternakan - UNPAD
# 50                          Jurnalistik - UNPAD
# 51                                   Fitb - ITB
# 52                             Statistika - ITS
# 53                 Hubungan Internasional - UGM
# 54                     Ilmu Keperawatan - UNPAD
# 55                              Matematika - UI
