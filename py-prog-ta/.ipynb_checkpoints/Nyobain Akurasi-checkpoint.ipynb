# %%
# %run Weighting.ipynb
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-watson-data-lab/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.1.18</span>
#         </div>

# %%
nilai_test = pd.read_csv("Splitted Test.csv", index_col = 0)

nilai_test
# Out:
#     Nama Panggilan                       Asal Sekolah Jurusan Sekolah  \
# 212           diah                     sma n banyumas             IPS
# 374           Disa                    SMAN 47 Jakarta             IPA
# 356          NAIDA                        MAN NGANJUK             IPA
# 486          Azura                   SMAN PINTAR RIAU             IPA
# 436           Kiki                SMAN 1 Probolinggo              IPA
# ..             ...                                ...             ...
# 748           Pida                SMA Negeri 1 Gresik             IPA
# 235          Retno                      SMAN 4 BEKASI             IPA
# 392          Agnes  SMA RK BUDI MULIA PEMATANGSIANTAR             IPS
# 218         Shasqi                     SMAN 6 Jakarta             IPS
# 529          Jihan                       SMAN 1 Medan             IPA
#
#     Jenis Sekolah PTN Pilihan I Jurusan Pilihan I di PTN Pilihan I  \
# 212           SMA           UGM                       Bahasa Korea
# 374           SMA         UNPAD                            Farmasi
# 356           SMA         UNDIP                      Ilmu Kelautan
# 486           SMA           ITB                               Fitb
# 436           SMA           ITB                               Fitb
# ..            ...           ...                                ...
# 748           SMA         UNAIR             Pendidikan Dokter Gigi
# 235           SMA            UI                              Kimia
# 392           SMA         UNPAD                              Hukum
# 218           SMA            UI                              Hukum
# 529           SMA           ITB                       Ftsl Ganesha
#
#     Jurusan Pilihan II di PTN Pilihan I PTN Pilihan II  \
# 212                      Sastra Inggris         KOSONG
# 374                                 NaN             UI
# 356                   Budidaya Perairan           UNEJ
# 486                               Fmipa           UNRI
# 436                                Ftsl         KOSONG
# ..                                  ...            ...
# 748                                 NaN         KOSONG
# 235                                 NaN          UNPAD
# 392                                 NaN         KOSONG
# 218                           Manajemen          UNPAD
# 529                                 NaN         KOSONG
#
#     Jurusan Pilihan I di PTN Pilihan II Jurusan Pilihan II di PTN Pilihan II  \
# 212                                 NaN                                  NaN
# 374                             Farmasi                                  NaN
# 356                       Agroteknologi                                  NaN
# 486                              Fisika                               Kosong
# 436                                 NaN                                  NaN
# ..                                  ...                                  ...
# 748                                 NaN                                  NaN
# 235                               Kimia                           Statistika
# 392                                 NaN                                  NaN
# 218                               Hukum                                  NaN
# 529                                 NaN                                  NaN
#
#      ... Rata-rata Matematika Rata-rata Inggris  Rata-rata Indonesia  \
# 212  ...                 83.0              87.0                 86.0
# 374  ...                 83.0              83.0                 83.0
# 356  ...                 82.0              83.0                 84.0
# 486  ...                 87.0              88.0                 85.0
# 436  ...                 97.0              92.0                 90.0
# ..   ...                  ...               ...                  ...
# 748  ...                 87.0              84.0                 86.0
# 235  ...                 85.0              83.0                 87.0
# 392  ...                 85.0              87.0                 80.0
# 218  ...                 80.0              89.0                 85.0
# 529  ...                 90.0              90.0                 89.0
#
#      Rata-rata Fisika  Rata-rata Kimia  Rata-rata Biologi  Rata-rata Ekonomi  \
# 212         86.843464        87.843137          87.058824          92.000000
# 374         83.000000        83.000000          83.000000          83.000000
# 356         82.000000        83.000000          87.000000          82.562857
# 486         91.000000        92.000000          92.000000          87.917424
# 436         87.000000        85.000000          95.000000          86.966970
# ..                ...              ...                ...                ...
# 748         82.000000        86.000000          87.000000          85.211111
# 235         81.000000        95.000000          88.000000          86.145714
# 392         83.198246        85.673434          84.964912          86.000000
# 218         84.493016        85.297674          84.182558          87.000000
# 529         91.000000        93.000000          90.000000          86.950455
#
#      Rata-rata Geografi  Rata-rata Sosiologi  Rata-rata Sejarah
# 212           87.000000            94.000000          89.000000
# 374           83.000000            77.450278          83.000000
# 356           82.700000            83.400000          81.000000
# 486           85.858929            89.898990          88.000000
# 436           85.858929            89.898990          97.000000
# ..                  ...                  ...                ...
# 748           84.793706            85.695971          83.664000
# 235           85.512727            86.930877          83.943883
# 392           81.000000            80.000000          85.000000
# 218           87.000000            84.000000          87.000000
# 529           85.858929            89.898990          93.000000
#
# [270 rows x 22 columns]

# %%
tabel_alternatif = open_tabel("Tabel Alternatif.csv")

tabel_alternatif
# Out:
#             Administrasi Fiskal - UI (IPS)  Administrasi Negara - UNPAD (IPS)  \
# Matematika                       84.000000                          88.500000
# Inggris                          84.000000                          80.500000
# Indonesia                        84.000000                          89.500000
# Fisika                           82.000000                          84.584430
# Kimia                            81.000000                          84.592411
# Biologi                          83.000000                          83.879942
# Ekonomi                          86.145714                          89.000000
# Geografi                         85.512727                          87.500000
# Sosiologi                        86.930877                          85.500000
# Sejarah                          83.943883                          88.000000
#
#             Administrasi Niaga - UI (IPS)  Administrasi Perpajakan - UB (IPS)  \
# Matematika                      85.465625                           92.000000
# Inggris                         83.888667                           86.000000
# Indonesia                       85.246032                           89.000000
# Fisika                          84.493016                           81.956615
# Kimia                           85.297674                           82.397782
# Biologi                         84.182558                           82.827536
# Ekonomi                         86.145714                           91.242143
# Geografi                        85.512727                           91.000000
# Sosiologi                       86.930877                           91.000000
# Sejarah                         83.943883                           93.000000
#
#             Agribisnis - IPB (IPA)  Agroekoteknologi - UB (IPA)  \
# Matematika                  95.000                    81.852143
# Inggris                     90.000                    84.729722
# Indonesia                   88.000                    85.837917
# Fisika                      91.000                    81.739154
# Kimia                       89.000                    82.349446
# Biologi                     90.000                    83.706884
# Ekonomi                     85.000                    83.726429
# Geografi                    81.316                    84.627747
# Sosiologi                      NaN                    85.702500
# Sejarah                     89.000                    85.517917
#
#             Agronomi Dan Holtikultura - IPB (IPA)  \
# Matematika                              91.000000
# Inggris                                 91.000000
# Indonesia                               89.000000
# Fisika                                  89.000000
# Kimia                                   90.000000
# Biologi                                 91.000000
# Ekonomi                                 83.000000
# Geografi                                83.526667
# Sosiologi                                     NaN
# Sejarah                                 82.676471
#
#             Agroteknologi - UNPAD (IPA)  Akuntansi - UGM (IPS)  \
# Matematika                    82.500000              91.625000
# Inggris                       82.750000              90.875000
# Indonesia                     84.000000              89.875000
# Fisika                        80.500000              89.437576
# Kimia                         81.500000              88.716106
# Biologi                       83.250000              89.695798
# Ekonomi                       82.062045              92.250000
# Geografi                      81.926031              88.959803
# Sosiologi                     81.331846              91.872475
# Sejarah                       81.000669              90.581317
#
#             Akutansi - UI (IPS)  ...  \
# Matematika            44.693125  ...
# Inggris               54.255467  ...
# Indonesia             85.000000  ...
# Fisika                87.000000  ...
# Kimia                 74.300000  ...
# Biologi               83.000000  ...
# Ekonomi               86.145714  ...
# Geografi              85.512727  ...
# Sosiologi             86.930877  ...
# Sejarah               85.000000  ...
#
#             Teknologi Dan Manajemen Perikanan Budidaya - IPB (IPS)  \
# Matematika                                          84.500000
# Inggris                                             85.500000
# Indonesia                                           86.500000
# Fisika                                              84.500000
# Kimia                                               84.000000
# Biologi                                             84.000000
# Ekonomi                                             84.422980
# Geografi                                            85.388333
# Sosiologi                                                 NaN
# Sejarah                                             85.958333
#
#             Teknologi Hasil Perikanan - UB (IPA)  \
# Matematika                             82.000000
# Inggris                                91.000000
# Indonesia                              89.000000
# Fisika                                 80.000000
# Kimia                                  79.000000
# Biologi                                83.000000
# Ekonomi                                88.726429
# Geografi                               84.808608
# Sosiologi                              84.850000
# Sejarah                                83.000000
#
#             Teknologi Industri Hasil Perikanan - UNAIR (IPA)  \
# Matematika                                         85.000000
# Inggris                                            84.000000
# Indonesia                                          86.000000
# Fisika                                             83.000000
# Kimia                                              81.000000
# Biologi                                            86.000000
# Ekonomi                                            85.211111
# Geografi                                           84.793706
# Sosiologi                                          85.695971
# Sejarah                                            84.000000
#
#             Teknologi Industri Pertanian - IPB (IPA)  \
# Matematika                                 85.410699
# Inggris                                    84.775000
# Indonesia                                  86.789540
# Fisika                                     85.810345
# Kimia                                      84.825000
# Biologi                                    86.391667
# Ekonomi                                    84.961490
# Geografi                                   83.645000
# Sosiologi                                        NaN
# Sejarah                                    85.088235
#
#             Teknologi Informasi - UGM (IPA)  Teknologi Pangan - IPB (IPA)  \
# Matematika                        92.000000                     92.000000
# Inggris                           90.000000                     88.000000
# Indonesia                         93.000000                     86.000000
# Fisika                            89.000000                     92.000000
# Kimia                             89.000000                     85.000000
# Biologi                           93.000000                     86.000000
# Ekonomi                           89.837895                     85.845960
# Geografi                          88.094322                     87.250000
# Sosiologi                         90.363636                           NaN
# Sejarah                           91.000000                     85.916667
#
#             Televisi & Film - UNPAD (IPS)  Tin - IPB (IPA)  Tip - UGM (IPA)  \
# Matematika                      85.000000            90.00        87.000000
# Inggris                         85.500000            83.00        94.000000
# Indonesia                       86.500000            89.00        80.000000
# Fisika                          84.584430            88.00        86.000000
# Kimia                           84.592411            88.00        87.000000
# Biologi                         83.879942            89.00        86.000000
# Ekonomi                         86.000000            83.00        89.837895
# Geografi                        86.500000            87.25        88.094322
# Sosiologi                       85.500000              NaN        90.363636
# Sejarah                         86.500000            88.00        88.650538
#
#             Tv & Film - UNPAD (IPS)
# Matematika                85.000000
# Inggris                   85.000000
# Indonesia                 84.000000
# Fisika                    84.584430
# Kimia                     84.592411
# Biologi                   83.879942
# Ekonomi                   86.000000
# Geografi                  87.000000
# Sosiologi                 85.000000
# Sejarah                   85.000000
#
# [10 rows x 162 columns]

# %%
pilihan_jurusan = get_jurusan(tabel_alternatif)

pilihan_jurusan
# Out:
# ['Administrasi Fiskal - UI (IPS)',
#  'Administrasi Negara - UNPAD (IPS)',
#  'Administrasi Niaga - UI (IPS)',
#  'Administrasi Perpajakan - UB (IPS)',
#  'Agribisnis - IPB (IPA)',
#  'Agroekoteknologi - UB (IPA)',
#  'Agronomi Dan Holtikultura - IPB (IPA)',
#  'Agroteknologi - UNPAD (IPA)',
#  'Akuntansi - UGM (IPS)',
#  'Akutansi - UI (IPS)',
#  'Antropologi - UNAIR (IPA)',
#  'Antropologi Sosial - UB (IPS)',
#  'Apoteker - UNAIR (IPA)',
#  'Arkeologi - UI (IPA)',
#  'Arsitektur - ITB (IPA)',
#  'Arsitektur Lansekap - IPB (IPA)',
#  'Astronomi - ITB (IPA)',
#  'Biokimia - IPB (IPA)',
#  'Biologi - ITS (IPA)',
#  'Budidaya Perairan - UNAIR (IPA)',
#  'Desain Interior - ITS (IPS)',
#  'Ekonomi Dan Studi Pembangunan - IPB (IPS)',
#  'Ekonomi Islam - UB (IPS)',
#  'Ekonomi Islam  - UNPAD (IPS)',
#  'Ekonomi Pembangunan - IPB (IPS)',
#  'Elektro - ITB (IPA)',
#  'Fakultas Kedokteran Gigi - UNAIR (IPA)',
#  'Fakultas Kedokteran Hewan - IPB (IPA)',
#  'Fakultas Teknik Industri - ITB (IPA)',
#  'Farmasi - UI (IPA)',
#  'Fisika - IPB (IPA)',
#  'Fiskal - UI (IPS)',
#  'Fitb - ITB (IPA)',
#  'Fkg - UGM (IPA)',
#  'Fmipa - ITB (IPA)',
#  'Fmipa Fisika - UB (IPA)',
#  'Fmipa- Ilmu Kimia - UNPAD (IPA)',
#  'Fsrd - ITB (IPS)',
#  'Geofisika - UGM (IPA)',
#  'Geofisika  - UI (IPA)',
#  'Gizi - UGM (IPA)',
#  'Hi - UB (IPS)',
#  'Hubungan Internasional - UGM (IPS)',
#  'Hubungan Masyarakat - UNPAD (IPS)',
#  'Hukum - UB (IPS)',
#  'Humas - UNPAD (IPS)',
#  'Ikk - IPB (IPA)',
#  'Ilmu Adm. Fiskal - UI (IPS)',
#  'Ilmu Administrasi Bisnis - UNPAD (IPS)',
#  'Ilmu Administrasi Negara - UI (IPS)',
#  'Ilmu Administrasi Publik - UB (IPS)',
#  'Ilmu Dan Teknologi Kelautan - IPB (IPA)',
#  'Ilmu Dan Teknologi Pangan - UB (IPA)',
#  'Ilmu Ekonomi - UGM (IPS)',
#  'Ilmu Ekonomi Islam - UI (IPS)',
#  'Ilmu Filsafat - UGM (IPS)',
#  'Ilmu Gizi - IPB (IPA)',
#  'Ilmu Hub. Internasional - UNPAD (IPA)',
#  'Ilmu Hubungan Internasional - UI (IPS)',
#  'Ilmu Hukum - UB (IPS)',
#  'Ilmu Kelautan - UNDIP (IPA)',
#  'Ilmu Keluarga Dan Konsumen - IPB (IPA)',
#  'Ilmu Keperawatan - UI (IPA)',
#  'Ilmu Keperawatan  - UNPAD  (IPA)',
#  'Ilmu Kesehatan Masyarakat - UI (IPA)',
#  'Ilmu Komputer - IPB (IPA)',
#  'Ilmu Komunikasi - UB (IPS)',
#  'Ilmu Peternakan - UNPAD (IPA)',
#  'Ilmu Politik - UB (IPS)',
#  'Ilmu Sejarah - UI (IPA)',
#  'Ilmu Sosiologi - UNPAD (IPS)',
#  'Ilmu Teknologi Pangan - IPB (IPA)',
#  'Itb - Sithr - ITB (IPA)',
#  'Jurnalistik - UNPAD (IPS)',
#  'Kedokteran - UI (IPA)',
#  'Kedokteran  - UNAIR (IPA)',
#  'Kedokteran Gigi - UGM (IPA)',
#  'Kedokteran Hewan - IPB (IPA)',
#  'Kehutanan - UGM (IPA)',
#  'Kesehatan Masyarakat - UI (IPA)',
#  'Kesehatan Masyarakat (Pdd Banyuwangi) - UNAIR (IPA)',
#  'Kesejahteraan Sosial - UI (IPS)',
#  'Kimia - IPB (IPA)',
#  'Kimia  - UI (IPA)',
#  'Kimia,  - UNPAD (IPA)',
#  'Komunikasi - UI (IPS)',
#  'Komunikasi Dan Pengembangan Masyarakat - IPB (IPS)',
#  'Kriminologi - UI (IPS)',
#  'Manajemen - IPB (IPS)',
#  'Manajemen Bisnis - ITS (IPS)',
#  'Manajemen Dan Kebijakan Publik (An) - UGM (IPS)',
#  'Manajemen Hutan - IPB (IPS)',
#  'Manajemen Komunikasi - UNPAD (IPS)',
#  'Manajemen Sd Perairan - UNDIP (IPS)',
#  'Matematika - IPB (IPA)',
#  'Matematika  - UI (IPA)',
#  'Matematika (Fak. Matematika & Ilmu Pengetahuan Alam) - ITB (IPA)',
#  'Menejemen - UNAIR  (IPA)',
#  'Meteorologi Terapan - IPB (IPA)',
#  'Mipa Geologi - UI (IPA)',
#  'Mipa Kimia - UB (IPA)',
#  'Nutrisi & Teknologi Pakan - IPB (IPA)',
#  'Oceanografi - UNDIP (IPA)',
#  'Pembangunan Wilayah - UGM (IPA)',
#  'Pend. Apoteker - UNAIR (IPA)',
#  'Pendidikan Dokter - UB (IPA)',
#  'Pendidikan Dokter Gigi - UNAIR (IPA)',
#  'Perencanaan Wilayah & Kota - UB (IPA)',
#  'Perencanaan Wilayah Dan Kota - ITS (IPA)',
#  'Perikanan - IPB (IPA)',
#  'Peternakan - UB (IPA)',
#  'Proteksi Tanaman - IPB (IPA)',
#  'Psdk - UGM (IPS)',
#  'Psikologi - UI (IPS)',
#  'Psikologi  - UGM (IPS)',
#  'S-1 Teknik Informatika - ITS (IPA)',
#  'Sappk - ITB (IPA)',
#  'Sbm - ITB (IPS)',
#  'Silvikultur - IPB (IPA)',
#  'Sistem Informasi - ITS (IPA)',
#  'Sith - Rekayasa - ITB (IPA)',
#  'Sosial Ekonomi Pertanian (Agrobisnis) - UGM (IPS)',
#  'Sosiologi - UB (IPS)',
#  'Sosiologi Murni - UNAIR (IPS)',
#  'Statistika - IPB (IPA)',
#  'Stei - ITB (IPA)',
#  'Tehnik Sipil - UGM (IPA)',
#  'Teknik Elektro - ITS (IPA)',
#  'Teknik Fisika - UGM (IPA)',
#  'Teknik Geodesi - UNDIP (IPA)',
#  'Teknik Geologi - UGM (IPA)',
#  'Teknik Geologi  - UNPAD (IPA)',
#  'Teknik Industri - ITB (IPA)',
#  'Teknik Industri Pertanian - UGM (IPA)',
#  'Teknik Informatika - ITS (IPA)',
#  'Teknik Kimia - ITB (IPA)',
#  'Teknik Komputer - ITS (IPA)',
#  'Teknik Lingkungan - UB (IPA)',
#  'Teknik Mesin - ITS (IPA)',
#  'Teknik Mesin Dan Biosistem - IPB (IPA)',
#  'Teknik Metalurgi & Material - UI (IPA)',
#  'Teknik Multimedia Dan Jaringan - ITS (IPA)',
#  'Teknik Nuklir - UGM (IPA)',
#  'Teknik Pengairan - UB (IPA)',
#  'Teknik Perkapalan - ITS (IPA)',
#  'Teknik Pertanian - UGM (IPA)',
#  'Teknik Sipil - ITB (IPA)',
#  'Teknik Sipil Dan Lingkungan - IPB (IPA)',
#  'Teknik Sipil Lingkungan - ITB (IPA)',
#  'Teknik Sistem Perkapalan - ITS (IPA)',
#  'Teknobiomedik - UNAIR (IPA)',
#  'Teknologi Bioproses - UI (IPA)',
#  'Teknologi Dan Manajemen Perikanan Budidaya - IPB (IPS)',
#  'Teknologi Hasil Perikanan - UB (IPA)',
#  'Teknologi Industri Hasil Perikanan - UNAIR (IPA)',
#  'Teknologi Industri Pertanian - IPB (IPA)',
#  'Teknologi Informasi - UGM (IPA)',
#  'Teknologi Pangan - IPB (IPA)',
#  'Televisi & Film - UNPAD (IPS)',
#  'Tin - IPB (IPA)',
#  'Tip - UGM (IPA)',
#  'Tv & Film - UNPAD (IPS)']

# %%
mean = get_mean(tabel_alternatif)
std = get_std(tabel_alternatif)

# %%
bener = 0
aw = list()
for test_index in nilai_test.index:
#assign nilai IPA/IPS
    try:
        if nilai_test["Jurusan Sekolah"][test_index].casefold() == "ipa":
            nilai = [
                nilai_test["Rata-rata Matematika"][test_index],
                nilai_test["Rata-rata Inggris"][test_index],
                nilai_test["Rata-rata Indonesia"][test_index],
                nilai_test["Rata-rata Fisika"][test_index],
                nilai_test["Rata-rata Kimia"][test_index],
                nilai_test["Rata-rata Biologi"][test_index],
                0,
                0,
                0,
                0,
            ]
        elif nilai_test["Jurusan Sekolah"][test_index].casefold() == "ips":
            nilai = [
                0,
                nilai_test["Rata-rata Inggris"][test_index],
                nilai_test["Rata-rata Indonesia"][test_index],
                0,
                0,
                0,
                nilai_test["Rata-rata Ekonomi"][test_index],
                nilai_test["Rata-rata Geografi"][test_index],
                nilai_test["Rata-rata Sosiologi"][test_index],
                nilai_test["Rata-rata Sejarah"][test_index],
            ]
    except AttributeError:
        continue

    #Mendapatkan nilai2 parameter yang hendak digunakan
    params = get_params(mean, nilai, std)

    #Menambahkan kolom parameter ke tabel_alternatif
    tabel_alternatif = add_parameter(params, tabel_alternatif)

    #Mencari nilai fungsi preferensi gaussian
    fp_gaussian = fungsi_preferensi_gaussian(tabel_alternatif)

    #Menghitung index preferensi global
    index_preferensi_global = idx_pref_global1(fp_gaussian, f'{nilai_test["Jurusan Diterima"][test_index]} - {nilai_test["PTN Diterima"][test_index]}',weight)

    #Menghitung entering flow
    e_flow = entering_flow(pilihan_jurusan, index_preferensi_global)

    #Menghitung leaving flow
    l_flow = leaving_flow(pilihan_jurusan, index_preferensi_global)

    #Menghitung net flow
    n_flow = net_flow(pilihan_jurusan, e_flow, l_flow)

    #Mendapatkan Hasil Outrank
    hasil_outrank = sorted(n_flow.items(), key = lambda kv:(kv[1], kv[0]), reverse = True)

    tab = dict()

    rank = list()
    jurusan = list()
    net = list()

    for i in range(len(hasil_outrank)):
        rank.append(i+1)
        jurusan.append(hasil_outrank[i][0])
        net.append(hasil_outrank[i][1])

    tab["Jurusan"] = jurusan
    tab["Net Flow"] = net

    tabel_hasil = pd.DataFrame(tab, index=rank)
    aw.append((tabel_hasil["Jurusan"][1], f'{nilai_test["Jurusan Diterima"][test_index]} - {nilai_test["PTN Diterima"][test_index]}'))

    #Menghitung yang benar
    pil_satu = tabel_hasil["Jurusan"][1]
    pref_jurusan = pil_satu.split(" - ")[0] #Get Nama Jurusan
    if nilai_test["Jurusan Sekolah"][test_index].casefold() == "IPA":
        pref_univ = pil_satu.split(" - ")[1].replace(" (IPA)", "") #Get Nama Univ
    else:
        pref_univ = pil_satu.split(" - ")[1].replace(" (IPS)", "") #Get Nama Univ

    if pref_jurusan.casefold() == nilai_test["Jurusan Diterima"][test_index].casefold()\
    and pref_univ.casefold() == nilai_test["PTN Diterima"][test_index].casefold():
        bener += 1

#     aw += 1
#     if aw == 162:
#         break

# %%
bener
# Out:
# 14

# %%
bener/162 * 100
# Out:
# 8.641975308641975

# %%
tul = 0
for i, val in enumerate(aw):
    if val[0].replace(" (IPA)", "") == val[1]:
        print(i, val)
        tul+=1
    elif val[0].replace(" (IPS)", "") == val[1]:
        print(i, val)
        tul+=1
        
print()
print(f"Akurasi = {tul/162 * 100}%")
# Out:
# 2 ('Ilmu Kelautan - UNDIP (IPA)', 'Ilmu Kelautan - UNDIP')
# 5 ('Ilmu Keperawatan - UI (IPA)', 'Ilmu Keperawatan - UI')
# 13 ('Geofisika - UGM (IPA)', 'Geofisika - UGM')
# 14 ('Ilmu Hukum - UB (IPS)', 'Ilmu Hukum - UB')
# 20 ('Teknik Elektro - ITS (IPA)', 'Teknik Elektro - ITS')
# 21 ('Stei - ITB (IPA)', 'Stei - ITB')
# 28 ('Kedokteran - UI (IPA)', 'Kedokteran - UI')
# 31 ('Agroekoteknologi - UB (IPA)', 'Agroekoteknologi - UB')
# 34 ('Kimia,  - UNPAD (IPA)', 'Kimia,  - UNPAD')
# 37 ('Teknik Informatika - ITS (IPA)', 'Teknik Informatika - ITS')
# 40 ('Budidaya Perairan - UNAIR (IPA)', 'Budidaya Perairan - UNAIR')
# 46 ('Perikanan - IPB (IPA)', 'Perikanan - IPB')
# 51 ('Hubungan Masyarakat - UNPAD (IPS)', 'Hubungan Masyarakat - UNPAD')
# 56 ('Teknik Sipil Dan Lingkungan - IPB (IPA)', 'Teknik Sipil Dan Lingkungan - IPB')
# 58 ('Fmipa - ITB (IPA)', 'Fmipa - ITB')
# 59 ('Fitb - ITB (IPA)', 'Fitb - ITB')
# 60 ('Perencanaan Wilayah Dan Kota - ITS (IPA)', 'Perencanaan Wilayah Dan Kota - ITS')
# 62 ('Arkeologi - UI (IPA)', 'Arkeologi - UI')
# 68 ('Akuntansi - UGM (IPS)', 'Akuntansi - UGM')
# 69 ('Ilmu Keluarga Dan Konsumen - IPB (IPA)', 'Ilmu Keluarga Dan Konsumen - IPB')
# 70 ('Geofisika - UGM (IPA)', 'Geofisika - UGM')
# 71 ('Ilmu Peternakan - UNPAD (IPA)', 'Ilmu Peternakan - UNPAD')
# 74 ('Desain Interior - ITS (IPS)', 'Desain Interior - ITS')
# 76 ('Kimia - IPB (IPA)', 'Kimia - IPB')
# 79 ('Teknik Geodesi - UNDIP (IPA)', 'Teknik Geodesi - UNDIP')
# 80 ('Akuntansi - UGM (IPS)', 'Akuntansi - UGM')
# 87 ('Manajemen Dan Kebijakan Publik (An) - UGM (IPS)', 'Manajemen Dan Kebijakan Publik (An) - UGM')
# 91 ('Fitb - ITB (IPA)', 'Fitb - ITB')
# 92 ('Kriminologi - UI (IPS)', 'Kriminologi - UI')
# 95 ('Psikologi - UI (IPS)', 'Psikologi - UI')
# 98 ('Desain Interior - ITS (IPS)', 'Desain Interior - ITS')
# 99 ('Teknik Komputer - ITS (IPA)', 'Teknik Komputer - ITS')
# 103 ('Fitb - ITB (IPA)', 'Fitb - ITB')
# 104 ('Fitb - ITB (IPA)', 'Fitb - ITB')
# 112 ('Meteorologi Terapan - IPB (IPA)', 'Meteorologi Terapan - IPB')
# 113 ('Apoteker - UNAIR (IPA)', 'Apoteker - UNAIR')
# 114 ('Teknologi Industri Pertanian - IPB (IPA)', 'Teknologi Industri Pertanian - IPB')
# 115 ('Akuntansi - UGM (IPS)', 'Akuntansi - UGM')
# 119 ('Akuntansi - UGM (IPS)', 'Akuntansi - UGM')
# 121 ('Ilmu Hubungan Internasional - UI (IPS)', 'Ilmu Hubungan Internasional - UI')
# 129 ('Teknik Sipil Lingkungan - ITB (IPA)', 'Teknik Sipil Lingkungan - ITB')
# 130 ('Stei - ITB (IPA)', 'Stei - ITB')
# 131 ('Fitb - ITB (IPA)', 'Fitb - ITB')
# 134 ('Ikk - IPB (IPA)', 'Ikk - IPB')
# 142 ('Fmipa - ITB (IPA)', 'Fmipa - ITB')
# 151 ('Pendidikan Dokter Gigi - UNAIR (IPA)', 'Pendidikan Dokter Gigi - UNAIR')
# 157 ('Mipa Geologi - UI (IPA)', 'Mipa Geologi - UI')
# 158 ('Teknik Sipil - ITB (IPA)', 'Teknik Sipil - ITB')
# 161 ('Ilmu Komunikasi - UB (IPS)', 'Ilmu Komunikasi - UB')
# 166 ('Teknik Industri Pertanian - UGM (IPA)', 'Teknik Industri Pertanian - UGM')
# 175 ('Ilmu Adm. Fiskal - UI (IPS)', 'Ilmu Adm. Fiskal - UI')
# 183 ('Teknik Mesin - ITS (IPA)', 'Teknik Mesin - ITS')
# 184 ('Pendidikan Dokter Gigi - UNAIR (IPA)', 'Pendidikan Dokter Gigi - UNAIR')
#
# Akurasi = 32.71604938271605%
