# %%
import blgndr
import pandas as pd

# %%
tabel_alternatif = blgndr.clean()

# %%
tabel_alternatif
# Out:
#             ADMINISTRASI NIAGA - UI (IPS)  SISTEM INFORMASI - UI (IPA)  \
# Biologi                         84.769668                    89.000000
# Sosiologi                       85.293746                    85.293746
# Ekonomi                         84.867923                    84.867923
# Fisika                          84.698593                    88.000000
# Indonesia                       85.393215                    85.000000
# Geografi                        84.839303                    87.000000
# Inggris                         84.697708                    83.000000
# Kimia                           85.152057                    88.000000
# Matematika                      84.236315                    91.000000
#
#             HUKUM - UI (IPS)  ILMU SEJARAH - UI (IPS)  FISIKA - UI (IPA)  \
# Biologi            84.769668                84.769668          84.476967
# Sosiologi          89.323436                85.431249          85.183798
# Ekonomi            88.966981                85.955974          84.890861
# Fisika             84.698593                82.465729          87.369859
# Indonesia          87.098304                86.464405          84.439321
# Geografi           86.709826                84.946434          84.727782
# Inggris            85.424427                83.899236          84.969771
# Kimia              85.152057                85.152057          83.915206
# Matematika         82.559079                82.745438          86.123632
#
#             ILMU KOMUNIKASI - UI (IPS)  FARMASI - UI (IPA)  \
# Biologi                      84.769668           84.769668
# Sosiologi                    88.431249           85.293746
# Ekonomi                      86.666667           84.867923
# Fisika                       84.698593           84.698593
# Indonesia                    87.000000           85.393215
# Geografi                     84.666667           84.839303
# Inggris                      86.232569           84.697708
# Kimia                        85.152057           85.152057
# Matematika                   83.666667           84.236315
#
#             TEKNIK KIMIA - UI (IPA)  KEDOKTERAN GIGI - UI (IPA)  \
# Biologi                   86.500000                   85.000000
# Sosiologi                 85.293746                   85.293746
# Ekonomi                   90.433962                   84.897180
# Fisika                    91.000000                   84.800000
# Indonesia                 92.000000                   86.200000
# Geografi                  84.839303                   84.839303
# Inggris                   86.000000                   85.400000
# Kimia                     93.500000                   85.800000
# Matematika                90.000000                   88.400000
#
#             MATEMATIKA - UI (IPA)  ...  ANTROPOLOGI SOSIAL - UNAIR (IPS)  \
# Biologi                 85.905359  ...                         84.769668
# Sosiologi               85.940862  ...                         84.146873
# Ekonomi                 84.691181  ...                         83.933962
# Fisika                  87.284507  ...                         84.698593
# Indonesia               86.261017  ...                         86.196607
# Geografi                84.839303  ...                         83.919652
# Inggris                 86.592131  ...                         85.348854
# Kimia                   87.088620  ...                         85.152057
# Matematika              91.769231  ...                         78.906746
#
#             PEND. APOTEKER - UNAIR (IPA)  PEND. DOKTER - UNAIR (IPA)  \
# Biologi                        91.000000                   98.000000
# Sosiologi                      85.293746                   85.293746
# Ekonomi                        84.867923                   84.867923
# Fisika                         91.000000                   98.000000
# Indonesia                      90.000000                   93.000000
# Geografi                       84.839303                   84.839303
# Inggris                        90.000000                   93.000000
# Kimia                          94.000000                   98.000000
# Matematika                     92.000000                   93.000000
#
#             KIMIA - UNAIR (IPA)  FAKULTAS KEDOKTERAN GIGI - UNAIR (IPA)  \
# Biologi               89.000000                               88.000000
# Sosiologi             85.293746                               85.293746
# Ekonomi               88.000000                               84.867923
# Fisika                91.000000                               88.000000
# Indonesia             87.000000                               97.000000
# Geografi              84.839303                               84.839303
# Inggris               91.000000                               91.000000
# Kimia                 90.000000                               88.000000
# Matematika            87.000000                               90.000000
#
#             FISIKA - UNAIR (IPA)  ILMU KESEHATAN MASYARAKAT - UNAIR (IPA)  \
# Biologi                73.000000                                92.000000
# Sosiologi              85.293746                                85.194267
# Ekonomi                76.014208                                82.000000
# Fisika                 73.000000                                90.000000
# Indonesia              73.000000                                88.000000
# Geografi               84.839303                                84.839303
# Inggris                73.000000                                83.000000
# Kimia                  73.000000                                87.000000
# Matematika             65.300000                                85.000000
#
#             STATISTIKA - UNAIR (IPA)  KEDOKTERAN GIGI - UNAIR (IPA)  \
# Biologi                    84.769668                      84.769668
# Sosiologi                  85.293746                      85.293746
# Ekonomi                    84.867923                      84.867923
# Fisika                     84.698593                      84.698593
# Indonesia                  85.393215                      85.393215
# Geografi                   84.839303                      84.839303
# Inggris                    84.697708                      84.697708
# Kimia                      85.152057                      85.152057
# Matematika                 84.236315                      84.236315
#
#             PEND. NERS - UNAIR (IPA)
# Biologi                    84.769668
# Sosiologi                  85.293746
# Ekonomi                    84.867923
# Fisika                     84.698593
# Indonesia                  85.393215
# Geografi                   84.839303
# Inggris                    84.697708
# Kimia                      85.152057
# Matematika                 84.236315
#
# [9 rows x 142 columns]

# %%
decision_matrix = blgndr.getDecisionMatrix(tabel_alternatif)

# %%
decision_matrix
# Out:
#                                                                            Biologi  \
# ADMINISTRASI NIAGA - UI (IPS)             [0.8476966770093084, 0.1523033229906916]
# SISTEM INFORMASI - UI (IPA)                            [0.89, 0.10999999999999999]
# HUKUM - UI (IPS)                          [0.8476966770093084, 0.1523033229906916]
# ILMU SEJARAH - UI (IPS)                   [0.8476966770093084, 0.1523033229906916]
# FISIKA - UI (IPA)                        [0.8447696677009309, 0.15523033229906913]
# ...                                                                            ...
# FISIKA - UNAIR (IPA)                                                  [0.73, 0.27]
# ILMU KESEHATAN MASYARAKAT - UNAIR (IPA)                [0.92, 0.07999999999999996]
# STATISTIKA - UNAIR (IPA)                  [0.8476966770093084, 0.1523033229906916]
# KEDOKTERAN GIGI - UNAIR (IPA)             [0.8476966770093084, 0.1523033229906916]
# PEND. NERS - UNAIR (IPA)                  [0.8476966770093084, 0.1523033229906916]
#
#                                                                          Sosiologi  \
# ADMINISTRASI NIAGA - UI (IPS)            [0.8529374595544092, 0.14706254044559075]
# SISTEM INFORMASI - UI (IPA)              [0.8529374595544092, 0.14706254044559075]
# HUKUM - UI (IPS)                         [0.8932343648886024, 0.10676563511139758]
# ILMU SEJARAH - UI (IPS)                  [0.8543124865181365, 0.14568751348186348]
# FISIKA - UI (IPA)                             [0.85183798032515, 0.14816201967485]
# ...                                                                            ...
# FISIKA - UNAIR (IPA)                     [0.8529374595544092, 0.14706254044559075]
# ILMU KESEHATAN MASYARAKAT - UNAIR (IPA)  [0.8519426672618162, 0.14805733273818378]
# STATISTIKA - UNAIR (IPA)                 [0.8529374595544092, 0.14706254044559075]
# KEDOKTERAN GIGI - UNAIR (IPA)            [0.8529374595544092, 0.14706254044559075]
# PEND. NERS - UNAIR (IPA)                 [0.8529374595544092, 0.14706254044559075]
#
#                                                                            Ekonomi  \
# ADMINISTRASI NIAGA - UI (IPS)            [0.8486792322169479, 0.15132076778305215]
# SISTEM INFORMASI - UI (IPA)              [0.8486792322169479, 0.15132076778305215]
# HUKUM - UI (IPS)                          [0.889669808054237, 0.11033019194576299]
# ILMU SEJARAH - UI (IPS)                  [0.8595597440723161, 0.14044025592768394]
# FISIKA - UI (IPA)                        [0.8489086129273776, 0.15109138707262237]
# ...                                                                            ...
# FISIKA - UNAIR (IPA)                     [0.7601420765027322, 0.23985792349726776]
# ILMU KESEHATAN MASYARAKAT - UNAIR (IPA)                [0.82, 0.18000000000000005]
# STATISTIKA - UNAIR (IPA)                 [0.8486792322169479, 0.15132076778305215]
# KEDOKTERAN GIGI - UNAIR (IPA)            [0.8486792322169479, 0.15132076778305215]
# PEND. NERS - UNAIR (IPA)                 [0.8486792322169479, 0.15132076778305215]
#
#                                                                             Fisika  \
# ADMINISTRASI NIAGA - UI (IPS)            [0.8469859299691537, 0.15301407003084633]
# SISTEM INFORMASI - UI (IPA)                                           [0.88, 0.12]
# HUKUM - UI (IPS)                         [0.8469859299691537, 0.15301407003084633]
# ILMU SEJARAH - UI (IPS)                  [0.8246572866461024, 0.17534271335389762]
# FISIKA - UI (IPA)                        [0.8736985929969154, 0.12630140700308456]
# ...                                                                            ...
# FISIKA - UNAIR (IPA)                                                  [0.73, 0.27]
# ILMU KESEHATAN MASYARAKAT - UNAIR (IPA)                 [0.9, 0.09999999999999998]
# STATISTIKA - UNAIR (IPA)                 [0.8469859299691537, 0.15301407003084633]
# KEDOKTERAN GIGI - UNAIR (IPA)            [0.8469859299691537, 0.15301407003084633]
# PEND. NERS - UNAIR (IPA)                 [0.8469859299691537, 0.15301407003084633]
#
#                                                                          Indonesia  \
# ADMINISTRASI NIAGA - UI (IPS)            [0.8539321488941178, 0.14606785110588216]
# SISTEM INFORMASI - UI (IPA)                            [0.85, 0.15000000000000002]
# HUKUM - UI (IPS)                         [0.8709830372235294, 0.12901696277647057]
# ILMU SEJARAH - UI (IPS)                  [0.8646440496313725, 0.13535595036862746]
# FISIKA - UI (IPA)                        [0.8443932148894118, 0.15560678511058823]
# ...                                                                            ...
# FISIKA - UNAIR (IPA)                                                  [0.73, 0.27]
# ILMU KESEHATAN MASYARAKAT - UNAIR (IPA)                               [0.88, 0.12]
# STATISTIKA - UNAIR (IPA)                 [0.8539321488941178, 0.14606785110588216]
# KEDOKTERAN GIGI - UNAIR (IPA)            [0.8539321488941178, 0.14606785110588216]
# PEND. NERS - UNAIR (IPA)                 [0.8539321488941178, 0.14606785110588216]
#
#                                                                           Geografi  \
# ADMINISTRASI NIAGA - UI (IPS)             [0.8483930315858026, 0.1516069684141974]
# SISTEM INFORMASI - UI (IPA)                                           [0.87, 0.13]
# HUKUM - UI (IPS)                         [0.8670982578964507, 0.13290174210354933]
# ILMU SEJARAH - UI (IPS)                  [0.8494643438619341, 0.15053565613806585]
# FISIKA - UI (IPA)                         [0.8472778248127646, 0.1527221751872354]
# ...                                                                            ...
# FISIKA - UNAIR (IPA)                      [0.8483930315858026, 0.1516069684141974]
# ILMU KESEHATAN MASYARAKAT - UNAIR (IPA)   [0.8483930315858026, 0.1516069684141974]
# STATISTIKA - UNAIR (IPA)                  [0.8483930315858026, 0.1516069684141974]
# KEDOKTERAN GIGI - UNAIR (IPA)             [0.8483930315858026, 0.1516069684141974]
# PEND. NERS - UNAIR (IPA)                  [0.8483930315858026, 0.1516069684141974]
#
#                                                                            Inggris  \
# ADMINISTRASI NIAGA - UI (IPS)             [0.8469770826702545, 0.1530229173297455]
# SISTEM INFORMASI - UI (IPA)                            [0.83, 0.17000000000000004]
# HUKUM - UI (IPS)                          [0.8542442706675637, 0.1457557293324363]
# ILMU SEJARAH - UI (IPS)                  [0.8389923608900848, 0.16100763910991522]
# FISIKA - UI (IPA)                         [0.8496977082670254, 0.1503022917329746]
# ...                                                                            ...
# FISIKA - UNAIR (IPA)                                                  [0.73, 0.27]
# ILMU KESEHATAN MASYARAKAT - UNAIR (IPA)                [0.83, 0.17000000000000004]
# STATISTIKA - UNAIR (IPA)                  [0.8469770826702545, 0.1530229173297455]
# KEDOKTERAN GIGI - UNAIR (IPA)             [0.8469770826702545, 0.1530229173297455]
# PEND. NERS - UNAIR (IPA)                  [0.8469770826702545, 0.1530229173297455]
#
#                                                                              Kimia  \
# ADMINISTRASI NIAGA - UI (IPS)            [0.8515205714226723, 0.14847942857732765]
# SISTEM INFORMASI - UI (IPA)                                           [0.88, 0.12]
# HUKUM - UI (IPS)                         [0.8515205714226723, 0.14847942857732765]
# ILMU SEJARAH - UI (IPS)                  [0.8515205714226723, 0.14847942857732765]
# FISIKA - UI (IPA)                        [0.8391520571422673, 0.16084794285773274]
# ...                                                                            ...
# FISIKA - UNAIR (IPA)                                                  [0.73, 0.27]
# ILMU KESEHATAN MASYARAKAT - UNAIR (IPA)                               [0.87, 0.13]
# STATISTIKA - UNAIR (IPA)                 [0.8515205714226723, 0.14847942857732765]
# KEDOKTERAN GIGI - UNAIR (IPA)            [0.8515205714226723, 0.14847942857732765]
# PEND. NERS - UNAIR (IPA)                 [0.8515205714226723, 0.14847942857732765]
#
#                                                                         Matematika
# ADMINISTRASI NIAGA - UI (IPS)            [0.8423631545305261, 0.15763684546947387]
# SISTEM INFORMASI - UI (IPA)                            [0.91, 0.08999999999999997]
# HUKUM - UI (IPS)                         [0.8255907886326316, 0.17440921136736842]
# ILMU SEJARAH - UI (IPS)                  [0.8274543848435088, 0.17254561515649125]
# FISIKA - UI (IPA)                        [0.8612363154530526, 0.13876368454694743]
# ...                                                                            ...
# FISIKA - UNAIR (IPA)                                                [0.653, 0.347]
# ILMU KESEHATAN MASYARAKAT - UNAIR (IPA)                [0.85, 0.15000000000000002]
# STATISTIKA - UNAIR (IPA)                 [0.8423631545305261, 0.15763684546947387]
# KEDOKTERAN GIGI - UNAIR (IPA)            [0.8423631545305261, 0.15763684546947387]
# PEND. NERS - UNAIR (IPA)                 [0.8423631545305261, 0.15763684546947387]
#
# [142 rows x 9 columns]

# %%
entropy_matrix = blgndr.getEntropyMatrix(decision_matrix)

# %%
entropy_matrix
# Out:
#                                           Biologi  Sosiologi   Ekonomi  \
# ADMINISTRASI NIAGA - UI (IPS)            0.304607   0.294125  0.302642
# SISTEM INFORMASI - UI (IPA)              0.220000   0.294125  0.302642
# HUKUM - UI (IPS)                         0.304607   0.213531  0.220660
# ILMU SEJARAH - UI (IPS)                  0.304607   0.291375  0.280881
# FISIKA - UI (IPA)                        0.310461   0.296324  0.302183
# ...                                           ...        ...       ...
# FISIKA - UNAIR (IPA)                     0.540000   0.294125  0.479716
# ILMU KESEHATAN MASYARAKAT - UNAIR (IPA)  0.160000   0.296115  0.360000
# STATISTIKA - UNAIR (IPA)                 0.304607   0.294125  0.302642
# KEDOKTERAN GIGI - UNAIR (IPA)            0.304607   0.294125  0.302642
# PEND. NERS - UNAIR (IPA)                 0.304607   0.294125  0.302642
#
#                                            Fisika  Indonesia  Geografi  \
# ADMINISTRASI NIAGA - UI (IPS)            0.306028   0.292136  0.303214
# SISTEM INFORMASI - UI (IPA)              0.240000   0.300000  0.260000
# HUKUM - UI (IPS)                         0.306028   0.258034  0.265803
# ILMU SEJARAH - UI (IPS)                  0.350685   0.270712  0.301071
# FISIKA - UI (IPA)                        0.252603   0.311214  0.305444
# ...                                           ...        ...       ...
# FISIKA - UNAIR (IPA)                     0.540000   0.540000  0.303214
# ILMU KESEHATAN MASYARAKAT - UNAIR (IPA)  0.200000   0.240000  0.303214
# STATISTIKA - UNAIR (IPA)                 0.306028   0.292136  0.303214
# KEDOKTERAN GIGI - UNAIR (IPA)            0.306028   0.292136  0.303214
# PEND. NERS - UNAIR (IPA)                 0.306028   0.292136  0.303214
#
#                                           Inggris     Kimia  Matematika
# ADMINISTRASI NIAGA - UI (IPS)            0.306046  0.296959    0.315274
# SISTEM INFORMASI - UI (IPA)              0.340000  0.240000    0.180000
# HUKUM - UI (IPS)                         0.291511  0.296959    0.348818
# ILMU SEJARAH - UI (IPS)                  0.322015  0.296959    0.345091
# FISIKA - UI (IPA)                        0.300605  0.321696    0.277527
# ...                                           ...       ...         ...
# FISIKA - UNAIR (IPA)                     0.540000  0.540000    0.694000
# ILMU KESEHATAN MASYARAKAT - UNAIR (IPA)  0.340000  0.260000    0.300000
# STATISTIKA - UNAIR (IPA)                 0.306046  0.296959    0.315274
# KEDOKTERAN GIGI - UNAIR (IPA)            0.306046  0.296959    0.315274
# PEND. NERS - UNAIR (IPA)                 0.306046  0.296959    0.315274
#
# [142 rows x 9 columns]

# %%
knowledge_matrix = blgndr.getKnowledgeMatrix(entropy_matrix)

# %%
knowledge_matrix
# Out:
#                                           Biologi  Sosiologi   Ekonomi  \
# ADMINISTRASI NIAGA - UI (IPS)            0.847697   0.852937  0.848679
# SISTEM INFORMASI - UI (IPA)              0.890000   0.852937  0.848679
# HUKUM - UI (IPS)                         0.847697   0.893234  0.889670
# ILMU SEJARAH - UI (IPS)                  0.847697   0.854312  0.859560
# FISIKA - UI (IPA)                        0.844770   0.851838  0.848909
# ...                                           ...        ...       ...
# FISIKA - UNAIR (IPA)                     0.730000   0.852937  0.760142
# ILMU KESEHATAN MASYARAKAT - UNAIR (IPA)  0.920000   0.851943  0.820000
# STATISTIKA - UNAIR (IPA)                 0.847697   0.852937  0.848679
# KEDOKTERAN GIGI - UNAIR (IPA)            0.847697   0.852937  0.848679
# PEND. NERS - UNAIR (IPA)                 0.847697   0.852937  0.848679
#
#                                            Fisika  Indonesia  Geografi  \
# ADMINISTRASI NIAGA - UI (IPS)            0.846986   0.853932  0.848393
# SISTEM INFORMASI - UI (IPA)              0.880000   0.850000  0.870000
# HUKUM - UI (IPS)                         0.846986   0.870983  0.867098
# ILMU SEJARAH - UI (IPS)                  0.824657   0.864644  0.849464
# FISIKA - UI (IPA)                        0.873699   0.844393  0.847278
# ...                                           ...        ...       ...
# FISIKA - UNAIR (IPA)                     0.730000   0.730000  0.848393
# ILMU KESEHATAN MASYARAKAT - UNAIR (IPA)  0.900000   0.880000  0.848393
# STATISTIKA - UNAIR (IPA)                 0.846986   0.853932  0.848393
# KEDOKTERAN GIGI - UNAIR (IPA)            0.846986   0.853932  0.848393
# PEND. NERS - UNAIR (IPA)                 0.846986   0.853932  0.848393
#
#                                           Inggris     Kimia  Matematika
# ADMINISTRASI NIAGA - UI (IPS)            0.846977  0.851521    0.842363
# SISTEM INFORMASI - UI (IPA)              0.830000  0.880000    0.910000
# HUKUM - UI (IPS)                         0.854244  0.851521    0.825591
# ILMU SEJARAH - UI (IPS)                  0.838992  0.851521    0.827454
# FISIKA - UI (IPA)                        0.849698  0.839152    0.861236
# ...                                           ...       ...         ...
# FISIKA - UNAIR (IPA)                     0.730000  0.730000    0.653000
# ILMU KESEHATAN MASYARAKAT - UNAIR (IPA)  0.830000  0.870000    0.850000
# STATISTIKA - UNAIR (IPA)                 0.846977  0.851521    0.842363
# KEDOKTERAN GIGI - UNAIR (IPA)            0.846977  0.851521    0.842363
# PEND. NERS - UNAIR (IPA)                 0.846977  0.851521    0.842363
#
# [142 rows x 9 columns]

# %%
weight = blgndr.getWeight(knowledge_matrix)

# %%
weight
# Out:
# {'Biologi': 0.11,
#  'Sosiologi': 0.11,
#  'Ekonomi': 0.11,
#  'Fisika': 0.11,
#  'Indonesia': 0.11,
#  'Geografi': 0.11,
#  'Inggris': 0.11,
#  'Kimia': 0.11,
#  'Matematika': 0.11}

# %%
data_test = pd.read_csv("data/train-test/Splitted Test.csv", index_col = 0)

# %%
data_test
# Out:
#     Nama Panggilan Jurusan Sekolah                           Pilihan I  \
# 24            Aini             IPA      TEKNOLOGI BIOPROSES - UI (IPA)
# 33            Iday             IPA                    KIMIA - UI (IPA)
# 371           Reni             IPA     BUDIDAYA PERAIRAN - UNAIR (IPA)
# 8            Dinda             IPA          KEDOKTERAN GIGI - UI (IPA)
# 180           Diah             IPA               FARMASI - UNPAD (IPA)
# ..             ...             ...                                 ...
# 332          Salma             IPA      PENDIDIKAN BIDAN - UNAIR (IPA)
# 27           risca             IPA                 GEOGRAFI - UI (IPA)
# 185           Dina             IPA               FARMASI - UNPAD (IPA)
# 312           Erva             IPA  KESEHATAN MASYARAKAT - UNAIR (IPA)
# 269           Ifah             IPA                FISIKA - UNPAD (IPA)
#
#                               Pilihan II  \
# 24                  PSIKOLOGI - UI (IPS)
# 33                                KOSONG
# 371  TEKNIK LINGKUNGAN - UPN JATIM (IPA)
# 8                                 KOSONG
# 180    PENDIDIKAN MATEMATIKA - UPI (IPA)
# ..                                   ...
# 332                               KOSONG
# 27                                KOSONG
# 185                  KIMIA - UNPAD (IPA)
# 312      BUDIDAYA PERAIRAN - UNAIR (IPA)
# 269                               KOSONG
#
#                               Pilihan III                    Jurusan Diterima  \
# 24   HUBUNGAN INTERNASIONAL - UNPAD (IPS)      TEKNOLOGI BIOPROSES - UI (IPA)
# 33                                 KOSONG                    KIMIA - UI (IPA)
# 371       TEKNIK PANGAN - UPN JATIM (IPA)     BUDIDAYA PERAIRAN - UNAIR (IPA)
# 8                                  KOSONG          KEDOKTERAN GIGI - UI (IPA)
# 180                                KOSONG               FARMASI - UNPAD (IPA)
# ..                                    ...                                 ...
# 332                                KOSONG      PENDIDIKAN BIDAN - UNAIR (IPA)
# 27                                 KOSONG                 GEOGRAFI - UI (IPA)
# 185                KEDOKTERAN - USU (IPA)               FARMASI - UNPAD (IPA)
# 312     KESEHATAN MASYARAKAT - UNEJ (IPA)  KESEHATAN MASYARAKAT - UNAIR (IPA)
# 269             PEND FISIKA - UNILA (IPA)                FISIKA - UNPAD (IPA)
#
#        Biologi  Sosiologi    Ekonomi     Fisika  Indonesia   Geografi  \
# 24   84.769668  85.293746  84.867923  84.698593  85.393215  84.839303
# 33   87.000000  85.293746  85.000000  85.000000  86.000000  84.839303
# 371  84.000000  85.293746  90.000000  80.000000  83.000000  84.839303
# 8    85.000000  85.293746  84.867923  84.000000  82.000000  84.839303
# 180  90.000000  85.293746  84.867923  91.000000  85.000000  84.839303
# ..         ...        ...        ...        ...        ...        ...
# 332  82.000000  85.293746  84.867923  88.000000  88.000000  84.839303
# 27   84.769668  85.293746  84.867923  84.698593  85.393215  84.839303
# 185  83.000000  85.293746  84.867923  86.000000  90.000000  84.839303
# 312  87.000000  85.293746  83.000000  83.000000  88.000000  84.839303
# 269  95.000000  85.293746  84.867923  94.000000  83.000000  84.839303
#
#        Inggris      Kimia  Matematika
# 24   84.697708  85.152057   84.236315
# 33   85.000000  85.000000   91.000000
# 371  80.000000  86.000000   84.000000
# 8    85.000000  87.000000   93.000000
# 180  89.000000  92.000000   95.000000
# ..         ...        ...         ...
# 332  87.000000  88.000000   82.000000
# 27   84.697708  85.152057   84.236315
# 185  89.000000  92.000000   85.000000
# 312  84.000000  81.000000   87.000000
# 269  80.000000  87.000000   83.000000
#
# [115 rows x 15 columns]

# %%
# #assign nilai dari datatest
# nilai = {
#     "Matematika": data_test.loc[332, "Matematika"],
#     "Indonesia": data_test.loc[332, "Indonesia"],
#     "Inggris": data_test.loc[332, "Inggris"],
# }
# for column in data_test.columns:
#     if "ipa" in data_test.loc[332, "Jurusan Sekolah"].casefold():
#         if column.casefold() == "fisika"\
#         or column.casefold() == "kimia"\
#         or column.casefold() == "biologi":
#             nilai[column] = data_test.loc[332, column]
#         elif column.casefold() == "ekonomi"\
#         or column.casefold() == "geografi"\
#         or column.casefold() == "sosiologi":
#             nilai[column] = 0
#     else:
#         if column.casefold() == "ekonomi"\
#         or column.casefold() == "geografi"\
#         or column.casefold() == "sosiologi":
#             nilai[column] = data_test.loc[332, column]
#         elif column.casefold() == "fisika"\
#         or column.casefold() == "kimia"\
#         or column.casefold() == "biologi":
#             nilai[column] = 0

# %%
# nilai

# %%
# pil_df = dict()
# for column in data_test:
#     if column == "Pilihan I" or column == "Pilihan II" or column == "Pilihan III":
#         if column not in pil_df:
#             if "kosong" not in data_test.loc[332, column].casefold():
#                 try:
#                     pil_df[data_test.loc[332, column]] = tabel_alternatif[data_test.loc[332, column]].copy()
#                 except:
#                     pil_df[data_test.loc[332, column]] = [78] * 9

# pilihan_siswa = pd.DataFrame(pil_df, index = [kriteria for kriteria in tabel_alternatif.index])

# %%
# pilihan_siswa

# %%
# #menghitung nilai indifference sebagai parameter
# indifference = dict()
# for key in nilai.keys():
#     min_val = abs(nilai[key] - pilihan_siswa.min(axis=1)[key])
#     max_val = abs(nilai[key] - pilihan_siswa.max(axis=1)[key])
#     if min_val > max_val:
#         indifference[key] = max_val
#     else:
#         indifference[key] = min_val

# %%
# indifference

# %%
# #mendapatkan fungsi preferensi
# fp_dataframe = dict()
# for alternatif in pilihan_siswa:
#     for alternatif_compare in pilihan_siswa:
#         fp_val_list = list()
#         if alternatif == alternatif_compare:
#             continue
#         else:
#             for kriteria in pilihan_siswa.index:
#                 #mendapatkan nilai deviasi
#                 dev = deviasi(pilihan_siswa, kriteria, alternatif, alternatif_compare)

#                 #mendapatkan nilai fungsi preferensi
#                 if dev <= indifference[kriteria]:
#                     fp_value = 0
#                 elif dev > indifference[kriteria]:
#                     fp_value = 1

#                 if "ips" in alternatif.casefold():
#                     if kriteria.casefold() == "fisika"\
#                     or kriteria.casefold() == "kimia"\
#                     or kriteria.casefold() == "biologi":
#                         fp_value = 0
#                 elif "ipa" in alternatif.casefold():
#                     if kriteria.casefold() == "ekonomi"\
#                     or kriteria.casefold() == "geografi"\
#                     or kriteria.casefold() == "sosiologi":
#                         fp_value = 0

# #                     if fp_value != 0:
# #                         print(fp_value)
#                 fp_val_list.append(fp_value)
#             else:
#                 fp_dataframe[f"{alternatif} / {alternatif_compare}"] = fp_val_list
# else:
#     fungsi_preferensi = pd.DataFrame(fp_dataframe, index = [kriteria for kriteria in pilihan_siswa.index])

# %%
# fungsi_preferensi

# %%
# #menghitung index preferensi global
# index_prefglob_df = dict()
# for key in fp_dataframe.keys():
#     index_prefglob_df[key] = [sum(fp_dataframe[key]) * weight["Matematika"]]
# else:
#     index_prefglob = pd.DataFrame(index_prefglob_df, index = ["Index Preferensi Global"])

# %%
# index_prefglob

# %%
# temp_alternatif = ""
# skip = 0
# entering_flow_df = dict()
# #mendapatkan entering flow
# for alternatif in index_prefglob.columns:
#     if skip == 0:
#         temp_alternatif = alternatif.split("/")[1].strip()
#         skip += 1

#     if temp_alternatif == alternatif.split("/")[1].strip():
#         if alternatif.split("/")[1].strip() not in entering_flow_df:
#             entering_flow_df[alternatif.split("/")[1].strip()] = index_prefglob[alternatif]["Index Preferensi Global"] * (1/len(pilihan_siswa.columns))
#         else:
#             entering_flow_df[alternatif.split("/")[1].strip()] += index_prefglob[alternatif]["Index Preferensi Global"] * (1/len(pilihan_siswa.columns))
#     else:
#         entering_flow_df[alternatif.split("/")[1].strip()] = index_prefglob[alternatif]["Index Preferensi Global"] * (1/len(pilihan_siswa.columns))
#         temp_alternatif = alternatif.split("/")[1].strip()
# else:
#     entering_flow = pd.DataFrame(entering_flow_df, index=["Entering Flow"])

# %%
# entering_flow

# %%
# temp_alternatif = ""
# skip = 0
# leaving_flow_df = dict()
# #mendapatkan leaving flow
# for alternatif in index_prefglob.columns:
#     if skip == 0:
#         temp_alternatif = alternatif.split("/")[0].strip()
#         skip += 1

#     if temp_alternatif == alternatif.split("/")[0].strip():
#         if alternatif.split("/")[0].strip() not in leaving_flow_df:
#             leaving_flow_df[alternatif.split("/")[0].strip()] = index_prefglob[alternatif]["Index Preferensi Global"] * (1/len(pilihan_siswa.columns))
#         else:
#             leaving_flow_df[alternatif.split("/")[0].strip()] += index_prefglob[alternatif]["Index Preferensi Global"] * (1/len(pilihan_siswa.columns))
#     else:
#         leaving_flow_df[alternatif.split("/")[0].strip()] = index_prefglob[alternatif]["Index Preferensi Global"] * (1/len(pilihan_siswa.columns))
#         temp_alternatif = alternatif.split("/")[0].strip()
# else:
#     leaving_flow = pd.DataFrame(leaving_flow_df, index=["Leaving Flow"])

# %%
# leaving_flow

# %%
# net_flow_df = dict()
# for alternatif in leaving_flow.columns:
#     net_flow_df[alternatif] = leaving_flow.loc["Leaving Flow", alternatif] - entering_flow.loc["Entering Flow", alternatif]
# else:
#     net_flow = pd.DataFrame(net_flow_df, index = ["Net Flow"])

# %%
# net_flow.sort_values(by = "Net Flow", axis = 1, ascending = False)

# %%
deviasi = lambda tabel_alternatif, kriteria, alternatif, alternatif_compare: tabel_alternatif.loc[kriteria, alternatif] - tabel_alternatif.loc[kriteria, alternatif_compare]

# %%
def getNilaiSiswa(index, data_test):
    #assign nilai dari datatest
    nilai = {
        "Matematika": data_test.loc[index, "Matematika"],
        "Indonesia": data_test.loc[index, "Indonesia"],
        "Inggris": data_test.loc[index, "Inggris"],
    }
    for column in data_test.columns:
        if "ipa" in data_test.loc[index, "Jurusan Sekolah"].casefold():
            if column.casefold() == "fisika"\
            or column.casefold() == "kimia"\
            or column.casefold() == "biologi":
                nilai[column] = data_test.loc[index, column]
            elif column.casefold() == "ekonomi"\
            or column.casefold() == "geografi"\
            or column.casefold() == "sosiologi":
                nilai[column] = 0
        else:
            if column.casefold() == "ekonomi"\
            or column.casefold() == "geografi"\
            or column.casefold() == "sosiologi":
                nilai[column] = data_test.loc[index, column]
            elif column.casefold() == "fisika"\
            or column.casefold() == "kimia"\
            or column.casefold() == "biologi":
                nilai[column] = 0
                
    return nilai

# %%
def getPilihanSiswa(data_test, tabel_alternatif, index):
    pil_df = dict()
    for column in data_test:
        if column == "Pilihan I" or column == "Pilihan II" or column == "Pilihan III":
            if column not in pil_df:
                if "kosong" not in data_test.loc[index, column].casefold():
                    try:
                        pil_df[data_test.loc[index, column]] = tabel_alternatif[data_test.loc[index, column]].copy()
                    except:
                        pil_df[data_test.loc[index, column]] = [78] * 9

    pilihan_siswa = pd.DataFrame(pil_df, index = [kriteria for kriteria in tabel_alternatif.index])
    
    return pilihan_siswa

# %%
def getIndifferenceParams(nilai, pilihan_siswa):
    #menghitung nilai indifference sebagai parameter
    indifference = dict()
    for key in nilai.keys():
        min_val = abs(nilai[key] - pilihan_siswa.min(axis=1)[key])
        max_val = abs(nilai[key] - pilihan_siswa.max(axis=1)[key])
        if min_val > max_val:
            indifference[key] = max_val
        else:
            indifference[key] = min_val
            
    return indifference

# %%
def getPreferenceParams(nilai, pilihan_siswa):
    #menghitung nilai preference sebagai parameter
    preference = dict()
    for key in nilai.keys():
        min_val = abs(nilai[key] - pilihan_siswa.min(axis=1)[key])
        max_val = abs(nilai[key] - pilihan_siswa.max(axis=1)[key])
        if min_val > max_val:
            preference[key] = min_val
        else:
            preference[key] = max_val
            
    return preference

# %%
def getFungsiPreferensi(indifference, preference):
    global pilihan_siswa
    #mendapatkan fungsi preferensi
    fp_dataframe = dict()
    for alternatif in pilihan_siswa:
        for alternatif_compare in pilihan_siswa:
            fp_val_list = list()
            if alternatif == alternatif_compare:
                continue
            else:
                for kriteria in pilihan_siswa.index:
                    #mendapatkan nilai deviasi
                    dev = deviasi(pilihan_siswa, kriteria, alternatif, alternatif_compare)

                    #mendapatkan nilai fungsi preferensi
                    if dev <= indifference[kriteria]:
                        fp_value = 0
                    elif indifference[kriteria] < dev and dev <= preference[kriteria]:
                        fp_value = 1/2
                    elif dev > preference[kriteria]:
                        fp_value = 1

                    if "ips" in alternatif.casefold():
                        if kriteria.casefold() == "fisika"\
                        or kriteria.casefold() == "kimia"\
                        or kriteria.casefold() == "biologi":
                            fp_value = 0
                    elif "ipa" in alternatif.casefold():
                        if kriteria.casefold() == "ekonomi"\
                        or kriteria.casefold() == "geografi"\
                        or kriteria.casefold() == "sosiologi":
                            fp_value = 0
                    
#                     if fp_value != 0:
#                         print(fp_value)
                    fp_val_list.append(fp_value)
                else:
                    fp_dataframe[f"{alternatif} / {alternatif_compare}"] = fp_val_list
    else:
        fungsi_preferensi = pd.DataFrame(fp_dataframe, index = [kriteria for kriteria in pilihan_siswa.index])
        return fungsi_preferensi

# %%
def getIndexPrefGlob(fp_dataframe, weight):
    #menghitung index preferensi global
    index_prefglob_df = dict()
    for key in fp_dataframe.keys():
        index_prefglob_df[key] = [sum(fp_dataframe[key]) * weight["Matematika"]]
    else:
        index_prefglob = pd.DataFrame(index_prefglob_df, index = ["Index Preferensi Global"])
        return index_prefglob

# %%
def getEnteringFlow(index_prefglob):
    global pilihan_siswa
    temp_alternatif = ""
    skip = 0
    entering_flow_df = dict()
    #mendapatkan entering flow
    for alternatif in index_prefglob.columns:
        if skip == 0:
            temp_alternatif = alternatif.split("/")[1].strip()
            skip += 1

        if temp_alternatif == alternatif.split("/")[1].strip():
            if alternatif.split("/")[1].strip() not in entering_flow_df:
                entering_flow_df[alternatif.split("/")[1].strip()] = index_prefglob[alternatif]["Index Preferensi Global"] * (1/len(pilihan_siswa.columns))
            else:
                entering_flow_df[alternatif.split("/")[1].strip()] += index_prefglob[alternatif]["Index Preferensi Global"] * (1/len(pilihan_siswa.columns))
        else:
            entering_flow_df[alternatif.split("/")[1].strip()] = index_prefglob[alternatif]["Index Preferensi Global"] * (1/len(pilihan_siswa.columns))
            temp_alternatif = alternatif.split("/")[1].strip()
    else:
        entering_flow = pd.DataFrame(entering_flow_df, index=["Entering Flow"])
        return entering_flow

# %%
def getLeavingFlow(index_prefglob):
    global pilihan_siswa
    temp_alternatif = ""
    skip = 0
    leaving_flow_df = dict()
    #mendapatkan leaving flow
    for alternatif in index_prefglob.columns:
        if skip == 0:
            temp_alternatif = alternatif.split("/")[0].strip()
            skip += 1

        if temp_alternatif == alternatif.split("/")[0].strip():
            if alternatif.split("/")[0].strip() not in leaving_flow_df:
                leaving_flow_df[alternatif.split("/")[0].strip()] = index_prefglob[alternatif]["Index Preferensi Global"] * (1/len(pilihan_siswa.columns))
            else:
                leaving_flow_df[alternatif.split("/")[0].strip()] += index_prefglob[alternatif]["Index Preferensi Global"] * (1/len(pilihan_siswa.columns))
        else:
            leaving_flow_df[alternatif.split("/")[0].strip()] = index_prefglob[alternatif]["Index Preferensi Global"] * (1/len(pilihan_siswa.columns))
            temp_alternatif = alternatif.split("/")[0].strip()
    else:
        leaving_flow = pd.DataFrame(leaving_flow_df, index=["Leaving Flow"])
        return leaving_flow

# %%
def getNetFlow(leaving_flow, entering_flow, jurusan_sekolah):
    #menghitung net flow
    net_flow_df = dict()
    for alternatif in leaving_flow.columns:
        net_flow_df[alternatif] = leaving_flow.loc["Leaving Flow", alternatif] - entering_flow.loc["Entering Flow", alternatif]
    else:
        net_flow = pd.DataFrame(net_flow_df, index = ["Net Flow"])
        return net_flow.sort_values(by = "Net Flow", axis = 1, ascending = False)

# %%
hasil = dict()
stop = 1
for index in data_test.index:
    if stop > 100:
        break
    nilai = getNilaiSiswa(index, data_test)
    pilihan_siswa = getPilihanSiswa(data_test, tabel_alternatif, index)
    indifference = getIndifferenceParams(nilai, pilihan_siswa)
    preference = getPreferenceParams(nilai, pilihan_siswa)
    fungsi_preferensi = getFungsiPreferensi(indifference, preference)
    index_prefglob = getIndexPrefGlob(fungsi_preferensi, weight)
    entering_flow = getEnteringFlow(index_prefglob)
    leaving_flow = getLeavingFlow(index_prefglob)
    net_flow = getNetFlow(leaving_flow, entering_flow, data_test.loc[index, "Jurusan Diterima"])
    print(index)
    print(pilihan_siswa)
    print(indifference)
#     print(index_prefglob)
    print(entering_flow)
    print(leaving_flow)
    print(net_flow)
    print()
    
    cek = list()
    if len(net_flow.columns) > 0:
        for rekomen in net_flow.columns:
            cek.append(rekomen)
    else: 
        cek.append((pilihan_siswa.columns)[0])
        
#     for i in range(3):
    if len(cek) > 0 :
        if f"Rekomendasi" not in hasil:
            hasil[f"Rekomendasi"] = [cek[0]]
        else:
            hasil[f"Rekomendasi"].append(cek[0])
        
        if "Riil" not in hasil:
            hasil["Riil"] = [data_test.loc[index, "Jurusan Diterima"]]
        else:
            hasil["Riil"].append(data_test.loc[index, "Jurusan Diterima"])
    stop += 1
# Out:
# 24
#             TEKNOLOGI BIOPROSES - UI (IPA)  PSIKOLOGI - UI (IPS)  \
# Biologi                          84.769668             82.544241
# Sosiologi                        85.293746             85.646873
# Ekonomi                          84.867923             85.183962
# Fisika                           84.698593             82.576709
# Indonesia                        85.393215             84.848304
# Geografi                         84.839303             82.669652
# Inggris                          84.697708             81.674427
# Kimia                            85.152057             84.614043
# Matematika                       84.236315             82.250000
#
#             HUBUNGAN INTERNASIONAL - UNPAD (IPS)
# Biologi                                84.769668
# Sosiologi                              85.573436
# Ekonomi                                84.716981
# Fisika                                 84.698593
# Indonesia                              85.848304
# Geografi                               84.459826
# Inggris                                86.674427
# Kimia                                  85.152057
# Matematika                             83.309079
# {'Matematika': 0.0, 'Indonesia': 0.45508883294115776, 'Inggris': 1.976718799730918, 'Biologi': 0.0, 'Sosiologi': 85.29374595544093, 'Ekonomi': 84.7169808054237, 'Fisika': 1.4210854715202004e-14, 'Geografi': 82.66965157929013, 'Kimia': 0.0}
#                PSIKOLOGI - UI (IPS)  HUBUNGAN INTERNASIONAL - UNPAD (IPS)  \
# Entering Flow              0.091667                                   0.0
#
#                TEKNOLOGI BIOPROSES - UI (IPA)
# Entering Flow                             0.0
#               TEKNOLOGI BIOPROSES - UI (IPA)  PSIKOLOGI - UI (IPS)  \
# Leaving Flow                        0.128333                   0.0
#
#               HUBUNGAN INTERNASIONAL - UNPAD (IPS)
# Leaving Flow                              0.091667
#           TEKNOLOGI BIOPROSES - UI (IPA)  \
# Net Flow                        0.128333
#
#           HUBUNGAN INTERNASIONAL - UNPAD (IPS)  PSIKOLOGI - UI (IPS)
# Net Flow                              0.091667             -0.091667
#
# 33
#             KIMIA - UI (IPA)
# Biologi            85.395667
# Sosiologi          85.293746
# Ekonomi            85.704259
# Fisika             85.599799
# Indonesia          86.699031
# Geografi           84.839303
# Inggris            84.313958
# Kimia              88.593151
# Matematika         87.890902
# {'Matematika': 3.1090977924210534, 'Indonesia': 0.6990306984873911, 'Inggris': 0.6860416761392116, 'Biologi': 1.604333185581325, 'Sosiologi': 85.29374595544094, 'Ekonomi': 85.70425945935169, 'Fisika': 0.5997989995593258, 'Geografi': 84.83930315858025, 'Kimia': 3.5931510203239014}
# Empty DataFrame
# Columns: []
# Index: [Entering Flow]
# Empty DataFrame
# Columns: []
# Index: [Leaving Flow]
# Empty DataFrame
# Columns: []
# Index: [Net Flow]
#
# 371
#             BUDIDAYA PERAIRAN - UNAIR (IPA)  \
# Biologi                           83.442417
# Sosiologi                         85.293746
# Ekonomi                           85.400942
# Fisika                            82.174648
# Indonesia                         84.473304
# Geografi                          84.839303
# Inggris                           82.924427
# Kimia                             82.038014
# Matematika                        82.809079
#
#             TEKNIK LINGKUNGAN - UPN JATIM (IPA)  \
# Biologi                                      78
# Sosiologi                                    78
# Ekonomi                                      78
# Fisika                                       78
# Indonesia                                    78
# Geografi                                     78
# Inggris                                      78
# Kimia                                        78
# Matematika                                   78
#
#             TEKNIK PANGAN - UPN JATIM (IPA)
# Biologi                                  78
# Sosiologi                                78
# Ekonomi                                  78
# Fisika                                   78
# Indonesia                                78
# Geografi                                 78
# Inggris                                  78
# Kimia                                    78
# Matematika                               78
# {'Matematika': 1.190921136736847, 'Indonesia': 1.473303722352938, 'Inggris': 2.0, 'Biologi': 0.5575830747672939, 'Sosiologi': 78.0, 'Ekonomi': 78.0, 'Fisika': 2.0, 'Geografi': 78.0, 'Kimia': 3.961985714433183}
#                TEKNIK LINGKUNGAN - UPN JATIM (IPA)  \
# Entering Flow                                  0.0
#
#                TEKNIK PANGAN - UPN JATIM (IPA)  \
# Entering Flow                              0.0
#
#                BUDIDAYA PERAIRAN - UNAIR (IPA)
# Entering Flow                              0.0
#               BUDIDAYA PERAIRAN - UNAIR (IPA)  \
# Leaving Flow                             0.33
#
#               TEKNIK LINGKUNGAN - UPN JATIM (IPA)  \
# Leaving Flow                                  0.0
#
#               TEKNIK PANGAN - UPN JATIM (IPA)
# Leaving Flow                              0.0
#           BUDIDAYA PERAIRAN - UNAIR (IPA)  \
# Net Flow                             0.33
#
#           TEKNIK LINGKUNGAN - UPN JATIM (IPA)  TEKNIK PANGAN - UPN JATIM (IPA)
# Net Flow                                  0.0                              0.0
#
# 8
#             KEDOKTERAN GIGI - UI (IPA)
# Biologi                      85.000000
# Sosiologi                    85.293746
# Ekonomi                      84.897180
# Fisika                       84.800000
# Indonesia                    86.200000
# Geografi                     84.839303
# Inggris                      85.400000
# Kimia                        85.800000
# Matematika                   88.400000
# {'Matematika': 4.599999999999994, 'Indonesia': 4.200000000000003, 'Inggris': 0.4000000000000057, 'Biologi': 0.0, 'Sosiologi': 85.29374595544093, 'Ekonomi': 84.89718010741046, 'Fisika': 0.7999999999999972, 'Geografi': 84.83930315858026, 'Kimia': 1.2000000000000028}
# Empty DataFrame
# Columns: []
# Index: [Entering Flow]
# Empty DataFrame
# Columns: []
# Index: [Leaving Flow]
# Empty DataFrame
# Columns: []
# Index: [Net Flow]
#
# 180
#             FARMASI - UNPAD (IPA)  PENDIDIKAN MATEMATIKA - UPI (IPA)
# Biologi                 86.367667                                 78
# Sosiologi               85.313633                                 78
# Ekonomi                 84.990887                                 78
# Fisika                  86.566198                                 78
# Indonesia               87.019961                                 78
# Geografi                84.397386                                 78
# Inggris                 87.343681                                 78
# Kimia                   87.606241                                 78
# Matematika              86.300994                                 78
# {'Matematika': 8.699005960093572, 'Indonesia': 2.0199605186928125, 'Inggris': 1.6563194665470888, 'Biologi': 3.6323329885785967, 'Sosiologi': 78.0, 'Ekonomi': 78.0, 'Fisika': 4.4338023343615305, 'Geografi': 78.0, 'Kimia': 4.3937587303553585}
#                PENDIDIKAN MATEMATIKA - UPI (IPA)  FARMASI - UNPAD (IPA)
# Entering Flow                              0.165                    0.0
#               FARMASI - UNPAD (IPA)  PENDIDIKAN MATEMATIKA - UPI (IPA)
# Leaving Flow                  0.165                                0.0
#           FARMASI - UNPAD (IPA)  PENDIDIKAN MATEMATIKA - UPI (IPA)
# Net Flow                  0.165                             -0.165
#
# 249
#             HUBUNGAN MASYARAKAT - UNPAD (IPS)  PSIKOLOGI - UPI (IPS)  \
# Biologi                             84.769668                     78
# Sosiologi                           89.264582                     78
# Ekonomi                             85.955974                     78
# Fisika                              84.698593                     78
# Indonesia                           86.797738                     78
# Geografi                            88.613101                     78
# Inggris                             85.899236                     78
# Kimia                               85.152057                     78
# Matematika                          81.345438                     78
#
#             ILMU KOMUNIKASI - UPI (IPS)
# Biologi                              78
# Sosiologi                            78
# Ekonomi                              78
# Fisika                               78
# Indonesia                            78
# Geografi                             78
# Inggris                              78
# Kimia                                78
# Matematika                           78
# {'Matematika': 8.400000000000006, 'Indonesia': 2.797738296470584, 'Inggris': 3.8992360890084825, 'Biologi': 78.0, 'Sosiologi': 0.2645819851469895, 'Ekonomi': 0.04402559276839213, 'Fisika': 78.0, 'Geografi': 5.386898947139912, 'Kimia': 78.0}
#                PSIKOLOGI - UPI (IPS)  ILMU KOMUNIKASI - UPI (IPS)  \
# Entering Flow                    0.0                          0.0
#
#                HUBUNGAN MASYARAKAT - UNPAD (IPS)
# Entering Flow                                0.0
#               HUBUNGAN MASYARAKAT - UNPAD (IPS)  PSIKOLOGI - UPI (IPS)  \
# Leaving Flow                           0.293333                    0.0
#
#               ILMU KOMUNIKASI - UPI (IPS)
# Leaving Flow                          0.0
#           HUBUNGAN MASYARAKAT - UNPAD (IPS)  PSIKOLOGI - UPI (IPS)  \
# Net Flow                           0.293333                    0.0
#
#           ILMU KOMUNIKASI - UPI (IPS)
# Net Flow                          0.0
#
# 301
#             KEDOKTERAN - UNAIR (IPA)
# Biologi                    87.261801
# Sosiologi                  85.634997
# Ekonomi                    85.720754
# Fisika                     86.619156
# Indonesia                  87.435929
# Geografi                   85.671443
# Inggris                    86.218625
# Kimia                      87.291234
# Matematika                 87.541789
# {'Matematika': 3.3054738187789496, 'Indonesia': 2.0427140442352965, 'Inggris': 1.5209166931898324, 'Biologi': 2.4921329196276503, 'Sosiologi': 85.63499676435273, 'Ekonomi': 85.72075393301687, 'Fisika': 1.920562801233828, 'Geografi': 85.67144252686421, 'Kimia': 2.139177143093093}
# Empty DataFrame
# Columns: []
# Index: [Entering Flow]
# Empty DataFrame
# Columns: []
# Index: [Leaving Flow]
# Empty DataFrame
# Columns: []
# Index: [Net Flow]
#
# 222
#             AKUNTANSI - UNPAD (IPS)  EKONOMI ISLAM - UNPAD (IPS)  \
# Biologi                   84.769668                    84.769668
# Sosiologi                 89.646873                    84.323306
# Ekonomi                   87.933962                    84.867923
# Fisika                    84.698593                    84.698593
# Indonesia                 87.196607                    85.393215
# Geografi                  86.919652                    84.839303
# Inggris                   87.348854                    83.552971
# Kimia                     85.152057                    85.152057
# Matematika                86.618158                    85.256746
#
#             AKUNTANSI - UPI (IPS)
# Biologi                        78
# Sosiologi                      78
# Ekonomi                        78
# Fisika                         78
# Indonesia                      78
# Geografi                       78
# Inggris                        78
# Kimia                          78
# Matematika                     78
# {'Matematika': 2.381842273473694, 'Indonesia': 1.80339255529411, 'Inggris': 2.6511458664872833, 'Biologi': 78.0, 'Sosiologi': 4.353127022279523, 'Ekonomi': 3.0660383891526095, 'Fisika': 78.0, 'Geografi': 2.0803484207098677, 'Kimia': 78.0}
#                EKONOMI ISLAM - UNPAD (IPS)  AKUNTANSI - UPI (IPS)  \
# Entering Flow                          0.0               0.128333
#
#                AKUNTANSI - UNPAD (IPS)
# Entering Flow                      0.0
#               AKUNTANSI - UNPAD (IPS)  EKONOMI ISLAM - UNPAD (IPS)  \
# Leaving Flow                 0.256667                     0.128333
#
#               AKUNTANSI - UPI (IPS)
# Leaving Flow                    0.0
#           AKUNTANSI - UNPAD (IPS)  EKONOMI ISLAM - UNPAD (IPS)  \
# Net Flow                 0.256667                     0.128333
#
#           AKUNTANSI - UPI (IPS)
# Net Flow              -0.128333
#
# 156
#             ARKEOLOGI - UI (IPS)  EKONOMI PERTANIAN - UIN JAKARTA (IPS)
# Biologi                84.769668                                     78
# Sosiologi              85.293746                                     78
# Ekonomi                84.867923                                     78
# Fisika                 84.698593                                     78
# Indonesia              85.393215                                     78
# Geografi               84.839303                                     78
# Inggris                84.697708                                     78
# Kimia                  85.152057                                     78
# Matematika             84.236315                                     78
# {'Matematika': 0.0, 'Indonesia': 0.0, 'Inggris': 0.0, 'Biologi': 78.0, 'Sosiologi': 1.4210854715202004e-14, 'Ekonomi': 0.0, 'Fisika': 78.0, 'Geografi': 0.0, 'Kimia': 78.0}
#                EKONOMI PERTANIAN - UIN JAKARTA (IPS)  ARKEOLOGI - UI (IPS)
# Entering Flow                                  0.165                   0.0
#               ARKEOLOGI - UI (IPS)  EKONOMI PERTANIAN - UIN JAKARTA (IPS)
# Leaving Flow                 0.165                                    0.0
#           ARKEOLOGI - UI (IPS)  EKONOMI PERTANIAN - UIN JAKARTA (IPS)
# Net Flow                 0.165                                 -0.165
#
# 300
#             HUKUM - UNAIR (IPS)  PSIKOLOGI - UNAIR (IPS)  \
# Biologi               83.846445                84.981361
# Sosiologi             85.293746                86.005111
# Ekonomi               84.867923                85.279588
# Fisika                84.132395                83.125765
# Indonesia             85.595477                85.269643
# Geografi              84.839303                85.806829
# Inggris               86.131806                84.862595
# Kimia                 84.434705                84.118334
# Matematika            83.824210                84.652871
#
#             PSIKOLOGI - UNS (IPS)
# Biologi                        78
# Sosiologi                      78
# Ekonomi                        78
# Fisika                         78
# Indonesia                      78
# Geografi                       78
# Inggris                        78
# Kimia                          78
# Matematika                     78
# {'Matematika': 1.652870660478456, 'Indonesia': 0.40452340705881795, 'Inggris': 2.868194488649692, 'Biologi': 2.9813609521296485, 'Sosiologi': 78.0, 'Ekonomi': 78.0, 'Fisika': 1.1323953312768964, 'Geografi': 78.0, 'Kimia': 1.4347047615114974}
#                PSIKOLOGI - UNAIR (IPS)  PSIKOLOGI - UNS (IPS)  \
# Entering Flow                      0.0               0.073333
#
#                HUKUM - UNAIR (IPS)
# Entering Flow                  0.0
#               HUKUM - UNAIR (IPS)  PSIKOLOGI - UNAIR (IPS)  \
# Leaving Flow             0.073333                 0.073333
#
#               PSIKOLOGI - UNS (IPS)
# Leaving Flow                    0.0
#           HUKUM - UNAIR (IPS)  PSIKOLOGI - UNAIR (IPS)  PSIKOLOGI - UNS (IPS)
# Net Flow             0.073333                 0.073333              -0.073333
#
# 174
#             HUBUNGAN INTERNASIONAL - UNPAD (IPS)
# Biologi                                84.769668
# Sosiologi                              85.573436
# Ekonomi                                84.716981
# Fisika                                 84.698593
# Indonesia                              85.848304
# Geografi                               84.459826
# Inggris                                86.674427
# Kimia                                  85.152057
# Matematika                             83.309079
# {'Matematika': 0.6909211367368471, 'Indonesia': 1.848303722352938, 'Inggris': 2.3255729332436346, 'Biologi': 84.76966770093084, 'Sosiologi': 4.573436488860239, 'Ekonomi': 1.7169808054237023, 'Fisika': 84.69859299691537, 'Geografi': 4.459825789645066, 'Kimia': 85.15205714226724}
# Empty DataFrame
# Columns: []
# Index: [Entering Flow]
# Empty DataFrame
# Columns: []
# Index: [Leaving Flow]
# Empty DataFrame
# Columns: []
# Index: [Net Flow]
#
# 373
#             BUDIDAYA PERAIRAN - UNAIR (IPA)  FISIKA - UNAIR (IPA)  \
# Biologi                           83.442417             73.000000
# Sosiologi                         85.293746             85.293746
# Ekonomi                           85.400942             76.014208
# Fisika                            82.174648             73.000000
# Indonesia                         84.473304             73.000000
# Geografi                          84.839303             84.839303
# Inggris                           82.924427             73.000000
# Kimia                             82.038014             73.000000
# Matematika                        82.809079             65.300000
#
#             TEKNIK INDUSTRI - UPN JATIM (IPA)
# Biologi                                    78
# Sosiologi                                  78
# Ekonomi                                    78
# Fisika                                     78
# Indonesia                                  78
# Geografi                                   78
# Inggris                                    78
# Kimia                                      78
# Matematika                                 78
# {'Matematika': 4.809078863263153, 'Indonesia': 1.473303722352938, 'Inggris': 0.07557293324363457, 'Biologi': 5.0, 'Sosiologi': 78.0, 'Ekonomi': 76.01420765027322, 'Fisika': 4.174648249228838, 'Geografi': 78.0, 'Kimia': 4.038014285566817}
#                FISIKA - UNAIR (IPA)  TEKNIK INDUSTRI - UPN JATIM (IPA)  \
# Entering Flow              0.091667                                0.0
#
#                BUDIDAYA PERAIRAN - UNAIR (IPA)
# Entering Flow                              0.0
#               BUDIDAYA PERAIRAN - UNAIR (IPA)  FISIKA - UNAIR (IPA)  \
# Leaving Flow                         0.256667                   0.0
#
#               TEKNIK INDUSTRI - UPN JATIM (IPA)
# Leaving Flow                           0.091667
#           BUDIDAYA PERAIRAN - UNAIR (IPA)  TEKNIK INDUSTRI - UPN JATIM (IPA)  \
# Net Flow                         0.256667                           0.091667
#
#           FISIKA - UNAIR (IPA)
# Net Flow             -0.091667
#
# 47
#             STATISTIKA - UI (IPA)  MATEMATIKA - UI (IPA)
# Biologi                 85.472715              85.905359
# Sosiologi               85.565249              85.940862
# Ekonomi                 84.938428              84.691181
# Fisika                  85.870826              87.284507
# Indonesia               86.025664              86.261017
# Geografi                85.719403              84.839303
# Inggris                 83.013304              86.592131
# Kimia                   84.493739              87.088620
# Matematika              87.244135              91.769231
# {'Matematika': 3.0078197411127974, 'Indonesia': 0.6324486346218237, 'Inggris': 1.6844047240145414, 'Biologi': 0.7030470280395207, 'Sosiologi': 85.5652489226896, 'Ekonomi': 84.6911808971996, 'Fisika': 1.1722325731912093, 'Geografi': 84.83930315858025, 'Kimia': 0.6583183670098549}
#                MATEMATIKA - UI (IPA)  STATISTIKA - UI (IPA)
# Entering Flow                    0.0                  0.165
#               STATISTIKA - UI (IPA)  MATEMATIKA - UI (IPA)
# Leaving Flow                    0.0                  0.165
#           MATEMATIKA - UI (IPA)  STATISTIKA - UI (IPA)
# Net Flow                  0.165                 -0.165
#
# 305
#             BIOLOGI - UNAIR (IPA)
# Biologi                 84.769668
# Sosiologi               85.293746
# Ekonomi                 84.867923
# Fisika                  84.698593
# Indonesia               85.393215
# Geografi                84.839303
# Inggris                 84.697708
# Kimia                   85.152057
# Matematika              84.236315
# {'Matematika': 0.0, 'Indonesia': 0.0, 'Inggris': 0.0, 'Biologi': 0.0, 'Sosiologi': 85.29374595544093, 'Ekonomi': 84.86792322169478, 'Fisika': 1.4210854715202004e-14, 'Geografi': 84.83930315858026, 'Kimia': 0.0}
# Empty DataFrame
# Columns: []
# Index: [Entering Flow]
# Empty DataFrame
# Columns: []
# Index: [Leaving Flow]
# Empty DataFrame
# Columns: []
# Index: [Net Flow]
#
# 10
#             AKUNTANSI - UI (IPS)  ADMINISTRASI NIAGA - UI (IPS)
# Biologi                84.769668                      84.769668
# Sosiologi              86.813540                      85.293746
# Ekonomi                86.933962                      84.867923
# Fisika                 84.698593                      84.698593
# Indonesia              85.363274                      85.393215
# Geografi               87.419652                      84.839303
# Inggris                84.348854                      84.697708
# Kimia                  85.152057                      85.152057
# Matematika             88.284824                      84.236315
# {'Matematika': 6.715175606807023, 'Indonesia': 0.6067851105882198, 'Inggris': 1.3022917329745525, 'Biologi': 84.76966770093084, 'Sosiologi': 0.7062540445590741, 'Ekonomi': 4.0660383891526095, 'Fisika': 84.69859299691537, 'Geografi': 3.5803484207098677, 'Kimia': 85.15205714226724}
#                ADMINISTRASI NIAGA - UI (IPS)  AKUNTANSI - UI (IPS)
# Entering Flow                          0.055                   0.0
#               AKUNTANSI - UI (IPS)  ADMINISTRASI NIAGA - UI (IPS)
# Leaving Flow                 0.055                            0.0
#           AKUNTANSI - UI (IPS)  ADMINISTRASI NIAGA - UI (IPS)
# Net Flow                 0.055                         -0.055
#
# 283
#             AGRIBISNIS - UNPAD (IPS)
# Biologi                    84.000000
# Sosiologi                  85.293746
# Ekonomi                    84.867923
# Fisika                     85.000000
# Indonesia                  80.000000
# Geografi                   84.839303
# Inggris                    85.000000
# Kimia                      86.000000
# Matematika                 86.000000
# {'Matematika': 0.0, 'Indonesia': 0.0, 'Inggris': 0.0, 'Biologi': 0.0, 'Sosiologi': 85.29374595544093, 'Ekonomi': 84.86792322169478, 'Fisika': 0.0, 'Geografi': 84.83930315858026, 'Kimia': 0.0}
# Empty DataFrame
# Columns: []
# Index: [Entering Flow]
# Empty DataFrame
# Columns: []
# Index: [Leaving Flow]
# Empty DataFrame
# Columns: []
# Index: [Net Flow]
#
# 107
#             FILSAFAT - UI (IPS)
# Biologi               84.769668
# Sosiologi             87.000000
# Ekonomi               85.000000
# Fisika                84.698593
# Indonesia             76.000000
# Geografi              86.000000
# Inggris               86.000000
# Kimia                 85.152057
# Matematika            88.000000
# {'Matematika': 0.0, 'Indonesia': 0.0, 'Inggris': 0.0, 'Biologi': 84.76966770093084, 'Sosiologi': 0.0, 'Ekonomi': 0.0, 'Fisika': 84.69859299691537, 'Geografi': 0.0, 'Kimia': 85.15205714226724}
# Empty DataFrame
# Columns: []
# Index: [Entering Flow]
# Empty DataFrame
# Columns: []
# Index: [Leaving Flow]
# Empty DataFrame
# Columns: []
# Index: [Net Flow]
#
# 209
#             ILMU HUBUNGAN INTERNASIONAL - UNPAD (IPS)  \
# Biologi                                     83.725655
# Sosiologi                                   84.000000
# Ekonomi                                     85.333333
# Fisika                                      84.102279
# Indonesia                                   85.000000
# Geografi                                    82.666667
# Inggris                                     84.666667
# Kimia                                       85.152057
# Matematika                                  82.333333
#
#             ILMU PEMERINTAHAN - UNPAD (IPA)  ILMU HUKUM - UPN JAKARTA (IPS)
# Biologi                                  78                              78
# Sosiologi                                78                              78
# Ekonomi                                  78                              78
# Fisika                                   78                              78
# Indonesia                                78                              78
# Geografi                                 78                              78
# Inggris                                  78                              78
# Kimia                                    78                              78
# Matematika                               78                              78
# {'Matematika': 3.6666666666666714, 'Indonesia': 0.0, 'Inggris': 0.3333333333333286, 'Biologi': 78.0, 'Sosiologi': 7.0, 'Ekonomi': 5.666666666666671, 'Fisika': 78.0, 'Geografi': 1.3333333333333286, 'Kimia': 78.0}
#                ILMU PEMERINTAHAN - UNPAD (IPA)  \
# Entering Flow                              0.0
#
#                ILMU HUKUM - UPN JAKARTA (IPS)  \
# Entering Flow                             0.0
#
#                ILMU HUBUNGAN INTERNASIONAL - UNPAD (IPS)
# Entering Flow                                        0.0
#               ILMU HUBUNGAN INTERNASIONAL - UNPAD (IPS)  \
# Leaving Flow                                   0.183333
#
#               ILMU PEMERINTAHAN - UNPAD (IPA)  ILMU HUKUM - UPN JAKARTA (IPS)
# Leaving Flow                              0.0                             0.0
#           ILMU HUBUNGAN INTERNASIONAL - UNPAD (IPS)  \
# Net Flow                                   0.183333
#
#           ILMU PEMERINTAHAN - UNPAD (IPA)  ILMU HUKUM - UPN JAKARTA (IPS)
# Net Flow                              0.0                             0.0
# 63
#             GEOLOGI - UI (IPA)  GEOFISIKA - UI (IPA)  FITB - ITB (IPA)
# Biologi              80.851125             85.800000                78
# Sosiologi            85.393876             85.293746                78
# Ekonomi              82.854412             84.294339                78
# Fisika               79.824472             88.800000                78
# Indonesia            79.459956             85.400000                78
# Geografi             85.054815             84.839303                78
# Inggris              79.074141             85.000000                78
# Kimia                79.244521             87.400000                78
# Matematika           79.276118             90.000000                78
# {'Matematika': 1.0, 'Indonesia': 5.599999999999994, 'Inggris': 1.0, 'Biologi': 10.200000000000003, 'Sosiologi': 78.0, 'Ekonomi': 78.0, 'Fisika': 0.20000000000000284, 'Geografi': 78.0, 'Kimia': 0.5999999999999943}
#                GEOFISIKA - UI (IPA)  FITB - ITB (IPA)  GEOLOGI - UI (IPA)
# Entering Flow                   0.0              0.11                 0.0
#               GEOLOGI - UI (IPA)  GEOFISIKA - UI (IPA)  FITB - ITB (IPA)
# Leaving Flow            0.073333              0.201667               0.0
#           GEOFISIKA - UI (IPA)  GEOLOGI - UI (IPA)  FITB - ITB (IPA)
# Net Flow              0.201667            0.073333             -0.11
#
# 14
#             KEDOKTERAN - UI (IPA)
# Biologi                 91.000000
# Sosiologi               87.431249
# Ekonomi                 85.911949
# Fisika                  87.333333
# Indonesia               87.000000
# Geografi                84.226202
# Inggris                 93.000000
# Kimia                   90.333333
# Matematika              88.000000
# {'Matematika': 2.0, 'Indonesia': 0.0, 'Inggris': 0.0, 'Biologi': 5.0, 'Sosiologi': 87.43124865181365, 'Ekonomi': 85.91194881446319, 'Fisika': 0.3333333333333286, 'Geografi': 84.22620210572018, 'Kimia': 1.6666666666666714}
# Empty DataFrame
# Columns: []
# Index: [Entering Flow]
# Empty DataFrame
# Columns: []
# Index: [Leaving Flow]
# Empty DataFrame
# Columns: []
# Index: [Net Flow]
#
# 345
#             ILMU HUKUM - UNAIR (IPS)  ILMU HUKUM - UNS (IPS)
# Biologi                    84.769668                      78
# Sosiologi                  86.646873                      78
# Ekonomi                    87.933962                      78
# Fisika                     84.698593                      78
# Indonesia                  87.196607                      78
# Geografi                   85.919652                      78
# Inggris                    85.348854                      78
# Kimia                      85.152057                      78
# Matematika                 83.118158                      78
# {'Matematika': 1.1181577265263059, 'Indonesia': 1.80339255529411, 'Inggris': 0.6511458664872691, 'Biologi': 78.0, 'Sosiologi': 1.353127022279537, 'Ekonomi': 3.0660383891526095, 'Fisika': 78.0, 'Geografi': 1.0803484207098677, 'Kimia': 78.0}
#                ILMU HUKUM - UNS (IPS)  ILMU HUKUM - UNAIR (IPS)
# Entering Flow                  0.1925                       0.0
#               ILMU HUKUM - UNAIR (IPS)  ILMU HUKUM - UNS (IPS)
# Leaving Flow                    0.1925                     0.0
#           ILMU HUKUM - UNAIR (IPS)  ILMU HUKUM - UNS (IPS)
# Net Flow                    0.1925                 -0.1925
#
# 247
#             MATEMATIKA - UNPAD (IPA)  PENDIDIKAN MATEMATIKA - UPI (IPA)
# Biologi                    85.000000                                 78
# Sosiologi                  85.293746                                 78
# Ekonomi                    84.867923                                 78
# Fisika                     83.849296                                 78
# Indonesia                  86.196607                                 78
# Geografi                   84.839303                                 78
# Inggris                    83.000000                                 78
# Kimia                      85.000000                                 78
# Matematika                 83.500000                                 78
# {'Matematika': 0.5, 'Indonesia': 0.8033925552941099, 'Inggris': 4.0, 'Biologi': 0.0, 'Sosiologi': 78.0, 'Ekonomi': 78.0, 'Fisika': 0.8492964984576759, 'Geografi': 78.0, 'Kimia': 0.0}
#                PENDIDIKAN MATEMATIKA - UPI (IPA)  MATEMATIKA - UNPAD (IPA)
# Entering Flow                             0.1925                       0.0
#               MATEMATIKA - UNPAD (IPA)  PENDIDIKAN MATEMATIKA - UPI (IPA)
# Leaving Flow                    0.1925                                0.0
#           MATEMATIKA - UNPAD (IPA)  PENDIDIKAN MATEMATIKA - UPI (IPA)
# Net Flow                    0.1925                            -0.1925
#
# 328
#             KESEHATAN MASYARAKAT - UNAIR (IPA)  PEND.BIDAN - UNAIR (IPA)  \
# Biologi                              86.192417                        78
# Sosiologi                            85.293746                        78
# Ekonomi                              84.087248                        78
# Fisika                               83.674648                        78
# Indonesia                            87.098304                        78
# Geografi                             84.839303                        78
# Inggris                              85.174427                        78
# Kimia                                85.288014                        78
# Matematika                           85.559079                        78
#
#             PEND. BIOLOGI - UNESA (IPA)
# Biologi                              78
# Sosiologi                            78
# Ekonomi                              78
# Fisika                               78
# Indonesia                            78
# Geografi                             78
# Inggris                              78
# Kimia                                78
# Matematika                           78
# {'Matematika': 0.4409211367368471, 'Indonesia': 3.901696277647062, 'Inggris': 1.8255729332436346, 'Biologi': 2.807583074767294, 'Sosiologi': 78.0, 'Ekonomi': 78.0, 'Fisika': 3.325351750771162, 'Geografi': 78.0, 'Kimia': 6.711985714433183}
#                PEND.BIDAN - UNAIR (IPA)  PEND. BIOLOGI - UNESA (IPA)  \
# Entering Flow                       0.0                          0.0
#
#                KESEHATAN MASYARAKAT - UNAIR (IPA)
# Entering Flow                                 0.0
#               KESEHATAN MASYARAKAT - UNAIR (IPA)  PEND.BIDAN - UNAIR (IPA)  \
# Leaving Flow                                0.22                       0.0
#
#               PEND. BIOLOGI - UNESA (IPA)
# Leaving Flow                          0.0
#           KESEHATAN MASYARAKAT - UNAIR (IPA)  PEND.BIDAN - UNAIR (IPA)  \
# Net Flow                                0.22                       0.0
#
#           PEND. BIOLOGI - UNESA (IPA)
# Net Flow                          0.0
#
# 296
#             TEKNIK INFORMATIKA - UNPAD (IPA)  SISTEM INFORMASI - UNAND (IPA)  \
# Biologi                            89.000000                              78
# Sosiologi                          85.293746                              78
# Ekonomi                            90.500000                              78
# Fisika                             87.000000                              78
# Indonesia                          88.500000                              78
# Geografi                           87.201351                              78
# Inggris                            90.000000                              78
# Kimia                              91.000000                              78
# Matematika                         89.500000                              78
#
#             TEKNIK ELEKTRO - UNAND (IPA)
# Biologi                               78
# Sosiologi                             78
# Ekonomi                               78
# Fisika                                78
# Indonesia                             78
# Geografi                              78
# Inggris                               78
# Kimia                                 78
# Matematika                            78
# {'Matematika': 3.5, 'Indonesia': 0.5, 'Inggris': 1.0, 'Biologi': 0.0, 'Sosiologi': 78.0, 'Ekonomi': 78.0, 'Fisika': 1.0, 'Geografi': 78.0, 'Kimia': 0.0}
#                SISTEM INFORMASI - UNAND (IPA)  TEKNIK ELEKTRO - UNAND (IPA)  \
# Entering Flow                             0.0                           0.0
#
#                TEKNIK INFORMATIKA - UNPAD (IPA)
# Entering Flow                               0.0
#               TEKNIK INFORMATIKA - UNPAD (IPA)  \
# Leaving Flow                          0.256667
#
#               SISTEM INFORMASI - UNAND (IPA)  TEKNIK ELEKTRO - UNAND (IPA)
# Leaving Flow                             0.0                           0.0
#           TEKNIK INFORMATIKA - UNPAD (IPA)  SISTEM INFORMASI - UNAND (IPA)  \
# Net Flow                          0.256667                             0.0
#
#           TEKNIK ELEKTRO - UNAND (IPA)
# Net Flow                           0.0
#
# 258
#             ILMU KOMUNIKASI - UNPAD (IPS)
# Biologi                         85.141390
# Sosiologi                       85.715624
# Ekonomi                         86.144654
# Fisika                          84.698593
# Indonesia                       86.898869
# Geografi                        85.639884
# Inggris                         87.116285
# Kimia                           85.152057
# Matematika                      83.418915
# {'Matematika': 4.094577191858164, 'Indonesia': 1.5056542588235118, 'Inggris': 2.418576444145458, 'Biologi': 85.1413897507757, 'Sosiologi': 0.4218783704658904, 'Ekonomi': 1.2767306485876873, 'Fisika': 84.69859299691537, 'Geografi': 0.8005807011831081, 'Kimia': 85.15205714226725}
# Empty DataFrame
# Columns: []
# Index: [Entering Flow]
# Empty DataFrame
# Columns: []
# Index: [Leaving Flow]
# Empty DataFrame
# Columns: []
# Index: [Net Flow]
#
# 218
#             HUBUNGAN MASYARAKAT - UNPAD (IPS)  ILMU KOMUNIKASI - UNPAD (IPS)
# Biologi                             84.769668                      85.141390
# Sosiologi                           89.264582                      85.715624
# Ekonomi                             85.955974                      86.144654
# Fisika                              84.698593                      84.698593
# Indonesia                           86.797738                      86.898869
# Geografi                            88.613101                      85.639884
# Inggris                             85.899236                      87.116285
# Kimia                               85.152057                      85.152057
# Matematika                          81.345438                      83.418915
# {'Matematika': 1.5810845616283729, 'Indonesia': 0.10113085176470804, 'Inggris': 2.8992360890084825, 'Biologi': 84.76966770093084, 'Sosiologi': 0.2645819851469895, 'Ekonomi': 4.955974407231608, 'Fisika': 84.69859299691537, 'Geografi': 0.3868989471399118, 'Kimia': 85.15205714226725}
#                ILMU KOMUNIKASI - UNPAD (IPS)  \
# Entering Flow                         0.0825
#
#                HUBUNGAN MASYARAKAT - UNPAD (IPS)
# Entering Flow                             0.0275
#               HUBUNGAN MASYARAKAT - UNPAD (IPS)  ILMU KOMUNIKASI - UNPAD (IPS)
# Leaving Flow                             0.0825                         0.0275
#           HUBUNGAN MASYARAKAT - UNPAD (IPS)  ILMU KOMUNIKASI - UNPAD (IPS)
# Net Flow                              0.055                         -0.055
#
# 31
#             GEOLOGI - UI (IPA)
# Biologi              80.851125
# Sosiologi            85.393876
# Ekonomi              82.854412
# Fisika               79.824472
# Indonesia            79.459956
# Geografi             85.054815
# Inggris              79.074141
# Kimia                79.244521
# Matematika           79.276118
# {'Matematika': 44.77611829489473, 'Indonesia': 44.95995558352942, 'Inggris': 44.57414060013454, 'Biologi': 46.351125387849066, 'Sosiologi': 85.3938761481261, 'Ekonomi': 82.8544121962415, 'Fisika': 45.324472373843264, 'Geografi': 85.05481520677304, 'Kimia': 44.74452142835021}
# Empty DataFrame
# Columns: []
# Index: [Entering Flow]
# Empty DataFrame
# Columns: []
# Index: [Leaving Flow]
# Empty DataFrame
# Columns: []
# Index: [Net Flow]
#
# 231
#             EKONOMI ISLAM - UNPAD (IPS)  ILMU PERPUSTAKAAN - UNPAD (IPA)
# Biologi                       84.769668                               78
# Sosiologi                     84.323306                               78
# Ekonomi                       84.867923                               78
# Fisika                        84.698593                               78
# Indonesia                     85.393215                               78
# Geografi                      84.839303                               78
# Inggris                       83.552971                               78
# Kimia                         85.152057                               78
# Matematika                    85.256746                               78
# {'Matematika': 2.7432536848851043, 'Indonesia': 0.0, 'Inggris': 1.144736842105246, 'Biologi': 78.0, 'Sosiologi': 0.9704402515723274, 'Ekonomi': 0.0, 'Fisika': 78.0, 'Geografi': 0.0, 'Kimia': 78.0}
#                ILMU PERPUSTAKAAN - UNPAD (IPA)  EKONOMI ISLAM - UNPAD (IPS)
# Entering Flow                           0.2475                          0.0
#               EKONOMI ISLAM - UNPAD (IPS)  ILMU PERPUSTAKAAN - UNPAD (IPA)
# Leaving Flow                       0.2475                              0.0
#           EKONOMI ISLAM - UNPAD (IPS)  ILMU PERPUSTAKAAN - UNPAD (IPA)
# Net Flow                       0.2475                          -0.2475
#
# 330
#             PENDIDIKAN DOKTER GIGI - UNAIR (IPA)
# Biologi                                88.333333
# Sosiologi                              84.907546
# Ekonomi                                84.900358
# Fisika                                 86.666667
# Indonesia                              86.333333
# Geografi                               84.468620
# Inggris                                87.000000
# Kimia                                  88.000000
# Matematika                             86.333333
# {'Matematika': 2.6666666666666714, 'Indonesia': 5.666666666666671, 'Inggris': 4.0, 'Biologi': 2.6666666666666714, 'Sosiologi': 84.90754638006938, 'Ekonomi': 84.9003578657363, 'Fisika': 5.333333333333329, 'Geografi': 84.46862042765657, 'Kimia': 5.0}
# Empty DataFrame
# Columns: []
# Index: [Entering Flow]
# Empty DataFrame
# Columns: []
# Index: [Leaving Flow]
# Empty DataFrame
# Columns: []
# Index: [Net Flow]
#
# 151
#             GEOGRAFI - UI (IPA)
# Biologi               84.953934
# Sosiologi             85.183798
# Ekonomi               84.013799
# Fisika                85.339719
# Indonesia             86.278643
# Geografi              84.855373
# Inggris               83.339542
# Kimia                 85.330411
# Matematika            84.723632
# {'Matematika': 9.276368454694733, 'Indonesia': 1.278642977882356, 'Inggris': 2.3395416534050923, 'Biologi': 6.953933540186171, 'Sosiologi': 85.183798032515, 'Ekonomi': 84.01379936378075, 'Fisika': 0.660281400616924, 'Geografi': 84.85537284272223, 'Kimia': 2.330411428453459}
# Empty DataFrame
# Columns: []
# Index: [Entering Flow]
# Empty DataFrame
# Columns: []
# Index: [Leaving Flow]
# Empty DataFrame
# Columns: []
# Index: [Net Flow]
# 155
#             MATEMATIKA - UI (IPA)  MANAJEMEN - IPB (IPS)
# Biologi                 85.905359                     78
# Sosiologi               85.940862                     78
# Ekonomi                 84.691181                     78
# Fisika                  87.284507                     78
# Indonesia               86.261017                     78
# Geografi                84.839303                     78
# Inggris                 86.592131                     78
# Kimia                   87.088620                     78
# Matematika              91.769231                     78
# {'Matematika': 1.2307692307692264, 'Indonesia': 0.8678016405429787, 'Inggris': 1.8944231381303638, 'Biologi': 1.1356913529869104, 'Sosiologi': 78.0, 'Ekonomi': 78.0, 'Fisika': 2.585914156693491, 'Geografi': 78.0, 'Kimia': 1.9365626379071728}
#                MANAJEMEN - IPB (IPS)  MATEMATIKA - UI (IPA)
# Entering Flow                 0.3025                    0.0
#               MATEMATIKA - UI (IPA)  MANAJEMEN - IPB (IPS)
# Leaving Flow                 0.3025                    0.0
#           MATEMATIKA - UI (IPA)  MANAJEMEN - IPB (IPS)
# Net Flow                 0.3025                -0.3025
#
# 160
#             KEDOKTERAN HEWAN - UNPAD (IPA)  AGROTEKNOLOGI - UNPAD (IPA)
# Biologi                          84.769668                    83.250000
# Sosiologi                        85.293746                    84.768876
# Ekonomi                          84.867923                    84.166575
# Fisika                           84.698593                    80.500000
# Indonesia                        85.393215                    84.000000
# Geografi                         84.839303                    84.554815
# Inggris                          84.697708                    82.750000
# Kimia                            85.152057                    81.500000
# Matematika                       84.236315                    82.500000
# {'Matematika': 0.0, 'Indonesia': 0.0, 'Inggris': 0.0, 'Biologi': 0.0, 'Sosiologi': 84.7688761481261, 'Ekonomi': 84.16657518775705, 'Fisika': 1.4210854715202004e-14, 'Geografi': 84.55481520677304, 'Kimia': 0.0}
#                AGROTEKNOLOGI - UNPAD (IPA)  KEDOKTERAN HEWAN - UNPAD (IPA)
# Entering Flow                        0.165                             0.0
#               KEDOKTERAN HEWAN - UNPAD (IPA)  AGROTEKNOLOGI - UNPAD (IPA)
# Leaving Flow                           0.165                          0.0
#           KEDOKTERAN HEWAN - UNPAD (IPA)  AGROTEKNOLOGI - UNPAD (IPA)
# Net Flow                           0.165                       -0.165
#
# 5
#             ILMU KOMUNIKASI - UI (IPS)
# Biologi                      84.769668
# Sosiologi                    88.431249
# Ekonomi                      86.666667
# Fisika                       84.698593
# Indonesia                    87.000000
# Geografi                     84.666667
# Inggris                      86.232569
# Kimia                        85.152057
# Matematika                   83.666667
# {'Matematika': 3.3333333333333286, 'Indonesia': 1.0, 'Inggris': 0.23256942234182532, 'Biologi': 84.76966770093084, 'Sosiologi': 3.5687513481863533, 'Ekonomi': 1.3333333333333286, 'Fisika': 84.69859299691537, 'Geografi': 3.3333333333333286, 'Kimia': 85.15205714226724}
# Empty DataFrame
# Columns: []
# Index: [Entering Flow]
# Empty DataFrame
# Columns: []
# Index: [Leaving Flow]
# Empty DataFrame
# Columns: []
# Index: [Net Flow]
#
# 176
#             MANAJEMEN - UNPAD (IPS)  ADMINISTRASI BISNIS - UNPAD (IPS)  \
# Biologi                   85.637629                                 78
# Sosiologi                 90.000000                                 78
# Ekonomi                   91.000000                                 78
# Fisika                    84.909651                                 78
# Indonesia                 90.000000                                 78
# Geografi                  87.000000                                 78
# Inggris                   83.000000                                 78
# Kimia                     84.085220                                 78
# Matematika                86.000000                                 78
#
#             PEND. AKUNTANSI - UNJ (IPS)
# Biologi                              78
# Sosiologi                            78
# Ekonomi                              78
# Fisika                               78
# Indonesia                            78
# Geografi                             78
# Inggris                              78
# Kimia                                78
# Matematika                           78
# {'Matematika': 0.0, 'Indonesia': 0.0, 'Inggris': 0.0, 'Biologi': 78.0, 'Sosiologi': 0.0, 'Ekonomi': 0.0, 'Fisika': 78.0, 'Geografi': 0.0, 'Kimia': 78.0}
#                ADMINISTRASI BISNIS - UNPAD (IPS)  PEND. AKUNTANSI - UNJ (IPS)  \
# Entering Flow                                0.0                          0.0
#
#                MANAJEMEN - UNPAD (IPS)
# Entering Flow                      0.0
#               MANAJEMEN - UNPAD (IPS)  ADMINISTRASI BISNIS - UNPAD (IPS)  \
# Leaving Flow                     0.22                                0.0
#
#               PEND. AKUNTANSI - UNJ (IPS)
# Leaving Flow                          0.0
#           MANAJEMEN - UNPAD (IPS)  ADMINISTRASI BISNIS - UNPAD (IPS)  \
# Net Flow                     0.22                                0.0
#
#           PEND. AKUNTANSI - UNJ (IPS)
# Net Flow                          0.0
#
# 132
#             FISIKA - UI (IPA)  AKUNTANSI - UI (IPS)  FISIKA - UNRAM (IPA)
# Biologi             84.476967             84.769668                    78
# Sosiologi           85.183798             86.813540                    78
# Ekonomi             84.890861             86.933962                    78
# Fisika              87.369859             84.698593                    78
# Indonesia           84.439321             85.363274                    78
# Geografi            84.727782             87.419652                    78
# Inggris             84.969771             84.348854                    78
# Kimia               83.915206             85.152057                    78
# Matematika          86.123632             88.284824                    78
# {'Matematika': 1.2848243931929773, 'Indonesia': 0.6367258886274385, 'Inggris': 2.0302291732974567, 'Biologi': 2.230332299069161, 'Sosiologi': 78.0, 'Ekonomi': 78.0, 'Fisika': 7.630140700308459, 'Geografi': 78.0, 'Kimia': 2.152057142267253}
#                AKUNTANSI - UI (IPS)  FISIKA - UNRAM (IPA)  FISIKA - UI (IPA)
# Entering Flow                   0.0              0.073333                0.0
#               FISIKA - UI (IPA)  AKUNTANSI - UI (IPS)  FISIKA - UNRAM (IPA)
# Leaving Flow           0.128333                  0.11                   0.0
#           FISIKA - UI (IPA)  AKUNTANSI - UI (IPS)  FISIKA - UNRAM (IPA)
# Net Flow           0.128333                  0.11             -0.073333
#
# 66
#             ILMU HUBUNGAN INTERNASIONAL - UI (IPS)  \
# Biologi                                  84.769668
# Sosiologi                                85.000000
# Ekonomi                                  87.622641
# Fisika                                   84.698593
# Indonesia                                84.000000
# Geografi                                 86.666667
# Inggris                                  84.000000
# Kimia                                    85.152057
# ...
# Entering Flow                      0.0                             0.0
#
#                KIMIA - UNAIR (IPA)
# Entering Flow                  0.0
#               KIMIA - UNAIR (IPA)  ILMU GIZI - UNAIR (IPA)  \
# Leaving Flow                 0.22                      0.0
#
#               TEKNIK KIMIA - UPN JATIM (IPA)
# Leaving Flow                             0.0
#           KIMIA - UNAIR (IPA)  ILMU GIZI - UNAIR (IPA)  \
# Net Flow                 0.22                      0.0
#
#           TEKNIK KIMIA - UPN JATIM (IPA)
# Net Flow                             0.0
#
# 362
#             MANAJEMEN - UNAIR (IPS)  HUKUM - UNAIR (IPS)  \
# Biologi                   86.537173            83.846445
# Sosiologi                 86.646873            85.293746
# Ekonomi                   86.183962            84.867923
# Fisika                    86.498418            84.132395
# Indonesia                 85.836777            85.595477
# Geografi                  84.169652            84.839303
# Inggris                   87.367963            86.131806
# Kimia                     86.881070            84.434705
# Matematika                88.775594            83.824210
#
#             MANAJEMEN - UNEJ (IPS)
# Biologi                         78
# Sosiologi                       78
# Ekonomi                         78
# Fisika                          78
# Indonesia                       78
# Geografi                        78
# Inggris                         78
# Kimia                           78
# Matematika                      78
# {'Matematika': 3.0904665912822935, 'Indonesia': 5.117116838394708, 'Inggris': 2.4061804098791555, 'Biologi': 5.302517265538967, 'Sosiologi': 78.0, 'Ekonomi': 78.0, 'Fisika': 5.399476304945054, 'Geografi': 78.0, 'Kimia': 5.187038224380643}
#                HUKUM - UNAIR (IPS)  MANAJEMEN - UNEJ (IPS)  \
# Entering Flow                  0.0                   0.055
#
#                MANAJEMEN - UNAIR (IPS)
# Entering Flow                      0.0
#               MANAJEMEN - UNAIR (IPS)  HUKUM - UNAIR (IPS)  \
# Leaving Flow                 0.073333                0.055
#
#               MANAJEMEN - UNEJ (IPS)
# Leaving Flow                     0.0
#           MANAJEMEN - UNAIR (IPS)  HUKUM - UNAIR (IPS)  MANAJEMEN - UNEJ (IPS)
# Net Flow                 0.073333                0.055                  -0.055
#
# 250
#             STATISTIKA - UNPAD (IPA)  TEKNIK PWK - UNDIP (IPA)
# Biologi                    84.179778                        78
# Sosiologi                  85.293746                        78
# Ekonomi                    84.233691                        78
# Fisika                     83.465729                        78
# Indonesia                  84.595477                        78
# Geografi                   84.839303                        78
# Inggris                    83.131806                        78
# Kimia                      83.768038                        78
# Matematika                 83.745438                        78
# {'Matematika': 4.254561515649129, 'Indonesia': 0.7977382964705981, 'Inggris': 1.5659027556751397, 'Biologi': 0.5898892336436177, 'Sosiologi': 78.0, 'Ekonomi': 78.0, 'Fisika': 1.232864332305141, 'Geografi': 78.0, 'Kimia': 1.384019047422413}
#                TEKNIK PWK - UNDIP (IPA)  STATISTIKA - UNPAD (IPA)
# Entering Flow                     0.165                       0.0
#               STATISTIKA - UNPAD (IPA)  TEKNIK PWK - UNDIP (IPA)
# Leaving Flow                     0.165                       0.0
#           STATISTIKA - UNPAD (IPA)  TEKNIK PWK - UNDIP (IPA)
# Net Flow                     0.165                    -0.165
#
# 291
#             GEOFISIKA - UNPAD (IPA)  PETERNAKAN - UNPAD (IPA)  \
# Biologi                   82.333333                 85.827251
# Sosiologi                 84.593920                 85.293746
# Ekonomi                   84.233691                 86.150942
# Fisika                    85.333333                 84.023945
# Indonesia                 84.333333                 86.044911
# Geografi                  84.126653                 84.839303
# Inggris                   83.666667                 84.273281
# Kimia                     83.333333                 85.364043
# Matematika                86.000000                 84.177237
#
#             TEKNIK SIPIL - UPI (IPA)
# Biologi                           78
# Sosiologi                         78
# Ekonomi                           78
# Fisika                            78
# Indonesia                         78
# Geografi                          78
# Inggris                           78
# Kimia                             78
# Matematika                        78
# {'Matematika': 7.0, 'Indonesia': 1.9550888329411578, 'Inggris': 1.2732812002690963, 'Biologi': 2.8272507756981184, 'Sosiologi': 78.0, 'Ekonomi': 78.0, 'Fisika': 3.6666666666666714, 'Geografi': 78.0, 'Kimia': 2.635957143299578}
#                PETERNAKAN - UNPAD (IPA)  TEKNIK SIPIL - UPI (IPA)  \
# Entering Flow                       0.0                  0.128333
#
#                GEOFISIKA - UNPAD (IPA)
# Entering Flow                      0.0
#               GEOFISIKA - UNPAD (IPA)  PETERNAKAN - UNPAD (IPA)  \
# Leaving Flow                 0.128333                  0.146667
#
#               TEKNIK SIPIL - UPI (IPA)
# Leaving Flow                       0.0
#           PETERNAKAN - UNPAD (IPA)  GEOFISIKA - UNPAD (IPA)  \
# Net Flow                  0.146667                 0.128333
#
#           TEKNIK SIPIL - UPI (IPA)
# Net Flow                 -0.128333
#
# 32
#             HUKUM - UI (IPS)  PSIKOLOGI - UI (IPS)  HUKUM - UNPAD (IPS)
# Biologi            84.769668             82.544241            78.195734
# Sosiologi          89.323436             85.646873            83.976248
# Ekonomi            88.966981             85.183962            84.120754
# Fisika             84.698593             82.576709            84.340805
# Indonesia          87.098304             84.848304            84.635929
# Geografi           86.709826             82.669652            83.503582
# Inggris            85.424427             81.674427            85.018625
# Kimia              85.152057             84.614043            85.152057
# Matematika         82.559079             82.250000            83.741789
# {'Matematika': 0.4945261812210475, 'Indonesia': 0.7572859557647007, 'Inggris': 0.7267187997309179, 'Biologi': 0.0, 'Sosiologi': 83.97624757326454, 'Ekonomi': 84.12075393301686, 'Fisika': 1.4210854715202004e-14, 'Geografi': 82.66965157929013, 'Kimia': 0.0}
#                PSIKOLOGI - UI (IPS)  HUKUM - UNPAD (IPS)  HUKUM - UI (IPS)
# Entering Flow                 0.055                  0.0          0.018333
#               HUKUM - UI (IPS)  PSIKOLOGI - UI (IPS)  HUKUM - UNPAD (IPS)
# Leaving Flow              0.11                   0.0             0.073333
#           HUKUM - UI (IPS)  HUKUM - UNPAD (IPS)  PSIKOLOGI - UI (IPS)
# Net Flow          0.091667             0.073333                -0.055
#
# 55
#             GEOLOGI - UI (IPA)  TEKNIK LINGKUNGAN - UI (IPA)
# Biologi              80.851125                            78
# Sosiologi            85.393876                            78
# Ekonomi              82.854412                            78
# Fisika               79.824472                            78
# Indonesia            79.459956                            78
# Geografi             85.054815                            78
# Inggris              79.074141                            78
# Kimia                79.244521                            78
# Matematika           79.276118                            78
# {'Matematika': 4.960197158157882, 'Indonesia': 5.933259305882359, 'Inggris': 5.6235676668909065, 'Biologi': 3.9185423130817725, 'Sosiologi': 78.0, 'Ekonomi': 78.0, 'Fisika': 4.874120623072116, 'Geografi': 78.0, 'Kimia': 5.907535713917028}
#                TEKNIK LINGKUNGAN - UI (IPA)  GEOLOGI - UI (IPA)
# Entering Flow                           0.0                 0.0
#               GEOLOGI - UI (IPA)  TEKNIK LINGKUNGAN - UI (IPA)
# Leaving Flow                 0.0                           0.0
#           GEOLOGI - UI (IPA)  TEKNIK LINGKUNGAN - UI (IPA)
# Net Flow                 0.0                           0.0
#
# 299
#             KEDOKTERAN - UNAIR (IPA)  KEDOKTERAN GIGI - UNAIR (IPA)
# Biologi                    87.261801                      84.769668
# Sosiologi                  85.634997                      85.293746
# Ekonomi                    85.720754                      84.867923
# Fisika                     86.619156                      84.698593
# Indonesia                  87.435929                      85.393215
# Geografi                   85.671443                      84.839303
# Inggris                    86.218625                      84.697708
# Kimia                      87.291234                      85.152057
# Matematika                 87.541789                      84.236315
# {'Matematika': 0.0, 'Indonesia': 0.0, 'Inggris': 0.0, 'Biologi': 0.0, 'Sosiologi': 85.29374595544093, 'Ekonomi': 84.86792322169478, 'Fisika': 1.4210854715202004e-14, 'Geografi': 84.83930315858026, 'Kimia': 0.0}
#                KEDOKTERAN GIGI - UNAIR (IPA)  KEDOKTERAN - UNAIR (IPA)
# Entering Flow                         0.1925                       0.0
#               KEDOKTERAN - UNAIR (IPA)  KEDOKTERAN GIGI - UNAIR (IPA)
# Leaving Flow                    0.1925                            0.0
#           KEDOKTERAN - UNAIR (IPA)  KEDOKTERAN GIGI - UNAIR (IPA)
# Net Flow                    0.1925                        -0.1925
#
# 175
#             ILMU ADMINISTRASI BISNIS - UNPAD (IPS)  \
# Biologi                                  84.815734
# Sosiologi                                85.176248
# Ekonomi                                  83.720754
# Fisika                                   84.740805
# Indonesia                                85.235929
# Geografi                                 84.103582
# Inggris                                  83.818625
# Kimia                                    85.152057
# Matematika                               80.601789
#
#             ILMU ADMINISTRASI NEGARA - UNPAD (IPS)  \
# Biologi                                  83.637629
# Sosiologi                                88.000000
# Ekonomi                                  83.000000
# Fisika                                   82.909651
# Indonesia                                86.000000
# Geografi                                 87.000000
# Inggris                                  87.000000
# Kimia                                    82.085220
# Matematika                               90.000000
#
#             EKONONI PEMBANGUNAN - UNSOED (IPA)
# Biologi                                     78
# Sosiologi                                   78
# Ekonomi                                     78
# Fisika                                      78
# Indonesia                                   78
# Geografi                                    78
# Inggris                                     78
# Kimia                                       78
# Matematika                                  78
# {'Matematika': 5.763684546947388, 'Indonesia': 0.6067851105882198, 'Inggris': 2.3022917329745525, 'Biologi': 78.0, 'Sosiologi': 2.70625404455906, 'Ekonomi': 1.1471692886779152, 'Fisika': 78.0, 'Geografi': 2.1606968414197354, 'Kimia': 78.0}
#                ILMU ADMINISTRASI NEGARA - UNPAD (IPS)  \
# Entering Flow                                     0.0
#
#                EKONONI PEMBANGUNAN - UNSOED (IPA)  \
# Entering Flow                            0.201667
#
#                ILMU ADMINISTRASI BISNIS - UNPAD (IPS)
# Entering Flow                                     0.0
#               ILMU ADMINISTRASI BISNIS - UNPAD (IPS)  \
# Leaving Flow                                0.091667
#
#               ILMU ADMINISTRASI NEGARA - UNPAD (IPS)  \
# Leaving Flow                                0.311667
#
#               EKONONI PEMBANGUNAN - UNSOED (IPA)
# Leaving Flow                                 0.0
#           ILMU ADMINISTRASI NEGARA - UNPAD (IPS)  \
# Net Flow                                0.311667
#
#           ILMU ADMINISTRASI BISNIS - UNPAD (IPS)  \
# Net Flow                                0.091667
#
#           EKONONI PEMBANGUNAN - UNSOED (IPA)
# Net Flow                           -0.201667
#
# 335
#             MANAJEMEN - UNAIR (IPS)  SOSIOLOGI - UNAIR (IPS)
# Biologi                   86.537173                84.849822
# Sosiologi                 86.646873                87.146873
# Ekonomi                   86.183962                85.933962
# Fisika                    86.498418                84.698593
# Indonesia                 85.836777                86.196607
# Geografi                  84.169652                88.919652
# Inggris                   87.367963                89.348854
# Kimia                     86.881070                85.152057
# Matematika                88.775594                87.118158
# {'Matematika': 3.118157726526306, 'Indonesia': 3.8367772426021673, 'Inggris': 2.3679628923015343, 'Biologi': 84.8498223401061, 'Sosiologi': 3.853127022279537, 'Ekonomi': 0.06603838915260951, 'Fisika': 84.69859299691537, 'Geografi': 0.1696515792901323, 'Kimia': 85.15205714226724}
#                SOSIOLOGI - UNAIR (IPS)  MANAJEMEN - UNAIR (IPS)
# Entering Flow                    0.055                   0.0275
#               MANAJEMEN - UNAIR (IPS)  SOSIOLOGI - UNAIR (IPS)
# Leaving Flow                    0.055                   0.0275
#           MANAJEMEN - UNAIR (IPS)  SOSIOLOGI - UNAIR (IPS)
# Net Flow                   0.0275                  -0.0275
#
# 34
#             GEOGRAF - UI (IPA)  FISIKA - UI (IPA)
# Biologi              85.000000          84.476967
# Sosiologi            84.880138          85.183798
# Ekonomi              84.965227          84.890861
# Fisika               80.000000          87.369859
# Indonesia            84.000000          84.439321
# Geografi             82.701351          84.727782
# Inggris              86.000000          84.969771
# Kimia                85.000000          83.915206
# Matematika           85.000000          86.123632
# {'Matematika': 0.0, 'Indonesia': 0.0, 'Inggris': 0.0, 'Biologi': 0.0, 'Sosiologi': 84.880138179569, 'Ekonomi': 84.89086129273777, 'Fisika': 0.0, 'Geografi': 82.70135135135135, 'Kimia': 0.0}
#                FISIKA - UI (IPA)  GEOGRAF - UI (IPA)
# Entering Flow             0.0825              0.0825
#               GEOGRAF - UI (IPA)  FISIKA - UI (IPA)
# Leaving Flow              0.0825             0.0825
#           GEOGRAF - UI (IPA)  FISIKA - UI (IPA)
# Net Flow                 0.0                0.0
#
# 99
#             ILMU EKONOMI - UI (IPS)  ILMU ADMINISTRASI NEGARA - UI (IPS)
# Biologi                   87.884834                            84.769668
# Sosiologi                 85.293746                            84.000000
# Ekonomi                   85.433962                            86.000000
# Fisika                    88.849296                            83.000000
# Indonesia                 89.196607                            83.000000
# Geografi                  84.839303                            84.000000
# Inggris                   88.848854                            84.000000
# Kimia                     89.076029                            85.152057
# Matematika                88.618158                            83.000000
# {'Matematika': 1.2363154530526117, 'Indonesia': 2.39321488941178, 'Inggris': 0.6977082670254475, 'Biologi': 84.76966770093084, 'Sosiologi': 1.4210854715202004e-14, 'Ekonomi': 0.5660383891526095, 'Fisika': 83.0, 'Geografi': 0.0, 'Kimia': 85.15205714226724}
#                ILMU ADMINISTRASI NEGARA - UI (IPS)  ILMU EKONOMI - UI (IPS)
# Entering Flow                                 0.22                      0.0
#               ILMU EKONOMI - UI (IPS)  ILMU ADMINISTRASI NEGARA - UI (IPS)
# Leaving Flow                     0.22                                  0.0
#           ILMU EKONOMI - UI (IPS)  ILMU ADMINISTRASI NEGARA - UI (IPS)
# Net Flow                     0.22                                -0.22

# %%
hasil_tabel = pd.DataFrame(hasil, index = data_test.index[:stop-1])

# %%
hasil_tabel
# Out:
#                                 Rekomendasi  \
# 24           TEKNOLOGI BIOPROSES - UI (IPA)
# 33                         KIMIA - UI (IPA)
# 371         BUDIDAYA PERAIRAN - UNAIR (IPA)
# 8                KEDOKTERAN GIGI - UI (IPA)
# 180                   FARMASI - UNPAD (IPA)
# ..                                      ...
# 299                KEDOKTERAN - UNAIR (IPA)
# 175  ILMU ADMINISTRASI NEGARA - UNPAD (IPS)
# 335                 MANAJEMEN - UNAIR (IPS)
# 34                       GEOGRAF - UI (IPA)
# 99                  ILMU EKONOMI - UI (IPS)
#
#                                        Riil
# 24           TEKNOLOGI BIOPROSES - UI (IPA)
# 33                         KIMIA - UI (IPA)
# 371         BUDIDAYA PERAIRAN - UNAIR (IPA)
# 8                KEDOKTERAN GIGI - UI (IPA)
# 180                   FARMASI - UNPAD (IPA)
# ..                                      ...
# 299                KEDOKTERAN - UNAIR (IPA)
# 175  ILMU ADMINISTRASI BISNIS - UNPAD (IPS)
# 335                 MANAJEMEN - UNAIR (IPS)
# 34                       GEOGRAF - UI (IPA)
# 99                  ILMU EKONOMI - UI (IPS)
#
# [100 rows x 2 columns]

# %%
i = 1
for index in hasil_tabel.index:
    for column in hasil_tabel.columns:
        if column != "Riil":
            if hasil_tabel.loc[index, column] == hasil_tabel.loc[index, "Riil"]:
                pil1 = data_test.loc[index, 'Pilihan I']
                pil2 = data_test.loc[index, 'Pilihan II']
                pil3 = data_test.loc[index, 'Pilihan III']
                terima = hasil_tabel.loc[index, "Riil"]
                print(f"""{i}
                index: {index}
                rekomendasi sistem: {hasil_tabel.loc[index, column]}
                pilihan I: {pil1}
                pilihan II: {pil2}
                pilihan III: {pil3}
                diterima dijurusan: {terima}
                """)
                print()
                i += 1
# Out:
# 1
#                 index: 24
#                 rekomendasi sistem: TEKNOLOGI BIOPROSES - UI (IPA)
#                 pilihan I: TEKNOLOGI BIOPROSES - UI (IPA)
#                 pilihan II: PSIKOLOGI - UI (IPS)
#                 pilihan III: HUBUNGAN INTERNASIONAL - UNPAD (IPS)
#                 diterima dijurusan: TEKNOLOGI BIOPROSES - UI (IPA)
#
#
# 2
#                 index: 33
#                 rekomendasi sistem: KIMIA - UI (IPA)
#                 pilihan I: KIMIA - UI (IPA)
#                 pilihan II: KOSONG
#                 pilihan III: KOSONG
#                 diterima dijurusan: KIMIA - UI (IPA)
#
#
# 3
#                 index: 371
#                 rekomendasi sistem: BUDIDAYA PERAIRAN - UNAIR (IPA)
#                 pilihan I: BUDIDAYA PERAIRAN - UNAIR (IPA)
#                 pilihan II: TEKNIK LINGKUNGAN - UPN JATIM (IPA)
#                 pilihan III: TEKNIK PANGAN - UPN JATIM (IPA)
#                 diterima dijurusan: BUDIDAYA PERAIRAN - UNAIR (IPA)
#
#
# 4
#                 index: 8
#                 rekomendasi sistem: KEDOKTERAN GIGI - UI (IPA)
#                 pilihan I: KEDOKTERAN GIGI - UI (IPA)
#                 pilihan II: KOSONG
#                 pilihan III: KOSONG
#                 diterima dijurusan: KEDOKTERAN GIGI - UI (IPA)
#
#
# 5
#                 index: 180
#                 rekomendasi sistem: FARMASI - UNPAD (IPA)
#                 pilihan I: FARMASI - UNPAD (IPA)
#                 pilihan II: PENDIDIKAN MATEMATIKA - UPI (IPA)
#                 pilihan III: KOSONG
#                 diterima dijurusan: FARMASI - UNPAD (IPA)
#
#
# 6
#                 index: 249
#                 rekomendasi sistem: HUBUNGAN MASYARAKAT - UNPAD (IPS)
#                 pilihan I: HUBUNGAN MASYARAKAT - UNPAD (IPS)
#                 pilihan II: PSIKOLOGI - UPI (IPS)
#                 pilihan III: ILMU KOMUNIKASI - UPI (IPS)
#                 diterima dijurusan: HUBUNGAN MASYARAKAT - UNPAD (IPS)
#
#
# 7
#                 index: 301
#                 rekomendasi sistem: KEDOKTERAN - UNAIR (IPA)
#                 pilihan I: KEDOKTERAN - UNAIR (IPA)
#                 pilihan II: KOSONG
#                 pilihan III: KOSONG
#                 diterima dijurusan: KEDOKTERAN - UNAIR (IPA)
#
#
# 8
#                 index: 222
#                 rekomendasi sistem: AKUNTANSI - UNPAD (IPS)
#                 pilihan I: AKUNTANSI - UNPAD (IPS)
#                 pilihan II: EKONOMI ISLAM - UNPAD (IPS)
#                 pilihan III: AKUNTANSI - UPI (IPS)
#                 diterima dijurusan: AKUNTANSI - UNPAD (IPS)
#
#
# 9
#                 index: 156
#                 rekomendasi sistem: ARKEOLOGI - UI (IPS)
#                 pilihan I: ARKEOLOGI - UI (IPS)
#                 pilihan II: KOSONG
#                 pilihan III: EKONOMI PERTANIAN - UIN JAKARTA (IPS)
#                 diterima dijurusan: ARKEOLOGI - UI (IPS)
#
#
# 10
#                 index: 300
#                 rekomendasi sistem: HUKUM - UNAIR (IPS)
#                 pilihan I: HUKUM - UNAIR (IPS)
#                 pilihan II: PSIKOLOGI - UNAIR (IPS)
#                 pilihan III: PSIKOLOGI - UNS (IPS)
#                 diterima dijurusan: HUKUM - UNAIR (IPS)
#
#
# 11
#                 index: 174
#                 rekomendasi sistem: HUBUNGAN INTERNASIONAL - UNPAD (IPS)
#                 pilihan I: HUBUNGAN INTERNASIONAL - UNPAD (IPS)
#                 pilihan II: KOSONG
#                 pilihan III: KOSONG
#                 diterima dijurusan: HUBUNGAN INTERNASIONAL - UNPAD (IPS)
#
#
# 12
#                 index: 373
#                 rekomendasi sistem: BUDIDAYA PERAIRAN - UNAIR (IPA)
#                 pilihan I: BUDIDAYA PERAIRAN - UNAIR (IPA)
#                 pilihan II: FISIKA - UNAIR (IPA)
#                 pilihan III: TEKNIK INDUSTRI - UPN JATIM (IPA)
#                 diterima dijurusan: BUDIDAYA PERAIRAN - UNAIR (IPA)
#
#
# 13
#                 index: 305
#                 rekomendasi sistem: BIOLOGI - UNAIR (IPA)
#                 pilihan I: BIOLOGI - UNAIR (IPA)
#                 pilihan II: KOSONG
#                 pilihan III: KOSONG
#                 diterima dijurusan: BIOLOGI - UNAIR (IPA)
#
#
# 14
#                 index: 10
#                 rekomendasi sistem: AKUNTANSI - UI (IPS)
#                 pilihan I: AKUNTANSI - UI (IPS)
#                 pilihan II: ADMINISTRASI NIAGA - UI (IPS)
#                 pilihan III: KOSONG
#                 diterima dijurusan: AKUNTANSI - UI (IPS)
#
#
# 15
#                 index: 283
#                 rekomendasi sistem: AGRIBISNIS - UNPAD (IPS)
#                 pilihan I: AGRIBISNIS - UNPAD (IPS)
#                 pilihan II: KOSONG
#                 pilihan III: KOSONG
#                 diterima dijurusan: AGRIBISNIS - UNPAD (IPS)
#
#
# 16
#                 index: 107
#                 rekomendasi sistem: FILSAFAT - UI (IPS)
#                 pilihan I: FILSAFAT - UI (IPS)
#                 pilihan II: KOSONG
#                 pilihan III: KOSONG
#                 diterima dijurusan: FILSAFAT - UI (IPS)
#
#
# 17
#                 index: 209
#                 rekomendasi sistem: ILMU HUBUNGAN INTERNASIONAL - UNPAD (IPS)
#                 pilihan I: ILMU HUBUNGAN INTERNASIONAL - UNPAD (IPS)
#                 pilihan II: ILMU PEMERINTAHAN - UNPAD (IPA)
#                 pilihan III: ILMU HUKUM - UPN JAKARTA (IPS)
#                 diterima dijurusan: ILMU HUBUNGAN INTERNASIONAL - UNPAD (IPS)
#
#
# 18
#                 index: 14
#                 rekomendasi sistem: KEDOKTERAN - UI (IPA)
#                 pilihan I: KEDOKTERAN - UI (IPA)
#                 pilihan II: KOSONG
#                 pilihan III: KOSONG
#                 diterima dijurusan: KEDOKTERAN - UI (IPA)
#
#
# 19
#                 index: 345
#                 rekomendasi sistem: ILMU HUKUM - UNAIR (IPS)
#                 pilihan I: ILMU HUKUM - UNAIR (IPS)
#                 pilihan II: ILMU HUKUM - UNS (IPS)
#                 pilihan III: KOSONG
#                 diterima dijurusan: ILMU HUKUM - UNAIR (IPS)
#
#
# 20
#                 index: 247
#                 rekomendasi sistem: MATEMATIKA - UNPAD (IPA)
#                 pilihan I: MATEMATIKA - UNPAD (IPA)
#                 pilihan II: PENDIDIKAN MATEMATIKA - UPI (IPA)
#                 pilihan III: KOSONG
#                 diterima dijurusan: MATEMATIKA - UNPAD (IPA)
#
#
# 21
#                 index: 328
#                 rekomendasi sistem: KESEHATAN MASYARAKAT - UNAIR (IPA)
#                 pilihan I: KESEHATAN MASYARAKAT - UNAIR (IPA)
#                 pilihan II: PEND.BIDAN - UNAIR (IPA)
#                 pilihan III: PEND. BIOLOGI - UNESA (IPA)
#                 diterima dijurusan: KESEHATAN MASYARAKAT - UNAIR (IPA)
#
#
# 22
#                 index: 296
#                 rekomendasi sistem: TEKNIK INFORMATIKA - UNPAD (IPA)
#                 pilihan I: TEKNIK INFORMATIKA - UNPAD (IPA)
#                 pilihan II: SISTEM INFORMASI - UNAND (IPA)
#                 pilihan III: TEKNIK ELEKTRO - UNAND (IPA)
#                 diterima dijurusan: TEKNIK INFORMATIKA - UNPAD (IPA)
#
#
# 23
#                 index: 258
#                 rekomendasi sistem: ILMU KOMUNIKASI - UNPAD (IPS)
#                 pilihan I: ILMU KOMUNIKASI - UNPAD (IPS)
#                 pilihan II: KOSONG
#                 pilihan III: KOSONG
#                 diterima dijurusan: ILMU KOMUNIKASI - UNPAD (IPS)
#
#
# 24
#                 index: 218
#                 rekomendasi sistem: HUBUNGAN MASYARAKAT - UNPAD (IPS)
#                 pilihan I: HUBUNGAN MASYARAKAT - UNPAD (IPS)
#                 pilihan II: ILMU KOMUNIKASI - UNPAD (IPS)
#                 pilihan III: KOSONG
#                 diterima dijurusan: HUBUNGAN MASYARAKAT - UNPAD (IPS)
#
#
# 25
#                 index: 31
#                 rekomendasi sistem: GEOLOGI - UI (IPA)
#                 pilihan I: GEOLOGI - UI (IPA)
#                 pilihan II: KOSONG
#                 pilihan III: KOSONG
#                 diterima dijurusan: GEOLOGI - UI (IPA)
#
#
# 26
#                 index: 231
#                 rekomendasi sistem: EKONOMI ISLAM - UNPAD (IPS)
#                 pilihan I: EKONOMI ISLAM - UNPAD (IPS)
#                 pilihan II: ILMU PERPUSTAKAAN - UNPAD (IPA)
#                 pilihan III: KOSONG
#                 diterima dijurusan: EKONOMI ISLAM - UNPAD (IPS)
#
#
# 27
#                 index: 330
#                 rekomendasi sistem: PENDIDIKAN DOKTER GIGI - UNAIR (IPA)
#                 pilihan I: PENDIDIKAN DOKTER GIGI - UNAIR (IPA)
#                 pilihan II: KOSONG
#                 pilihan III: KOSONG
#                 diterima dijurusan: PENDIDIKAN DOKTER GIGI - UNAIR (IPA)
#
#
# 28
#                 index: 151
#                 rekomendasi sistem: GEOGRAFI - UI (IPA)
#                 pilihan I: GEOGRAFI - UI (IPA)
#                 pilihan II: KOSONG
#                 pilihan III: KOSONG
#                 diterima dijurusan: GEOGRAFI - UI (IPA)
#
#
# 29
#                 index: 155
#                 rekomendasi sistem: MATEMATIKA - UI (IPA)
#                 pilihan I: MATEMATIKA - UI (IPA)
#                 pilihan II: KOSONG
#                 pilihan III: MANAJEMEN - IPB (IPS)
#                 diterima dijurusan: MATEMATIKA - UI (IPA)
#
#
# 30
#                 index: 160
#                 rekomendasi sistem: KEDOKTERAN HEWAN - UNPAD (IPA)
#                 pilihan I: KEDOKTERAN HEWAN - UNPAD (IPA)
#                 pilihan II: AGROTEKNOLOGI - UNPAD (IPA)
#                 pilihan III: KOSONG
#                 diterima dijurusan: KEDOKTERAN HEWAN - UNPAD (IPA)
#
#
# 31
#                 index: 5
#                 rekomendasi sistem: ILMU KOMUNIKASI - UI (IPS)
#                 pilihan I: ILMU KOMUNIKASI - UI (IPS)
#                 pilihan II: KOSONG
#                 pilihan III: KOSONG
#                 diterima dijurusan: ILMU KOMUNIKASI - UI (IPS)
#
#
# 32
#                 index: 176
#                 rekomendasi sistem: MANAJEMEN - UNPAD (IPS)
#                 pilihan I: MANAJEMEN - UNPAD (IPS)
#                 pilihan II: ADMINISTRASI BISNIS - UNPAD (IPS)
#                 pilihan III: PEND. AKUNTANSI - UNJ (IPS)
#                 diterima dijurusan: MANAJEMEN - UNPAD (IPS)
#
#
# 33
#                 index: 132
#                 rekomendasi sistem: FISIKA - UI (IPA)
#                 pilihan I: FISIKA - UI (IPA)
#                 pilihan II: AKUNTANSI - UI (IPS)
#                 pilihan III: FISIKA - UNRAM (IPA)
#                 diterima dijurusan: FISIKA - UI (IPA)
#
#
# 34
#                 index: 66
#                 rekomendasi sistem: ILMU HUBUNGAN INTERNASIONAL - UI (IPS)
#                 pilihan I: ILMU HUBUNGAN INTERNASIONAL - UI (IPS)
#                 pilihan II: ILMU ADMINISTRASI FISKAL - UI (IPS)
#                 pilihan III: KOSONG
#                 diterima dijurusan: ILMU HUBUNGAN INTERNASIONAL - UI (IPS)
#
#
# 35
#                 index: 4
#                 rekomendasi sistem: FISIKA - UI (IPA)
#                 pilihan I: FISIKA - UI (IPA)
#                 pilihan II: TEKNIK FISIKA - ITS (IPA)
#                 pilihan III: STATISTIKA - ITS (IPA)
#                 diterima dijurusan: FISIKA - UI (IPA)
#
#
# 36
#                 index: 97
#                 rekomendasi sistem: MANAJEMEN - UI (IPS)
#                 pilihan I: MANAJEMEN - UI (IPS)
#                 pilihan II: KOSONG
#                 pilihan III: KOSONG
#                 diterima dijurusan: MANAJEMEN - UI (IPS)
#
#
# 37
#                 index: 181
#                 rekomendasi sistem: PETERNAKAN - UNPAD (IPA)
#                 pilihan I: PETERNAKAN - UNPAD (IPA)
#                 pilihan II: KOSONG
#                 pilihan III: KOSONG
#                 diterima dijurusan: PETERNAKAN - UNPAD (IPA)
#
#
# 38
#                 index: 341
#                 rekomendasi sistem: PENDIDIKAN DOKTER GIGI - UNAIR (IPA)
#                 pilihan I: PENDIDIKAN DOKTER GIGI - UNAIR (IPA)
#                 pilihan II: PENDIDIKAN DOKTER HEWAN - UNAIR (IPA)
#                 pilihan III: SASTRA PERANCIS - UGM (IPA)
#                 diterima dijurusan: PENDIDIKAN DOKTER GIGI - UNAIR (IPA)
#
#
# 39
#                 index: 270
#                 rekomendasi sistem: HUMAS - UNPAD (IPS)
#                 pilihan I: HUMAS - UNPAD (IPS)
#                 pilihan II: ILMU ADMINISTRASI BISNIS - UNPAD (IPS)
#                 pilihan III: KOSONG
#                 diterima dijurusan: HUMAS - UNPAD (IPS)
#
#
# 40
#                 index: 91
#                 rekomendasi sistem: MATEMATIKA - UI (IPA)
#                 pilihan I: MATEMATIKA - UI (IPA)
#                 pilihan II: AKTUARIA - IPB (IPA)
#                 pilihan III: KOSONG
#                 diterima dijurusan: MATEMATIKA - UI (IPA)
#
#
# 41
#                 index: 229
#                 rekomendasi sistem: ILMU KEPERAWATAN - UNPAD (IPA)
#                 pilihan I: ILMU KEPERAWATAN - UNPAD (IPA)
#                 pilihan II: PSIKOLOGI - UNPAD (IPS)
#                 pilihan III: KOSONG
#                 diterima dijurusan: ILMU KEPERAWATAN - UNPAD (IPA)
#
#
# 42
#                 index: 144
#                 rekomendasi sistem: ILMU HUBUNGAN INTERNASIONAL - UI (IPS)
#                 pilihan I: ILMU HUBUNGAN INTERNASIONAL - UI (IPS)
#                 pilihan II: KOSONG
#                 pilihan III: KOSONG
#                 diterima dijurusan: ILMU HUBUNGAN INTERNASIONAL - UI (IPS)
#
#
# 43
#                 index: 177
#                 rekomendasi sistem: KIMIA - UNPAD (IPA)
#                 pilihan I: KIMIA - UNPAD (IPA)
#                 pilihan II: KOSONG
#                 pilihan III: KOSONG
#                 diterima dijurusan: KIMIA - UNPAD (IPA)
#
#
# 44
#                 index: 30
#                 rekomendasi sistem: GEOGRAFI - UI (IPA)
#                 pilihan I: GEOGRAFI - UI (IPA)
#                 pilihan II: KOSONG
#                 pilihan III: KOSONG
#                 diterima dijurusan: GEOGRAFI - UI (IPA)
#
#
# 45
#                 index: 225
#                 rekomendasi sistem: BIOLOGI - UNPAD (IPA)
#                 pilihan I: BIOLOGI - UNPAD (IPA)
#                 pilihan II: KEPERAWATAN - UNPAD (IPA)
#                 pilihan III: PENDIDIKAN BIOLOGI - UPI (IPA)
#                 diterima dijurusan: BIOLOGI - UNPAD (IPA)
#
#
# 46
#                 index: 254
#                 rekomendasi sistem: FISIKA - UNPAD (IPA)
#                 pilihan I: FISIKA - UNPAD (IPA)
#                 pilihan II: TEKNIK SIPIL - UPI (IPA)
#                 pilihan III: TEKNIK ARSITEKTUR - UPI (IPA)
#                 diterima dijurusan: FISIKA - UNPAD (IPA)
#
#
# 47
#                 index: 203
#                 rekomendasi sistem: ILMU HUKUM - UNPAD (IPS)
#                 pilihan I: ILMU HUKUM - UNPAD (IPS)
#                 pilihan II: KOSONG
#                 pilihan III: KOSONG
#                 diterima dijurusan: ILMU HUKUM - UNPAD (IPS)
#
#
# 48
#                 index: 210
#                 rekomendasi sistem: AGROTEKNOLOGI - UNPAD (IPA)
#                 pilihan I: AGROTEKNOLOGI - UNPAD (IPA)
#                 pilihan II: KOSONG
#                 pilihan III: KOSONG
#                 diterima dijurusan: AGROTEKNOLOGI - UNPAD (IPA)
#
#
# 49
#                 index: 243
#                 rekomendasi sistem: PSIKOLOGI - UNPAD (IPS)
#                 pilihan I: PSIKOLOGI - UNPAD (IPS)
#                 pilihan II: KOSONG
#                 pilihan III: PSIKOLOGI - UGM (IPS)
#                 diterima dijurusan: PSIKOLOGI - UNPAD (IPS)
#
#
# 50
#                 index: 130
#                 rekomendasi sistem: HUKUM - UI (IPS)
#                 pilihan I: HUKUM - UI (IPS)
#                 pilihan II: HUKUM - UI (IPS)
#                 pilihan III: HUKUM - UGM (IPS)
#                 diterima dijurusan: HUKUM - UI (IPS)
#
#
# 51
#                 index: 122
#                 rekomendasi sistem: GEOGRAFI - UI (IPA)
#                 pilihan I: GEOGRAFI - UI (IPA)
#                 pilihan II: KOSONG
#                 pilihan III: KOSONG
#                 diterima dijurusan: GEOGRAFI - UI (IPA)
#
#
# 52
#                 index: 303
#                 rekomendasi sistem: MANAJEMEN - UNAIR (IPS)
#                 pilihan I: MANAJEMEN - UNAIR (IPS)
#                 pilihan II: EKONOMI ISLAM - UNESA (IPS)
#                 pilihan III: KOSONG
#                 diterima dijurusan: MANAJEMEN - UNAIR (IPS)
#
#
# 53
#                 index: 350
#                 rekomendasi sistem: SOSIOLOGI MURNI - UNAIR (IPS)
#                 pilihan I: MANAJEMEN - UNEJ (IPS)
#                 pilihan II: SASTRA INDONESIA - UNEJ (IPA)
#                 pilihan III: SOSIOLOGI MURNI - UNAIR (IPS)
#                 diterima dijurusan: SOSIOLOGI MURNI - UNAIR (IPS)
#
#
# 54
#                 index: 322
#                 rekomendasi sistem: APOTEKER - UNAIR (IPA)
#                 pilihan I: APOTEKER - UNAIR (IPA)
#                 pilihan II: STATISTIKA - UNAIR (IPA)
#                 pilihan III: KOSONG
#                 diterima dijurusan: APOTEKER - UNAIR (IPA)
#
#
# 55
#                 index: 123
#                 rekomendasi sistem: KESEHATAN MASYARAKAT - UI (IPA)
#                 pilihan I: KESEHATAN MASYARAKAT - UI (IPA)
#                 pilihan II: KOSONG
#                 pilihan III: MANAGEMEN - UPN JAKARTA (IPA)
#                 diterima dijurusan: KESEHATAN MASYARAKAT - UI (IPA)
#
#
# 56
#                 index: 169
#                 rekomendasi sistem: ILMU ADMINISTRASI BISNIS - UNPAD (IPS)
#                 pilihan I: ILMU ADMINISTRASI BISNIS - UNPAD (IPS)
#                 pilihan II: MANAJEMEN KOMUNIKASI - UNPAD (IPS)
#                 pilihan III: KOSONG
#                 diterima dijurusan: ILMU ADMINISTRASI BISNIS - UNPAD (IPS)
#
#
# 57
#                 index: 184
#                 rekomendasi sistem: KIMIA - UNPAD (IPA)
#                 pilihan I: KIMIA - UNPAD (IPA)
#                 pilihan II: ILMU GIZI - IPB (IPA)
#                 pilihan III: KIMIA - IPB (IPA)
#                 diterima dijurusan: KIMIA - UNPAD (IPA)
#
#
# 58
#                 index: 257
#                 rekomendasi sistem: FISIKA - UNPAD (IPA)
#                 pilihan I: FISIKA - UNPAD (IPA)
#                 pilihan II: TEKNIK PERTANIAN - UNPAD (IPA)
#                 pilihan III: KOSONG
#                 diterima dijurusan: FISIKA - UNPAD (IPA)
#
#
# 59
#                 index: 172
#                 rekomendasi sistem: FARMASI - UNPAD (IPA)
#                 pilihan I: FARMASI - UNPAD (IPA)
#                 pilihan II: FARMASI - UI (IPA)
#                 pilihan III: KOSONG
#                 diterima dijurusan: FARMASI - UNPAD (IPA)
#
#
# 60
#                 index: 228
#                 rekomendasi sistem: ILMU PETERNAKAN - UNPAD (IPA)
#                 pilihan I: ILMU PETERNAKAN - UNPAD (IPA)
#                 pilihan II: AGROTEKNOLOGI - UNPAD (IPA)
#                 pilihan III: AGROTEKNOLOGI - UPN YOGYAKARTA (IPA)
#                 diterima dijurusan: ILMU PETERNAKAN - UNPAD (IPA)
#
#
# 61
#                 index: 194
#                 rekomendasi sistem: AGROTEKNOLOGI - UNPAD (IPA)
#                 pilihan I: AGROTEKNOLOGI - UNPAD (IPA)
#                 pilihan II: TEKNIK PERTANIAN - UNPAD (IPA)
#                 pilihan III: TEKNOLOGI PANGAN - UNS (IPA)
#                 diterima dijurusan: AGROTEKNOLOGI - UNPAD (IPA)
#
#
# 62
#                 index: 379
#                 rekomendasi sistem: STATISTIKA - UNAIR (IPA)
#                 pilihan I: STATISTIKA - UNAIR (IPA)
#                 pilihan II: KOSONG
#                 pilihan III: KOSONG
#                 diterima dijurusan: STATISTIKA - UNAIR (IPA)
#
#
# 63
#                 index: 81
#                 rekomendasi sistem: AKUNTANSI - UI (IPS)
#                 pilihan I: AKUNTANSI - UI (IPS)
#                 pilihan II: ILMU EKONOMI - UI (IPS)
#                 pilihan III: KOSONG
#                 diterima dijurusan: AKUNTANSI - UI (IPS)
#
#
# 64
#                 index: 297
#                 rekomendasi sistem: KIMIA, - UNPAD (IPA)
#                 pilihan I: KIMIA, - UNPAD (IPA)
#                 pilihan II: MATEMATIKA - UNPAD (IPA)
#                 pilihan III: MATEMATIKA - UIN BANDUNG (IPA)
#                 diterima dijurusan: KIMIA, - UNPAD (IPA)
#
#
# 65
#                 index: 245
#                 rekomendasi sistem: KIMIA - UNPAD (IPA)
#                 pilihan I: KIMIA - UNPAD (IPA)
#                 pilihan II: KIMIA - UNSOED (IPA)
#                 pilihan III: KOSONG
#                 diterima dijurusan: KIMIA - UNPAD (IPA)
#
#
# 66
#                 index: 323
#                 rekomendasi sistem: HUKUM - UNAIR (IPS)
#                 pilihan I: HUKUM - UNAIR (IPS)
#                 pilihan II: ILMU POLITIK - UNAIR (IPS)
#                 pilihan III: KOSONG
#                 diterima dijurusan: HUKUM - UNAIR (IPS)
#
#
# 67
#                 index: 76
#                 rekomendasi sistem: TEKNIK INDUSTRI - UI (IPA)
#                 pilihan I: TEKNIK INDUSTRI - UI (IPA)
#                 pilihan II: HUBUNGAN INTERNASIONAL - UI (IPS)
#                 pilihan III: PENDIDIKAN KEDOKTERNA - UNSRAT (IPA)
#                 diterima dijurusan: TEKNIK INDUSTRI - UI (IPA)
#
#
# 68
#                 index: 128
#                 rekomendasi sistem: SATRA JERMAN - UI (IPA)
#                 pilihan I: SATRA JERMAN - UI (IPA)
#                 pilihan II: ILMU KESEJATERAAN SOSIAL - UI (IPS)
#                 pilihan III: SASTRA JERMAN - UNPAD (IPA)
#                 diterima dijurusan: SATRA JERMAN - UI (IPA)
#
#
# 69
#                 index: 9
#                 rekomendasi sistem: MATEMATIKA - UI (IPA)
#                 pilihan I: MATEMATIKA - UI (IPA)
#                 pilihan II: FISIKA - UI (IPA)
#                 pilihan III: KOSONG
#                 diterima dijurusan: MATEMATIKA - UI (IPA)
#
#
# 70
#                 index: 224
#                 rekomendasi sistem: HUKUM - UNPAD (IPS)
#                 pilihan I: HUKUM - UNPAD (IPS)
#                 pilihan II: TIDAK ADQ - UNPAD (IPA)
#                 pilihan III: HUKUN - UIN JAKARTA (IPA)
#                 diterima dijurusan: HUKUM - UNPAD (IPS)
#
#
# 71
#                 index: 11
#                 rekomendasi sistem: KEDOKTERAN GIGI - UI (IPA)
#                 pilihan I: KEDOKTERAN GIGI - UI (IPA)
#                 pilihan II: KOSONG
#                 pilihan III: KOSONG
#                 diterima dijurusan: KEDOKTERAN GIGI - UI (IPA)
#
#
# 72
#                 index: 58
#                 rekomendasi sistem: ILMU ADM. FISKAL - UI (IPS)
#                 pilihan I: ILMU ADM. FISKAL - UI (IPS)
#                 pilihan II: ILMU ADM. PERPAJAKAN - UB (IPA)
#                 pilihan III: KOSONG
#                 diterima dijurusan: ILMU ADM. FISKAL - UI (IPS)
#
#
# 73
#                 index: 129
#                 rekomendasi sistem: BIOLOGI - UI (IPA)
#                 pilihan I: BIOLOGI - UI (IPA)
#                 pilihan II: KESELAMATAN DAN KESEHATAN KERJA - UI (IPA)
#                 pilihan III: ILMU GIZI - IPB (IPA)
#                 diterima dijurusan: BIOLOGI - UI (IPA)
#
#
# 74
#                 index: 318
#                 rekomendasi sistem: TEKNOBIOMEDIK - UNAIR (IPA)
#                 pilihan I: TEKNOBIOMEDIK - UNAIR (IPA)
#                 pilihan II: BUDIDAYA PERAIRAN - UNAIR (IPA)
#                 pilihan III: AGROTEKNOLOGI - UPN (IPA)
#                 diterima dijurusan: TEKNOBIOMEDIK - UNAIR (IPA)
#
#
# 75
#                 index: 147
#                 rekomendasi sistem: MATEMATIKA - UI (IPA)
#                 pilihan I: MATEMATIKA - UI (IPA)
#                 pilihan II: STATISTIKA - UI (IPA)
#                 pilihan III: PENDIDIKAN MATEMATIKA - UNJ (IPA)
#                 diterima dijurusan: MATEMATIKA - UI (IPA)
#
#
# 76
#                 index: 150
#                 rekomendasi sistem: TEKNIK ELEKTRO - UI (IPA)
#                 pilihan I: TEKNIK ELEKTRO - UI (IPA)
#                 pilihan II: KOSONG
#                 pilihan III: TEKNIK ELEKTRO - UNPAD (IPA)
#                 diterima dijurusan: TEKNIK ELEKTRO - UI (IPA)
#
#
# 77
#                 index: 361
#                 rekomendasi sistem: KIMIA - UNAIR (IPA)
#                 pilihan I: KIMIA - UNAIR (IPA)
#                 pilihan II: ILMU GIZI - UNAIR (IPA)
#                 pilihan III: TEKNIK KIMIA - UPN JATIM (IPA)
#                 diterima dijurusan: KIMIA - UNAIR (IPA)
#
#
# 78
#                 index: 362
#                 rekomendasi sistem: MANAJEMEN - UNAIR (IPS)
#                 pilihan I: MANAJEMEN - UNAIR (IPS)
#                 pilihan II: HUKUM - UNAIR (IPS)
#                 pilihan III: MANAJEMEN - UNEJ (IPS)
#                 diterima dijurusan: MANAJEMEN - UNAIR (IPS)
#
#
# 79
#                 index: 250
#                 rekomendasi sistem: STATISTIKA - UNPAD (IPA)
#                 pilihan I: STATISTIKA - UNPAD (IPA)
#                 pilihan II: KOSONG
#                 pilihan III: TEKNIK PWK - UNDIP (IPA)
#                 diterima dijurusan: STATISTIKA - UNPAD (IPA)
#
#
# 80
#                 index: 32
#                 rekomendasi sistem: HUKUM - UI (IPS)
#                 pilihan I: HUKUM - UI (IPS)
#                 pilihan II: PSIKOLOGI - UI (IPS)
#                 pilihan III: HUKUM - UNPAD (IPS)
#                 diterima dijurusan: HUKUM - UI (IPS)
#
#
# 81
#                 index: 55
#                 rekomendasi sistem: GEOLOGI - UI (IPA)
#                 pilihan I: GEOLOGI - UI (IPA)
#                 pilihan II: TEKNIK LINGKUNGAN - UI (IPA)
#                 pilihan III: KOSONG
#                 diterima dijurusan: GEOLOGI - UI (IPA)
#
#
# 82
#                 index: 299
#                 rekomendasi sistem: KEDOKTERAN - UNAIR (IPA)
#                 pilihan I: KEDOKTERAN - UNAIR (IPA)
#                 pilihan II: KEDOKTERAN GIGI - UNAIR (IPA)
#                 pilihan III: KOSONG
#                 diterima dijurusan: KEDOKTERAN - UNAIR (IPA)
#
#
# 83
#                 index: 335
#                 rekomendasi sistem: MANAJEMEN - UNAIR (IPS)
#                 pilihan I: MANAJEMEN - UNAIR (IPS)
#                 pilihan II: SOSIOLOGI - UNAIR (IPS)
#                 pilihan III: KOSONG
#                 diterima dijurusan: MANAJEMEN - UNAIR (IPS)
#
#
# 84
#                 index: 34
#                 rekomendasi sistem: GEOGRAF - UI (IPA)
#                 pilihan I: GEOGRAF - UI (IPA)
#                 pilihan II: FISIKA - UI (IPA)
#                 pilihan III: KOSONG
#                 diterima dijurusan: GEOGRAF - UI (IPA)
#
#
# 85
#                 index: 99
#                 rekomendasi sistem: ILMU EKONOMI - UI (IPS)
#                 pilihan I: ILMU EKONOMI - UI (IPS)
#                 pilihan II: ILMU ADMINISTRASI NEGARA - UI (IPS)
#                 pilihan III: KOSONG
#                 diterima dijurusan: ILMU EKONOMI - UI (IPS)

# %%
i = 1
for index in hasil_tabel.index:
    for column in hasil_tabel.columns:
        if column != "Riil":
            if hasil_tabel.loc[index, column] != hasil_tabel.loc[index, "Riil"]:
                pil1 = data_test.loc[index, 'Pilihan I']
                pil2 = data_test.loc[index, 'Pilihan II']
                pil3 = data_test.loc[index, 'Pilihan III']
                terima = hasil_tabel.loc[index, "Riil"]
                print(f"""{i}
                index: {index}
                rekomendasi sistem: {hasil_tabel.loc[index, column]}
                pilihan I: {pil1}
                pilihan II: {pil2}
                pilihan III: {pil3}
                diterima dijurusan: {terima}
                """)
                print()
                i += 1
# Out:
# 1
#                 index: 47
#                 rekomendasi sistem: MATEMATIKA - UI (IPA)
#                 pilihan I: STATISTIKA - UI (IPA)
#                 pilihan II: MATEMATIKA - UI (IPA)
#                 pilihan III: KOSONG
#                 diterima dijurusan: STATISTIKA - UI (IPA)
#
#
# 2
#                 index: 63
#                 rekomendasi sistem: GEOFISIKA - UI (IPA)
#                 pilihan I: GEOLOGI - UI (IPA)
#                 pilihan II: GEOFISIKA - UI (IPA)
#                 pilihan III: FITB - ITB (IPA)
#                 diterima dijurusan: GEOLOGI - UI (IPA)
#
#
# 3
#                 index: 372
#                 rekomendasi sistem: MATEMATIKA - UNAIR (IPA)
#                 pilihan I: MATEMATIKA - UNAIR (IPA)
#                 pilihan II: FISIKA - UNAIR (IPA)
#                 pilihan III: MATEMATIKA - UNUD (IPA)
#                 diterima dijurusan: FISIKA - UNAIR (IPA)
#
#
# 4
#                 index: 145
#                 rekomendasi sistem: KIMIA - UI (IPA)
#                 pilihan I: BIOLOGI - UI (IPA)
#                 pilihan II: KIMIA - UI (IPA)
#                 pilihan III: BIOLOGI - UIN JAKARTA (IPA)
#                 diterima dijurusan: BIOLOGI - UI (IPA)
#
#
# 5
#                 index: 191
#                 rekomendasi sistem: ILMU ADMINISTRASI NEGARA - UNPAD (IPS)
#                 pilihan I: ILMU ADMINISTRASI BISNIS - UNPAD (IPS)
#                 pilihan II: ILMU ADMINISTRASI NEGARA - UNPAD (IPS)
#                 pilihan III: KOSONG
#                 diterima dijurusan: ILMU ADMINISTRASI BISNIS - UNPAD (IPS)
#
#
# 6
#                 index: 109
#                 rekomendasi sistem: GEOFISIKA - UI (IPA)
#                 pilihan I: GEOLOGI - UI (IPA)
#                 pilihan II: GEOFISIKA - UI (IPA)
#                 pilihan III: KOSONG
#                 diterima dijurusan: GEOLOGI - UI (IPA)
#
#
# 7
#                 index: 358
#                 rekomendasi sistem: ILMU KESEHATAN MASYARAKAT - UNAIR (IPA)
#                 pilihan I: PENDIDIKAN DOKTER - UNAIR (IPA)
#                 pilihan II: ILMU KESEHATAN MASYARAKAT - UNAIR (IPA)
#                 pilihan III: PENDIDIKAN DOKTER - UNTAN (IPA)
#                 diterima dijurusan: PENDIDIKAN DOKTER - UNAIR (IPA)
#
#
# 8
#                 index: 146
#                 rekomendasi sistem: GEOGRAFI - UI (IPA)
#                 pilihan I: BIOLOGI - UI (IPA)
#                 pilihan II: GEOGRAFI - UI (IPA)
#                 pilihan III: KOSONG
#                 diterima dijurusan: BIOLOGI - UI (IPA)
#
#
# 9
#                 index: 346
#                 rekomendasi sistem: SOSIOLOGI - UNAIR (IPS)
#                 pilihan I: ILMU POLITIK - UNAIR (IPS)
#                 pilihan II: SOSIOLOGI - UNAIR (IPS)
#                 pilihan III: MANAJEMEN - UPN JATIM (IPS)
#                 diterima dijurusan: ILMU POLITIK - UNAIR (IPS)
#
#
# 10
#                 index: 351
#                 rekomendasi sistem: ILMU HUKUM - UNAIR (IPS)
#                 pilihan I: ILMU HUKUM - UNAIR (IPS)
#                 pilihan II: ANTROPOLOGI SOSIAL - UNAIR (IPS)
#                 pilihan III: KOSONG
#                 diterima dijurusan: ANTROPOLOGI SOSIAL - UNAIR (IPS)
#
#
# 11
#                 index: 201
#                 rekomendasi sistem: HUBUNGAN MASYARAKAT - UNPAD (IPS)
#                 pilihan I: MANAJEMEN KOMUNIKASI - UNPAD (IPS)
#                 pilihan II: HUBUNGAN MASYARAKAT - UNPAD (IPS)
#                 pilihan III: ILMU KOMUNIKASI - UNSOED (IPS)
#                 diterima dijurusan: MANAJEMEN KOMUNIKASI - UNPAD (IPS)
#
#
# 12
#                 index: 43
#                 rekomendasi sistem: MATEMATIKA - UI (IPA)
#                 pilihan I: FISIKA - UI (IPA)
#                 pilihan II: MATEMATIKA - UI (IPA)
#                 pilihan III: FISIKA - UNPAD (IPA)
#                 diterima dijurusan: FISIKA - UI (IPA)
#
#
# 13
#                 index: 206
#                 rekomendasi sistem: KESEJAHTERAAN SOSIAL - UNPAD (IPS)
#                 pilihan I: ADMINISTRASI NEGARA - UNPAD (IPS)
#                 pilihan II: KESEJAHTERAAN SOSIAL - UNPAD (IPS)
#                 pilihan III: PENDIDIKAN SEJARAH - UPI (IPS)
#                 diterima dijurusan: ADMINISTRASI NEGARA - UNPAD (IPS)
#
#
# 14
#                 index: 291
#                 rekomendasi sistem: PETERNAKAN - UNPAD (IPA)
#                 pilihan I: GEOFISIKA - UNPAD (IPA)
#                 pilihan II: PETERNAKAN - UNPAD (IPA)
#                 pilihan III: TEKNIK SIPIL - UPI (IPA)
#                 diterima dijurusan: GEOFISIKA - UNPAD (IPA)
#
#
# 15
#                 index: 175
#                 rekomendasi sistem: ILMU ADMINISTRASI NEGARA - UNPAD (IPS)
#                 pilihan I: ILMU ADMINISTRASI BISNIS - UNPAD (IPS)
#                 pilihan II: ILMU ADMINISTRASI NEGARA - UNPAD (IPS)
#                 pilihan III: EKONONI PEMBANGUNAN - UNSOED (IPA)
#                 diterima dijurusan: ILMU ADMINISTRASI BISNIS - UNPAD (IPS)
