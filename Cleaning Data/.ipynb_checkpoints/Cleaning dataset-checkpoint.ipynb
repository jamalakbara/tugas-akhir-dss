# %%
import pandas as pd
import math
import numpy as np

# %% [markdown]
# # Open File
#
# Membuka file dataset dengan ekstensi **csv**. Setelah itu merename nama-nama header. Baru kemudian men-drop column-column yang tidak akan digunakan.

# %%
def open_file(file):
    #read dataset
    raw_data = pd.read_csv(file, header=6)

    #ganti nama header
    raw_data.columns = [
                        "Nama Panggilan", 
                        "Asal Sekolah", 
                        "Jurusan Sekolah", 
                        "Jenis Sekolah",
                        "Jenis Kelas", 
                        "Akreditasi Sekolah", 
                        "Prestasi Sekolah", 
                        "Alumni Sekolah", 
                        "PTN Pilihan I", 
                        "Jurusan Pilihan I di PTN Pilihan I" ,
                        "Jurusan Pilihan II di PTN Pilihan I", 
                        "PTN Pilihan II", 
                        "Jurusan Pilihan I di PTN Pilihan II" ,
                        "Jurusan Pilihan II di PTN Pilihan II", 
                        "Jurusan Diterima", "PTN Diterima", 
                        "Matematika Semester 1", 
                        "Matematika Semester 2", 
                        "Matematika Semester 3", 
                        "Matematika Semester 4", 
                        "Matematika Semester 5", 
                        "Inggris Semester 1", 
                        "Inggris Semester 2", 
                        "Inggris Semester 3", 
                        "Inggris Semester 4", 
                        "Inggris Semester 5",
                        "Indonesia Semester 1",
                        "Indonesia Semester 2",
                        "Indonesia Semester 3",
                        "Indonesia Semester 4",
                        "Indonesia Semester 5",
                        "Fisika Semester 1",
                        "Fisika Semester 2",
                        "Fisika Semester 3",
                        "Fisika Semester 4",
                        "Fisika Semester 5",
                        "Kimia Semester 1",
                        "Kimia Semester 2",
                        "Kimia Semester 3",
                        "Kimia Semester 4",
                        "Kimia Semester 5",
                        "Biologi Semester 1",
                        "Biologi Semester 2",
                        "Biologi Semester 3",
                        "Biologi Semester 4",
                        "Biologi Semester 5",
                        "Ekonomi Semester 1",
                        "Ekonomi Semester 2",
                        "Ekonomi Semester 3",
                        "Ekonomi Semester 4",
                        "Ekonomi Semester 5",
                        "Geografi Semester 1",
                        "Geografi Semester 2",
                        "Geografi Semester 3",
                        "Geografi Semester 4",
                        "Geografi Semester 5",
                        "Sosiologi Semester 1",
                        "Sosiologi Semester 2",
                        "Sosiologi Semester 3",
                        "Sosiologi Semester 4",
                        "Sosiologi Semester 5",
                        "Sejarah Semester 1",
                        "Sejarah Semester 2",
                        "Sejarah Semester 3",
                        "Sejarah Semester 4",
                        "Sejarah Semester 5",
                        "Komputer Semester 1",
                        "Komputer Semester 2",
                        "Komputer Semester 3",
                        "Komputer Semester 4",
                        "Komputer Semester 5",
                        "Peringkat Kelas Semester 1",
                        "Peringkat Kelas Semester 2",
                        "Peringkat Kelas Semester 3",
                        "Peringkat Kelas Semester 4",
                        "Peringkat Kelas Semester 5",
                        "Nilai UN", 
                        "Saran",
                        "Prestasi Lain"
                    ]
    
    #drop column yang tidak digunakan
    data = raw_data.drop([
                "Jenis Kelas",
                "Akreditasi Sekolah", 
                "Prestasi Sekolah", 
                "Alumni Sekolah", 
                "Komputer Semester 1",
                "Komputer Semester 2",
                "Komputer Semester 3",
                "Komputer Semester 4",
                "Komputer Semester 5",
                "Peringkat Kelas Semester 1",
                "Peringkat Kelas Semester 2",
                "Peringkat Kelas Semester 3",
                "Peringkat Kelas Semester 4",
                "Peringkat Kelas Semester 5",
                "Nilai UN", 
                "Saran",
                "Prestasi Lain"
        ],axis=1)
    
    return data

# %% [markdown]
# # Cleaning Nilai
#
# Proses cleaning nilai terdiri dari beberapa langkah:
#
# 1. Mengambil nilai tengah dari tiap mata pelajaran
# 2. Mengganti setiap NaN/null data dengan mean per mata pelajaran

# %%
def cleaning_nilai(data):

    #Mengambil nilai tengah dari tiap nilai
    data = data.replace("<70", 34.5)
    data = data.replace("71 - 75", 73)
    data = data.replace("76 - 80", 78)
    data = data.replace("81 - 85", 83)
    data = data.replace("86 - 90", 88)
    data = data.replace("91 - 95", 93)
    data = data.replace("> 95", 98)
    data = data.replace("No data", np.NaN)

    return data

# %%
def replace_zero_w_mean(data, mata_pelajaran):
    
    #mencari rata-rata dari per mata pelajaran
    rata2 = (data[f"{mata_pelajaran} Semester 1"].mean() 
            + data[f"{mata_pelajaran} Semester 2"].mean() 
            + data[f"{mata_pelajaran} Semester 3"].mean()
            + data[f"{mata_pelajaran} Semester 4"].mean()
            + data[f"{mata_pelajaran} Semester 5"].mean())/5
    
    #mengganti NaN value dengan nilai rata-rata
    values = {
        f"{mata_pelajaran} Semester 1": rata2,
        f"{mata_pelajaran} Semester 2": rata2,
        f"{mata_pelajaran} Semester 3": rata2,
        f"{mata_pelajaran} Semester 4": rata2,
        f"{mata_pelajaran} Semester 5": rata2,
    }
    data = data.fillna(value=values)
                    
    return data

# %% [markdown]
# # Menghitung Rata-Rata Per 5 Semester
#
# Dari nilai-nilai yang telah di-clean kemudian akan dicari rata-rata tiap mata pelajarannya per semester

# %%
def rata2_mp_semester(data, mata_pelajaran):
    data_rata2 = {}
    
    #drop column tiap mata pelajaran untuk digantikan dengan rata-rata semester
    mapel = []
    for i in range(1,6):
        mapel.append(f"{mata_pelajaran} Semester {i}")

    data_drop = data.drop(mapel, axis=1)
    
    
    for column in data_drop:
        isi = []
        for i in range(len(data)):
            isi.append(data[column][i])
        data_rata2[column] = isi

    #menghitung rata-rata nilai 5 semester
    mean = []
    for i in range(len(data)):
        jumlah_nilai = 0
        jumlah_nilai += data[f"{mata_pelajaran} Semester 1"][i] + data[f"{mata_pelajaran} Semester 2"][i] + data[f"{mata_pelajaran} Semester 3"][i] + data[f"{mata_pelajaran} Semester 4"][i] + data[f"{mata_pelajaran} Semester 5"][i]
        mean.append(jumlah_nilai/5)

    #memasukkan column rata-rata 5 semester tiap mata pelajaran ke dataframe
    data_rata2[f"Rata-rata {mata_pelajaran}"] = mean

    data_rata2_frame = pd.DataFrame(data=data_rata2)
    
    return data_rata2_frame

# %% [markdown]
# # Menghapus NaN
#
# Proses ini akan menghapus tiap rows yang memiliki NaN value yang ada pada column Jurusan Diterima

# %%
def remove_nan(data):
    drop_index = []

    #menghapus NaN value
    for i in range(len(data)):
        try:
            float(data["Jurusan Diterima"][i])
        except ValueError:
            pass
        else:
            if math.isnan(float(data["Jurusan Diterima"][i])) or int(data["Jurusan Diterima"][i]) == 0:
                drop_index.append(i)

    data = data.drop(drop_index)
        
    return data

# %%
def clean_jurusan_ptn(data):
    for i in range(len(data)):
        for column in data:
            if column == "Jurusan Diterima"  or column == "Jurusan Pilihan I di PTN Pilihan I" or column == "Jurusan Pilihan II di PTN Pilihan I" or column == "Jurusan Pilihan I di PTN Pilihan II" or column == "Jurusan Pilihan II di PTN Pilihan II":
                if isinstance(data[column][i], float):
                    pass
                else:
                    data[column][i] = data[column][i].title()
            elif column == "PTN Diterima" or column == "PTN Pilihan I" or column == "PTN Pilihan II":
                if isinstance(data[column][i], float):
                    pass
                else:
                    data[column][i] = data[column][i].upper()
    
    return data

# %%
def clean(files):
    cleanned_data = []
    
    for file in files:
        data = open_file(file)

        data = cleaning_nilai(data)

        matpel = ["Matematika", "Inggris", "Indonesia", "Fisika", "Kimia", "Biologi", "Ekonomi", "Geografi", "Sosiologi","Sejarah"]

        for item in matpel:
            data = replace_zero_w_mean(data, item)
            data = rata2_mp_semester(data, item)
                    
        data = remove_nan(data)
        
        cleanned_data.append(data)
        
        data_merge = pd.concat(cleanned_data, ignore_index=True)
        
        result = clean_jurusan_ptn(data_merge)
        
    #Split data test - data train
    test = result.sample(frac=0.2, replace=True)
    test.to_csv("Splitted Test.csv", encoding="utf-8")
    
    rest_of_data = result.drop(test.index).reset_index()
    
    train_w_index = rest_of_data.drop([
            "Nama Panggilan", 
            "Asal Sekolah", 
            "PTN Pilihan I", 
            "Jurusan Pilihan I di PTN Pilihan I" ,
            "Jurusan Pilihan II di PTN Pilihan I", 
            "PTN Pilihan II", 
            "Jurusan Pilihan I di PTN Pilihan II" ,
            "Jurusan Pilihan II di PTN Pilihan II", 
        ],axis=1)
    
    train_w_index.to_csv("Splitted Train.csv", encoding="utf-8")
    
    train = train_w_index.drop(["index"],axis=1)

    return train

# %%
def sort_data(data):
    data_sort = data.sort_values(by=['Jurusan Diterima', 'PTN Diterima'])
    
    data_sort.reset_index(inplace = True)

    data_sort = data_sort.drop(["index"], axis=1)

    return data_sort

# %%
def get_jurusan_ptn(data):
    temp_jurusan = ""
    temp_ptn = ""
    list_jurusan_ptn = []
    for i in range(len(data)):
        if data["Jurusan Diterima"][i] != temp_jurusan and data["PTN Diterima"][i] != temp_ptn:
            temp_jurusan = data["Jurusan Diterima"][i]
            temp_ptn = data["PTN Diterima"][i]
            list_jurusan_ptn.append((temp_jurusan, temp_ptn))
        else:
            pass

    return list_jurusan_ptn

# %%
def get_tabel_alternatif(data, list_jurusan_ptn):
    frame = {}
    for j in range(len(list_jurusan_ptn)):
        list_nilai = []
        for column in data:
            jum = 0
            byk = 0
            for i in range(len(data)):
                if data["Jurusan Diterima"][i] == list_jurusan_ptn[j][0] and data["PTN Diterima"][i] == list_jurusan_ptn[j][1]:
    #                 print(data_sort["Jurusan Diterima"][i], data_sort["PTN Diterima"][i])
                    temp_jurusan = data["Jurusan Diterima"][i]
                    temp_ptn = data["PTN Diterima"][i]
                    try:
                        float(data[column][i])
                    except ValueError:
                        break
                    else:
                        jum += data[column][i]
                        byk += 1
                else:
                    pass
            try:
    #             print(column, jum/byk)
                list_nilai.append(jum/byk)
            except ZeroDivisionError:
                continue
        nama_alternatif = f"{temp_jurusan} - {temp_ptn}"
        if "administrasi" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "sosial" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "ekonomi" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "hi" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "hukum" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "komunikasi" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "politik" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "sosiologi" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "fsrd" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "sbm" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "akuntansi" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "manajemen" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "psdk" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "fiskal" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif ("hubungan" in temp_jurusan.casefold().split() and "internasional" in temp_jurusan.casefold().split()):
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "kriminologi" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "psikologi" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "bisnis" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "filsafat" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "jurnalistik" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "humas" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "desain" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "film" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif ("hubungan" in temp_jurusan.casefold().split() and "masyarakat" in temp_jurusan.casefold().split()):
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "sastra" in temp_jurusan.casefold().split():
            continue
        elif "bahasa" in temp_jurusan.casefold().split():
            continue
        elif "perpustakaan" in temp_jurusan.casefold().split():
            continue
        elif "ugm" in temp_jurusan.casefold().split():
            continue
        
        if "(IPS)" not in nama_alternatif.split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPA)"
            
        frame[nama_alternatif] = list_nilai

    tabel = pd.DataFrame(frame, index=["Matematika", "Inggris", "Indonesia", "Fisika", "Kimia", "Biologi", "Ekonomi", "Geografi", "Sosiologi", "Sejarah"])

    return tabel

# %%
datasets = ["Data SNMPTN 2016 IPB by @halokampus.csv",
            "Data SNMPTN 2016 ITB by @halokampus.csv",
            "Data SNMPTN 2016 ITS by @halokampus.csv",
            "Data SNMPTN 2016 UB by @halokampus.csv",
            "Data SNMPTN 2016 UGM by @halokampus.csv",
            "Data SNMPTN 2016 UI by @halokampus.csv",
            "Data SNMPTN 2016 Unair by @halokampus.csv",
            "Data SNMPTN 2016 Undip by @halokampus.csv",
            "Data SNMPTN 2016 Unpad by @halokampus.csv",
            "Data SNMPTN 2017 IPB by @halokampus.csv",
            "Data SNMPTN 2017 ITB by @halokampus.csv",
            "Data SNMPTN 2017 ITS by @halokampus.csv",
            "Data SNMPTN 2017 UGM by @halokampus.csv",
            "Data SNMPTN 2017 UI by @halokampus.csv",
            "Data SNMPTN 2017 Unair by @halokampus.csv",
            "Data SNMPTN 2017 Unpad by @halokampus.csv",]

# %%
result = clean(datasets)

result
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#     Jurusan Sekolah Jenis Sekolah                        Jurusan Diterima  \
# 0               IPA           SMA                                   Kimia
# 1               IPA           SMA                        Kedokteran Hewan
# 2               IPA           SMA             Nutrisi Dan Teknologi Pakan
# 3               IPA           SMA              Teknik Mesin Dan Biosistem
# 4               IPA           SMA               Nutrisi & Teknologi Pakan
# 5               IPA           SMA            Teknologi Industri Pertanian
# 6               IPA           SMA  Komunikasi Dan Pengembangan Masyarakat
# 7               IPA           SMA                           Ilmu Komputer
# 8               IPA           SMA                               Ilmu Gizi
# 9               IPA           SMA              Ilmu Keluarga Dan Konsumen
# 10              IPA           SMA            Teknologi Industri Pertanian
# 11              IPA           SMA           Ekonomi Dan Studi Pembangunan
# 12              IPA           SMA                                 Biologi
# 13              IPA           SMA                     Meteorologi Terapan
# 14              IPA           SMA                               Manajemen
# 15              IPA           SMA               Teknologi Produksi Ternak
# 16              IPA           SMA                              Matematika
# 17              IPA           SMA                                  Fisika
# 18              IPA           SMA       Ekonomi Sumberdaya Dan Lingkungan
# 19              IPA           SMA                   Ilmu Teknologi Pangan
# 20              IPA           SMA                               Perikanan
# 21              IPA           SMA                                   Kimia
# 22              IPA           SMA               Teknologi Produksi Ternak
# 23              IPA           SMA               Agronomi Dan Hortikultura
# 24              IPA           SMA           Ekonomi Dan Studi Pembangunan
# 25              IPA           SMA              Ilmu Keluarga Dan Konsumen
# 26              IPA           SMA                        Proteksi Tanaman
# 27              IPA           SMA      Ekonomi Dan Sumber Daya Lingkungan
# 28              IPA           SMA              Ilmu Keluarga Dan Konsumen
# 29              IPA           SMA                                     Ikk
# ..              ...           ...                                     ...
# 710             IPA           SMA                               Psikologi
# 711             IPS           SMA                    Manajemen Komunikasi
# 712             IPS           SMA                           Sastra Jerman
# 713             IPA           SMA                                  Fisika
# 714             IPS           SMA                                  Humas
# 715             IPS           SMA                  Hubungan Internasional
# 716             IPA           SMA                          Teknik Geologi
# 717             IPA           SMA                          Teknik Geologi
# 718             IPS           SMA                  Hubungan Internasional
# 719             IPA           SMA                                   Kimia
# 720             IPS           SMA                    Manajemen Komunikasi
# 721             IPS           SMA                     Hubungan Masyarakat
# 722             IPA           SMA                                 Farmasi
# 723             IPS           SMA                              Ilmu Hukum
# 724             IPS           SMA                Ilmu Administrasi Negara
# 725             IPS           SMA        Ilmu Informasi Dan Perpustakaan
# 726             IPS           SMA                                   Humas
# 727             IPA           SMA                              Agribisnis
# 728             IPA           SMA                              Kedokteran
# 729             IPS           SMA             Ilmu Hubungan Internasional
# 730             IPS           SMA                 Ilmu Hub. Internasional
# 731             IPA           SMA                              Peternakan
# 732             IPA           SMA                               Perikanan
# 733             IPS           SMA                             Jurnalistik
# 734             IPA           SMA                               Geofisika
# 735             IPS           SMA                            Tv Dan Film
# 736             IPA           SMA                             Matematika
# 737             IPS           SMA                           Ekonomi Islam
# 738             IPA           SMA                      Teknik Informatika
# 739             IPA           SMA                                 Kimia,
#
#     PTN Diterima  Rata-rata Matematika  Rata-rata Inggris  \
# 0            IPB             85.321398          85.050000
# 1            IPB             85.321398          85.050000
# 2            IPB             85.321398          85.050000
# 3            IPB             85.321398          85.050000
# 4            IPB             93.000000          91.000000
# 5            IPB             83.000000          83.000000
# 6            IPB             82.000000          83.000000
# 7            IPB             94.000000          86.000000
# 8            IPB             85.321398          85.050000
# 9            IPB             85.321398          85.050000
# 10           IPB             85.321398          85.050000
# 11           IPB             86.000000          87.000000
# 12           IPB             85.000000          85.000000
# 13           IPB             85.321398          85.050000
# 14           IPB             88.000000          81.000000
# 15           IPB             34.500000          34.500000
# 16           IPB             85.321398          85.050000
# 17           IPB             85.321398          85.050000
# 18           IPB             85.321398          85.050000
# 19           IPB             87.000000          91.000000
# 20           IPB             87.000000          89.000000
# 21           IPB             85.000000          81.000000
# 22           IPB             82.000000          84.000000
# 23           IPB             85.321398          85.050000
# 24           IPB             82.000000          85.000000
# 25           IPB             83.000000          90.000000
# 26           IPB             84.000000          88.000000
# 27           IPB             86.000000          82.000000
# 28           IPB             88.000000          89.000000
# 29           IPB             83.000000          90.000000
# ..           ...                   ...                ...
# 710        UNPAD             80.000000          83.000000
# 711        UNPAD             90.000000          91.000000
# 712        UNPAD             84.000000          87.000000
# 713        UNPAD             83.000000          80.000000
# 714        UNPAD             73.000000          73.000000
# 715        UNPAD             81.000000          89.000000
# 716        UNPAD             87.000000          85.000000
# 717        UNPAD             84.000000          84.000000
# 718        UNPAD             82.237153          84.880013
# 719        UNPAD             88.000000          79.000000
# 720        UNPAD             34.500000          34.500000
# 721        UNPAD             82.237153          84.880013
# 722        UNPAD             82.237153          84.880013
# 723        UNPAD             82.000000          86.000000
# 724        UNPAD             90.000000          87.000000
# 725        UNPAD             78.000000          84.000000
# 726        UNPAD             78.000000          87.000000
# 727        UNPAD             86.000000          85.000000
# 728        UNPAD             93.000000          87.000000
# 729        UNPAD             82.000000          86.000000
# 730        UNPAD             81.000000          85.000000
# 731        UNPAD             82.237153          84.880013
# 732        UNPAD             73.000000          82.504010
# 733        UNPAD             82.237153          84.880013
# 734        UNPAD             93.000000          83.000000
# 735        UNPAD             83.000000          77.000000
# 736        UNPAD             83.000000          79.000000
# 737        UNPAD             88.000000          84.880013
# 738        UNPAD             93.000000          89.000000
# 739        UNPAD             82.237153          84.880013
#
#      Rata-rata Indonesia  Rata-rata Fisika  Rata-rata Kimia  \
# 0              85.579080         84.120690        85.150000
# 1              85.579080         84.120690        85.150000
# 2              85.579080         84.120690        85.150000
# 3              85.579080         84.120690        85.150000
# 4              90.000000         93.000000        88.000000
# 5              86.000000         82.000000        82.000000
# 6              81.000000         83.000000        85.000000
# 7              86.000000         90.000000        88.000000
# 8              85.579080         84.120690        85.150000
# 9              85.579080         84.120690        85.150000
# 10             85.579080         84.120690        85.150000
# 11             83.515816         84.120690        86.000000
# 12             84.000000         87.000000        84.000000
# 13             85.579080         84.120690        85.150000
# 14             81.000000         86.000000        83.000000
# 15             34.500000         34.500000        34.500000
# 16             85.579080         84.120690        85.150000
# 17             85.579080         84.120690        85.150000
# 18             85.579080         84.120690        85.150000
# 19             91.000000         87.000000        89.000000
# 20             89.000000         80.000000        83.000000
# 21             83.000000         87.000000        86.000000
# 22             87.000000         84.000000        77.000000
# 23             85.579080         84.120690        85.150000
# 24             82.000000         81.000000        82.000000
# 25             89.000000         81.000000        93.000000
# 26             89.000000         87.000000        86.000000
# 27             89.000000         83.000000        86.000000
# 28             95.000000         88.000000        89.000000
# 29             84.000000         79.000000        83.000000
# ..                   ...               ...              ...
# 710            85.472349         81.000000        81.000000
# 711            90.000000         84.584430        84.592411
# 712            84.000000         81.950658        81.955447
# 713            83.000000         94.000000        87.000000
# 714            73.000000         79.950658        79.955447
# 715            91.000000         84.584430        84.592411
# 716            88.000000         84.000000        82.000000
# 717            84.000000         78.000000        84.000000
# 718            85.361743         84.584430        84.592411
# 719            89.000000         81.000000        92.000000
# 720            34.500000         84.584430        84.592411
# 721            85.361743         84.584430        84.592411
# 722            85.361743         84.584430        84.592411
# 723            85.000000         84.584430        84.592411
# 724            86.000000         81.950658        80.955447
# 725            84.000000         84.584430        84.592411
# 726            83.000000         84.584430        84.592411
# 727            80.000000         85.000000        86.000000
# 728            92.000000         94.000000        87.000000
# 729            84.000000         81.950658        84.592411
# 730            85.000000         84.584430        84.592411
# 731            85.361743         84.584430        84.592411
# 732            85.361743         84.584430        84.592411
# 733            85.361743         84.584430        84.592411
# 734            88.000000         89.000000        88.000000
# 735            82.000000         84.584430        84.592411
# 736            85.361743         84.584430        85.000000
# 737            85.361743         84.584430        84.592411
# 738            89.000000         88.000000        91.000000
# 739            85.361743         84.584430        84.592411
#
#      Rata-rata Biologi  Rata-rata Ekonomi  Rata-rata Geografi  \
# 0            85.283333          83.000000           83.526667
# 1            85.283333          83.000000           83.526667
# 2            85.283333          83.000000           83.526667
# 3            85.283333          83.000000           83.526667
# 4            86.000000          83.000000           83.526667
# 5            88.000000          88.000000           83.526667
# 6            81.000000          83.000000           83.526667
# 7            85.000000          87.000000           81.316000
# 8            85.283333          83.000000           83.526667
# 9            85.283333          83.000000           83.526667
# 10           85.283333          83.000000           83.526667
# 11           88.000000          81.000000           83.316000
# 12           86.000000          83.000000           83.526667
# 13           85.283333          83.000000           83.526667
# 14           87.000000          83.000000           86.000000
# 15           34.500000          63.600000           63.916000
# 16           85.283333          83.000000           83.526667
# 17           85.283333          83.000000           83.526667
# 18           85.283333          83.000000           83.526667
# 19           88.000000          83.000000           83.526667
# 20           90.000000          83.000000           83.526667
# 21           87.000000          84.000000           85.316000
# 22           86.000000          83.000000           83.526667
# 23           85.283333          83.000000           83.526667
# 24           87.000000          83.000000           83.526667
# 25           88.000000          83.000000           83.526667
# 26           85.000000          83.000000           83.526667
# 27           85.000000          80.000000           85.316000
# 28           91.000000          83.000000           83.526667
# 29           83.000000          83.000000           83.526667
# ..                 ...                ...                 ...
# 710          80.000000          79.581358           79.769883
# 711          83.879942          97.000000           94.000000
# 712          81.527965          79.000000           82.000000
# 713          95.000000          83.968929           84.283138
# 714          79.527965          73.000000           73.000000
# 715          83.879942          86.000000           89.000000
# 716          83.000000          83.968929           84.000000
# 717          85.000000          82.775144           83.026510
# 718          83.879942          83.968929           84.283138
# 719          90.000000          83.968929           82.026510
# 720          83.879942          34.500000           34.500000
# 721          83.879942          83.968929           84.283138
# 722          83.879942          83.968929           84.283138
# 723          83.879942          88.000000           83.000000
# 724          82.527965          83.000000           87.000000
# 725          83.879942          82.000000           83.000000
# 726          83.879942          82.000000           85.000000
# 727          84.000000          83.968929           84.283138
# 728          90.000000          83.968929           84.283138
# 729          80.527965          84.000000           84.000000
# 730          83.879942          84.000000           86.000000
# 731          83.879942          83.968929           84.283138
# 732          83.879942          83.968929           84.283138
# 733          83.879942          83.968929           84.283138
# 734          83.000000          83.968929           84.283138
# 735          83.879942          83.000000           85.000000
# 736          85.000000          83.968929           84.283138
# 737          83.879942          83.968929           84.283138
# 738          89.000000          92.000000           85.769883
# 739          83.879942          83.968929           84.283138
#
#      Rata-rata Sosiologi  Rata-rata Sejarah
# 0                    NaN          82.676471
# 1                    NaN          82.676471
# 2                    NaN          82.676471
# 3                    NaN          82.676471
# 4                    NaN          82.676471
# 5                    NaN          87.000000
# 6                    NaN          82.676471
# 7                    NaN          84.000000
# 8                    NaN          82.676471
# 9                    NaN          82.676471
# 10                   NaN          82.676471
# 11                   NaN          80.000000
# 12                   NaN          82.676471
# 13                   NaN          82.676471
# 14                   NaN          85.000000
# 15                   NaN          34.500000
# 16                   NaN          82.676471
# 17                   NaN          82.676471
# 18                   NaN          82.676471
# 19                   NaN          82.676471
# 20                   NaN          82.676471
# 21                   NaN          83.000000
# 22                   NaN          81.000000
# 23                   NaN          82.676471
# 24                   NaN          82.676471
# 25                   NaN          82.676471
# 26                   NaN          82.676471
# 27                   NaN          85.000000
# 28                   NaN          92.000000
# 29                   NaN          82.676471
# ..                   ...                ...
# 710            80.262082          78.000000
# 711            96.000000          94.000000
# 712            84.000000          82.000000
# 713            85.103470          84.169997
# 714            73.000000          73.000000
# 715            92.000000          90.000000
# 716            85.103470          84.169997
# 717            83.682776          82.935997
# 718            85.103470          84.169997
# 719            85.103470          84.169997
# 720            34.500000          34.500000
# 721            85.103470          84.169997
# 722            85.103470          84.169997
# 723            86.000000          88.000000
# 724            88.000000          87.000000
# 725            83.000000          84.169997
# 726            86.000000          82.000000
# 727            85.103470          84.169997
# 728            85.103470          87.000000
# 729            84.000000          86.000000
# 730            87.000000          84.000000
# 731            85.103470          84.169997
# 732            85.103470          84.169997
# 733            85.103470          84.169997
# 734            85.103470          84.169997
# 735            87.000000          83.000000
# 736            85.103470          84.169997
# 737            85.103470          84.169997
# 738            85.103470          91.000000
# 739            85.103470          84.169997
#
# [740 rows x 14 columns]

# %%
data_sort = sort_data(result)

data_sort
# Out:
#     Jurusan Sekolah Jenis Sekolah                            Jurusan Diterima  \
# 0               IPA           SMA                         Administrasi Fiskal
# 1               IPS           SMA                         Administrasi Negara
# 2               IPS           SMA                         Administrasi Negara
# 3               IPS           SMA                         Administrasi Negara
# 4               IPS           SMA                          Administrasi Niaga
# 5               IPS           SMA                     Administrasi Perpajakan
# 6               IPA           SMA                                  Agribisnis
# 7               IPA           SMA                                  Agribisnis
# 8               IPA           SMA                                  Agribisnis
# 9               IPA           SMA                            Agroekoteknologi
# 10              IPA           SMA                            Agroekoteknologi
# 11              IPA           SMA                            Agroekoteknologi
# 12              IPA           SMA                   Agronomi Dan Hortikultura
# 13              IPA           SMA                   Agronomi Dan Hortikultura
# 14              IPA           SMA                               Agroteknologi
# 15              IPA           SMA                               Agroteknologi
# 16              IPA           SMA                               Agroteknologi
# 17              IPS           SMA                                   Akuntansi
# 18              IPA           SMA                                   Akuntansi
# 19              IPS           SMA                                   Akuntansi
# 20              IPA           SMA                                   Akuntansi
# 21              IPA           SMA                                   Akuntansi
# 22              IPS           SMA                                   Akuntansi
# 23              IPA           SMA                                   Akuntansi
# 24              IPS           SMA                                   Akuntansi
# 25              IPA           SMA                                   Akuntansi
# 26              IPS           SMA                                   Akuntansi
# 27              IPS           SMA                                   Akuntansi
# 28              IPS           SMA                                   Akuntansi
# 29              IPS           SMA                                   Akuntansi
# ..              ...           ...                                         ...
# 710             IPA           SMA                    Teknik Sistem Perkapalan
# 711             IPA           SMA                    Teknik Sistem Perkapalan
# 712             IPA           SMA                    Teknik Sistem Perkapalan
# 713             IPA           SMA    Teknik Sistem Perkapalan (Double Degree)
# 714             IPA           SMA                               Teknobiomedik
# 715             IPA           SMA                         Teknologi Bioproses
# 716             IPA           SMA  Teknologi Dan Manajemen Perikanan Budidaya
# 717             IPA           SMA  Teknologi Dan Manajemen Perikanan Budidaya
# 718             IPA           SMA                   Teknologi Hasil Perikanan
# 719             IPA           SMA          Teknologi Industri Hasil Perikanan
# 720             IPA           SMA                Teknologi Industri Pertanian
# 721             IPA           SMA                Teknologi Industri Pertanian
# 722             IPA           SMA                Teknologi Industri Pertanian
# 723             IPA           SMA                Teknologi Industri Pertanian
# 724             IPA           SMA                Teknologi Industri Pertanian
# 725             IPA           SMA                Teknologi Industri Pertanian
# 726             IPA           SMA                Teknologi Industri Pertanian
# 727             IPA           SMA                         Teknologi Informasi
# 728             IPA           SMA                            Teknologi Pangan
# 729             IPA           SMA                            Teknologi Pangan
# 730             IPA           SMA                   Teknologi Produksi Ternak
# 731             IPA           SMA                   Teknologi Produksi Ternak
# 732             IPA           SMA                   Teknologi Produksi Ternak
# 733             IPS           SMA                             Televisi & Film
# 734             IPA           SMA                                         Tin
# 735             IPA           SMA                                         Tip
# 736             IPA           SMA                                        Tphp
# 737             IPS           SMA                              Tv & Perfilman
# 738             IPS           SMA                                Tv Dan Film
# 739             IPA           SMA                                         Ugm
#
#     PTN Diterima  Rata-rata Matematika  Rata-rata Inggris  \
# 0             UI             84.000000          84.000000
# 1             UI             88.000000          86.000000
# 2          UNPAD             87.000000          83.000000
# 3          UNPAD             90.000000          78.000000
# 4             UI             85.465625          83.888667
# 5             UB             92.000000          86.000000
# 6             UB             82.000000          86.000000
# 7             UB             82.000000          83.000000
# 8          UNPAD             86.000000          85.000000
# 9             UB             82.408571          83.918889
# 10            UB             80.000000          82.000000
# 11            UB             84.000000          85.000000
# 12           IPB             85.321398          85.050000
# 13           IPB             71.300000          84.000000
# 14         UNPAD             84.000000          87.000000
# 15         UNPAD             82.000000          80.000000
# 16         UNPAD             76.000000          76.000000
# 17           UGM             93.000000          93.000000
# 18           UGM             92.000000          93.000000
# 19           UGM             89.000000          91.000000
# 20           UGM             88.000000          86.000000
# 21           UGM             93.000000          88.000000
# 22           UGM             97.000000          86.000000
# 23           UGM             91.000000          97.000000
# 24            UI             95.000000          86.000000
# 25            UI             85.465625          83.888667
# 26            UI             85.465625          83.888667
# 27         UNAIR             87.733333          87.000000
# 28         UNAIR             81.000000          80.000000
# 29         UNAIR             85.000000          89.000000
# ..           ...                   ...                ...
# 710          ITS             86.000000          91.000000
# 711          ITS             93.000000          86.000000
# 712          ITS             87.000000          88.000000
# 713          ITS             81.000000          86.000000
# 714        UNAIR             84.576004          85.307966
# 715           UI             85.465625          83.888667
# 716          IPB             86.000000          85.000000
# 717          IPB             83.000000          86.000000
# 718          UGM             89.000000          86.000000
# 719        UNAIR             85.000000          84.000000
# 720          IPB             83.000000          83.000000
# 721          IPB             85.321398          85.050000
# 722          IPB             85.321398          85.050000
# 723          IPB             88.000000          86.000000
# 724          UGM             87.259259          87.788889
# 725          UGM             87.259259          87.788889
# 726        UNPAD             82.000000          84.000000
# 727          UGM             92.000000          90.000000
# 728          IPB             92.000000          88.000000
# 729        UNPAD             87.000000          88.000000
# 730          IPB             34.500000          34.500000
# 731          IPB             82.000000          84.000000
# 732          IPB             86.000000          84.000000
# 733        UNPAD             83.000000          86.000000
# 734          IPB             90.000000          83.000000
# 735          UGM             87.000000          94.000000
# 736          UGM             86.000000          90.000000
# 737        UNPAD             84.000000          91.000000
# 738        UNPAD             83.000000          77.000000
# 739          UGM             93.000000          89.000000
#
#      Rata-rata Indonesia  Rata-rata Fisika  Rata-rata Kimia  \
# 0              84.000000         82.000000        81.000000
# 1              87.000000         85.458673        85.232000
# 2              91.000000         84.584430        84.592411
# 3              88.000000         84.584430        84.592411
# 4              85.246032         84.493016        85.297674
# 5              89.000000         81.956615        82.397782
# 6              94.000000         82.000000        85.000000
# 7              83.000000         81.000000        80.000000
# 8              80.000000         85.000000        86.000000
# 9              84.351667         81.956615        82.397782
# 10             88.000000         79.000000        81.000000
# 11             86.000000         83.000000        84.000000
# 12             85.579080         84.120690        85.150000
# 13             87.000000         87.000000        83.000000
# 14             84.000000         79.000000        79.000000
# 15             83.000000         84.000000        81.000000
# 16             76.000000         76.000000        76.000000
# 17             92.000000         86.843464        87.843137
# 18             92.000000         92.000000        92.000000
# 19             92.000000         87.828571        87.628571
# 20             94.000000         88.000000        87.000000
# 21             84.000000         93.000000        89.000000
# 22             88.000000         90.000000        87.628571
# 23             92.000000         90.000000        91.000000
# 24             86.000000         84.493016        85.297674
# 25             85.246032         84.493016        85.297674
# 26             85.246032         84.493016        85.297674
# 27             87.333333         85.450000        85.537879
# 28             82.000000         80.470000        80.522727
# 29             87.000000         85.450000        85.537879
# ..                   ...               ...              ...
# 710            90.000000         93.000000        81.000000
# 711            83.000000         93.000000        93.000000
# 712            93.000000         84.000000        86.000000
# 713            88.000000         85.000000        87.000000
# 714            85.970128         84.646720        85.035214
# 715            85.246032         84.493016        85.297674
# 716            85.000000         84.000000        84.000000
# 717            88.000000         85.000000        84.000000
# 718            83.000000         83.000000        86.000000
# 719            86.000000         83.000000        81.000000
# 720            86.000000         82.000000        82.000000
# 721            85.579080         84.120690        85.150000
# 722            85.579080         84.120690        85.150000
# 723            90.000000         93.000000        87.000000
# 724            87.974074         86.843464        87.843137
# 725            87.974074         86.843464        87.843137
# 726            84.000000         83.000000        83.000000
# 727            93.000000         89.000000        89.000000
# 728            86.000000         92.000000        85.000000
# 729            87.000000         87.000000        87.000000
# 730            34.500000         34.500000        34.500000
# 731            87.000000         84.000000        77.000000
# 732            90.000000         82.000000        85.000000
# 733            83.000000         84.584430        84.592411
# 734            89.000000         88.000000        88.000000
# 735            80.000000         86.000000        87.000000
# 736            91.000000         88.000000        89.000000
# 737            88.000000         84.584430        84.592411
# 738            82.000000         84.584430        84.592411
# 739            97.000000         89.000000        94.000000
#
#      Rata-rata Biologi  Rata-rata Ekonomi  Rata-rata Geografi  \
# 0            83.000000          86.145714           85.512727
# 1            84.774154          92.000000           92.000000
# 2            83.879942          85.000000           90.000000
# 3            83.879942          93.000000           85.000000
# 4            84.182558          86.145714           85.512727
# 5            82.827536          91.242143           91.000000
# 6            86.000000          85.000000           84.808608
# 7            81.000000          84.210714           83.000000
# 8            84.000000          83.968929           84.283138
# 9            82.827536          84.210714           84.808608
# 10           82.000000          80.242143           84.808608
# 11           86.000000          85.726429           84.808608
# 12           85.283333          83.000000           83.526667
# 13           92.000000          85.845960           87.250000
# 14           88.000000          83.136710           79.801692
# 15           81.000000          83.968929           84.283138
# 16           78.000000          79.581358           84.283138
# 17           87.058824          93.000000           90.000000
# 18           97.000000          97.000000           89.395455
# 19           88.502521          90.000000           90.000000
# 20           87.000000          89.000000           88.094322
# 21           92.000000          93.000000           88.094322
# 22           88.502521          96.000000           87.000000
# 23           89.000000          90.000000           88.094322
# 24           84.182558          91.000000           91.000000
# 25           84.182558          86.145714           85.512727
# 26           84.182558          86.145714           85.512727
# 27           86.522727          86.097619           85.933333
# 28           83.113636          86.000000           81.000000
# 29           86.522727          86.000000           89.000000
# ..                 ...                ...                 ...
# 710          86.000000          87.942857                 NaN
# 711          93.000000          87.839744           84.333333
# 712          91.000000          87.839744           84.333333
# 713          90.000000          84.000000           84.800000
# 714          86.206897          85.211111           84.793706
# 715          84.182558          86.145714           85.512727
# 716          82.000000          83.000000           83.526667
# 717          86.000000          85.845960           87.250000
# 718          84.000000          86.877381           88.659091
# 719          86.000000          85.211111           84.793706
# 720          88.000000          88.000000           83.526667
# 721          85.283333          83.000000           83.526667
# 722          85.283333          83.000000           83.526667
# 723          87.000000          85.845960           84.000000
# 724          87.058824          86.877381           88.659091
# 725          87.058824          86.877381           88.659091
# 726          86.000000          81.561183           79.336154
# 727          93.000000          89.837895           88.094322
# 728          86.000000          85.845960           87.250000
# 729          90.000000          81.561183           87.000000
# 730          34.500000          63.600000           63.916000
# 731          86.000000          83.000000           83.526667
# 732          82.000000          85.000000           85.210667
# 733          83.879942          83.000000           86.000000
# 734          89.000000          83.000000           87.250000
# 735          86.000000          89.837895           88.094322
# 736          90.000000          89.837895           88.094322
# 737          83.879942          87.000000           87.000000
# 738          83.879942          83.000000           85.000000
# 739          93.000000          89.837895           88.094322
#
#      Rata-rata Sosiologi  Rata-rata Sejarah
# 0              86.930877          83.943883
# 1              89.000000          87.482442
# 2              84.000000          88.000000
# 3              87.000000          88.000000
# 4              86.930877          83.943883
# 5              91.000000          93.000000
# 6              84.850000          85.071667
# 7              84.110000          83.000000
# 8              85.103470          84.169997
# 9              84.850000          85.071667
# 10             84.850000          85.000000
# 11             90.000000          83.000000
# 12                   NaN          82.676471
# 13                   NaN          85.916667
# 14             77.670167          80.000000
# 15             85.103470          84.169997
# 16             85.103470          78.000000
# 17             94.000000          95.000000
# 18             91.888889          92.000000
# 19             92.000000          92.000000
# 20             90.363636          89.000000
# 21             90.363636          88.650538
# 22             98.000000          93.000000
# 23             90.363636          87.000000
# 24             86.000000          89.000000
# 25             86.930877          83.943883
# 26             86.930877          83.943883
# 27             85.366667          86.600000
# 28             84.000000          85.000000
# 29             84.000000          90.000000
# ..                   ...                ...
# 710                  NaN          87.250000
# 711            84.666667          84.086667
# 712            84.666667          89.000000
# 713            84.666667          82.000000
# 714            85.695971          83.664000
# 715            86.930877          83.943883
# 716                  NaN          86.000000
# 717                  NaN          85.916667
# 718            91.888889          87.812500
# 719            85.695971          84.000000
# 720                  NaN          87.000000
# 721                  NaN          82.676471
# 722                  NaN          82.676471
# 723                  NaN          88.000000
# 724            91.888889          87.812500
# 725            91.888889          87.812500
# 726            77.450278          81.832680
# 727            90.363636          91.000000
# 728                  NaN          85.916667
# 729            77.450278          81.832680
# 730                  NaN          34.500000
# 731                  NaN          81.000000
# 732                  NaN          86.000000
# 733            84.000000          85.000000
# 734                  NaN          88.000000
# 735            90.363636          88.650538
# 736            90.363636          88.650538
# 737            90.000000          88.467999
# 738            87.000000          83.000000
# 739            90.363636          88.650538
#
# [740 rows x 14 columns]

# %%
list_jurusan_ptn = get_jurusan_ptn(data_sort)

list_jurusan_ptn
# Out:
# [('Administrasi Fiskal', 'UI'),
#  ('Administrasi Negara', 'UNPAD'),
#  ('Administrasi Niaga', 'UI'),
#  ('Administrasi Perpajakan', 'UB'),
#  ('Agribisnis', 'UNPAD'),
#  ('Agroekoteknologi', 'UB'),
#  ('Agronomi Dan Hortikultura', 'IPB'),
#  ('Agroteknologi', 'UNPAD'),
#  ('Akuntansi', 'UGM'),
#  ('Antropologi', 'UNAIR'),
#  ('Antropologi Sosial', 'UB'),
#  ('Apoteker', 'UNAIR'),
#  ('Arkeologi', 'UI'),
#  ('Arsitektur', 'ITB'),
#  ('Arsitektur Lansekap', 'IPB'),
#  ('Astronomi', 'ITB'),
#  ('Bahasa Korea', 'UGM'),
#  ('Biokimia', 'IPB'),
#  ('Biologi', 'ITS'),
#  ('Budidaya Perairan', 'UNAIR'),
#  ('Desain Interior', 'ITS'),
#  ('Ekonomi Dan Studi Pembangunan', 'IPB'),
#  ('Ekonomi Islam', 'UB'),
#  ('Ekonomi Islam ', 'UNPAD'),
#  ('Ekonomi Pembangunan', 'IPB'),
#  ('Fakultas Ilmu Dan Teknologi Kebumian', 'ITB'),
#  ('Fakultas Kedokteran Gigi', 'UNAIR'),
#  ('Fakultas Kedokteran Hewan', 'IPB'),
#  ('Fakultas Teknik Mesin Dan Dirgantara', 'ITB'),
#  ('Farmasi', 'UI'),
#  ('Fisika', 'IPB'),
#  ('Fitb', 'ITB'),
#  ('Fkg', 'UGM'),
#  ('Fmipa', 'ITB'),
#  ('Fmipa Fisika', 'UB'),
#  ('Fmipa- Ilmu Kimia', 'UNPAD'),
#  ('Fsrd', 'ITB'),
#  ('Geofisika', 'UGM'),
#  ('Geofisika ', 'UI'),
#  ('Gizi', 'UGM'),
#  ('Hi', 'UB'),
#  ('Hubungan Internasional', 'UGM'),
#  ('Hubungan Masyarakat', 'UNPAD'),
#  ('Hukum', 'UB'),
#  ('Humas', 'UNPAD'),
#  ('Ikk', 'IPB'),
#  ('Ilmu Adm. Fiskal', 'UI'),
#  ('Ilmu Administrasi Bisnis', 'UNPAD'),
#  ('Ilmu Administrasi Negara', 'UI'),
#  ('Ilmu Administrasi Publik', 'UB'),
#  ('Ilmu Dan Teknologi Kelautan', 'IPB'),
#  ('Ilmu Dan Teknologi Pangan', 'UB'),
#  ('Ilmu Ekonomi', 'UGM'),
#  ('Ilmu Ekonomi Islam', 'UI'),
#  ('Ilmu Filsafat', 'UGM'),
#  ('Ilmu Gizi', 'IPB'),
#  ('Ilmu Hub. Internasional', 'UNPAD'),
#  ('Ilmu Hubungan Internasional', 'UI'),
#  ('Ilmu Hukum', 'UB'),
#  ('Ilmu Informasi Dan Perpustakaan ', 'UNPAD'),
#  ('Ilmu Kelautan', 'UNDIP'),
#  ('Ilmu Keluarga Dan Konsumen', 'IPB'),
#  ('Ilmu Keperawatan', 'UI'),
#  ('Ilmu Keperawatan ', 'UNPAD '),
#  ('Ilmu Kesehatan Masyarakat', 'UNAIR'),
#  ('Ilmu Kesejahteraan Sosial', 'UI'),
#  ('Ilmu Komputer', 'IPB'),
#  ('Ilmu Komunikasi', 'UB'),
#  ('Ilmu Perpustakaan', 'UI'),
#  ('Ilmu Peternakan', 'UNPAD'),
#  ('Ilmu Politik', 'UB'),
#  ('Ilmu Sejarah', 'UI'),
#  ('Ilmu Sosiologi', 'UNPAD'),
#  ('Ilmu Teknologi Pangan', 'IPB'),
#  ('Informasi Dan Ilmu Perpustakaan', 'UNPAD'),
#  ('Kedokteran', 'UI'),
#  ('Kedokteran ', 'UNAIR'),
#  ('Kedokteran Gigi', 'UGM'),
#  ('Kedokteran Hewan', 'IPB'),
#  ('Kehutanan', 'UGM'),
#  ('Kesehatan Masyarakat', 'UI'),
#  ('Kesehatan Masyarakat (Pdd Banyuwangi)', 'UNAIR'),
#  ('Kesejahteraan Sosial', 'UI'),
#  ('Kimia', 'IPB'),
#  ('Kimia ', 'UI'),
#  ('Kimia, ', 'UNPAD'),
#  ('Komunikasi Dan Pengembangan Masyarakat', 'IPB'),
#  ('Kriminologi', 'UI'),
#  ('Manajemen', 'IPB'),
#  ('Manajemen Bisnis', 'ITS'),
#  ('Manajemen Dan Kebijakan Publik (An)', 'UGM'),
#  ('Manajemen Komunikasi', 'UNPAD'),
#  ('Manajemen Sd Perairan', 'UNDIP'),
#  ('Matematika', 'IPB'),
#  ('Matematika ', 'UI'),
#  ('Matematika (Fak. Matematika & Ilmu Pengetahuan Alam)', 'ITB'),
#  ('Menejemen', 'UNAIR '),
#  ('Meteorologi Terapan', 'IPB'),
#  ('Mipa Geologi', 'UI'),
#  ('Nutrisi & Teknologi Pakan', 'IPB'),
#  ('Oceanografi', 'UNDIP'),
#  ('Pembangunan Wilayah', 'UGM'),
#  ('Pend. Apoteker', 'UNAIR'),
#  ('Pendidikan Dokter', 'UB'),
#  ('Pendidikan Dokter Gigi', 'UNAIR'),
#  ('Perencanaan Wilayah & Kota', 'UB'),
#  ('Perencanaan Wilayah Dan Kota', 'ITS'),
#  ('Perikanan', 'IPB'),
#  ('Peternakan', 'UB'),
#  ('Proteksi Tanaman', 'IPB'),
#  ('Psdk', 'UGM'),
#  ('Psikologi', 'UI'),
#  ('Psikologi ', 'UNAIR'),
#  ('Pwk', 'UGM'),
#  ('S-1 Teknik Informatika', 'ITS'),
#  ('Sappk', 'ITB'),
#  ('Sastra', 'UI'),
#  ('Sastra Arab', 'UGM'),
#  ('Sastra Belanda', 'UI'),
#  ('Sastra Indonesia', 'UNPAD'),
#  ('Sastra Inggris', 'UI'),
#  ('Sastra Inggris ', 'UNAIR'),
#  ('Sastra Jawa', 'UI'),
#  ('Sastra Jepang', 'UB'),
#  ('Sastra Jerman', 'UI'),
#  ('Sbm', 'ITB'),
#  ('Silvikultur', 'IPB'),
#  ('Sistem Informasi', 'UB'),
#  ('Sith S', 'ITB'),
#  ('Sosial Ekonomi Pertanian (Agrobisnis)', 'UGM'),
#  ('Sosiologi', 'UB'),
#  ('Sosiologi Murni', 'UNAIR'),
#  ('Statistika', 'IPB'),
#  ('Stei', 'ITB'),
#  ('Tehnik Sipil', 'UGM'),
#  ('Teknik Elektro', 'ITS'),
#  ('Teknik Fisika', 'UGM'),
#  ('Teknik Geologi', 'UNPAD'),
#  ('Teknik Industri', 'ITB'),
#  ('Teknik Industri Pertanian', 'UGM'),
#  ('Teknik Informatika', 'ITS'),
#  ('Teknik Kimia', 'ITB'),
#  ('Teknik Komputer', 'ITS'),
#  ('Teknik Lingkungan', 'UB'),
#  ('Teknik Mesin', 'ITS'),
#  ('Teknik Mesin Dan Biosistem', 'IPB'),
#  ('Teknik Metalurgi & Material', 'UI'),
#  ('Teknik Multimedia Dan Jaringan', 'ITS'),
#  ('Teknik Nuklir', 'UGM'),
#  ('Teknik Pengairan', 'UB'),
#  ('Teknik Perkapalan', 'UI'),
#  ('Teknik Pertanian', 'UGM'),
#  ('Teknik Sipil', 'ITB'),
#  ('Teknik Sipil Dan Lingkungan', 'IPB'),
#  ('Teknik Sipil Lingkungan', 'ITB'),
#  ('Teknik Sistem Perkapalan', 'ITS'),
#  ('Teknobiomedik', 'UNAIR'),
#  ('Teknologi Bioproses', 'UI'),
#  ('Teknologi Dan Manajemen Perikanan Budidaya', 'IPB'),
#  ('Teknologi Hasil Perikanan', 'UGM'),
#  ('Teknologi Industri Hasil Perikanan', 'UNAIR'),
#  ('Teknologi Industri Pertanian', 'IPB'),
#  ('Teknologi Informasi', 'UGM'),
#  ('Teknologi Pangan', 'IPB'),
#  ('Televisi & Film', 'UNPAD'),
#  ('Tin', 'IPB'),
#  ('Tip', 'UGM'),
#  ('Tv & Perfilman', 'UNPAD'),
#  ('Ugm', 'UGM')]

# %%
tabel_alternatif = get_tabel_alternatif(data_sort, list_jurusan_ptn)

tabel_alternatif
# Out:
#             Administrasi Fiskal - UI (IPS)  Administrasi Negara - UNPAD (IPS)  \
# Matematika                       84.000000                          88.500000
# Inggris                          84.000000                          80.500000
# Indonesia                        84.000000                          89.500000
# Fisika                           82.000000                          84.584430
# Kimia                            81.000000                          84.592411
# Biologi                          83.000000                          83.879942
# Ekonomi                          86.145714                          89.000000
# Geografi                         85.512727                          87.500000
# Sosiologi                        86.930877                          85.500000
# Sejarah                          83.943883                          88.000000
#
#             Administrasi Niaga - UI (IPS)  Administrasi Perpajakan - UB (IPS)  \
# Matematika                      85.465625                           92.000000
# Inggris                         83.888667                           86.000000
# Indonesia                       85.246032                           89.000000
# Fisika                          84.493016                           81.956615
# Kimia                           85.297674                           82.397782
# Biologi                         84.182558                           82.827536
# Ekonomi                         86.145714                           91.242143
# Geografi                        85.512727                           91.000000
# Sosiologi                       86.930877                           91.000000
# Sejarah                         83.943883                           93.000000
#
#             Agribisnis - UNPAD (IPA)  Agroekoteknologi - UB (IPA)  \
# Matematika                 86.000000                    82.136190
# Inggris                    85.000000                    83.639630
# Indonesia                  80.000000                    86.117222
# Fisika                     85.000000                    81.318872
# Kimia                      86.000000                    82.465927
# Biologi                    84.000000                    83.609179
# Ekonomi                    83.968929                    83.393095
# Geografi                   84.283138                    84.808608
# Sosiologi                  85.103470                    86.566667
# Sejarah                    84.169997                    84.357222
#
#             Agronomi Dan Hortikultura - IPB (IPA)  \
# Matematika                              78.310699
# Inggris                                 84.525000
# Indonesia                               86.289540
# Fisika                                  85.560345
# Kimia                                   84.075000
# Biologi                                 88.641667
# Ekonomi                                 84.422980
# Geografi                                85.388333
# Sosiologi                                     NaN
# Sejarah                                 84.296569
#
#             Agroteknologi - UNPAD (IPA)  Akuntansi - UGM (IPS)  \
# Matematika                    80.666667              91.857143
# Inggris                       81.000000              90.571429
# Indonesia                     81.000000              90.571429
# Fisika                        79.666667              89.667434
# Kimia                         78.666667              88.871469
# Biologi                       82.333333              89.866267
# Ekonomi                       82.228999              92.571429
# Geografi                      82.789323              88.668346
# Sosiologi                     82.625702              92.425685
# Sejarah                       80.723332              90.950077
#
#             Antropologi - UNAIR (IPA)  ...  \
# Matematika                  84.576004  ...
# Inggris                     85.307966  ...
# Indonesia                   85.970128  ...
# Fisika                      84.646720  ...
# Kimia                       85.035214  ...
# Biologi                     86.206897  ...
# Ekonomi                     85.211111  ...
# Geografi                    84.793706  ...
# Sosiologi                   85.695971  ...
# Sejarah                     83.664000  ...
#
#             Teknologi Dan Manajemen Perikanan Budidaya - IPB (IPS)  \
# Matematika                                          84.500000
# Inggris                                             85.500000
# Indonesia                                           86.500000
# Fisika                                              84.500000
# Kimia                                               84.000000
# Biologi                                             84.000000
# Ekonomi                                             84.422980
# Geografi                                            85.388333
# Sosiologi                                                 NaN
# Sejarah                                             85.958333
#
#             Teknologi Hasil Perikanan - UGM (IPA)  \
# Matematika                              89.000000
# Inggris                                 86.000000
# Indonesia                               83.000000
# Fisika                                  83.000000
# Kimia                                   86.000000
# Biologi                                 84.000000
# Ekonomi                                 86.877381
# Geografi                                88.659091
# Sosiologi                               91.888889
# Sejarah                                 87.812500
#
#             Teknologi Industri Hasil Perikanan - UNAIR (IPA)  \
# Matematika                                         85.000000
# Inggris                                            84.000000
# Indonesia                                          86.000000
# Fisika                                             83.000000
# Kimia                                              81.000000
# Biologi                                            86.000000
# Ekonomi                                            85.211111
# Geografi                                           84.793706
# Sosiologi                                          85.695971
# Sejarah                                            84.000000
#
#             Teknologi Industri Pertanian - IPB (IPA)  \
# Matematika                                 85.410699
# Inggris                                    84.775000
# Indonesia                                  86.789540
# Fisika                                     85.810345
# Kimia                                      84.825000
# Biologi                                    86.391667
# Ekonomi                                    84.961490
# Geografi                                   83.645000
# Sosiologi                                        NaN
# Sejarah                                    85.088235
#
#             Teknologi Informasi - UGM (IPA)  Teknologi Pangan - IPB (IPA)  \
# Matematika                        92.000000                     92.000000
# Inggris                           90.000000                     88.000000
# Indonesia                         93.000000                     86.000000
# Fisika                            89.000000                     92.000000
# Kimia                             89.000000                     85.000000
# Biologi                           93.000000                     86.000000
# Ekonomi                           89.837895                     85.845960
# Geografi                          88.094322                     87.250000
# Sosiologi                         90.363636                           NaN
# Sejarah                           91.000000                     85.916667
#
#             Televisi & Film - UNPAD (IPS)  Tin - IPB (IPA)  Tip - UGM (IPA)  \
# Matematika                      83.000000            90.00        87.000000
# Inggris                         86.000000            83.00        94.000000
# Indonesia                       83.000000            89.00        80.000000
# Fisika                          84.584430            88.00        86.000000
# Kimia                           84.592411            88.00        87.000000
# Biologi                         83.879942            89.00        86.000000
# Ekonomi                         83.000000            83.00        89.837895
# Geografi                        86.000000            87.25        88.094322
# Sosiologi                       84.000000              NaN        90.363636
# Sejarah                         85.000000            88.00        88.650538
#
#             Tv & Perfilman - UNPAD (IPA)
# Matematika                     84.000000
# Inggris                        91.000000
# Indonesia                      88.000000
# Fisika                         84.584430
# Kimia                          84.592411
# Biologi                        83.879942
# Ekonomi                        87.000000
# Geografi                       87.000000
# Sosiologi                      90.000000
# Sejarah                        88.467999
#
# [10 rows x 155 columns]

# %%
tabel_alternatif.to_csv("Tabel Alternatif.csv", encoding="utf-8")
