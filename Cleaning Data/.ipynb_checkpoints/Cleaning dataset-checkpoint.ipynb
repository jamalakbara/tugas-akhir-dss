# %%
import pandas as pd
import math
import numpy as np

# %% [markdown]
# # Open File
#
# Membuka file dataset dengan ekstensi **csv**. Setelah itu merename nama-nama header. Baru kemudian men-drop column-column yang tidak akan digunakan.

# %%
def open_file(file):
    #read dataset
    raw_data = pd.read_csv(file, header=6)

    #ganti nama header
    raw_data.columns = [
                        "Nama Panggilan", 
                        "Asal Sekolah", 
                        "Jurusan Sekolah", 
                        "Jenis Sekolah",
                        "Jenis Kelas", 
                        "Akreditasi Sekolah", 
                        "Prestasi Sekolah", 
                        "Alumni Sekolah", 
                        "PTN Pilihan I", 
                        "Jurusan Pilihan I di PTN Pilihan I" ,
                        "Jurusan Pilihan II di PTN Pilihan I", 
                        "PTN Pilihan II", 
                        "Jurusan Pilihan I di PTN Pilihan II" ,
                        "Jurusan Pilihan II di PTN Pilihan II", 
                        "Jurusan Diterima", "PTN Diterima", 
                        "Matematika Semester 1", 
                        "Matematika Semester 2", 
                        "Matematika Semester 3", 
                        "Matematika Semester 4", 
                        "Matematika Semester 5", 
                        "Inggris Semester 1", 
                        "Inggris Semester 2", 
                        "Inggris Semester 3", 
                        "Inggris Semester 4", 
                        "Inggris Semester 5",
                        "Indonesia Semester 1",
                        "Indonesia Semester 2",
                        "Indonesia Semester 3",
                        "Indonesia Semester 4",
                        "Indonesia Semester 5",
                        "Fisika Semester 1",
                        "Fisika Semester 2",
                        "Fisika Semester 3",
                        "Fisika Semester 4",
                        "Fisika Semester 5",
                        "Kimia Semester 1",
                        "Kimia Semester 2",
                        "Kimia Semester 3",
                        "Kimia Semester 4",
                        "Kimia Semester 5",
                        "Biologi Semester 1",
                        "Biologi Semester 2",
                        "Biologi Semester 3",
                        "Biologi Semester 4",
                        "Biologi Semester 5",
                        "Ekonomi Semester 1",
                        "Ekonomi Semester 2",
                        "Ekonomi Semester 3",
                        "Ekonomi Semester 4",
                        "Ekonomi Semester 5",
                        "Geografi Semester 1",
                        "Geografi Semester 2",
                        "Geografi Semester 3",
                        "Geografi Semester 4",
                        "Geografi Semester 5",
                        "Sosiologi Semester 1",
                        "Sosiologi Semester 2",
                        "Sosiologi Semester 3",
                        "Sosiologi Semester 4",
                        "Sosiologi Semester 5",
                        "Sejarah Semester 1",
                        "Sejarah Semester 2",
                        "Sejarah Semester 3",
                        "Sejarah Semester 4",
                        "Sejarah Semester 5",
                        "Komputer Semester 1",
                        "Komputer Semester 2",
                        "Komputer Semester 3",
                        "Komputer Semester 4",
                        "Komputer Semester 5",
                        "Peringkat Kelas Semester 1",
                        "Peringkat Kelas Semester 2",
                        "Peringkat Kelas Semester 3",
                        "Peringkat Kelas Semester 4",
                        "Peringkat Kelas Semester 5",
                        "Nilai UN", 
                        "Saran",
                        "Prestasi Lain"
                    ]
    
    #drop column yang tidak digunakan
    data = raw_data.drop([
            "Nama Panggilan", 
            "Asal Sekolah", 
            "Jenis Kelas", 
            "Akreditasi Sekolah",
            "Prestasi Sekolah", 
            "Alumni Sekolah", 
            "PTN Pilihan I", 
            "Jurusan Pilihan I di PTN Pilihan I" ,
            "Jurusan Pilihan II di PTN Pilihan I", 
            "PTN Pilihan II", 
            "Jurusan Pilihan I di PTN Pilihan II" ,
            "Jurusan Pilihan II di PTN Pilihan II", 
            "Komputer Semester 1",
            "Komputer Semester 2",
            "Komputer Semester 3",
            "Komputer Semester 4",
            "Komputer Semester 5",
            "Peringkat Kelas Semester 1",
            "Peringkat Kelas Semester 2",
            "Peringkat Kelas Semester 3",
            "Peringkat Kelas Semester 4",
            "Peringkat Kelas Semester 5",
            "Nilai UN", 
            "Saran",
            "Prestasi Lain"
        ],axis=1)
    
    return data

# %% [markdown]
# # Cleaning Nilai
#
# Proses cleaning nilai terdiri dari beberapa langkah:
# 1. Mengambil nilai tengah dari tiap mata kuliah yang ada
# 2.

# %%
def cleaning_nilai(data):

    #Mengambil nilai tengah dari tiap nilai
    data = data.replace("<70", 69)
    data = data.replace("71 - 75", 73)
    data = data.replace("76 - 80", 78)
    data = data.replace("81 - 85", 83)
    data = data.replace("86 - 90", 88)
    data = data.replace("91 - 95", 93)
    data = data.replace("> 95", 96)
    data = data.replace("No data", np.NaN)

    return data

# %%
def replace_zero_w_mean(data, mata_pelajaran):        
    rata2 = (data[f"{mata_pelajaran} Semester 1"].mean() 
            + data[f"{mata_pelajaran} Semester 2"].mean() 
            + data[f"{mata_pelajaran} Semester 3"].mean()
            + data[f"{mata_pelajaran} Semester 4"].mean()
            + data[f"{mata_pelajaran} Semester 5"].mean())/5
    
    values = {
        f"{mata_pelajaran} Semester 1": rata2,
        f"{mata_pelajaran} Semester 2": rata2,
        f"{mata_pelajaran} Semester 3": rata2,
        f"{mata_pelajaran} Semester 4": rata2,
        f"{mata_pelajaran} Semester 5": rata2,
    }
    data = data.fillna(value=values)
                    
    return data

# %%
def rata2_mp_semester(data, mata_pelajaran):
    data_rata2 = {}
    
    mapel = []
    for i in range(1,6):
        mapel.append(f"{mata_pelajaran} Semester {i}")

    data_drop = data.drop(mapel, axis=1)

    for column in data_drop:
        isi = []
        for i in range(len(data)):
            header = column
            isi.append(data[column][i])
        data_rata2[column] = isi

    mean = []
    for i in range(len(data)):
        jumlah_nilai = 0
        jumlah_nilai += data[f"{mata_pelajaran} Semester 1"][i] + data[f"{mata_pelajaran} Semester 2"][i] + data[f"{mata_pelajaran} Semester 3"][i] + data[f"{mata_pelajaran} Semester 4"][i] + data[f"{mata_pelajaran} Semester 5"][i]
        mean.append(jumlah_nilai/5)

    data_rata2[f"Rata-rata {mata_pelajaran}"] = mean

    data_rata2_frame = pd.DataFrame(data=data_rata2)
    return data_rata2_frame

# %%
def remove_nan(data):
    drop_index = []

    for i in range(len(data)):
        try:
            float(data["Jurusan Diterima"][i])
        except ValueError:
            pass
        else:
            if math.isnan(float(data["Jurusan Diterima"][i])) or int(data["Jurusan Diterima"][i]) == 0:
                drop_index.append(i)

    data = data.drop(drop_index)
        
    return data

# %%
def clean_jurusan_ptn(data):
    for i in range(len(data)):
        for column in data:
            if column == "Jurusan Diterima":
                data[column][i] = data[column][i].title()
            elif column == "PTN Diterima":
                data[column][i] = data[column][i].upper()
    
    return data

# %%
def clean(files):
    cleanned_data = []
    
    for file in files:
        data = open_file(file)

        data = cleaning_nilai(data)

        matpel = ["Matematika", "Inggris", "Indonesia", "Fisika", "Kimia", "Biologi", "Ekonomi", "Geografi", "Sosiologi","Sejarah"]

        for item in matpel:
            data = replace_zero_w_mean(data, item)
            data = rata2_mp_semester(data, item)
                    
        data = remove_nan(data)
        
        cleanned_data.append(data)
        
        data_merge = pd.concat(cleanned_data, ignore_index=True)
        
        result = clean_jurusan_ptn(data_merge)

    return result

# %%
def sort_data(data):
    data_sort = data.sort_values(by=['Jurusan Diterima', 'PTN Diterima'])
    
    data_sort.reset_index(inplace = True)

    data_sort = data_sort.drop(["index"], axis=1)

    return data_sort

# %%
# data_sort.reset_index(inplace = True)

# data_sort = data_sort.drop(["index"], axis=1)

# data_sort

# %%
def get_jurusan_ptn(data):
    temp_jurusan = ""
    temp_ptn = ""
    list_jurusan_ptn = []
    for i in range(len(data)):
        if data["Jurusan Diterima"][i] != temp_jurusan and data["PTN Diterima"][i] != temp_ptn:
            temp_jurusan = data["Jurusan Diterima"][i]
            temp_ptn = data["PTN Diterima"][i]
            list_jurusan_ptn.append((temp_jurusan, temp_ptn))
        else:
            pass

    return list_jurusan_ptn

# %%
def get_tabel_alternatif(data, list_jurusan_ptn):
    frame = {}
    for j in range(len(list_jurusan_ptn)):
        list_nilai = []
        for column in data:
            jum = 0
            byk = 0
            for i in range(len(data)):
                if data["Jurusan Diterima"][i] == list_jurusan_ptn[j][0] and data["PTN Diterima"][i] == list_jurusan_ptn[j][1]:
    #                 print(data_sort["Jurusan Diterima"][i], data_sort["PTN Diterima"][i])
                    temp_jurusan = data["Jurusan Diterima"][i]
                    temp_ptn = data["PTN Diterima"][i]
                    try:
                        float(data[column][i])
                    except ValueError:
                        break
                    else:
                        jum += data[column][i]
                        byk += 1
                else:
                    pass
            try:
    #             print(column, jum/byk)
                list_nilai.append(jum/byk)
            except ZeroDivisionError:
                continue
        nama_alternatif = f"{temp_jurusan} - {temp_ptn}"
        if "administrasi" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "sosial" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "ekonomi" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "hi" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "hukum" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "komunikasi" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "politik" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "sosiologi" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "fsrd" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "sbm" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "akuntansi" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "manajemen" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "psdk" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "fiskal" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif ("hubungan" and "internasional") in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "kriminologi" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif ("psikologi" and "-" and "ui") in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "bisnis" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "sastra" in temp_jurusan.casefold().split():
            continue
        elif "bahasa" in temp_jurusan.casefold().split():
            continue
        
        if "(IPS)" not in nama_alternatif.split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPA)"
            
        frame[nama_alternatif] = list_nilai

    tabel = pd.DataFrame(frame, index=["Matematika", "Inggris", "Indonesia", "Fisika", "Kimia", "Biologi", "Ekonomi", "Geografi", "Sosiologi", "Sejarah"])

    return tabel

# %%
datasets = ["Data SNMPTN 2016 IPB by @halokampus.csv",
            "Data SNMPTN 2016 ITB by @halokampus.csv",
            "Data SNMPTN 2016 ITS by @halokampus.csv",
            "Data SNMPTN 2016 UB by @halokampus.csv",
            "Data SNMPTN 2016 UGM by @halokampus.csv",
            "Data SNMPTN 2016 UI by @halokampus.csv",
            "Data SNMPTN 2016 Unair by @halokampus.csv",
            "Data SNMPTN 2016 Undip by @halokampus.csv",
            "Data SNMPTN 2016 Unpad by @halokampus.csv",]

result = clean(datasets)

data_sort = sort_data(result)

list_jurusan_ptn = get_jurusan_ptn(data_sort)

tabel_alternatif = get_tabel_alternatif(data_sort, list_jurusan_ptn)

tabel_alternatif
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#             Administrasi Fiskal - UI (IPS)  \
# Matematika                       84.000000
# Inggris                          84.000000
# Indonesia                        84.000000
# Fisika                           82.000000
# Kimia                            81.000000
# Biologi                          83.000000
# Ekonomi                          86.437143
# Geografi                         85.460364
# Sosiologi                        86.857068
# Sejarah                          84.850782
#
#             Administrasi Perpajakan - UB (IPS)  Agribisnis - IPB (IPA)  \
# Matematika                           92.000000                  93.800
# Inggris                              86.000000                  90.000
# Indonesia                            89.000000                  88.000
# Fisika                               83.248000                  91.000
# Kimia                                83.670667                  88.600
# Biologi                              84.209420                  90.000
# Ekonomi                              90.828333                  85.690
# Geografi                             91.000000                  82.144
# Sosiologi                            90.600000                     NaN
# Sejarah                              92.200000                  89.000
#
#             Agroekoteknologi - UB (IPA)  \
# Matematika                    82.084683
# Inggris                       84.953929
# Indonesia                     86.046270
# Fisika                        82.062000
# Kimia                         82.567667
# Biologi                       84.052355
# Ekonomi                       83.685000
# Geografi                      84.627747
# Sosiologi                     85.680833
# Sejarah                       85.497583
#
#             Agronomi Dan Holtikultura - IPB (IPA)  \
# Matematika                              90.200000
# Inggris                                 90.200000
# Indonesia                               88.600000
# Fisika                                  89.000000
# Kimia                                   90.000000
# Biologi                                 91.000000
# Ekonomi                                 84.150000
# Geografi                                84.906667
# Sosiologi                                     NaN
# Sejarah                                 84.705882
#
#             Agroteknologi - UNPAD (IPA)  Akuntansi - UGM (IPS)  \
# Matematika                    86.000000              92.500000
# Inggris                       87.500000              92.800000
# Indonesia                     88.100000              92.000000
# Fisika                        81.000000              89.501634
# Kimia                         84.500000              89.786275
# Biologi                       86.800000              91.111765
# Ekonomi                       84.241875              93.800000
# Geografi                      81.649538              89.656818
# Sosiologi                     80.580889              92.033333
# Sejarah                       81.885948              93.100000
#
#             Akutansi - UI (IPA)  Antropologi - UNPAD (IPA)  \
# Matematika            72.457490                  84.000000
# Inggris               75.311764                  79.000000
# Indonesia             85.000000                  80.000000
# Fisika                87.000000                  84.141855
# Kimia                 81.200000                  85.938847
# Biologi               83.000000                  84.882707
# Ekonomi               86.437143                  80.000000
# Geografi              85.460364                  82.000000
# Sosiologi             86.857068                  80.000000
# Sejarah               85.000000                  81.000000
#
#             Antropologi Sosial - UB (IPS)  ...  Teknik Sipil - UB (IPA)  \
# Matematika                           77.0  ...                90.000000
# Inggris                              81.0  ...                86.000000
# Indonesia                            80.0  ...                85.000000
# Fisika                               73.0  ...                85.000000
# Kimia                                73.0  ...                79.000000
# Biologi                              73.0  ...                85.000000
# Ekonomi                              79.0  ...                84.141667
# Geografi                             77.0  ...                84.808608
# Sosiologi                            83.0  ...                84.816667
# Sejarah                              80.0  ...                83.000000
#
#             Teknik Sipil Dan Lingkungan - IPB (IPA)  \
# Matematika                                     89.0
# Inggris                                        87.0
# Indonesia                                      89.0
# Fisika                                         87.0
# Kimia                                          91.6
# Biologi                                        92.0
# Ekonomi                                        86.0
# Geografi                                       86.0
# Sosiologi                                       NaN
# Sejarah                                        89.0
#
#             Teknik Sistem Perkapalan - ITS (IPA)  Teknobiomedik - UNAIR (IPA)  \
# Matematika                             86.000000                    87.573333
# Inggris                                91.000000                    86.946667
# Indonesia                              90.000000                    87.200000
# Fisika                                 93.000000                    85.337273
# Kimia                                  81.000000                    85.395455
# Biologi                                86.000000                    86.380303
# Ekonomi                                87.862857                    86.047619
# Geografi                                     NaN                    85.866667
# Sosiologi                                    NaN                    85.366667
# Sejarah                                87.100000                    86.560000
#
#             Teknologi Bioproses - UI (IPA)  \
# Matematika                       86.287450
# Inggris                          84.779410
# Indonesia                        85.768254
# Fisika                           85.167068
# Kimia                            86.120930
# Biologi                          84.857082
# Ekonomi                          86.437143
# Geografi                         85.460364
# Sosiologi                        86.857068
# Sejarah                          84.850782
#
#             Teknologi Dan Manajemen Perikanan Budidaya - IPB (IPS)  \
# Matematika                                          86.000000
# Inggris                                             85.000000
# Indonesia                                           85.000000
# Fisika                                              84.000000
# Kimia                                               84.000000
# Biologi                                             82.000000
# Ekonomi                                             84.150000
# Geografi                                            84.906667
# Sosiologi                                                 NaN
# Sejarah                                             86.000000
#
#             Teknologi Hasil Perikanan - UB (IPA)  \
# Matematika                             82.000000
# Inggris                                91.000000
# Indonesia                              89.000000
# Fisika                                 80.000000
# Kimia                                  79.000000
# Biologi                                83.000000
# Ekonomi                                88.285000
# Geografi                               84.808608
# Sosiologi                              84.816667
# Sejarah                                83.000000
#
#             Teknologi Industri Pertanian - IPB (IPA)  \
# Matematika                                 85.197993
# Inggris                                    85.044444
# Indonesia                                  86.392644
# Fisika                                     84.151724
# Kimia                                      84.786667
# Biologi                                    86.937778
# Ekonomi                                    85.433333
# Geografi                                   84.906667
# Sosiologi                                        NaN
# Sejarah                                    85.470588
#
#             Teknologi Pangan - UB (IPA)  Teknologi Produksi Ternak - IPB (IPA)
# Matematika                    83.338730                              79.000000
# Inggris                       84.815714                              79.000000
# Indonesia                     85.185079                              82.000000
# Fisika                        83.248000                              78.333333
# Kimia                         83.670667                              77.000000
# Biologi                       84.209420                              79.000000
# Ekonomi                       84.141667                              82.643333
# Geografi                      84.808608                              83.071111
# Sosiologi                     84.816667                                    NaN
# Sejarah                       84.990333                              78.666667
#
# [10 rows x 117 columns]

# %%
deviasi = {}
dev_val = {}

for index_name in tabel_alternatif.index:
    dev_val[index_name] = 0
    
for column in tabel_alternatif:
    for col_compare in tabel_alternatif:
        if column == col_compare:
            continue
        else:
            for index_name in tabel_alternatif.index:
#                 print(column, col_compare, index_name, tabel_alternatif[column][index_name], tabel_alternatif[col_compare][index_name])
                nilai_deviasi = tabel_alternatif[column][index_name] - tabel_alternatif[col_compare][index_name]
                deviasi_name = f"{column}-{col_compare}"
                dev_val[index_name] = nilai_deviasi
        
#         print(dev_val)
#         print()
    
        deviasi[deviasi_name] = dev_val
        dev_val = {}
    
deviasi
# Out:
# {'Administrasi Fiskal - UI (IPS)-Administrasi Perpajakan - UB (IPS)': {'Matematika': -8.0,
#   'Inggris': -2.0,
#   'Indonesia': -5.0,
#   'Fisika': -1.2480000000000047,
#   'Kimia': -2.6706666666666763,
#   'Biologi': -1.2094202898550748,
#   'Ekonomi': -4.391190476190474,
#   'Geografi': -5.539636363636362,
#   'Sosiologi': -3.7429324298889526,
#   'Sejarah': -7.349217638691329},
#  'Administrasi Fiskal - UI (IPS)-Agribisnis - IPB (IPA)': {'Matematika': -9.799999999999997,
#   'Inggris': -6.0,
#   'Indonesia': -4.0,
#   'Fisika': -9.0,
#   'Kimia': -7.599999999999994,
#   'Biologi': -7.0,
#   'Ekonomi': 0.747142857142876,
#   'Geografi': 3.316363636363633,
#   'Sosiologi': nan,
#   'Sejarah': -4.149217638691326},
#  'Administrasi Fiskal - UI (IPS)-Agroekoteknologi - UB (IPA)': {'Matematika': 1.9153174603174534,
#   'Inggris': -0.9539285714285768,
#   'Indonesia': -2.046269841269833,
#   'Fisika': -0.06199999999999761,
#   'Kimia': -1.5676666666666677,
#   'Biologi': -1.0523550724637687,
#   'Ekonomi': 2.7521428571428572,
#   'Geografi': 0.8326163836163829,
#   'Sosiologi': 1.1762342367777023,
#   'Sejarah': -0.6468009720246499},
#  'Administrasi Fiskal - UI (IPS)-Agronomi Dan Holtikultura - IPB (IPA)': {'Matematika': -6.200000000000003,
#   'Inggris': -6.200000000000003,
#   'Indonesia': -4.599999999999994,
#   'Fisika': -7.0,
#   'Kimia': -9.0,
#   'Biologi': -8.0,
#   'Ekonomi': 2.287142857142854,
#   'Geografi': 0.553696969696972,
#   'Sosiologi': nan,
#   'Sejarah': 0.14490000836748607},
#  'Administrasi Fiskal - UI (IPS)-Agroteknologi - UNPAD (IPA)': {'Matematika': -2.0,
#   'Inggris': -3.5,
#   'Indonesia': -4.099999999999994,
#   'Fisika': 1.0,
#   'Kimia': -3.5,
#   'Biologi': -3.799999999999997,
#   'Ekonomi': 2.1952682611506162,
#   'Geografi': 3.810825174825169,
#   'Sosiologi': 6.276178681222149,
#   'Sejarah': 2.964834648890374},
#  'Administrasi Fiskal - UI (IPS)-Akuntansi - UGM (IPS)': {'Matematika': -8.5,
#   'Inggris': -8.799999999999997,
#   'Indonesia': -8.0,
#   'Fisika': -7.501633986928113,
#   'Kimia': -8.786274509803917,
#   'Biologi': -8.11176470588235,
#   'Ekonomi': -7.362857142857152,
#   'Geografi': -4.196454545454543,
#   'Sosiologi': -5.17626576322229,
#   'Sejarah': -8.24921763869132},
#  'Administrasi Fiskal - UI (IPS)-Akutansi - UI (IPA)': {'Matematika': 11.542509920634913,
#   'Inggris': 8.688235991479104,
#   'Indonesia': -1.0,
#   'Fisika': -5.0,
#   'Kimia': -0.20000000000000284,
#   'Biologi': 0.0,
#   'Ekonomi': 0.0,
#   'Geografi': 0.0,
#   'Sosiologi': 0.0,
#   'Sejarah': -0.14921763869132576},
#  'Administrasi Fiskal - UI (IPS)-Antropologi - UNPAD (IPA)': {'Matematika': 0.0,
#   'Inggris': 5.0,
#   'Indonesia': 4.0,
#   'Fisika': -2.141854636591475,
#   'Kimia': -4.938847117794495,
#   'Biologi': -1.8827067669172806,
#   'Ekonomi': 6.4371428571428595,
#   'Geografi': 3.4603636363636383,
#   'Sosiologi': 6.857067570111042,
#   'Sejarah': 3.8507823613086742},
#  'Administrasi Fiskal - UI (IPS)-Antropologi Sosial - UB (IPS)': {'Matematika': 7.0,
#   'Inggris': 3.0,
#   'Indonesia': 4.0,
#   'Fisika': 9.0,
#   'Kimia': 8.0,
#   'Biologi': 10.0,
#   'Ekonomi': 7.4371428571428595,
#   'Geografi': 8.460363636363638,
#   'Sosiologi': 3.8570675701110417,
#   'Sejarah': 4.850782361308674},
#  'Administrasi Fiskal - UI (IPS)-Apoteker - UNAIR (IPA)': {'Matematika': -3.5733333333333377,
#   'Inggris': -2.9466666666666725,
#   'Indonesia': -3.200000000000003,
#   'Fisika': -3.337272727272733,
#   'Kimia': -4.395454545454541,
#   'Biologi': -3.3803030303030255,
#   'Ekonomi': 0.3895238095238085,
#   'Geografi': -0.40630303030303594,
#   'Sosiologi': 1.4904009034443675,
#   'Sejarah': -1.709217638691328},
#  'Administrasi Fiskal - UI (IPS)-Arsitektur - ITB (IPA)': {'Matematika': -5.0,
#   'Inggris': -6.0,
#   'Indonesia': -7.0,
#   'Fisika': -4.0,
#   'Kimia': -7.0,
#   'Biologi': -3.0,
#   'Ekonomi': 1.8748051948052051,
#   'Geografi': 0.5603636363636326,
#   'Sosiologi': nan,
#   'Sejarah': -1.8425509720246538},
#  'Administrasi Fiskal - UI (IPS)-Arsitektur Lansekap - IPB (IPA)': {'Matematika': -7.200000000000003,
#   'Inggris': 3.0,
#   'Indonesia': -3.5999999999999943,
#   'Fisika': 1.0,
#   'Kimia': -10.0,
#   'Biologi': -4.0,
#   'Ekonomi': 2.287142857142854,
#   'Geografi': 0.553696969696972,
#   'Sosiologi': nan,
#   'Sejarah': 1.8507823613086742},
#  'Administrasi Fiskal - UI (IPS)-Biokimia - IPB (IPA)': {'Matematika': -2.2969892473118136,
#   'Inggris': -2.066666666666663,
#   'Indonesia': -2.588965517241377,
#   'Fisika': -3.227586206896561,
#   'Kimia': -5.179999999999993,
#   'Biologi': -3.4066666666666663,
#   'Ekonomi': 2.287142857142854,
#   'Geografi': 0.553696969696972,
#   'Sosiologi': nan,
#   'Sejarah': 0.14490000836748607},
#  'Administrasi Fiskal - UI (IPS)-Biologi - ITS (IPA)': {'Matematika': -6.461794871794865,
#   'Inggris': -4.353846153846149,
#   'Indonesia': -3.1538461538461604,
#   'Fisika': -5.353846153846149,
#   'Kimia': -4.923076923076934,
#   'Biologi': -4.292307692307688,
#   'Ekonomi': -1.4257142857142782,
#   'Geografi': nan,
#   'Sosiologi': nan,
#   'Sejarah': -2.24921763869132},
#  'Administrasi Fiskal - UI (IPS)-Budidaya Perairan - UNAIR (IPA)': {'Matematika': -3.5733333333333377,
#   'Inggris': -2.9466666666666725,
#   'Indonesia': -3.200000000000003,
#   'Fisika': -3.337272727272733,
#   'Kimia': -4.395454545454541,
#   'Biologi': -3.3803030303030255,
#   'Ekonomi': 0.3895238095238085,
#   'Geografi': -0.40630303030303594,
#   'Sosiologi': 1.4904009034443675,
#   'Sejarah': -1.709217638691328},
#  'Administrasi Fiskal - UI (IPS)-Ekonomi Dan Studi Pembangunan - IPB (IPS)': {'Matematika': 0.0,
#   'Inggris': -2.0,
#   'Indonesia': 1.1411034482758566,
#   'Fisika': -1.1137931034482733,
#   'Kimia': -3.0,
#   'Biologi': -4.5,
#   'Ekonomi': 3.5171428571428436,
#   'Geografi': 0.9350303030303024,
#   'Sosiologi': nan,
#   'Sejarah': 2.49784118483808},
#  'Administrasi Fiskal - UI (IPS)-Ekonomi Islam - UB (IPS)': {'Matematika': 0.6612698412698421,
#   'Inggris': -0.8157142857142787,
#   'Indonesia': -1.1850793650793605,
#   'Fisika': -1.2480000000000047,
#   'Kimia': -2.6706666666666763,
#   'Biologi': -1.2094202898550748,
#   'Ekonomi': 2.295476190476194,
#   'Geografi': 0.6517555777555799,
#   'Sosiologi': 2.040400903444379,
#   'Sejarah': -0.13955097202465083},
#  'Administrasi Fiskal - UI (IPS)-Ekonomi Sumberdaya Dan Lingkungan - IPB (IPS)': {'Matematika': -2.2969892473118136,
#   'Inggris': -2.066666666666663,
#   'Indonesia': -2.588965517241377,
#   'Fisika': -3.227586206896561,
#   'Kimia': -5.179999999999993,
#   'Biologi': -3.4066666666666663,
#   'Ekonomi': 2.287142857142854,
#   'Geografi': 0.553696969696972,
#   'Sosiologi': nan,
#   'Sejarah': 0.14490000836748607},
#  'Administrasi Fiskal - UI (IPS)-Elektro - ITB (IPA)': {'Matematika': -1.0,
#   'Inggris': -7.0,
#   'Indonesia': -2.0,
#   'Fisika': -2.0,
#   'Kimia': -4.0,
#   'Biologi': -4.0,
#   'Ekonomi': 1.8748051948052051,
#   'Geografi': -2.5396363636363617,
#   'Sosiologi': nan,
#   'Sejarah': 0.8507823613086742},
#  'Administrasi Fiskal - UI (IPS)-Fakultas Kedokteran Hewan - IPB (IPA)': {'Matematika': -2.5999999999999943,
#   'Inggris': -12.0,
#   'Indonesia': -12.0,
#   'Fisika': -10.200000000000003,
#   'Kimia': -13.200000000000003,
#   'Biologi': -7.599999999999994,
#   'Ekonomi': 2.287142857142854,
#   'Geografi': 0.553696969696972,
#   'Sosiologi': nan,
#   'Sejarah': 0.14490000836748607},
#  'Administrasi Fiskal - UI (IPS)-Fakultas Teknik Industri - ITB (IPA)': {'Matematika': -3.8585365853658544,
#   'Inggris': -0.5176585365853441,
#   'Indonesia': -1.990243902439019,
#   'Fisika': -5.553846153846152,
#   'Kimia': -7.146341463414629,
#   'Biologi': -2.8459756097560955,
#   'Ekonomi': 1.8748051948052051,
#   'Geografi': 0.5603636363636326,
#   'Sosiologi': nan,
#   'Sejarah': -1.8425509720246538},
#  'Administrasi Fiskal - UI (IPS)-Farmasi - UI (IPA)': {'Matematika': -2.287450396825392,
#   'Inggris': -0.7794100213022119,
#   'Indonesia': -1.7682539682539726,
#   'Fisika': -3.16706753006477,
#   'Kimia': -5.120930232558152,
#   'Biologi': -1.8570824524312854,
#   'Ekonomi': 0.0,
#   'Geografi': 0.0,
#   'Sosiologi': 0.0,
#   'Sejarah': 0.0},
#  'Administrasi Fiskal - UI (IPS)-Fisika - IPB (IPA)': {'Matematika': -2.2969892473118136,
#   'Inggris': -2.066666666666663,
#   'Indonesia': -2.588965517241377,
#   'Fisika': -3.227586206896561,
#   'Kimia': -5.179999999999993,
#   'Biologi': -3.4066666666666663,
#   'Ekonomi': 2.287142857142854,
#   'Geografi': 0.553696969696972,
#   'Sosiologi': nan,
#   'Sejarah': 0.14490000836748607},
#  'Administrasi Fiskal - UI (IPS)-Fitb - ITB (IPA)': {'Matematika': -3.7333333333333343,
#   'Inggris': -2.6666666666666714,
#   'Indonesia': -5.0,
#   'Fisika': -5.333333333333329,
#   'Kimia': -4.666666666666671,
#   'Biologi': -2.0,
#   'Ekonomi': 1.8748051948052051,
#   'Geografi': 0.5603636363636326,
#   'Sosiologi': nan,
#   'Sejarah': -1.8425509720246538},
#  'Administrasi Fiskal - UI (IPS)-Fkg - UGM (IPA)': {'Matematika': -4.0,
#   'Inggris': -5.0,
#   'Indonesia': -5.0,
#   'Fisika': -10.0,
#   'Kimia': -8.0,
#   'Biologi': -6.599999999999994,
#   'Ekonomi': -2.2337142857142993,
#   'Geografi': -3.062363636363642,
#   'Sosiologi': -4.409599096555638,
#   'Sejarah': -6.149217638691326},
#  'Administrasi Fiskal - UI (IPS)-Fmipa - ITB (IPA)': {'Matematika': -4.679549718574123,
#   'Inggris': -1.6760225140712919,
#   'Indonesia': -0.16697936210130138,
#   'Fisika': -5.527810650887588,
#   'Kimia': -8.003001876172604,
#   'Biologi': -1.241378986866792,
#   'Ekonomi': 1.9680519480519507,
#   'Geografi': 1.3034405594405598,
#   'Sosiologi': nan,
#   'Sejarah': -2.005627895101597},
#  'Administrasi Fiskal - UI (IPS)-Fmipa Fisika - UB (IPA)': {'Matematika': -8.0,
#   'Inggris': -10.799999999999997,
#   'Indonesia': -9.599999999999994,
#   'Fisika': -11.0,
#   'Kimia': -10.200000000000003,
#   'Biologi': -8.599999999999994,
#   'Ekonomi': -1.5628571428571405,
#   'Geografi': 0.6517555777555799,
#   'Sosiologi': 2.040400903444379,
#   'Sejarah': -6.149217638691326},
#  'Administrasi Fiskal - UI (IPS)-Fsrd - ITB (IPS)': {'Matematika': 7.0,
#   'Inggris': -3.3970731707317015,
#   'Indonesia': -1.990243902439019,
#   'Fisika': -5.553846153846152,
#   'Kimia': -7.146341463414629,
#   'Biologi': -2.8459756097560955,
#   'Ekonomi': 1.8748051948052051,
#   'Geografi': 0.5603636363636326,
#   'Sosiologi': nan,
#   'Sejarah': -1.8425509720246538},
#  'Administrasi Fiskal - UI (IPS)-Geofisika - UGM (IPA)': {'Matematika': -3.066666666666663,
#   'Inggris': -3.8518518518518476,
#   'Indonesia': -4.066666666666663,
#   'Fisika': -5.003267973856211,
#   'Kimia': -6.572549019607848,
#   'Biologi': -3.823529411764696,
#   'Ekonomi': -1.151428571428582,
#   'Geografi': -3.062363636363642,
#   'Sosiologi': -4.409599096555638,
#   'Sejarah': -2.886717638691323},
#  'Administrasi Fiskal - UI (IPS)-Geograf - UI (IPA)': {'Matematika': -1.0,
#   'Inggris': -2.0,
#   'Indonesia': 0.0,
#   'Fisika': 2.0,
#   'Kimia': -4.0,
#   'Biologi': -2.0,
#   'Ekonomi': 1.3748571428571381,
#   'Geografi': 2.9841454545454553,
#   'Sosiologi': 1.5428270280444139,
#   'Sejarah': 2.8507823613086742},
#  'Administrasi Fiskal - UI (IPS)-Gizi - UGM (IPA)': {'Matematika': -2.0,
#   'Inggris': -2.0,
#   'Indonesia': -5.0,
#   'Fisika': -6.0,
#   'Kimia': -10.0,
#   'Biologi': -7.0,
#   'Ekonomi': 5.4371428571428595,
#   'Geografi': -3.062363636363642,
#   'Sosiologi': -4.409599096555638,
#   'Sejarah': -2.886717638691323},
#  'Administrasi Fiskal - UI (IPS)-Hi - UB (IPS)': {'Matematika': 6.0,
#   'Inggris': -6.0,
#   'Indonesia': -4.0,
#   'Fisika': -1.2480000000000047,
#   'Kimia': -2.6706666666666763,
#   'Biologi': -1.2094202898550748,
#   'Ekonomi': -3.5628571428571405,
#   'Geografi': -3.5396363636363617,
#   'Sosiologi': -2.1429324298889583,
#   'Sejarah': -4.149217638691326},
#  'Administrasi Fiskal - UI (IPS)-Hubungan Internasional - UNPAD (IPS)': {'Matematika': 0.0,
#   'Inggris': -5.0,
#   'Indonesia': 0.0,
#   'Fisika': -2.141854636591475,
#   'Kimia': -4.938847117794495,
#   'Biologi': -1.8827067669172806,
#   'Ekonomi': 3.4371428571428595,
#   'Geografi': 5.460363636363638,
#   'Sosiologi': 5.857067570111042,
#   'Sejarah': -2.1492176386913258},
#  'Administrasi Fiskal - UI (IPS)-Hukum - UB (IPS)': {'Matematika': 6.0,
#   'Inggris': 1.0,
#   'Indonesia': 3.0,
#   'Fisika': -1.2480000000000047,
#   'Kimia': -2.6706666666666763,
#   'Biologi': -1.2094202898550748,
#   'Ekonomi': 5.4371428571428595,
#   'Geografi': -0.5396363636363617,
#   'Sosiologi': 2.8570675701110417,
#   'Sejarah': 2.8507823613086742},
#  'Administrasi Fiskal - UI (IPS)-Ikk - IPB (IPA)': {'Matematika': 1.0,
#   'Inggris': -6.0,
#   'Indonesia': 0.0,
#   'Fisika': 3.0,
#   'Kimia': -2.0,
#   'Biologi': 0.0,
#   'Ekonomi': 2.287142857142854,
#   'Geografi': 0.553696969696972,
#   'Sosiologi': nan,
#   'Sejarah': 0.14490000836748607},
#  'Administrasi Fiskal - UI (IPS)-Ilmu Adm. Fiskal - UI (IPS)': {'Matematika': -2.287450396825392,
#   'Inggris': -0.7794100213022119,
#   'Indonesia': -1.7682539682539726,
#   'Fisika': -3.16706753006477,
#   'Kimia': -5.120930232558152,
#   'Biologi': -1.8570824524312854,
#   'Ekonomi': 0.0,
#   'Geografi': 0.0,
#   'Sosiologi': 0.0,
#   'Sejarah': 0.0},
#  'Administrasi Fiskal - UI (IPS)-Ilmu Administrasi Bisnis - UNPAD (IPS)': {'Matematika': 0.059259259259263786,
#   'Inggris': -1.5259259259259323,
#   'Indonesia': -0.86666666666666,
#   'Fisika': -2.141854636591475,
#   'Kimia': -4.938847117794509,
#   'Biologi': -1.8827067669172806,
#   'Ekonomi': 2.5097996121525483,
#   'Geografi': 3.5234405594405587,
#   'Sosiologi': 5.630956458999933,
#   'Sejarah': 1.078886936472074},
#  'Administrasi Fiskal - UI (IPS)-Ilmu Administrasi Negara - UI (IPS)': {'Matematika': 1.0,
#   'Inggris': 0.0,
#   'Indonesia': 1.0,
#   'Fisika': -1.0,
#   'Kimia': -5.120930232558152,
#   'Biologi': -1.8570824524312854,
#   'Ekonomi': 0.4371428571428595,
#   'Geografi': 1.4603636363636383,
#   'Sosiologi': 2.8570675701110417,
#   'Sejarah': -0.14921763869132576},
#  'Administrasi Fiskal - UI (IPS)-Ilmu Administrasi Publik - UB (IPS)': {'Matematika': 0.6612698412698421,
#   'Inggris': -0.8157142857142787,
#   'Indonesia': -1.1850793650793605,
#   'Fisika': -1.2480000000000047,
#   'Kimia': -2.6706666666666763,
#   'Biologi': -1.2094202898550748,
#   'Ekonomi': 2.295476190476194,
#   'Geografi': 0.6517555777555799,
#   'Sosiologi': 2.040400903444379,
#   'Sejarah': -0.13955097202465083},
#  'Administrasi Fiskal - UI (IPS)-Ilmu Ekonomi - UGM (IPS)': {'Matematika': -3.066666666666663,
#   'Inggris': -3.8518518518518476,
#   'Indonesia': -4.066666666666663,
#   'Fisika': -5.003267973856211,
#   'Kimia': -6.572549019607848,
#   'Biologi': -3.823529411764696,
#   'Ekonomi': -1.151428571428582,
#   'Geografi': -3.062363636363642,
#   'Sosiologi': -4.409599096555638,
#   'Sejarah': -2.886717638691323},
#  'Administrasi Fiskal - UI (IPS)-Ilmu Ekonomi Islam - UI (IPS)': {'Matematika': -5.443725198412693,
#   'Inggris': -1.889705010651113,
#   'Indonesia': -2.3841269841269934,
#   'Fisika': -3.16706753006477,
#   'Kimia': -5.120930232558152,
#   'Biologi': -1.8570824524312854,
#   'Ekonomi': -4.181428571428569,
#   'Geografi': -0.26981818181818085,
#   'Sosiologi': 0.9285337850555209,
#   'Sejarah': -0.57460881934567},
#  'Administrasi Fiskal - UI (IPS)-Ilmu Gizi - IPB (IPA)': {'Matematika': 0.3515053763440932,
#   'Inggris': -5.133333333333326,
#   'Indonesia': -2.2944827586206884,
#   'Fisika': -3.6137931034482733,
#   'Kimia': -7.090000000000003,
#   'Biologi': -3.203333333333333,
#   'Ekonomi': 2.287142857142854,
#   'Geografi': 0.553696969696972,
#   'Sosiologi': nan,
#   'Sejarah': 0.14490000836748607},
#  'Administrasi Fiskal - UI (IPS)-Ilmu Hubungan Internasional - UI (IPS)': {'Matematika': 1.0,
#   'Inggris': -2.0,
#   'Indonesia': -2.0,
#   'Fisika': -3.16706753006477,
#   'Kimia': -5.120930232558152,
#   'Biologi': -1.8570824524312854,
#   'Ekonomi': 1.4371428571428595,
#   'Geografi': 1.4603636363636383,
#   'Sosiologi': -2.1429324298889583,
#   'Sejarah': -6.149217638691326},
#  'Administrasi Fiskal - UI (IPS)-Ilmu Hukum - UB (IPS)': {'Matematika': 0.44084656084656615,
#   'Inggris': 1.4561904761904856,
#   'Indonesia': -0.4567195767195784,
#   'Fisika': -1.2480000000000047,
#   'Kimia': -2.6706666666666763,
#   'Biologi': -1.2094202898550748,
#   'Ekonomi': 1.6760317460317538,
#   'Geografi': 1.5879582639582708,
#   'Sosiologi': 2.3126231256666046,
#   'Sejarah': 0.5238934724197861},
#  'Administrasi Fiskal - UI (IPS)-Ilmu Kelautan - UNDIP (IPA)': {'Matematika': 2.0,
#   'Inggris': 0.5,
#   'Indonesia': 0.0,
#   'Fisika': 2.0,
#   'Kimia': -3.299999999999997,
#   'Biologi': -2.5,
#   'Ekonomi': 1.583999999999989,
#   'Geografi': 0.5203636363636406,
#   'Sosiologi': 1.657067570111039,
#   'Sejarah': 0.42221093273724364},
#  'Administrasi Fiskal - UI (IPS)-Ilmu Keluarga Dan Konsumen - IPB (IPA)': {'Matematika': -2.4286953405017897,
#   'Inggris': -2.5333333333333456,
#   'Indonesia': -3.827816091954034,
#   'Fisika': -2.947126436781602,
#   'Kimia': -6.389999999999986,
#   'Biologi': -4.3700000000000045,
#   'Ekonomi': 2.8121428571428595,
#   'Geografi': 0.5536969696969862,
#   'Sosiologi': nan,
#   'Sejarah': -0.7864725406521131},
#  'Administrasi Fiskal - UI (IPS)-Ilmu Keperawatan - UI (IPA)': {'Matematika': -2.287450396825392,
#   'Inggris': -0.7794100213022119,
#   'Indonesia': -1.7682539682539726,
#   'Fisika': -3.16706753006477,
#   'Kimia': -5.120930232558152,
#   'Biologi': -1.8570824524312854,
#   'Ekonomi': 0.0,
#   'Geografi': 0.0,
#   'Sosiologi': 0.0,
#   'Sejarah': 0.0},
#  'Administrasi Fiskal - UI (IPS)-Ilmu Keperawatan  - UNPAD  (IPA)': {'Matematika': 0.0,
#   'Inggris': -6.0,
#   'Indonesia': -5.0,
#   'Fisika': 1.0,
#   'Kimia': -5.0,
#   'Biologi': -6.0,
#   'Ekonomi': 1.4371428571428595,
#   'Geografi': 3.5234405594405587,
#   'Sosiologi': 5.630956458999933,
#   'Sejarah': -0.14921763869132576},
#  'Administrasi Fiskal - UI (IPS)-Ilmu Kesehatan Masyarakat - UI (IPA)': {'Matematika': -2.0,
#   'Inggris': -1.0,
#   'Indonesia': -2.0,
#   'Fisika': -2.0,
#   'Kimia': -3.0,
#   'Biologi': 1.0,
#   'Ekonomi': 2.374857142857138,
#   'Geografi': 0.9841454545454553,
#   'Sosiologi': 2.542827028044414,
#   'Sejarah': 0.8507823613086742},
#  'Administrasi Fiskal - UI (IPS)-Ilmu Komputer - IPB (IPA)': {'Matematika': -9.599999999999994,
#   'Inggris': -2.0,
#   'Indonesia': -2.0,
#   'Fisika': -8.0,
#   'Kimia': -7.0,
#   'Biologi': -2.0,
#   'Ekonomi': -1.252857142857124,
#   'Geografi': 3.316363636363633,
#   'Sosiologi': nan,
#   'Sejarah': 0.8507823613086742},
#  'Administrasi Fiskal - UI (IPS)-Ilmu Komunikasi - UB (IPS)': {'Matematika': 3.5537566137566188,
#   'Inggris': -1.9262857142857115,
#   'Indonesia': -0.5950264550264563,
#   'Fisika': -1.2480000000000047,
#   'Kimia': -2.6706666666666763,
#   'Biologi': -1.2094202898550748,
#   'Ekonomi': 2.0565873015873137,
#   'Geografi': -0.9297462537462593,
#   'Sosiologi': 3.2515120145554874,
#   'Sejarah': -0.14599541646910552},
#  'Administrasi Fiskal - UI (IPS)-Ilmu Peternakan - UNPAD (IPA)': {'Matematika': 0.059259259259263786,
#   'Inggris': -1.5259259259259323,
#   'Indonesia': -0.86666666666666,
#   'Fisika': -2.141854636591475,
#   'Kimia': -4.938847117794495,
#   'Biologi': -1.8827067669172806,
#   'Ekonomi': 2.5097996121525483,
#   'Geografi': 3.5234405594405587,
#   'Sosiologi': 5.630956458999933,
#   'Sejarah': 1.078886936472074},
#  'Administrasi Fiskal - UI (IPS)-Ilmu Politik - UB (IPS)': {'Matematika': 4.0,
#   'Inggris': 1.0,
#   'Indonesia': 5.0,
#   'Fisika': -1.2480000000000047,
#   'Kimia': -2.6706666666666763,
#   'Biologi': -1.2094202898550748,
#   'Ekonomi': 9.43714285714286,
#   'Geografi': 4.460363636363638,
#   'Sosiologi': 4.857067570111042,
#   'Sejarah': 0.8507823613086742},
#  'Administrasi Fiskal - UI (IPS)-Ilmu Sejarah - UI (IPA)': {'Matematika': -2.143725198412696,
#   'Inggris': -1.889705010651113,
#   'Indonesia': -3.8841269841269934,
#   'Fisika': 0.4164662349676149,
#   'Kimia': -5.120930232558152,
#   'Biologi': -1.8570824524312854,
#   'Ekonomi': -0.7814285714285774,
#   'Geografi': 0.23018181818181915,
#   'Sosiologi': 0.42853378505552087,
#   'Sejarah': 0.42539118065433},
#  'Administrasi Fiskal - UI (IPS)-Ilmu Teknologi Pangan - IPB (IPA)': {'Matematika': -3.0,
#   'Inggris': -7.0,
#   'Indonesia': -7.0,
#   'Fisika': -5.0,
#   'Kimia': -8.0,
#   'Biologi': -5.0,
#   'Ekonomi': 2.287142857142854,
#   'Geografi': 0.553696969696972,
#   'Sosiologi': nan,
#   'Sejarah': 0.14490000836748607},
#  'Administrasi Fiskal - UI (IPS)-Kedokteran - UI (IPA)': {'Matematika': -3.799999999999997,
#   'Inggris': -8.799999999999997,
#   'Indonesia': -5.0,
#   'Fisika': -7.099999999999994,
#   'Kimia': -11.299999999999997,
#   'Biologi': -9.5,
#   'Ekonomi': 0.0,
#   'Geografi': 0.0,
#   'Sosiologi': -2.571466214944479,
#   'Sejarah': 0.0},
#  'Administrasi Fiskal - UI (IPS)-Kedokteran  - UNAIR (IPA)': {'Matematika': -3.5733333333333377,
#   'Inggris': -2.9466666666666725,
#   'Indonesia': -3.200000000000003,
#   'Fisika': -3.337272727272733,
#   'Kimia': -4.395454545454541,
#   'Biologi': -3.3803030303030255,
#   'Ekonomi': 0.3895238095238085,
#   'Geografi': -0.40630303030303594,
#   'Sosiologi': 1.4904009034443675,
#   'Sejarah': -1.709217638691328},
#  'Administrasi Fiskal - UI (IPS)-Kedokteran Gigi - UI (IPA)': {'Matematika': -3.3999999999999915,
#   'Inggris': -0.6666666666666714,
#   'Indonesia': -2.3999999999999915,
#   'Fisika': -1.6666666666666714,
#   'Kimia': -3.6666666666666714,
#   'Biologi': -1.0,
#   'Ekonomi': 0.0,
#   'Geografi': 0.0,
#   'Sosiologi': 0.0,
#   'Sejarah': 0.9502607871028914},
#  'Administrasi Fiskal - UI (IPS)-Kedokteran Hewan - IPB (IPA)': {'Matematika': -2.2969892473118136,
#   'Inggris': -2.066666666666663,
#   'Indonesia': -2.588965517241377,
#   'Fisika': -3.227586206896561,
#   'Kimia': -5.179999999999993,
#   'Biologi': -3.4066666666666663,
#   'Ekonomi': 2.287142857142854,
#   'Geografi': 0.553696969696972,
#   'Sosiologi': nan,
#   'Sejarah': 0.14490000836748607},
#  'Administrasi Fiskal - UI (IPS)-Kesehatan Masyarakat - UNAIR (IPA)': {'Matematika': -2.0,
#   'Inggris': -1.3333333333333286,
#   'Indonesia': -3.6666666666666714,
#   'Fisika': -1.3333333333333286,
#   'Kimia': -4.333333333333329,
#   'Biologi': -3.6666666666666714,
#   'Ekonomi': 2.348253968253971,
#   'Geografi': -0.40630303030303594,
#   'Sosiologi': 1.4904009034443675,
#   'Sejarah': -0.3358843053579932},
#  'Administrasi Fiskal - UI (IPS)-Kimia - IPB (IPA)': {'Matematika': -2.2989964157706027,
#   'Inggris': 0.6444444444444457,
#   'Indonesia': 0.1370114942528744,
#   'Fisika': -2.7425287356321775,
#   'Kimia': -6.060000000000002,
#   'Biologi': -1.468888888888884,
#   'Ekonomi': 3.157142857142844,
#   'Geografi': 0.14125252525253984,
#   'Sosiologi': nan,
#   'Sejarah': 0.7135274593478869},
#  'Administrasi Fiskal - UI (IPS)-Kriminologi - UI (IPS)': {'Matematika': 0.0,
#   'Inggris': -0.3558820042604509,
#   'Indonesia': -4.0,
#   'Fisika': 2.0,
#   'Kimia': -5.120930232558152,
#   'Biologi': -1.8570824524312854,
#   'Ekonomi': -1.5628571428571405,
#   'Geografi': -0.5396363636363617,
#   'Sosiologi': 1.8570675701110417,
#   'Sejarah': -0.14921763869132576},
#  'Administrasi Fiskal - UI (IPS)-Manajemen - IPB (IPS)': {'Matematika': -4.0,
#   'Inggris': 3.0,
#   'Indonesia': 3.0,
#   'Fisika': -4.0,
#   'Kimia': -2.0,
#   'Biologi': -4.0,
#   'Ekonomi': 2.287142857142854,
#   'Geografi': -0.5396363636363617,
#   'Sosiologi': nan,
#   'Sejarah': -0.14921763869132576},
#  'Administrasi Fiskal - UI (IPS)-Manajemen Dan Kebijakan Publik (An) - UGM (IPS)': {'Matematika': -7.0,
#   'Inggris': -1.0,
#   'Indonesia': -5.0,
#   'Fisika': -5.003267973856211,
#   'Kimia': -6.572549019607848,
#   'Biologi': -3.823529411764696,
#   'Ekonomi': -2.2337142857142993,
#   'Geografi': -2.5396363636363617,
#   'Sosiologi': -3.1429324298889583,
#   'Sejarah': -7.149217638691326},
#  'Administrasi Fiskal - UI (IPS)-Manajemen Sd Perairan - UNDIP (IPS)': {'Matematika': 8.0,
#   'Inggris': 1.0,
#   'Indonesia': -1.0,
#   'Fisika': 9.599999999999994,
#   'Kimia': 7.599999999999994,
#   'Biologi': 1.0,
#   'Ekonomi': 1.4371428571428595,
#   'Geografi': -1.8396363636363589,
#   'Sosiologi': -0.14293242988895827,
#   'Sejarah': -1.0635033529770368},
#  'Administrasi Fiskal - UI (IPS)-Matematika - IPB (IPA)': {'Matematika': -2.2969892473118136,
#   'Inggris': -2.066666666666663,
#   'Indonesia': -2.588965517241377,
#   'Fisika': -3.227586206896561,
#   'Kimia': -5.179999999999993,
#   'Biologi': -3.4066666666666663,
#   'Ekonomi': 2.287142857142854,
#   'Geografi': 0.553696969696972,
#   'Sosiologi': nan,
#   'Sejarah': 0.14490000836748607},
#  'Administrasi Fiskal - UI (IPS)-Matematika  - UI (IPA)': {'Matematika': -9.200000000000003,
#   'Inggris': -1.0,
#   'Indonesia': -4.0,
#   'Fisika': -12.200000000000003,
#   'Kimia': -8.0,
#   'Biologi': -4.0,
#   'Ekonomi': 0.4371428571428595,
#   'Geografi': 0.0,
#   'Sosiologi': 0.0,
#   'Sejarah': 0.8507823613086742},
#  'Administrasi Fiskal - UI (IPS)-Matematika (Fak. Matematika & Ilmu Pengetahuan Alam) - ITB (IPA)': {'Matematika': -6.0,
#   'Inggris': -3.0,
#   'Indonesia': 2.0,
#   'Fisika': -7.599999999999994,
#   'Kimia': -7.0,
#   'Biologi': -2.0,
#   'Ekonomi': 3.124675324675323,
#   'Geografi': 3.3203636363636235,
#   'Sosiologi': nan,
#   'Sejarah': -3.1492176386913258},
#  'Administrasi Fiskal - UI (IPS)-Meteorologi Terapan - IPB (IPA)': {'Matematika': -2.2969892473118136,
#   'Inggris': -2.066666666666663,
#   'Indonesia': -2.588965517241377,
#   'Fisika': -3.227586206896561,
#   'Kimia': -5.179999999999993,
#   'Biologi': -3.4066666666666663,
#   'Ekonomi': 2.287142857142854,
#   'Geografi': 0.553696969696972,
#   'Sosiologi': nan,
#   'Sejarah': 0.14490000836748607},
#  'Administrasi Fiskal - UI (IPS)-Mipa Kimia - UB (IPA)': {'Matematika': -5.0,
#   'Inggris': 1.0,
#   'Indonesia': 2.0,
#   'Fisika': -6.0,
#   'Kimia': -11.599999999999994,
#   'Biologi': 4.0,
#   'Ekonomi': 2.295476190476194,
#   'Geografi': 0.6517555777555799,
#   'Sosiologi': 2.040400903444379,
#   'Sejarah': -0.13955097202465083},
#  'Administrasi Fiskal - UI (IPS)-Nutrisi & Teknologi Pakan - IPB (IPA)': {'Matematika': -9.0,
#   'Inggris': -7.0,
#   'Indonesia': -6.0,
#   'Fisika': -11.0,
#   'Kimia': -7.0,
#   'Biologi': -3.0,
#   'Ekonomi': 2.287142857142854,
#   'Geografi': 0.553696969696972,
#   'Sosiologi': nan,
#   'Sejarah': 0.14490000836748607},
#  'Administrasi Fiskal - UI (IPS)-Oceanografi - UNDIP (IPA)': {'Matematika': -2.11666666666666,
#   'Inggris': -1.36666666666666,
#   'Indonesia': -3.6333333333333258,
#   'Fisika': -2.6199999999999903,
#   'Kimia': -5.194545454545462,
#   'Biologi': -3.0927272727272737,
#   'Ekonomi': -0.7542857142857287,
#   'Geografi': -1.8396363636363589,
#   'Sosiologi': -0.14293242988895827,
#   'Sejarah': -3.006360495834187},
#  'Administrasi Fiskal - UI (IPS)-Pembangunan Wilayah - UGM (IPA)': {'Matematika': 2.0,
#   'Inggris': -10.200000000000003,
#   'Indonesia': -9.799999999999997,
#   'Fisika': 3.0,
#   'Kimia': -6.0,
#   'Biologi': -8.799999999999997,
#   'Ekonomi': 2.6839999999999833,
#   'Geografi': -1.5396363636363617,
#   'Sosiologi': -4.409599096555638,
#   'Sejarah': -2.886717638691323},
#  'Administrasi Fiskal - UI (IPS)-Pendidikan Apoteker - UNAIR (IPA)': {'Matematika': -3.5733333333333377,
#   'Inggris': -2.9466666666666725,
#   'Indonesia': -3.200000000000003,
#   'Fisika': -3.337272727272733,
#   'Kimia': -4.395454545454541,
#   'Biologi': -3.3803030303030255,
#   'Ekonomi': 0.3895238095238085,
#   'Geografi': -0.40630303030303594,
#   'Sosiologi': 1.4904009034443675,
#   'Sejarah': -1.709217638691328},
#  'Administrasi Fiskal - UI (IPS)-Pendidikan Dokter - UB (IPA)': {'Matematika': -7.0,
#   'Inggris': -8.0,
#   'Indonesia': -10.200000000000003,
#   'Fisika': -2.0,
#   'Kimia': -12.599999999999994,
#   'Biologi': -11.799999999999997,
#   'Ekonomi': 2.295476190476194,
#   'Geografi': 0.6517555777555799,
#   'Sosiologi': 2.040400903444379,
#   'Sejarah': -0.13955097202465083},
#  'Administrasi Fiskal - UI (IPS)-Pendidikan Dokter Gigi - UNAIR (IPA)': {'Matematika': -5.0,
#   'Inggris': -7.0,
#   'Indonesia': -8.0,
#   'Fisika': -10.0,
#   'Kimia': -12.0,
#   'Biologi': -8.0,
#   'Ekonomi': 0.3895238095238085,
#   'Geografi': -0.40630303030303594,
#   'Sosiologi': 1.4904009034443675,
#   'Sejarah': -1.709217638691328},
#  'Administrasi Fiskal - UI (IPS)-Perencanaan Wilayah & Kota - UB (IPA)': {'Matematika': 0.0,
#   'Inggris': 2.0,
#   'Indonesia': 0.0,
#   'Fisika': -4.0,
#   'Kimia': -3.0,
#   'Biologi': 0.0,
#   'Ekonomi': 5.4371428571428595,
#   'Geografi': 0.6517555777555799,
#   'Sosiologi': 2.040400903444379,
#   'Sejarah': 2.8507823613086742},
#  'Administrasi Fiskal - UI (IPS)-Perencanaan Wilayah Dan Kota - ITS (IPA)': {'Matematika': -7.53089743589743,
#   'Inggris': -4.1769230769230745,
#   'Indonesia': -4.0,
#   'Fisika': -6.0,
#   'Kimia': -7.5,
#   'Biologi': -5.5,
#   'Ekonomi': -3.321714285714279,
#   'Geografi': nan,
#   'Sosiologi': nan,
#   'Sejarah': -2.449217638691323},
#  'Administrasi Fiskal - UI (IPS)-Perikanan - IPB (IPA)': {'Matematika': -3.0,
#   'Inggris': -5.0,
#   'Indonesia': -4.599999999999994,
#   'Fisika': 2.0,
#   'Kimia': -2.0,
#   'Biologi': -7.0,
#   'Ekonomi': 2.287142857142854,
#   'Geografi': 0.553696969696972,
#   'Sosiologi': nan,
#   'Sejarah': 0.14490000836748607},
#  'Administrasi Fiskal - UI (IPS)-Peternakan - UB (IPA)': {'Matematika': 0.6612698412698421,
#   'Inggris': -0.8157142857142787,
#   'Indonesia': -1.1850793650793605,
#   'Fisika': -1.2480000000000047,
#   'Kimia': -2.6706666666666763,
#   'Biologi': -1.2094202898550748,
#   'Ekonomi': 2.295476190476194,
#   'Geografi': 0.6517555777555799,
#   'Sosiologi': 2.040400903444379,
#   'Sejarah': -0.13955097202465083},
#  'Administrasi Fiskal - UI (IPS)-Proteksi Tanaman - IPB (IPA)': {'Matematika': 0.0,
#   'Inggris': -4.0,
#   'Indonesia': -5.0,
#   'Fisika': -5.0,
#   'Kimia': -5.0,
#   'Biologi': -2.0,
#   'Ekonomi': 2.287142857142854,
#   'Geografi': 0.553696969696972,
#   'Sosiologi': nan,
#   'Sejarah': 0.14490000836748607},
#  'Administrasi Fiskal - UI (IPS)-Psdk - UGM (IPS)': {'Matematika': -3.066666666666663,
#   'Inggris': -3.8518518518518476,
#   'Indonesia': -4.066666666666663,
#   'Fisika': -5.003267973856211,
#   'Kimia': -6.572549019607848,
#   'Biologi': -3.823529411764696,
#   'Ekonomi': -1.151428571428582,
#   'Geografi': -3.062363636363642,
#   'Sosiologi': -4.409599096555638,
#   'Sejarah': -2.886717638691323},
#  'Administrasi Fiskal - UI (IPS)-Psikologi - UI (IPA)': {'Matematika': 1.0,
#   'Inggris': 2.110294989348887,
#   'Indonesia': -2.8841269841269934,
#   'Fisika': 0.9164662349676149,
#   'Kimia': -3.360465116279073,
#   'Biologi': 1.5714587737843573,
#   'Ekonomi': 0.0,
#   'Geografi': 0.0,
#   'Sosiologi': 0.0,
#   'Sejarah': 0.0},
#  'Administrasi Fiskal - UI (IPS)-Pwk - UGM (IPA)': {'Matematika': -2.0,
#   'Inggris': -4.0,
#   'Indonesia': -4.0,
#   'Fisika': -10.200000000000003,
#   'Kimia': -7.0,
#   'Biologi': -5.0,
#   'Ekonomi': -1.151428571428582,
#   'Geografi': -3.062363636363642,
#   'Sosiologi': -4.409599096555638,
#   'Sejarah': -2.886717638691323},
#  'Administrasi Fiskal - UI (IPS)-Sappk - ITB (IPA)': {'Matematika': -1.5,
#   'Inggris': -4.5,
#   'Indonesia': -5.5,
#   'Fisika': 0.5,
#   'Kimia': -6.0,
#   'Biologi': -6.799999999999997,
#   'Ekonomi': 1.8748051948052051,
#   'Geografi': 0.5603636363636326,
#   'Sosiologi': nan,
#   'Sejarah': -2.4958843053579898},
#  'Administrasi Fiskal - UI (IPS)-Sbm - ITB (IPS)': {'Matematika': -3.8585365853658544,
#   'Inggris': -3.3970731707317015,
#   'Indonesia': -1.990243902439019,
#   'Fisika': -5.553846153846152,
#   'Kimia': -7.146341463414629,
#   'Biologi': -2.8459756097560955,
#   'Ekonomi': 1.8748051948052051,
#   'Geografi': 0.5603636363636326,
#   'Sosiologi': nan,
#   'Sejarah': -1.8425509720246538},
#  'Administrasi Fiskal - UI (IPS)-Silvikultur - IPB (IPA)': {'Matematika': -2.2969892473118136,
#   'Inggris': -2.066666666666663,
#   'Indonesia': -2.588965517241377,
#   'Fisika': -3.227586206896561,
#   'Kimia': -5.179999999999993,
#   'Biologi': -3.4066666666666663,
#   'Ekonomi': 2.287142857142854,
#   'Geografi': 0.553696969696972,
#   'Sosiologi': nan,
#   'Sejarah': 0.14490000836748607},
#  'Administrasi Fiskal - UI (IPS)-Sistem Informasi - ITS (IPA)': {'Matematika': -6.461794871794865,
#   'Inggris': -9.0,
#   'Indonesia': -3.1538461538461604,
#   'Fisika': -5.353846153846149,
#   'Kimia': -4.923076923076934,
#   'Biologi': -4.292307692307688,
#   'Ekonomi': -1.4257142857142782,
#   'Geografi': nan,
#   'Sosiologi': nan,
#   'Sejarah': -2.24921763869132},
#  'Administrasi Fiskal - UI (IPS)-Sith-Program Rekayasa - ITB (IPA)': {'Matematika': -5.0,
#   'Inggris': -3.0,
#   'Indonesia': -5.599999999999994,
#   'Fisika': -8.599999999999994,
#   'Kimia': -10.0,
#   'Biologi': -5.0,
#   'Ekonomi': -3.162857142857135,
#   'Geografi': 0.5603636363636326,
#   'Sosiologi': nan,
#   'Sejarah': -1.8425509720246538},
#  'Administrasi Fiskal - UI (IPS)-Sosiologi - UB (IPS)': {'Matematika': 0.6612698412698421,
#   'Inggris': -0.8157142857142787,
#   'Indonesia': -1.1850793650793605,
#   'Fisika': -1.2480000000000047,
#   'Kimia': -2.6706666666666763,
#   'Biologi': -1.2094202898550748,
#   'Ekonomi': 2.295476190476194,
#   'Geografi': 0.6517555777555799,
#   'Sosiologi': 2.040400903444379,
#   'Sejarah': -0.13955097202465083},
#  'Administrasi Fiskal - UI (IPS)-Statistika - IPB (IPA)': {'Matematika': -2.648494623655907,
#   'Inggris': -1.0333333333333314,
#   'Indonesia': -4.294482758620688,
#   'Fisika': -5.913793103448285,
#   'Kimia': -4.590000000000003,
#   'Biologi': -6.203333333333333,
#   'Ekonomi': 2.287142857142854,
#   'Geografi': 0.9350303030303024,
#   'Sosiologi': nan,
#   'Sejarah': -1.0021588151619198},
#  'Administrasi Fiskal - UI (IPS)-Stei - ITB (IPA)': {'Matematika': -5.0,
#   'Inggris': -5.25,
#   'Indonesia': -2.9000000000000057,
#   'Fisika': -5.5,
#   'Kimia': -8.799999999999997,
#   'Biologi': -5.25,
#   'Ekonomi': 2.421623376623387,
#   'Geografi': 0.5603636363636326,
#   'Sosiologi': nan,
#   'Sejarah': -1.7458843053579898},
#  'Administrasi Fiskal - UI (IPS)-Tehnik Sipil - UGM (IPA)': {'Matematika': -7.200000000000003,
#   'Inggris': 2.200000000000003,
#   'Indonesia': 2.200000000000003,
#   'Fisika': -1.4006535947712422,
#   'Kimia': -7.200000000000003,
#   'Biologi': -3.823529411764696,
#   'Ekonomi': -1.151428571428582,
#   'Geografi': -3.062363636363642,
#   'Sosiologi': -4.409599096555638,
#   'Sejarah': -2.886717638691323},
#  'Administrasi Fiskal - UI (IPS)-Teknik Elektro - ITS (IPA)': {'Matematika': -6.461794871794865,
#   'Inggris': -4.353846153846149,
#   'Indonesia': -3.1538461538461604,
#   'Fisika': -5.353846153846149,
#   'Kimia': -4.923076923076934,
#   'Biologi': -4.292307692307688,
#   'Ekonomi': -1.4257142857142782,
#   'Geografi': nan,
#   'Sosiologi': nan,
#   'Sejarah': -2.24921763869132},
#  'Administrasi Fiskal - UI (IPS)-Teknik Geodesi - UNDIP (IPA)': {'Matematika': -2.11666666666666,
#   'Inggris': -1.36666666666666,
#   'Indonesia': -3.6333333333333258,
#   'Fisika': -2.6199999999999903,
#   'Kimia': -5.194545454545462,
#   'Biologi': -3.0927272727272737,
#   'Ekonomi': -0.7542857142857287,
#   'Geografi': -1.8396363636363589,
#   'Sosiologi': -0.14293242988895827,
#   'Sejarah': -3.006360495834187},
#  'Administrasi Fiskal - UI (IPS)-Teknik Geologi - UNPAD (IPA)': {'Matematika': 9.0,
#   'Inggris': -4.599999999999994,
#   'Indonesia': 3.0,
#   'Fisika': 8.599999999999994,
#   'Kimia': 6.0,
#   'Biologi': 7.0,
#   'Ekonomi': 2.5097996121525483,
#   'Geografi': 3.5234405594405587,
#   'Sosiologi': 5.630956458999933,
#   'Sejarah': 1.078886936472074},
#  'Administrasi Fiskal - UI (IPS)-Teknik Industri - ITS (IPA)': {'Matematika': -7.733333333333334,
#   'Inggris': -5.4512820512820355,
#   'Indonesia': -5.384615384615401,
#   'Fisika': -6.117948717948707,
#   'Kimia': -6.174358974358981,
#   'Biologi': -5.764102564102572,
#   'Ekonomi': -3.1380952380952323,
#   'Geografi': nan,
#   'Sosiologi': nan,
#   'Sejarah': -3.2158843053579886},
#  'Administrasi Fiskal - UI (IPS)-Teknik Informatika - UB (IPA)': {'Matematika': -0.4693650793650761,
#   'Inggris': 0.5921428571428606,
#   'Indonesia': -5.511047619047616,
#   'Fisika': -0.12399999999999523,
#   'Kimia': -3.835333333333338,
#   'Biologi': -5.104710144927537,
#   'Ekonomi': 2.295476190476194,
#   'Geografi': 0.6517555777555799,
#   'Sosiologi': 2.040400903444379,
#   'Sejarah': -0.13955097202465083},
#  'Administrasi Fiskal - UI (IPS)-Teknik Kimia - UGM (IPA)': {'Matematika': -7.155555555555566,
#   'Inggris': -5.283950617283949,
#   'Indonesia': -7.488888888888894,
#   'Fisika': -9.334422657952075,
#   'Kimia': -9.857516339869278,
#   'Biologi': -5.607843137254903,
#   'Ekonomi': -1.9552380952381014,
#   'Geografi': -2.954787878787883,
#   'Sosiologi': -4.409599096555652,
#   'Sejarah': -0.640884305358},
#  'Administrasi Fiskal - UI (IPS)-Teknik Lingkungan - ITS (IPA)': {'Matematika': -6.461794871794865,
#   'Inggris': -4.353846153846149,
#   'Indonesia': -3.1538461538461604,
#   'Fisika': -5.353846153846149,
#   'Kimia': -4.923076923076934,
#   'Biologi': -4.292307692307688,
#   'Ekonomi': -1.4257142857142782,
#   'Geografi': nan,
#   'Sosiologi': nan,
#   'Sejarah': -2.24921763869132},
#  'Administrasi Fiskal - UI (IPS)-Teknik Mesin - UB (IPA)': {'Matematika': 1.0,
#   'Inggris': -4.599999999999994,
#   'Indonesia': 3.0,
#   'Fisika': -3.5999999999999943,
#   'Kimia': 2.0,
#   'Biologi': -3.0,
#   'Ekonomi': 2.295476190476194,
#   'Geografi': 0.6517555777555799,
#   'Sosiologi': 2.040400903444379,
#   'Sejarah': -0.13955097202465083},
#  'Administrasi Fiskal - UI (IPS)-Teknik Mesin Dan Biosistem - IPB (IPA)': {'Matematika': -6.248494623655915,
#   'Inggris': -5.833333333333329,
#   'Indonesia': -6.094482758620686,
#   'Fisika': -8.013793103448279,
#   'Kimia': -9.189999999999998,
#   'Biologi': -7.00333333333333,
#   'Ekonomi': 1.3621428571428567,
#   'Geografi': 0.553696969696972,
#   'Sosiologi': nan,
#   'Sejarah': -3.00215881516192},
#  'Administrasi Fiskal - UI (IPS)-Teknik Multimedia Dan Jaringan - ITS (IPA)': {'Matematika': -4.0,
#   'Inggris': -3.0,
#   'Indonesia': -1.0,
#   'Fisika': -2.0,
#   'Kimia': -2.0,
#   'Biologi': 2.0,
#   'Ekonomi': 5.4371428571428595,
#   'Geografi': nan,
#   'Sosiologi': nan,
#   'Sejarah': 2.8507823613086742},
#  'Administrasi Fiskal - UI (IPS)-Teknik Nuklir - UGM (IPA)': {'Matematika': -3.066666666666663,
#   'Inggris': -3.8518518518518476,
#   'Indonesia': -4.066666666666663,
#   'Fisika': -5.003267973856211,
#   'Kimia': -6.572549019607848,
#   'Biologi': -3.823529411764696,
#   'Ekonomi': -1.151428571428582,
#   'Geografi': -3.062363636363642,
#   'Sosiologi': -4.409599096555638,
#   'Sejarah': -2.886717638691323},
#  'Administrasi Fiskal - UI (IPS)-Teknik Pengairan - UB (IPA)': {'Matematika': 1.0,
#   'Inggris': -6.0,
#   'Indonesia': -4.0,
#   'Fisika': -3.0,
#   'Kimia': -2.0,
#   'Biologi': -6.0,
#   'Ekonomi': 2.295476190476194,
#   'Geografi': 0.6517555777555799,
#   'Sosiologi': 2.040400903444379,
#   'Sejarah': -0.14921763869132576},
#  'Administrasi Fiskal - UI (IPS)-Teknik Pertanian - UGM (IPA)': {'Matematika': -3.066666666666663,
#   'Inggris': -3.8518518518518476,
#   'Indonesia': -4.066666666666663,
#   'Fisika': -5.003267973856211,
#   'Kimia': -6.572549019607848,
#   'Biologi': -3.823529411764696,
#   'Ekonomi': -1.151428571428582,
#   'Geografi': -3.062363636363642,
#   'Sosiologi': -4.409599096555638,
#   'Sejarah': -2.886717638691323},
#  'Administrasi Fiskal - UI (IPS)-Teknik Sipil - UB (IPA)': {'Matematika': -6.0,
#   'Inggris': -2.0,
#   'Indonesia': -1.0,
#   'Fisika': -3.0,
#   'Kimia': 2.0,
#   'Biologi': -2.0,
#   'Ekonomi': 2.295476190476194,
#   'Geografi': 0.6517555777555799,
#   'Sosiologi': 2.040400903444379,
#   'Sejarah': 1.8507823613086742},
#  'Administrasi Fiskal - UI (IPS)-Teknik Sipil Dan Lingkungan - IPB (IPA)': {'Matematika': -5.0,
#   'Inggris': -3.0,
#   'Indonesia': -5.0,
#   'Fisika': -5.0,
#   'Kimia': -10.599999999999994,
#   'Biologi': -9.0,
#   'Ekonomi': 0.4371428571428595,
#   'Geografi': -0.5396363636363617,
#   'Sosiologi': nan,
#   'Sejarah': -4.149217638691326},
#  'Administrasi Fiskal - UI (IPS)-Teknik Sistem Perkapalan - ITS (IPA)': {'Matematika': -2.0,
#   'Inggris': -7.0,
#   'Indonesia': -6.0,
#   'Fisika': -11.0,
#   'Kimia': 0.0,
#   'Biologi': -3.0,
#   'Ekonomi': -1.4257142857142782,
#   'Geografi': nan,
#   'Sosiologi': nan,
#   'Sejarah': -2.24921763869132},
#  'Administrasi Fiskal - UI (IPS)-Teknobiomedik - UNAIR (IPA)': {'Matematika': -3.5733333333333377,
#   'Inggris': -2.9466666666666725,
#   'Indonesia': -3.200000000000003,
#   'Fisika': -3.337272727272733,
#   'Kimia': -4.395454545454541,
#   'Biologi': -3.3803030303030255,
#   'Ekonomi': 0.3895238095238085,
#   'Geografi': -0.40630303030303594,
#   'Sosiologi': 1.4904009034443675,
#   'Sejarah': -1.709217638691328},
#  'Administrasi Fiskal - UI (IPS)-Teknologi Bioproses - UI (IPA)': {'Matematika': -2.287450396825392,
#   'Inggris': -0.7794100213022119,
#   'Indonesia': -1.7682539682539726,
#   'Fisika': -3.16706753006477,
#   'Kimia': -5.120930232558152,
#   'Biologi': -1.8570824524312854,
#   'Ekonomi': 0.0,
#   'Geografi': 0.0,
#   'Sosiologi': 0.0,
#   'Sejarah': 0.0},
#  'Administrasi Fiskal - UI (IPS)-Teknologi Dan Manajemen Perikanan Budidaya - IPB (IPS)': {'Matematika': -2.0,
#   'Inggris': -1.0,
#   'Indonesia': -1.0,
#   'Fisika': -2.0,
#   'Kimia': -3.0,
#   'Biologi': 1.0,
#   'Ekonomi': 2.287142857142854,
#   'Geografi': 0.553696969696972,
#   'Sosiologi': nan,
#   'Sejarah': -1.1492176386913258},
#  'Administrasi Fiskal - UI (IPS)-Teknologi Hasil Perikanan - UB (IPA)': {'Matematika': 2.0,
#   'Inggris': -7.0,
#   'Indonesia': -5.0,
#   'Fisika': 2.0,
#   'Kimia': 2.0,
#   'Biologi': 0.0,
#   'Ekonomi': -1.847857142857137,
#   'Geografi': 0.6517555777555799,
#   'Sosiologi': 2.040400903444379,
#   'Sejarah': 1.8507823613086742},
#  'Administrasi Fiskal - UI (IPS)-Teknologi Industri Pertanian - IPB (IPA)': {'Matematika': -1.1979928315412138,
#   'Inggris': -1.0444444444444372,
#   'Indonesia': -2.3926436781609226,
#   'Fisika': -2.1517241379310263,
#   'Kimia': -3.786666666666676,
#   'Biologi': -3.9377777777777823,
#   'Ekonomi': 1.0038095238095224,
#   'Geografi': 0.553696969696972,
#   'Sosiologi': nan,
#   'Sejarah': -0.619805873985456},
#  'Administrasi Fiskal - UI (IPS)-Teknologi Pangan - UB (IPA)': {'Matematika': 0.6612698412698421,
#   'Inggris': -0.8157142857142787,
#   'Indonesia': -1.1850793650793605,
#   'Fisika': -1.2480000000000047,
#   'Kimia': -2.6706666666666763,
#   'Biologi': -1.2094202898550748,
#   'Ekonomi': 2.295476190476194,
#   'Geografi': 0.6517555777555799,
#   'Sosiologi': 2.040400903444379,
#   'Sejarah': -0.13955097202465083},
#  'Administrasi Fiskal - UI (IPS)-Teknologi Produksi Ternak - IPB (IPA)': {'Matematika': 5.0,
#   'Inggris': 5.0,
#   'Indonesia': 2.0,
#   'Fisika': 3.6666666666666714,
#   'Kimia': 4.0,
#   'Biologi': 4.0,
#   'Ekonomi': 3.7938095238095286,
#   'Geografi': 2.3892525252525303,
#   'Sosiologi': nan,
#   'Sejarah': 6.184115694642003},
#  'Administrasi Perpajakan - UB (IPS)-Administrasi Fiskal - UI (IPS)': {'Matematika': 8.0,
#   'Inggris': 2.0,
#   'Indonesia': 5.0,
#   'Fisika': 1.2480000000000047,
#   'Kimia': 2.6706666666666763,
#   'Biologi': 1.2094202898550748,
#   'Ekonomi': 4.391190476190474,
#   'Geografi': 5.539636363636362,
#   'Sosiologi': 3.7429324298889526,
#   'Sejarah': 7.349217638691329},
#  'Administrasi Perpajakan - UB (IPS)-Agribisnis - IPB (IPA)': {'Matematika': -1.7999999999999972,
#   'Inggris': -4.0,
#   'Indonesia': 1.0,
#   'Fisika': -7.751999999999995,
#   'Kimia': -4.929333333333318,
#   'Biologi': -5.790579710144925,
#   'Ekonomi': 5.13833333333335,
#   'Geografi': 8.855999999999995,
#   'Sosiologi': nan,
#   'Sejarah': 3.200000000000003},
#  'Administrasi Perpajakan - UB (IPS)-Agroekoteknologi - UB (IPA)': {'Matematika': 9.915317460317453,
#   'Inggris': 1.0460714285714232,
#   'Indonesia': 2.953730158730167,
#   'Fisika': 1.186000000000007,
#   'Kimia': 1.1030000000000086,
#   'Biologi': 0.15706521739130608,
#   'Ekonomi': 7.143333333333331,
#   'Geografi': 6.372252747252745,
#   'Sosiologi': 4.919166666666655,
#   'Sejarah': 6.702416666666679},
#  'Administrasi Perpajakan - UB (IPS)-Agronomi Dan Holtikultura - IPB (IPA)': {'Matematika': 1.7999999999999972,
#   'Inggris': -4.200000000000003,
#   'Indonesia': 0.4000000000000057,
#   'Fisika': -5.751999999999995,
#   'Kimia': -6.329333333333324,
#   'Biologi': -6.790579710144925,
#   'Ekonomi': 6.6783333333333275,
#   'Geografi': 6.093333333333334,
#   'Sosiologi': nan,
#   'Sejarah': 7.494117647058815},
#  'Administrasi Perpajakan - UB (IPS)-Agroteknologi - UNPAD (IPA)': {'Matematika': 6.0,
#   'Inggris': -1.5,
#   'Indonesia': 0.9000000000000057,
#   'Fisika': 2.2480000000000047,
#   'Kimia': -0.8293333333333237,
#   'Biologi': -2.5905797101449224,
#   'Ekonomi': 6.58645873734109,
#   'Geografi': 9.35046153846153,
#   'Sosiologi': 10.019111111111101,
#   'Sejarah': 10.314052287581703},
#  'Administrasi Perpajakan - UB (IPS)-Akuntansi - UGM (IPS)': {'Matematika': -0.5,
#   'Inggris': -6.799999999999997,
#   'Indonesia': -3.0,
#   'Fisika': -6.253633986928108,
#   'Kimia': -6.115607843137241,
#   'Biologi': -6.902344416027276,
#   'Ekonomi': -2.9716666666666782,
#   'Geografi': 1.3431818181818187,
#   'Sosiologi': -1.4333333333333371,
#   'Sejarah': -0.8999999999999915},
#  'Administrasi Perpajakan - UB (IPS)-Akutansi - UI (IPA)': {'Matematika': 19.542509920634913,
#   'Inggris': 10.688235991479104,
#   'Indonesia': 4.0,
#   'Fisika': -3.7519999999999953,
#   'Kimia': 2.4706666666666734,
#   'Biologi': 1.2094202898550748,
#   'Ekonomi': 4.391190476190474,
#   'Geografi': 5.539636363636362,
#   'Sosiologi': 3.7429324298889526,
#   'Sejarah': 7.200000000000003},
#  'Administrasi Perpajakan - UB (IPS)-Antropologi - UNPAD (IPA)': {'Matematika': 8.0,
#   'Inggris': 7.0,
#   'Indonesia': 9.0,
#   'Fisika': -0.8938546365914704,
#   'Kimia': -2.2681804511278187,
#   'Biologi': -0.6732864770622058,
#   'Ekonomi': 10.828333333333333,
#   'Geografi': 9.0,
#   'Sosiologi': 10.599999999999994,
#   'Sejarah': 11.200000000000003},
#  'Administrasi Perpajakan - UB (IPS)-Antropologi Sosial - UB (IPS)': {'Matematika': 15.0,
#   'Inggris': 5.0,
#   'Indonesia': 9.0,
#   'Fisika': 10.248000000000005,
#   'Kimia': 10.670666666666676,
#   'Biologi': 11.209420289855075,
#   'Ekonomi': 11.828333333333333,
#   'Geografi': 14.0,
#   'Sosiologi': 7.599999999999994,
#   'Sejarah': 12.200000000000003},
#  'Administrasi Perpajakan - UB (IPS)-Apoteker - UNAIR (IPA)': {'Matematika': 4.426666666666662,
#   'Inggris': -0.9466666666666725,
#   'Indonesia': 1.7999999999999972,
#   'Fisika': -2.0892727272727285,
#   'Kimia': -1.7247878787878648,
#   'Biologi': -2.1708827404479507,
#   'Ekonomi': 4.780714285714282,
#   'Geografi': 5.133333333333326,
#   'Sosiologi': 5.23333333333332,
#   'Sejarah': 5.640000000000001},
#  'Administrasi Perpajakan - UB (IPS)-Arsitektur - ITB (IPA)': {'Matematika': 3.0,
#   'Inggris': -4.0,
#   'Indonesia': -2.0,
#   'Fisika': -2.7519999999999953,
#   'Kimia': -4.329333333333324,
#   'Biologi': -1.7905797101449252,
#   'Ekonomi': 6.265995670995679,
#   'Geografi': 6.099999999999994,
#   'Sosiologi': nan,
#   'Sejarah': 5.506666666666675},
#  'Administrasi Perpajakan - UB (IPS)-Arsitektur Lansekap - IPB (IPA)': {'Matematika': 0.7999999999999972,
#   'Inggris': 5.0,
#   'Indonesia': 1.4000000000000057,
#   'Fisika': 2.2480000000000047,
#   'Kimia': -7.329333333333324,
#   'Biologi': -2.7905797101449252,
#   'Ekonomi': 6.6783333333333275,
#   'Geografi': 6.093333333333334,
#   'Sosiologi': nan,
#   'Sejarah': 9.200000000000003},
#  'Administrasi Perpajakan - UB (IPS)-Biokimia - IPB (IPA)': {'Matematika': 5.703010752688186,
#   'Inggris': -0.06666666666666288,
#   'Indonesia': 2.411034482758623,
#   'Fisika': -1.9795862068965562,
#   'Kimia': -2.5093333333333163,
#   'Biologi': -2.1972463768115915,
#   'Ekonomi': 6.6783333333333275,
#   'Geografi': 6.093333333333334,
#   'Sosiologi': nan,
#   'Sejarah': 7.494117647058815},
#  'Administrasi Perpajakan - UB (IPS)-Biologi - ITS (IPA)': {'Matematika': 1.538205128205135,
#   'Inggris': -2.353846153846149,
#   'Indonesia': 1.8461538461538396,
#   'Fisika': -4.105846153846144,
#   'Kimia': -2.2524102564102577,
#   'Biologi': -3.082887402452613,
#   'Ekonomi': 2.9654761904761955,
#   'Geografi': nan,
#   'Sosiologi': nan,
#   'Sejarah': 5.1000000000000085},
#  'Administrasi Perpajakan - UB (IPS)-Budidaya Perairan - UNAIR (IPA)': {'Matematika': 4.426666666666662,
#   'Inggris': -0.9466666666666725,
#   'Indonesia': 1.7999999999999972,
#   'Fisika': -2.0892727272727285,
#   'Kimia': -1.7247878787878648,
#   'Biologi': -2.1708827404479507,
#   'Ekonomi': 4.780714285714282,
#   'Geografi': 5.133333333333326,
#   'Sosiologi': 5.23333333333332,
#   'Sejarah': 5.640000000000001},
#  'Administrasi Perpajakan - UB (IPS)-Ekonomi Dan Studi Pembangunan - IPB (IPS)': {'Matematika': 8.0,
#   'Inggris': 0.0,
#   'Indonesia': 6.141103448275857,
#   'Fisika': 0.13420689655173135,
#   'Kimia': -0.3293333333333237,
#   'Biologi': -3.2905797101449252,
#   'Ekonomi': 7.908333333333317,
#   'Geografi': 6.474666666666664,
#   'Sosiologi': nan,
#   'Sejarah': 9.847058823529409},
#  'Administrasi Perpajakan - UB (IPS)-Ekonomi Islam - UB (IPS)': {'Matematika': 8.661269841269842,
#   'Inggris': 1.1842857142857213,
#   'Indonesia': 3.8149206349206395,
#   'Fisika': 0.0,
#   'Kimia': 0.0,
#   'Biologi': 0.0,
#   'Ekonomi': 6.686666666666667,
#   'Geografi': 6.191391941391942,
#   'Sosiologi': 5.783333333333331,
#   'Sejarah': 7.209666666666678},
#  'Administrasi Perpajakan - UB (IPS)-Ekonomi Sumberdaya Dan Lingkungan - IPB (IPS)': {'Matematika': 5.703010752688186,
#   'Inggris': -0.06666666666666288,
#   'Indonesia': 2.411034482758623,
#   'Fisika': -1.9795862068965562,
#   'Kimia': -2.5093333333333163,
#   'Biologi': -2.1972463768115915,
#   'Ekonomi': 6.6783333333333275,
#   'Geografi': 6.093333333333334,
#   'Sosiologi': nan,
#   'Sejarah': 7.494117647058815},
#  'Administrasi Perpajakan - UB (IPS)-Elektro - ITB (IPA)': {'Matematika': 7.0,
# ...
#   'Sejarah': -10.0},
#  'Antropologi - UNPAD (IPA)-Fsrd - ITB (IPS)': {'Matematika': 7.0,
#   'Inggris': -8.397073170731701,
#   'Indonesia': -5.990243902439019,
#   'Fisika': -3.411991517254677,
#   'Kimia': -2.207494345620134,
#   'Biologi': -0.963268842838815,
#   'Ekonomi': -4.562337662337654,
#   'Geografi': -2.9000000000000057,
#   'Sosiologi': nan,
#   'Sejarah': -5.693333333333328},
#  'Antropologi - UNPAD (IPA)-Geofisika - UGM (IPA)': {'Matematika': -3.066666666666663,
#   'Inggris': -8.851851851851848,
#   'Indonesia': -8.066666666666663,
#   'Fisika': -2.861413337264736,
#   'Kimia': -1.6337019018133532,
#   'Biologi': -1.9408226448474153,
#   'Ekonomi': -7.588571428571441,
#   'Geografi': -6.5227272727272805,
#   'Sosiologi': -11.26666666666668,
#   'Sejarah': -6.737499999999997},
#  'Antropologi - UNPAD (IPA)-Geograf - UI (IPA)': {'Matematika': -1.0,
#   'Inggris': -7.0,
#   'Indonesia': -4.0,
#   'Fisika': 4.141854636591475,
#   'Kimia': 0.938847117794495,
#   'Biologi': -0.11729323308271944,
#   'Ekonomi': -5.062285714285721,
#   'Geografi': -0.476218181818183,
#   'Sosiologi': -5.314240542066628,
#   'Sejarah': -1.0},
#  'Antropologi - UNPAD (IPA)-Gizi - UGM (IPA)': {'Matematika': -2.0,
#   'Inggris': -7.0,
#   'Indonesia': -9.0,
#   'Fisika': -3.858145363408525,
#   'Kimia': -5.061152882205505,
#   'Biologi': -5.117293233082719,
#   'Ekonomi': -1.0,
#   'Geografi': -6.5227272727272805,
#   'Sosiologi': -11.26666666666668,
#   'Sejarah': -6.737499999999997},
#  'Antropologi - UNPAD (IPA)-Hi - UB (IPS)': {'Matematika': 6.0,
#   'Inggris': -11.0,
#   'Indonesia': -8.0,
#   'Fisika': 0.8938546365914704,
#   'Kimia': 2.2681804511278187,
#   'Biologi': 0.6732864770622058,
#   'Ekonomi': -10.0,
#   'Geografi': -7.0,
#   'Sosiologi': -9.0,
#   'Sejarah': -8.0},
#  'Antropologi - UNPAD (IPA)-Hubungan Internasional - UNPAD (IPS)': {'Matematika': 0.0,
#   'Inggris': -10.0,
#   'Indonesia': -4.0,
#   'Fisika': 0.0,
#   'Kimia': 0.0,
#   'Biologi': 0.0,
#   'Ekonomi': -3.0,
#   'Geografi': 2.0,
#   'Sosiologi': -1.0,
#   'Sejarah': -6.0},
#  'Antropologi - UNPAD (IPA)-Hukum - UB (IPS)': {'Matematika': 6.0,
#   'Inggris': -4.0,
#   'Indonesia': -1.0,
#   'Fisika': 0.8938546365914704,
#   'Kimia': 2.2681804511278187,
#   'Biologi': 0.6732864770622058,
#   'Ekonomi': -1.0,
#   'Geografi': -4.0,
#   'Sosiologi': -4.0,
#   'Sejarah': -1.0},
#  'Antropologi - UNPAD (IPA)-Ikk - IPB (IPA)': {'Matematika': 1.0,
#   'Inggris': -11.0,
#   'Indonesia': -4.0,
#   'Fisika': 5.141854636591475,
#   'Kimia': 2.938847117794495,
#   'Biologi': 1.8827067669172806,
#   'Ekonomi': -4.150000000000006,
#   'Geografi': -2.9066666666666663,
#   'Sosiologi': nan,
#   'Sejarah': -3.705882352941188},
#  'Antropologi - UNPAD (IPA)-Ilmu Adm. Fiskal - UI (IPS)': {'Matematika': -2.287450396825392,
#   'Inggris': -5.779410021302212,
#   'Indonesia': -5.768253968253973,
#   'Fisika': -1.0252128934732951,
#   'Kimia': -0.1820831147636568,
#   'Biologi': 0.025624314485995114,
#   'Ekonomi': -6.4371428571428595,
#   'Geografi': -3.4603636363636383,
#   'Sosiologi': -6.857067570111042,
#   'Sejarah': -3.8507823613086742},
#  'Antropologi - UNPAD (IPA)-Ilmu Administrasi Bisnis - UNPAD (IPS)': {'Matematika': 0.059259259259263786,
#   'Inggris': -6.525925925925932,
#   'Indonesia': -4.86666666666666,
#   'Fisika': 0.0,
#   'Kimia': -1.4210854715202004e-14,
#   'Biologi': 0.0,
#   'Ekonomi': -3.927343244990311,
#   'Geografi': 0.06307692307692037,
#   'Sosiologi': -1.2261111111111092,
#   'Sejarah': -2.7718954248366003},
#  'Antropologi - UNPAD (IPA)-Ilmu Administrasi Negara - UI (IPS)': {'Matematika': 1.0,
#   'Inggris': -5.0,
#   'Indonesia': -3.0,
#   'Fisika': 1.141854636591475,
#   'Kimia': -0.1820831147636568,
#   'Biologi': 0.025624314485995114,
#   'Ekonomi': -6.0,
#   'Geografi': -2.0,
#   'Sosiologi': -4.0,
#   'Sejarah': -4.0},
#  'Antropologi - UNPAD (IPA)-Ilmu Administrasi Publik - UB (IPS)': {'Matematika': 0.6612698412698421,
#   'Inggris': -5.815714285714279,
#   'Indonesia': -5.1850793650793605,
#   'Fisika': 0.8938546365914704,
#   'Kimia': 2.2681804511278187,
#   'Biologi': 0.6732864770622058,
#   'Ekonomi': -4.141666666666666,
#   'Geografi': -2.8086080586080584,
#   'Sosiologi': -4.816666666666663,
#   'Sejarah': -3.990333333333325},
#  'Antropologi - UNPAD (IPA)-Ilmu Ekonomi - UGM (IPS)': {'Matematika': -3.066666666666663,
#   'Inggris': -8.851851851851848,
#   'Indonesia': -8.066666666666663,
#   'Fisika': -2.861413337264736,
#   'Kimia': -1.6337019018133532,
#   'Biologi': -1.9408226448474153,
#   'Ekonomi': -7.588571428571441,
#   'Geografi': -6.5227272727272805,
#   'Sosiologi': -11.26666666666668,
#   'Sejarah': -6.737499999999997},
#  'Antropologi - UNPAD (IPA)-Ilmu Ekonomi Islam - UI (IPS)': {'Matematika': -5.443725198412693,
#   'Inggris': -6.889705010651113,
#   'Indonesia': -6.384126984126993,
#   'Fisika': -1.0252128934732951,
#   'Kimia': -0.1820831147636568,
#   'Biologi': 0.025624314485995114,
#   'Ekonomi': -10.618571428571428,
#   'Geografi': -3.730181818181819,
#   'Sosiologi': -5.928533785055521,
#   'Sejarah': -4.425391180654344},
#  'Antropologi - UNPAD (IPA)-Ilmu Gizi - IPB (IPA)': {'Matematika': 0.3515053763440932,
#   'Inggris': -10.133333333333326,
#   'Indonesia': -6.294482758620688,
#   'Fisika': -1.4719384668567983,
#   'Kimia': -2.1511528822055084,
#   'Biologi': -1.3206265664160526,
#   'Ekonomi': -4.150000000000006,
#   'Geografi': -2.9066666666666663,
#   'Sosiologi': nan,
#   'Sejarah': -3.705882352941188},
#  'Antropologi - UNPAD (IPA)-Ilmu Hubungan Internasional - UI (IPS)': {'Matematika': 1.0,
#   'Inggris': -7.0,
#   'Indonesia': -6.0,
#   'Fisika': -1.0252128934732951,
#   'Kimia': -0.1820831147636568,
#   'Biologi': 0.025624314485995114,
#   'Ekonomi': -5.0,
#   'Geografi': -2.0,
#   'Sosiologi': -9.0,
#   'Sejarah': -10.0},
#  'Antropologi - UNPAD (IPA)-Ilmu Hukum - UB (IPS)': {'Matematika': 0.44084656084656615,
#   'Inggris': -3.5438095238095144,
#   'Indonesia': -4.456719576719578,
#   'Fisika': 0.8938546365914704,
#   'Kimia': 2.2681804511278187,
#   'Biologi': 0.6732864770622058,
#   'Ekonomi': -4.761111111111106,
#   'Geografi': -1.8724053724053675,
#   'Sosiologi': -4.544444444444437,
#   'Sejarah': -3.326888888888888},
#  'Antropologi - UNPAD (IPA)-Ilmu Kelautan - UNDIP (IPA)': {'Matematika': 2.0,
#   'Inggris': -4.5,
#   'Indonesia': -4.0,
#   'Fisika': 4.141854636591475,
#   'Kimia': 1.6388471177944979,
#   'Biologi': -0.6172932330827194,
#   'Ekonomi': -4.8531428571428705,
#   'Geografi': -2.9399999999999977,
#   'Sosiologi': -5.200000000000003,
#   'Sejarah': -3.4285714285714306},
#  'Antropologi - UNPAD (IPA)-Ilmu Keluarga Dan Konsumen - IPB (IPA)': {'Matematika': -2.4286953405017897,
#   'Inggris': -7.533333333333346,
#   'Indonesia': -7.827816091954034,
#   'Fisika': -0.8052718001901269,
#   'Kimia': -1.4511528822054913,
#   'Biologi': -2.487293233082724,
#   'Ekonomi': -3.625,
#   'Geografi': -2.906666666666652,
#   'Sosiologi': nan,
#   'Sejarah': -4.637254901960787},
#  'Antropologi - UNPAD (IPA)-Ilmu Keperawatan - UI (IPA)': {'Matematika': -2.287450396825392,
#   'Inggris': -5.779410021302212,
#   'Indonesia': -5.768253968253973,
#   'Fisika': -1.0252128934732951,
#   'Kimia': -0.1820831147636568,
#   'Biologi': 0.025624314485995114,
#   'Ekonomi': -6.4371428571428595,
#   'Geografi': -3.4603636363636383,
#   'Sosiologi': -6.857067570111042,
#   'Sejarah': -3.8507823613086742},
#  'Antropologi - UNPAD (IPA)-Ilmu Keperawatan  - UNPAD  (IPA)': {'Matematika': 0.0,
#   'Inggris': -11.0,
#   'Indonesia': -9.0,
#   'Fisika': 3.141854636591475,
#   'Kimia': -0.061152882205504966,
#   'Biologi': -4.117293233082719,
#   'Ekonomi': -5.0,
#   'Geografi': 0.06307692307692037,
#   'Sosiologi': -1.2261111111111092,
#   'Sejarah': -4.0},
#  'Antropologi - UNPAD (IPA)-Ilmu Kesehatan Masyarakat - UI (IPA)': {'Matematika': -2.0,
#   'Inggris': -6.0,
#   'Indonesia': -6.0,
#   'Fisika': 0.14185463659147501,
#   'Kimia': 1.938847117794495,
#   'Biologi': 2.8827067669172806,
#   'Ekonomi': -4.062285714285721,
#   'Geografi': -2.476218181818183,
#   'Sosiologi': -4.314240542066628,
#   'Sejarah': -3.0},
#  'Antropologi - UNPAD (IPA)-Ilmu Komputer - IPB (IPA)': {'Matematika': -9.599999999999994,
#   'Inggris': -7.0,
#   'Indonesia': -6.0,
#   'Fisika': -5.858145363408525,
#   'Kimia': -2.061152882205505,
#   'Biologi': -0.11729323308271944,
#   'Ekonomi': -7.6899999999999835,
#   'Geografi': -0.14400000000000546,
#   'Sosiologi': nan,
#   'Sejarah': -3.0},
#  'Antropologi - UNPAD (IPA)-Ilmu Komunikasi - UB (IPS)': {'Matematika': 3.5537566137566188,
#   'Inggris': -6.9262857142857115,
#   'Indonesia': -4.595026455026456,
#   'Fisika': 0.8938546365914704,
#   'Kimia': 2.2681804511278187,
#   'Biologi': 0.6732864770622058,
#   'Ekonomi': -4.380555555555546,
#   'Geografi': -4.390109890109898,
#   'Sosiologi': -3.6055555555555543,
#   'Sejarah': -3.9967777777777798},
#  'Antropologi - UNPAD (IPA)-Ilmu Peternakan - UNPAD (IPA)': {'Matematika': 0.059259259259263786,
#   'Inggris': -6.525925925925932,
#   'Indonesia': -4.86666666666666,
#   'Fisika': 0.0,
#   'Kimia': 0.0,
#   'Biologi': 0.0,
#   'Ekonomi': -3.927343244990311,
#   'Geografi': 0.06307692307692037,
#   'Sosiologi': -1.2261111111111092,
#   'Sejarah': -2.7718954248366003},
#  'Antropologi - UNPAD (IPA)-Ilmu Politik - UB (IPS)': {'Matematika': 4.0,
#   'Inggris': -4.0,
#   'Indonesia': 1.0,
#   'Fisika': 0.8938546365914704,
#   'Kimia': 2.2681804511278187,
#   'Biologi': 0.6732864770622058,
#   'Ekonomi': 3.0,
#   'Geografi': 1.0,
#   'Sosiologi': -2.0,
#   'Sejarah': -3.0},
#  'Antropologi - UNPAD (IPA)-Ilmu Sejarah - UI (IPA)': {'Matematika': -2.143725198412696,
#   'Inggris': -6.889705010651113,
#   'Indonesia': -7.884126984126993,
#   'Fisika': 2.55832087155909,
#   'Kimia': -0.1820831147636568,
#   'Biologi': 0.025624314485995114,
#   'Ekonomi': -7.218571428571437,
#   'Geografi': -3.230181818181819,
#   'Sosiologi': -6.428533785055521,
#   'Sejarah': -3.4253911806543442},
#  'Antropologi - UNPAD (IPA)-Ilmu Teknologi Pangan - IPB (IPA)': {'Matematika': -3.0,
#   'Inggris': -12.0,
#   'Indonesia': -11.0,
#   'Fisika': -2.858145363408525,
#   'Kimia': -3.061152882205505,
#   'Biologi': -3.1172932330827194,
#   'Ekonomi': -4.150000000000006,
#   'Geografi': -2.9066666666666663,
#   'Sosiologi': nan,
#   'Sejarah': -3.705882352941188},
#  'Antropologi - UNPAD (IPA)-Kedokteran - UI (IPA)': {'Matematika': -3.799999999999997,
#   'Inggris': -13.799999999999997,
#   'Indonesia': -9.0,
#   'Fisika': -4.958145363408519,
#   'Kimia': -6.361152882205502,
#   'Biologi': -7.617293233082719,
#   'Ekonomi': -6.4371428571428595,
#   'Geografi': -3.4603636363636383,
#   'Sosiologi': -9.42853378505552,
#   'Sejarah': -3.8507823613086742},
#  'Antropologi - UNPAD (IPA)-Kedokteran  - UNAIR (IPA)': {'Matematika': -3.5733333333333377,
#   'Inggris': -7.9466666666666725,
#   'Indonesia': -7.200000000000003,
#   'Fisika': -1.1954180906812581,
#   'Kimia': 0.543392572339954,
#   'Biologi': -1.497596263385745,
#   'Ekonomi': -6.047619047619051,
#   'Geografi': -3.8666666666666742,
#   'Sosiologi': -5.366666666666674,
#   'Sejarah': -5.560000000000002},
#  'Antropologi - UNPAD (IPA)-Kedokteran Gigi - UI (IPA)': {'Matematika': -3.3999999999999915,
#   'Inggris': -5.666666666666671,
#   'Indonesia': -6.3999999999999915,
#   'Fisika': 0.4751879699248036,
#   'Kimia': 1.2721804511278236,
#   'Biologi': 0.8827067669172806,
#   'Ekonomi': -6.4371428571428595,
#   'Geografi': -3.4603636363636383,
#   'Sosiologi': -6.857067570111042,
#   'Sejarah': -2.900521574205783},
#  'Antropologi - UNPAD (IPA)-Kedokteran Hewan - IPB (IPA)': {'Matematika': -2.2969892473118136,
#   'Inggris': -7.066666666666663,
#   'Indonesia': -6.588965517241377,
#   'Fisika': -1.0857315703050858,
#   'Kimia': -0.24115288220549758,
#   'Biologi': -1.5239598997493857,
#   'Ekonomi': -4.150000000000006,
#   'Geografi': -2.9066666666666663,
#   'Sosiologi': nan,
#   'Sejarah': -3.705882352941188},
#  'Antropologi - UNPAD (IPA)-Kesehatan Masyarakat - UNAIR (IPA)': {'Matematika': -2.0,
#   'Inggris': -6.333333333333329,
#   'Indonesia': -7.666666666666671,
#   'Fisika': 0.8085213032581464,
#   'Kimia': 0.6055137844611664,
#   'Biologi': -1.7839598997493908,
#   'Ekonomi': -4.088888888888889,
#   'Geografi': -3.8666666666666742,
#   'Sosiologi': -5.366666666666674,
#   'Sejarah': -4.186666666666667},
#  'Antropologi - UNPAD (IPA)-Kimia - IPB (IPA)': {'Matematika': -2.2989964157706027,
#   'Inggris': -4.355555555555554,
#   'Indonesia': -3.8629885057471256,
#   'Fisika': -0.6006740990407025,
#   'Kimia': -1.1211528822055072,
#   'Biologi': 0.41381787802839654,
#   'Ekonomi': -3.2800000000000153,
#   'Geografi': -3.3191111111110985,
#   'Sosiologi': nan,
#   'Sejarah': -3.1372549019607874},
#  'Antropologi - UNPAD (IPA)-Kriminologi - UI (IPS)': {'Matematika': 0.0,
#   'Inggris': -5.355882004260451,
#   'Indonesia': -8.0,
#   'Fisika': 4.141854636591475,
#   'Kimia': -0.1820831147636568,
#   'Biologi': 0.025624314485995114,
#   'Ekonomi': -8.0,
#   'Geografi': -4.0,
#   'Sosiologi': -5.0,
#   'Sejarah': -4.0},
#  'Antropologi - UNPAD (IPA)-Manajemen - IPB (IPS)': {'Matematika': -4.0,
#   'Inggris': -2.0,
#   'Indonesia': -1.0,
#   'Fisika': -1.858145363408525,
#   'Kimia': 2.938847117794495,
#   'Biologi': -2.1172932330827194,
#   'Ekonomi': -4.150000000000006,
#   'Geografi': -4.0,
#   'Sosiologi': nan,
#   'Sejarah': -4.0},
#  'Antropologi - UNPAD (IPA)-Manajemen Dan Kebijakan Publik (An) - UGM (IPS)': {'Matematika': -7.0,
#   'Inggris': -6.0,
#   'Indonesia': -9.0,
#   'Fisika': -2.861413337264736,
#   'Kimia': -1.6337019018133532,
#   'Biologi': -1.9408226448474153,
#   'Ekonomi': -8.670857142857159,
#   'Geografi': -6.0,
#   'Sosiologi': -10.0,
#   'Sejarah': -11.0},
#  'Antropologi - UNPAD (IPA)-Manajemen Sd Perairan - UNDIP (IPS)': {'Matematika': 8.0,
#   'Inggris': -4.0,
#   'Indonesia': -5.0,
#   'Fisika': 11.74185463659147,
#   'Kimia': 12.53884711779449,
#   'Biologi': 2.8827067669172806,
#   'Ekonomi': -5.0,
#   'Geografi': -5.299999999999997,
#   'Sosiologi': -7.0,
#   'Sejarah': -4.914285714285711},
#  'Antropologi - UNPAD (IPA)-Matematika - IPB (IPA)': {'Matematika': -2.2969892473118136,
#   'Inggris': -7.066666666666663,
#   'Indonesia': -6.588965517241377,
#   'Fisika': -1.0857315703050858,
#   'Kimia': -0.24115288220549758,
#   'Biologi': -1.5239598997493857,
#   'Ekonomi': -4.150000000000006,
#   'Geografi': -2.9066666666666663,
#   'Sosiologi': nan,
#   'Sejarah': -3.705882352941188},
#  'Antropologi - UNPAD (IPA)-Matematika  - UI (IPA)': {'Matematika': -9.200000000000003,
#   'Inggris': -6.0,
#   'Indonesia': -8.0,
#   'Fisika': -10.058145363408528,
#   'Kimia': -3.061152882205505,
#   'Biologi': -2.1172932330827194,
#   'Ekonomi': -6.0,
#   'Geografi': -3.4603636363636383,
#   'Sosiologi': -6.857067570111042,
#   'Sejarah': -3.0},
#  'Antropologi - UNPAD (IPA)-Matematika (Fak. Matematika & Ilmu Pengetahuan Alam) - ITB (IPA)': {'Matematika': -6.0,
#   'Inggris': -8.0,
#   'Indonesia': -2.0,
#   'Fisika': -5.458145363408519,
#   'Kimia': -2.061152882205505,
#   'Biologi': -0.11729323308271944,
#   'Ekonomi': -3.3124675324675366,
#   'Geografi': -0.14000000000001478,
#   'Sosiologi': nan,
#   'Sejarah': -7.0},
#  'Antropologi - UNPAD (IPA)-Meteorologi Terapan - IPB (IPA)': {'Matematika': -2.2969892473118136,
#   'Inggris': -7.066666666666663,
#   'Indonesia': -6.588965517241377,
#   'Fisika': -1.0857315703050858,
#   'Kimia': -0.24115288220549758,
#   'Biologi': -1.5239598997493857,
#   'Ekonomi': -4.150000000000006,
#   'Geografi': -2.9066666666666663,
#   'Sosiologi': nan,
#   'Sejarah': -3.705882352941188},
#  'Antropologi - UNPAD (IPA)-Mipa Kimia - UB (IPA)': {'Matematika': -5.0,
#   'Inggris': -4.0,
#   'Indonesia': -2.0,
#   'Fisika': -3.858145363408525,
#   'Kimia': -6.661152882205499,
#   'Biologi': 5.882706766917281,
#   'Ekonomi': -4.141666666666666,
#   'Geografi': -2.8086080586080584,
#   'Sosiologi': -4.816666666666663,
#   'Sejarah': -3.990333333333325},
#  'Antropologi - UNPAD (IPA)-Nutrisi & Teknologi Pakan - IPB (IPA)': {'Matematika': -9.0,
#   'Inggris': -12.0,
#   'Indonesia': -10.0,
#   'Fisika': -8.858145363408525,
#   'Kimia': -2.061152882205505,
#   'Biologi': -1.1172932330827194,
#   'Ekonomi': -4.150000000000006,
#   'Geografi': -2.9066666666666663,
#   'Sosiologi': nan,
#   'Sejarah': -3.705882352941188},
#  'Antropologi - UNPAD (IPA)-Oceanografi - UNDIP (IPA)': {'Matematika': -2.11666666666666,
#   'Inggris': -6.36666666666666,
#   'Indonesia': -7.633333333333326,
#   'Fisika': -0.4781453634085153,
#   'Kimia': -0.2556983367509673,
#   'Biologi': -1.210020505809993,
#   'Ekonomi': -7.191428571428588,
#   'Geografi': -5.299999999999997,
#   'Sosiologi': -7.0,
#   'Sejarah': -6.857142857142861},
#  ...}
