# %%
import pandas as pd
import math
import numpy as np

# %% [markdown]
# # Open File
#
# Membuka file dataset dengan ekstensi **csv**. Setelah itu merename nama-nama header. Baru kemudian men-drop column-column yang tidak akan digunakan.

# %%
def open_file(file):
    #read dataset
    raw_data = pd.read_csv(file, header=6)

    #ganti nama header
    raw_data.columns = [
                        "Nama Panggilan", 
                        "Asal Sekolah", 
                        "Jurusan Sekolah", 
                        "Jenis Sekolah",
                        "Jenis Kelas", 
                        "Akreditasi Sekolah", 
                        "Prestasi Sekolah", 
                        "Alumni Sekolah", 
                        "PTN Pilihan I", 
                        "Jurusan Pilihan I di PTN Pilihan I" ,
                        "Jurusan Pilihan II di PTN Pilihan I", 
                        "PTN Pilihan II", 
                        "Jurusan Pilihan I di PTN Pilihan II" ,
                        "Jurusan Pilihan II di PTN Pilihan II", 
                        "Jurusan Diterima", "PTN Diterima", 
                        "Matematika Semester 1", 
                        "Matematika Semester 2", 
                        "Matematika Semester 3", 
                        "Matematika Semester 4", 
                        "Matematika Semester 5", 
                        "Inggris Semester 1", 
                        "Inggris Semester 2", 
                        "Inggris Semester 3", 
                        "Inggris Semester 4", 
                        "Inggris Semester 5",
                        "Indonesia Semester 1",
                        "Indonesia Semester 2",
                        "Indonesia Semester 3",
                        "Indonesia Semester 4",
                        "Indonesia Semester 5",
                        "Fisika Semester 1",
                        "Fisika Semester 2",
                        "Fisika Semester 3",
                        "Fisika Semester 4",
                        "Fisika Semester 5",
                        "Kimia Semester 1",
                        "Kimia Semester 2",
                        "Kimia Semester 3",
                        "Kimia Semester 4",
                        "Kimia Semester 5",
                        "Biologi Semester 1",
                        "Biologi Semester 2",
                        "Biologi Semester 3",
                        "Biologi Semester 4",
                        "Biologi Semester 5",
                        "Ekonomi Semester 1",
                        "Ekonomi Semester 2",
                        "Ekonomi Semester 3",
                        "Ekonomi Semester 4",
                        "Ekonomi Semester 5",
                        "Geografi Semester 1",
                        "Geografi Semester 2",
                        "Geografi Semester 3",
                        "Geografi Semester 4",
                        "Geografi Semester 5",
                        "Sosiologi Semester 1",
                        "Sosiologi Semester 2",
                        "Sosiologi Semester 3",
                        "Sosiologi Semester 4",
                        "Sosiologi Semester 5",
                        "Sejarah Semester 1",
                        "Sejarah Semester 2",
                        "Sejarah Semester 3",
                        "Sejarah Semester 4",
                        "Sejarah Semester 5",
                        "Komputer Semester 1",
                        "Komputer Semester 2",
                        "Komputer Semester 3",
                        "Komputer Semester 4",
                        "Komputer Semester 5",
                        "Peringkat Kelas Semester 1",
                        "Peringkat Kelas Semester 2",
                        "Peringkat Kelas Semester 3",
                        "Peringkat Kelas Semester 4",
                        "Peringkat Kelas Semester 5",
                        "Nilai UN", 
                        "Saran",
                        "Prestasi Lain"
                    ]
    
    #drop column yang tidak digunakan
    data = raw_data.drop([
                "Jenis Kelas",
                "Akreditasi Sekolah", 
                "Prestasi Sekolah", 
                "Alumni Sekolah", 
                "Komputer Semester 1",
                "Komputer Semester 2",
                "Komputer Semester 3",
                "Komputer Semester 4",
                "Komputer Semester 5",
                "Peringkat Kelas Semester 1",
                "Peringkat Kelas Semester 2",
                "Peringkat Kelas Semester 3",
                "Peringkat Kelas Semester 4",
                "Peringkat Kelas Semester 5",
                "Nilai UN", 
                "Saran",
                "Prestasi Lain"
        ],axis=1)
    
    return data

# %% [markdown]
# # Cleaning Nilai
#
# Proses cleaning nilai terdiri dari beberapa langkah:
#
# 1. Mengambil nilai tengah dari tiap mata pelajaran
# 2. Mengganti setiap NaN/null data dengan mean per mata pelajaran

# %%
def cleaning_nilai(data):

    #Mengambil nilai tengah dari tiap nilai
    data = data.replace("<70", 34.5)
    data = data.replace("71 - 75", 73)
    data = data.replace("76 - 80", 78)
    data = data.replace("81 - 85", 83)
    data = data.replace("86 - 90", 88)
    data = data.replace("91 - 95", 93)
    data = data.replace("> 95", 98)
    data = data.replace("No data", np.NaN)

    return data

# %%
def replace_zero_w_mean(data, mata_pelajaran):
    
    #mencari rata-rata dari per mata pelajaran
    rata2 = (data[f"{mata_pelajaran} Semester 1"].mean() 
            + data[f"{mata_pelajaran} Semester 2"].mean() 
            + data[f"{mata_pelajaran} Semester 3"].mean()
            + data[f"{mata_pelajaran} Semester 4"].mean()
            + data[f"{mata_pelajaran} Semester 5"].mean())/5
    
    #mengganti NaN value dengan nilai rata-rata
    values = {
        f"{mata_pelajaran} Semester 1": rata2,
        f"{mata_pelajaran} Semester 2": rata2,
        f"{mata_pelajaran} Semester 3": rata2,
        f"{mata_pelajaran} Semester 4": rata2,
        f"{mata_pelajaran} Semester 5": rata2,
    }
    data = data.fillna(value=values)
                    
    return data

# %% [markdown]
# # Menghitung Rata-Rata Per 5 Semester
#
# Dari nilai-nilai yang telah di-clean kemudian akan dicari rata-rata tiap mata pelajarannya per semester

# %%
def rata2_mp_semester(data, mata_pelajaran):
    data_rata2 = {}
    
    #drop column tiap mata pelajaran untuk digantikan dengan rata-rata semester
    mapel = []
    for i in range(1,6):
        mapel.append(f"{mata_pelajaran} Semester {i}")

    data_drop = data.drop(mapel, axis=1)
    
    
    for column in data_drop:
        isi = []
        for i in range(len(data)):
            isi.append(data[column][i])
        data_rata2[column] = isi

    #menghitung rata-rata nilai 5 semester
    mean = []
    for i in range(len(data)):
        jumlah_nilai = 0
        jumlah_nilai += data[f"{mata_pelajaran} Semester 1"][i] + data[f"{mata_pelajaran} Semester 2"][i] + data[f"{mata_pelajaran} Semester 3"][i] + data[f"{mata_pelajaran} Semester 4"][i] + data[f"{mata_pelajaran} Semester 5"][i]
        mean.append(jumlah_nilai/5)

    #memasukkan column rata-rata 5 semester tiap mata pelajaran ke dataframe
    data_rata2[f"Rata-rata {mata_pelajaran}"] = mean

    data_rata2_frame = pd.DataFrame(data=data_rata2)
    
    return data_rata2_frame

# %% [markdown]
# # Menghapus NaN
#
# Proses ini akan menghapus tiap rows yang memiliki NaN value yang ada pada column Jurusan Diterima

# %%
def remove_nan(data):
    drop_index = []

    #menghapus NaN value
    for i in range(len(data)):
        try:
            float(data["Jurusan Diterima"][i])
        except ValueError:
            pass
        else:
            if math.isnan(float(data["Jurusan Diterima"][i])) or int(data["Jurusan Diterima"][i]) == 0:
                drop_index.append(i)

    data = data.drop(drop_index)
        
    return data

# %%
def clean_jurusan_ptn(data):
    for i in range(len(data)):
        for column in data:
            if column == "Jurusan Diterima"  or column == "Jurusan Pilihan I di PTN Pilihan I" or column == "Jurusan Pilihan II di PTN Pilihan I" or column == "Jurusan Pilihan I di PTN Pilihan II" or column == "Jurusan Pilihan II di PTN Pilihan II":
                if isinstance(data[column][i], float):
                    pass
                else:
                    data[column][i] = data[column][i].title()
            elif column == "PTN Diterima" or column == "PTN Pilihan I" or column == "PTN Pilihan II":
                if isinstance(data[column][i], float):
                    pass
                else:
                    data[column][i] = data[column][i].upper()
    
    return data

# %%
def clean(files):
    cleanned_data = []
    
    for file in files:
        data = open_file(file)

        data = cleaning_nilai(data)

        matpel = ["Matematika", "Inggris", "Indonesia", "Fisika", "Kimia", "Biologi", "Ekonomi", "Geografi", "Sosiologi","Sejarah"]

        for item in matpel:
            data = replace_zero_w_mean(data, item)
            data = rata2_mp_semester(data, item)
                    
        data = remove_nan(data)
        
        cleanned_data.append(data)
        
        data_merge = pd.concat(cleanned_data, ignore_index=True)
        
        result = clean_jurusan_ptn(data_merge)
        
    #Split data test - data train
    test = result.sample(frac=0.2, replace=True)
    test.to_csv("Splitted Test.csv", encoding="utf-8")
    
#     rest_of_data = result.drop(test.index).reset_index()
    
    train = result.drop([
            "Nama Panggilan", 
            "Asal Sekolah", 
            "PTN Pilihan I", 
            "Jurusan Pilihan I di PTN Pilihan I" ,
            "Jurusan Pilihan II di PTN Pilihan I", 
            "PTN Pilihan II", 
            "Jurusan Pilihan I di PTN Pilihan II" ,
            "Jurusan Pilihan II di PTN Pilihan II", 
        ],axis=1)
    
    train.to_csv("Splitted Train.csv", encoding="utf-8")
    
#     train = train_w_index.drop(["index"],axis=1)

    return train

# %%
def sort_data(data):
    data_sort = data.sort_values(by=['Jurusan Diterima', 'PTN Diterima'])
    
    data_sort.reset_index(inplace = True)

    data_sort = data_sort.drop(["index"], axis=1)

    return data_sort

# %%
def get_jurusan_ptn(data):
    temp_jurusan = ""
    temp_ptn = ""
    list_jurusan_ptn = []
    for i in range(len(data)):
        if data["Jurusan Diterima"][i] != temp_jurusan and data["PTN Diterima"][i] != temp_ptn:
            temp_jurusan = data["Jurusan Diterima"][i]
            temp_ptn = data["PTN Diterima"][i]
            list_jurusan_ptn.append((temp_jurusan, temp_ptn))
        else:
            pass

    return list_jurusan_ptn

# %%
def get_tabel_alternatif(data, list_jurusan_ptn):
    frame = {}
    for j in range(len(list_jurusan_ptn)):
        list_nilai = []
        for column in data:
            jum = 0
            byk = 0
            for i in range(len(data)):
                if data["Jurusan Diterima"][i] == list_jurusan_ptn[j][0] and data["PTN Diterima"][i] == list_jurusan_ptn[j][1]:
    #                 print(data_sort["Jurusan Diterima"][i], data_sort["PTN Diterima"][i])
                    temp_jurusan = data["Jurusan Diterima"][i]
                    temp_ptn = data["PTN Diterima"][i]
                    try:
                        float(data[column][i])
                    except ValueError:
                        break
                    else:
                        jum += data[column][i]
                        byk += 1
                else:
                    pass
            try:
    #             print(column, jum/byk)
                list_nilai.append(jum/byk)
            except ZeroDivisionError:
                continue
        nama_alternatif = f"{temp_jurusan} - {temp_ptn}"
        if "administrasi" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "sosial" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "ekonomi" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "hi" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "hukum" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "komunikasi" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "politik" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "sosiologi" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "fsrd" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "sbm" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "akuntansi" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "manajemen" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "psdk" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "fiskal" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif ("hubungan" in temp_jurusan.casefold().split() and "internasional" in temp_jurusan.casefold().split()):
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "kriminologi" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "psikologi" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "bisnis" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "filsafat" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "jurnalistik" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "humas" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "desain" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "film" in temp_jurusan.casefold().split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif ("hubungan" in temp_jurusan.casefold().split() and "masyarakat" in temp_jurusan.casefold().split()):
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPS)"
        elif "sastra" in temp_jurusan.casefold().split():
            continue
        elif "bahasa" in temp_jurusan.casefold().split():
            continue
        elif "perpustakaan" in temp_jurusan.casefold().split():
            continue
        elif "ugm" in temp_jurusan.casefold().split():
            continue
        
        if "(IPS)" not in nama_alternatif.split():
            nama_alternatif = f"{temp_jurusan} - {temp_ptn} (IPA)"
            
        frame[nama_alternatif] = list_nilai

    tabel = pd.DataFrame(frame, index=["Matematika", "Inggris", "Indonesia", "Fisika", "Kimia", "Biologi", "Ekonomi", "Geografi", "Sosiologi", "Sejarah"])

    return tabel

# %%
datasets = ["Data SNMPTN 2016 IPB by @halokampus.csv",
            "Data SNMPTN 2016 ITB by @halokampus.csv",
            "Data SNMPTN 2016 ITS by @halokampus.csv",
            "Data SNMPTN 2016 UB by @halokampus.csv",
            "Data SNMPTN 2016 UGM by @halokampus.csv",
            "Data SNMPTN 2016 UI by @halokampus.csv",
            "Data SNMPTN 2016 Unair by @halokampus.csv",
            "Data SNMPTN 2016 Undip by @halokampus.csv",
            "Data SNMPTN 2016 Unpad by @halokampus.csv",
            "Data SNMPTN 2017 IPB by @halokampus.csv",
            "Data SNMPTN 2017 ITB by @halokampus.csv",
            "Data SNMPTN 2017 ITS by @halokampus.csv",
            "Data SNMPTN 2017 UGM by @halokampus.csv",
            "Data SNMPTN 2017 UI by @halokampus.csv",
            "Data SNMPTN 2017 Unair by @halokampus.csv",
            "Data SNMPTN 2017 Unpad by @halokampus.csv",]

# %%
result = clean(datasets)

result
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#     Jurusan Sekolah Jenis Sekolah                        Jurusan Diterima  \
# 0               IPA           SMA                                   Kimia
# 1               IPA           SMA                        Kedokteran Hewan
# 2               IPA           SMA             Nutrisi Dan Teknologi Pakan
# 3               IPA           SMA              Teknik Mesin Dan Biosistem
# 4               IPA           SMA              Ilmu Keluarga Dan Konsumen
# 5               IPA           SMA                                   Kimia
# 6               IPA           SMA                                 Biologi
# 7               IPA           SMA               Nutrisi & Teknologi Pakan
# 8               IPA           SMA            Teknologi Industri Pertanian
# 9               IPA           SMA  Komunikasi Dan Pengembangan Masyarakat
# 10              IPA           SMA                           Ilmu Komputer
# 11              IPA           SMA                               Ilmu Gizi
# 12              IPA           SMA                               Ilmu Gizi
# 13              IPA           SMA              Ilmu Keluarga Dan Konsumen
# 14              IPA           SMA            Teknologi Industri Pertanian
# 15              IPA           SMA           Ekonomi Dan Studi Pembangunan
# 16              IPA           SMA                                 Biologi
# 17              IPA           SMA                     Meteorologi Terapan
# 18              IPA           SMA                               Manajemen
# 19              IPA           SMA               Teknologi Produksi Ternak
# 20              IPA           SMA                              Matematika
# 21              IPA           SMA                                  Fisika
# 22              IPA           SMA       Ekonomi Sumberdaya Dan Lingkungan
# 23              IPA           SMA                   Ilmu Teknologi Pangan
# 24              IPA           SMA                               Perikanan
# 25              IPA           SMA                                   Kimia
# 26              IPA           SMA               Teknologi Produksi Ternak
# 27              IPA           SMA               Agronomi Dan Hortikultura
# 28              IPA           SMA           Ekonomi Dan Studi Pembangunan
# 29              IPA           SMA              Ilmu Keluarga Dan Konsumen
# ..              ...           ...                                     ...
# 870             IPS           SMA                                  Humas
# 871             IPS           SMA                  Hubungan Internasional
# 872             IPA           SMA                          Teknik Geologi
# 873             IPA           SMA                          Teknik Geologi
# 874             IPS           SMA                  Hubungan Internasional
# 875             IPA           SMA                                   Kimia
# 876             IPS           SMA                    Manajemen Komunikasi
# 877             IPS           SMA                     Hubungan Masyarakat
# 878             IPA           SMA                                 Farmasi
# 879             IPS           SMA                     Hubungan Masyarakat
# 880             IPS           SMA                              Ilmu Hukum
# 881             IPS           SMA                Ilmu Administrasi Negara
# 882             IPS           SMA        Ilmu Informasi Dan Perpustakaan
# 883             IPS           SMA                                   Humas
# 884             IPA           SMA                              Agribisnis
# 885             IPA           SMA                              Kedokteran
# 886             IPS           SMA             Ilmu Hubungan Internasional
# 887             IPS           SMA                 Ilmu Hub. Internasional
# 888             IPA           SMA                              Peternakan
# 889             IPS           SMA                Ilmu Administrasi Bisnis
# 890             IPA           SMA                               Perikanan
# 891             IPS           SMA                             Jurnalistik
# 892             IPA           SMA                               Geofisika
# 893             IPS           SMA                            Tv Dan Film
# 894             IPA           SMA                             Matematika
# 895             IPA           SMA                                  Kimia
# 896             IPS           SMA                           Ekonomi Islam
# 897             IPA           SMA                      Teknik Informatika
# 898             IPA           SMA                                 Kimia,
# 899             IPS           SMA                              Komunikasi
#
#     PTN Diterima  Rata-rata Matematika  Rata-rata Inggris  \
# 0            IPB             85.321398          85.050000
# 1            IPB             85.321398          85.050000
# 2            IPB             85.321398          85.050000
# 3            IPB             85.321398          85.050000
# 4            IPB             87.392839          85.050000
# 5            IPB             88.000000          83.000000
# 6            IPB             85.321398          85.050000
# 7            IPB             93.000000          91.000000
# 8            IPB             83.000000          83.000000
# 9            IPB             82.000000          83.000000
# 10           IPB             94.000000          86.000000
# 11           IPB             85.321398          85.050000
# 12           IPB             81.000000          93.000000
# 13           IPB             85.321398          85.050000
# 14           IPB             85.321398          85.050000
# 15           IPB             86.000000          87.000000
# 16           IPB             85.000000          85.000000
# 17           IPB             85.321398          85.050000
# 18           IPB             88.000000          81.000000
# 892          83.000000          83.968929           84.283138
# 893          83.879942          83.000000           85.000000
# 894          85.000000          83.968929           84.283138
# 895          86.000000          83.968929           84.283138
# 896          83.879942          83.968929           84.283138
# 897          89.000000          92.000000           85.769883
# 898          83.879942          83.968929           84.283138
# 899          78.000000          83.000000           83.000000
#
#      Rata-rata Sosiologi  Rata-rata Sejarah
# 0                    NaN          82.676471
# 1                    NaN          82.676471
# 2                    NaN          82.676471
# 3                    NaN          82.676471
# 4                    NaN          82.676471
# 5                    NaN          82.676471
# 6                    NaN          82.676471
# 7                    NaN          82.676471
# 8                    NaN          87.000000
# 9                    NaN          82.676471
# 10                   NaN          84.000000
# 11                   NaN          82.676471
# 12                   NaN          82.676471
# 13                   NaN          82.676471
# 14                   NaN          82.676471
# 15                   NaN          80.000000
# 16                   NaN          82.676471
# 17                   NaN          82.676471
# 18                   NaN          85.000000
# 19                   NaN          34.500000
# 20                   NaN          82.676471
# 21                   NaN          82.676471
# 22                   NaN          82.676471
# 23                   NaN          82.676471
# 24                   NaN          82.676471
# 25                   NaN          83.000000
# 26                   NaN          81.000000
# 27                   NaN          82.676471
# 28                   NaN          82.676471
# 29                   NaN          82.676471
# ..                   ...                ...
# 870            73.000000          73.000000
# 871            92.000000          90.000000
# 872            85.103470          84.169997
# 873            83.682776          82.935997
# 874            85.103470          84.169997
# 875            85.103470          84.169997
# 876            34.500000          34.500000
# 877            85.103470          84.169997
# 878            85.103470          84.169997
# 879            93.000000          93.000000
# 880            86.000000          88.000000
# 881            88.000000          87.000000
# 882            83.000000          84.169997
# 883            86.000000          82.000000
# 884            85.103470          84.169997
# 885            85.103470          87.000000
# 886            84.000000          86.000000
# 887            87.000000          84.000000
# 888            85.103470          84.169997
# 889            83.000000          81.000000
# 890            85.103470          84.169997
# 891            85.103470          84.169997
# 892            85.103470          84.169997
# 893            87.000000          83.000000
# 894            85.103470          84.169997
# 895            85.103470          83.000000
# 896            85.103470          84.169997
# 897            85.103470          91.000000
# 898            85.103470          84.169997
# 899            88.000000          93.000000
#
# [900 rows x 14 columns]

# %%
data_sort = sort_data(result)

data_sort
# Out:
#     Jurusan Sekolah Jenis Sekolah                            Jurusan Diterima  \
# 0               IPA           SMA                         Administrasi Fiskal
# 1               IPS           SMA                         Administrasi Negara
# 2               IPS           SMA                         Administrasi Negara
# 3               IPS           SMA                         Administrasi Negara
# 4               IPS           SMA                          Administrasi Niaga
# 5               IPS           SMA                     Administrasi Perpajakan
# 6               IPA           SMA                                  Agribisnis
# 7               IPA           SMA                                  Agribisnis
# 8               IPA           SMA                                  Agribisnis
# 9               IPA           SMA                                  Agribisnis
# 10              IPA           SMA                                  Agribisnis
# 11              IPA           SMA                            Agroekoteknologi
# 12              IPA           SMA                            Agroekoteknologi
# 13              IPA           SMA                            Agroekoteknologi
# 14              IPA           SMA                            Agroekoteknologi
# 15              IPA           SMA                   Agronomi Dan Holtikultura
# 16              IPA           SMA                   Agronomi Dan Hortikultura
# 17              IPA           SMA                   Agronomi Dan Hortikultura
# 18              IPA           SMA                               Agroteknologi
# 19              IPA           SMA                               Agroteknologi
# 20              IPA           SMA                               Agroteknologi
# 21              IPA           SMA                               Agroteknologi
# 22              IPS           SMA                                   Akuntansi
# 23              IPA           SMA                                   Akuntansi
# 24              IPS           SMA                                   Akuntansi
# 25              IPS           SMA                                   Akuntansi
# 26              IPA           SMA                                   Akuntansi
# 27              IPA           SMA                                   Akuntansi
# 28              IPS           SMA                                   Akuntansi
# 29              IPA           SMA                                   Akuntansi
# ..              ...           ...                                         ...
# 870             IPA           SMA  Teknologi Dan Manajemen Perikanan Budidaya
# 871             IPA           SMA  Teknologi Dan Manajemen Perikanan Budidaya
# 872             IPA           SMA                   Teknologi Hasil Perikanan
# 873             IPA           SMA                   Teknologi Hasil Perikanan
# 874             IPA           SMA          Teknologi Industri Hasil Perikanan
# 875             IPA           SMA                Teknologi Industri Pertanian
# 876             IPA           SMA                Teknologi Industri Pertanian
# 877             IPA           SMA                Teknologi Industri Pertanian
# 878             IPA           SMA                Teknologi Industri Pertanian
# 879             IPA           SMA                Teknologi Industri Pertanian
# 880             IPA           SMA                Teknologi Industri Pertanian
# 881             IPA           SMA                Teknologi Industri Pertanian
# 882             IPA           SMA                Teknologi Industri Pertanian
# 883             IPA           SMA                         Teknologi Informasi
# 884             IPA           SMA                            Teknologi Pangan
# 885             IPA           SMA                            Teknologi Pangan
# 886             IPA           SMA                            Teknologi Pangan
# 887             IPA           SMA                            Teknologi Pangan
# 888             IPA           SMA                   Teknologi Produksi Ternak
# 889             IPA           SMA                   Teknologi Produksi Ternak
# 890             IPA           SMA                   Teknologi Produksi Ternak
# 891             IPS           SMA                             Televisi & Film
# 892             IPS           SMA                             Televisi & Film
# 893             IPA           SMA                                         Tin
# 894             IPA           SMA                                         Tip
# 895             IPA           SMA                                        Tphp
# 896             IPS           SMA                                   Tv & Film
# 897             IPS           SMA                              Tv & Perfilman
# 898             IPS           SMA                                Tv Dan Film
# 899             IPA           SMA                                         Ugm
#
#     PTN Diterima  Rata-rata Matematika  Rata-rata Inggris  \
# 0             UI             84.000000          84.000000
# 1             UI             88.000000          86.000000
# 2          UNPAD             87.000000          83.000000
# 3          UNPAD             90.000000          78.000000
# 4             UI             85.465625          83.888667
# 5             UB             92.000000          86.000000
# 6            IPB             95.000000          90.000000
# 7             UB             82.000000          86.000000
# 8             UB             82.000000          83.000000
# 9          UNDIP             86.250000          85.500000
# 10         UNPAD             86.000000          85.000000
# 11            UB             82.408571          83.918889
# 12            UB             80.000000          82.000000
# 13            UB             81.000000          88.000000
# 14            UB             84.000000          85.000000
# 15           IPB             91.000000          91.000000
# 16           IPB             85.321398          85.050000
# 17           IPB             71.300000          84.000000
# 18         UNPAD             88.000000          88.000000
# 19         UNPAD             84.000000          87.000000
# 20         UNPAD             82.000000          80.000000
# 21         UNPAD             76.000000          76.000000
# 22           UGM             93.000000          93.000000
# 23           UGM             92.000000          93.000000
# 24           UGM             89.000000          91.000000
# 25           UGM             90.000000          93.000000
# 0              86.930877          83.943883
# 1              89.000000          87.482442
# 2              84.000000          88.000000
# 3              87.000000          88.000000
# 4              86.930877          83.943883
# 5              91.000000          93.000000
# 6                    NaN          89.000000
# 7              84.850000          85.071667
# 8              84.110000          83.000000
# 9              87.000000          88.190476
# 10             85.103470          84.169997
# 11             84.850000          85.071667
# 12             84.850000          85.000000
# 13             83.110000          89.000000
# 14             90.000000          83.000000
# 15                   NaN          82.676471
# 16                   NaN          82.676471
# 17                   NaN          85.916667
# 18             77.450278          81.832680
# 19             77.670167          80.000000
# 20             85.103470          84.169997
# 21             85.103470          78.000000
# 22             94.000000          95.000000
# 23             91.888889          92.000000
# 24             92.000000          92.000000
# 25             88.000000          88.000000
# 26             90.363636          89.000000
# 27             90.363636          88.650538
# 28             98.000000          93.000000
# 29             90.363636          87.000000
# ..                   ...                ...
# 870                  NaN          86.000000
# 871                  NaN          85.916667
# 872            84.850000          83.000000
# 873            91.888889          87.812500
# 874            85.695971          84.000000
# 875                  NaN          87.000000
# 876                  NaN          82.676471
# 877                  NaN          82.676471
# 878                  NaN          88.000000
# 879            91.888889          87.812500
# 880            91.888889          87.812500
# 881            90.363636          83.000000
# 882            77.450278          81.832680
# 883            90.363636          91.000000
# 884                  NaN          85.916667
# 885            84.850000          85.071667
# 886            87.000000          88.190476
# 887            77.450278          81.832680
# 888                  NaN          34.500000
# 889                  NaN          81.000000
# 890                  NaN          86.000000
# 891            84.000000          85.000000
# 892            87.000000          88.000000
# 893                  NaN          88.000000
# 894            90.363636          88.650538
# 895            90.363636          88.650538
# 896            85.000000          85.000000
# 897            90.000000          88.467999
# 898            87.000000          83.000000
# 899            90.363636          88.650538
#
# [900 rows x 14 columns]

# %%
list_jurusan_ptn = get_jurusan_ptn(data_sort)

list_jurusan_ptn
# Out:
# [('Administrasi Fiskal', 'UI'),
#  ('Administrasi Negara', 'UNPAD'),
#  ('Administrasi Niaga', 'UI'),
#  ('Administrasi Perpajakan', 'UB'),
#  ('Agribisnis', 'IPB'),
#  ('Agroekoteknologi', 'UB'),
#  ('Agronomi Dan Holtikultura', 'IPB'),
#  ('Agroteknologi', 'UNPAD'),
#  ('Akuntansi', 'UGM'),
#  ('Akutansi', 'UI'),
#  ('Antropologi', 'UNAIR'),
#  ('Antropologi Sosial', 'UB'),
#  ('Apoteker', 'UNAIR'),
#  ('Arkeologi', 'UI'),
#  ('Arsitektur', 'ITB'),
#  ('Arsitektur Lansekap', 'IPB'),
#  ('Astronomi', 'ITB'),
#  ('Bahasa Dan Kebudayaan Korea', 'UI'),
#  ('Bahasa Korea', 'UGM'),
#  ('Biokimia', 'IPB'),
#  ('Biologi', 'ITS'),
#  ('Budidaya Perairan', 'UNAIR'),
#  ('Desain Interior', 'ITS'),
#  ('Ekonomi Dan Studi Pembangunan', 'IPB'),
#  ('Ekonomi Islam', 'UB'),
#  ('Ekonomi Islam ', 'UNPAD'),
#  ('Ekonomi Pembangunan', 'IPB'),
#  ('Elektro', 'ITB'),
#  ('Fakultas Kedokteran Gigi', 'UNAIR'),
#  ('Fakultas Kedokteran Hewan', 'IPB'),
#  ('Fakultas Teknik Industri', 'ITB'),
#  ('Farmasi', 'UI'),
#  ('Fisika', 'IPB'),
#  ('Fiskal', 'UI'),
#  ('Fitb', 'ITB'),
#  ('Fkg', 'UGM'),
#  ('Fmipa', 'ITB'),
#  ('Fmipa Fisika', 'UB'),
#  ('Fmipa- Ilmu Kimia', 'UNPAD'),
#  ('Fsrd', 'ITB'),
#  ('Geofisika', 'UGM'),
#  ('Geofisika ', 'UI'),
#  ('Gizi', 'UGM'),
#  ('Hi', 'UB'),
#  ('Hubungan Internasional', 'UGM'),
#  ('Hubungan Masyarakat', 'UNPAD'),
#  ('Hukum', 'UB'),
#  ('Humas', 'UNPAD'),
#  ('Ikk', 'IPB'),
#  ('Ilmu Adm. Fiskal', 'UI'),
#  ('Ilmu Administrasi Bisnis', 'UNPAD'),
#  ('Ilmu Administrasi Negara', 'UI'),
#  ('Ilmu Administrasi Publik', 'UB'),
#  ('Ilmu Dan Teknologi Kelautan', 'IPB'),
#  ('Ilmu Dan Teknologi Pangan', 'UB'),
#  ('Ilmu Ekonomi', 'UGM'),
#  ('Ilmu Ekonomi Islam', 'UI'),
#  ('Ilmu Filsafat', 'UGM'),
#  ('Ilmu Gizi', 'IPB'),
#  ('Ilmu Hub. Internasional', 'UNPAD'),
#  ('Ilmu Hubungan Internasional', 'UI'),
#  ('Ilmu Hukum', 'UB'),
#  ('Ilmu Informasi Dan Perpustakaan ', 'UNPAD'),
#  ('Ilmu Kelautan', 'UNDIP'),
#  ('Ilmu Keluarga Dan Konsumen', 'IPB'),
#  ('Ilmu Keperawatan', 'UI'),
#  ('Ilmu Keperawatan ', 'UNPAD '),
#  ('Ilmu Kesehatan Masyarakat', 'UI'),
#  ('Ilmu Komputer', 'IPB'),
#  ('Ilmu Komunikasi', 'UB'),
#  ('Ilmu Perpustakaan', 'UI'),
#  ('Ilmu Peternakan', 'UNPAD'),
#  ('Ilmu Politik', 'UB'),
#  ('Ilmu Sejarah', 'UI'),
#  ('Ilmu Sosiologi', 'UNPAD'),
#  ('Ilmu Teknologi Pangan', 'IPB'),
#  ('Informasi Dan Ilmu Perpustakaan', 'UNPAD'),
#  ('Itb - Sithr', 'ITB'),
#  ('Jurnalistik', 'UNPAD'),
#  ('Kedokteran', 'UI'),
#  ('Kedokteran ', 'UNAIR'),
#  ('Kedokteran Gigi', 'UGM'),
#  ('Kedokteran Hewan', 'IPB'),
#  ('Kehutanan', 'UGM'),
#  ('Kesehatan Masyarakat', 'UI'),
#  ('Kesehatan Masyarakat (Pdd Banyuwangi)', 'UNAIR'),
#  ('Kesejahteraan Sosial', 'UI'),
#  ('Kimia', 'IPB'),
#  ('Kimia ', 'UI'),
#  ('Kimia, ', 'UNPAD'),
#  ('Komunikasi', 'UI'),
#  ('Komunikasi Dan Pengembangan Masyarakat', 'IPB'),
#  ('Kriminologi', 'UI'),
#  ('Manajemen', 'IPB'),
#  ('Manajemen Bisnis', 'ITS'),
#  ('Manajemen Dan Kebijakan Publik (An)', 'UGM'),
#  ('Manajemen Hutan', 'IPB'),
#  ('Manajemen Komunikasi', 'UNPAD'),
#  ('Manajemen Sd Perairan', 'UNDIP'),
#  ('Matematika', 'IPB'),
#  ('Matematika ', 'UI'),
#  ('Matematika (Fak. Matematika & Ilmu Pengetahuan Alam)', 'ITB'),
#  ('Menejemen', 'UNAIR '),
#  ('Meteorologi Terapan', 'IPB'),
#  ('Mipa Geologi', 'UI'),
#  ('Mipa Kimia', 'UB'),
#  ('Nutrisi & Teknologi Pakan', 'IPB'),
#  ('Oceanografi', 'UNDIP'),
#  ('Pembangunan Wilayah', 'UGM'),
#  ('Pend. Apoteker', 'UNAIR'),
#  ('Pendidikan Dokter', 'UB'),
#  ('Pendidikan Dokter Gigi', 'UNAIR'),
#  ('Perencanaan Wilayah & Kota', 'UB'),
#  ('Perencanaan Wilayah Dan Kota', 'ITS'),
#  ('Perikanan', 'IPB'),
#  ('Peternakan', 'UB'),
#  ('Proteksi Tanaman', 'IPB'),
#  ('Psdk', 'UGM'),
#  ('Psikologi', 'UI'),
#  ('Psikologi ', 'UGM'),
#  ('S-1 Teknik Informatika', 'ITS'),
#  ('Sappk', 'ITB'),
#  ('Sastra', 'UI'),
#  ('Sastra Arab', 'UGM'),
#  ('Sastra Belanda', 'UI'),
#  ('Sastra Indonesia', 'UNPAD'),
#  ('Sastra Inggris', 'UI'),
#  ('Sastra Inggris ', 'UNAIR'),
#  ('Sastra Jawa', 'UI'),
#  ('Sastra Jepang', 'UB'),
#  ('Sastra Jerman', 'UI'),
#  ('Sastra Jerman ', 'UNPAD'),
#  ('Sastra Perancis', 'UI'),
#  ('Sbm', 'ITB'),
#  ('Silvikultur', 'IPB'),
#  ('Sistem Informasi', 'ITS'),
#  ('Sith - Rekayasa', 'ITB'),
#  ('Sosial Ekonomi Pertanian (Agrobisnis)', 'UGM'),
#  ('Sosiologi', 'UB'),
#  ('Sosiologi Murni', 'UNAIR'),
#  ('Statistika', 'IPB'),
#  ('Stei', 'ITB'),
#  ('Tehnik Sipil', 'UGM'),
#  ('Teknik Elektro', 'ITS'),
#  ('Teknik Fisika', 'UGM'),
#  ('Teknik Geodesi', 'UNDIP'),
#  ('Teknik Geologi', 'UGM'),
#  ('Teknik Geologi ', 'UNPAD'),
#  ('Teknik Industri', 'ITB'),
#  ('Teknik Industri Pertanian', 'UGM'),
#  ('Teknik Informatika', 'ITS'),
#  ('Teknik Kimia', 'ITB'),
#  ('Teknik Komputer', 'ITS'),
#  ('Teknik Lingkungan', 'UB'),
#  ('Teknik Mesin', 'ITS'),
#  ('Teknik Mesin Dan Biosistem', 'IPB'),
#  ('Teknik Metalurgi & Material', 'UI'),
#  ('Teknik Multimedia Dan Jaringan', 'ITS'),
#  ('Teknik Nuklir', 'UGM'),
#  ('Teknik Pengairan', 'UB'),
#  ('Teknik Perkapalan', 'ITS'),
#  ('Teknik Pertanian', 'UGM'),
#  ('Teknik Sipil', 'ITB'),
#  ('Teknik Sipil Dan Lingkungan', 'IPB'),
#  ('Teknik Sipil Lingkungan', 'ITB'),
#  ('Teknik Sistem Perkapalan', 'ITS'),
#  ('Teknobiomedik', 'UNAIR'),
#  ('Teknologi Bioproses', 'UI'),
#  ('Teknologi Dan Manajemen Perikanan Budidaya', 'IPB'),
#  ('Teknologi Hasil Perikanan', 'UB'),
#  ('Teknologi Industri Hasil Perikanan', 'UNAIR'),
#  ('Teknologi Industri Pertanian', 'IPB'),
#  ('Teknologi Informasi', 'UGM'),
#  ('Teknologi Pangan', 'IPB'),
#  ('Televisi & Film', 'UNPAD'),
#  ('Tin', 'IPB'),
#  ('Tip', 'UGM'),
#  ('Tv & Film', 'UNPAD'),
#  ('Ugm', 'UGM')]

# %%
tabel_alternatif = get_tabel_alternatif(data_sort, list_jurusan_ptn)

tabel_alternatif
# Out:
#             Administrasi Fiskal - UI (IPS)  Administrasi Negara - UNPAD (IPS)  \
# Matematika                       84.000000                          88.500000
# Inggris                          84.000000                          80.500000
# Indonesia                        84.000000                          89.500000
# Fisika                           82.000000                          84.584430
# Kimia                            81.000000                          84.592411
# Biologi                          83.000000                          83.879942
# Ekonomi                          86.145714                          89.000000
# Geografi                         85.512727                          87.500000
# Sosiologi                        86.930877                          85.500000
# Sejarah                          83.943883                          88.000000
#
#             Administrasi Niaga - UI (IPS)  Administrasi Perpajakan - UB (IPS)  \
# Matematika                      85.465625                           92.000000
# Inggris                         83.888667                           86.000000
# Indonesia                       85.246032                           89.000000
# Fisika                          84.493016                           81.956615
# Kimia                           85.297674                           82.397782
# Biologi                         84.182558                           82.827536
# Ekonomi                         86.145714                           91.242143
# Geografi                        85.512727                           91.000000
# Sosiologi                       86.930877                           91.000000
# Sejarah                         83.943883                           93.000000
#
#             Agribisnis - IPB (IPA)  Agroekoteknologi - UB (IPA)  \
# Matematika                  95.000                    81.852143
# Inggris                     90.000                    84.729722
# Indonesia                   88.000                    85.837917
# Fisika                      91.000                    81.739154
# Kimia                       89.000                    82.349446
# Biologi                     90.000                    83.706884
# Ekonomi                     85.000                    83.726429
# Geografi                    81.316                    84.627747
# Sosiologi                      NaN                    85.702500
# Sejarah                     89.000                    85.517917
#
#             Agronomi Dan Holtikultura - IPB (IPA)  \
# Matematika                              91.000000
# Inggris                                 91.000000
# Indonesia                               89.000000
# Fisika                                  89.000000
# Kimia                                   90.000000
# Biologi                                 91.000000
# Ekonomi                                 83.000000
# Geografi                                83.526667
# Sosiologi                                     NaN
# Sejarah                                 82.676471
#
#             Agroteknologi - UNPAD (IPA)  Akuntansi - UGM (IPS)  \
# Matematika                    82.500000              91.625000
# Inggris                       82.750000              90.875000
# Indonesia                     84.000000              89.875000
# Fisika                        80.500000              89.437576
# Kimia                         81.500000              88.716106
# Biologi                       83.250000              89.695798
# Ekonomi                       82.062045              92.250000
# Geografi                      81.926031              88.959803
# Sosiologi                     81.331846              91.872475
# Sejarah                       81.000669              90.581317
#
#             Akutansi - UI (IPA)  ...  \
# Matematika            44.693125  ...
# Inggris               54.255467  ...
# Indonesia             85.000000  ...
# Fisika                87.000000  ...
# Kimia                 74.300000  ...
# Biologi               83.000000  ...
# Ekonomi               86.145714  ...
# Geografi              85.512727  ...
# Sosiologi             86.930877  ...
# Sejarah               85.000000  ...
#
#             Teknologi Dan Manajemen Perikanan Budidaya - IPB (IPS)  \
# Matematika                                          84.500000
# Inggris                                             85.500000
# Indonesia                                           86.500000
# Fisika                                              84.500000
# Kimia                                               84.000000
# Biologi                                             84.000000
# Ekonomi                                             84.422980
# Geografi                                            85.388333
# Sosiologi                                                 NaN
# Sejarah                                             85.958333
#
#             Teknologi Hasil Perikanan - UB (IPA)  \
# Matematika                             82.000000
# Inggris                                91.000000
# Indonesia                              89.000000
# Fisika                                 80.000000
# Kimia                                  79.000000
# Biologi                                83.000000
# Ekonomi                                88.726429
# Geografi                               84.808608
# Sosiologi                              84.850000
# Sejarah                                83.000000
#
#             Teknologi Industri Hasil Perikanan - UNAIR (IPA)  \
# Matematika                                         85.000000
# Inggris                                            84.000000
# Indonesia                                          86.000000
# Fisika                                             83.000000
# Kimia                                              81.000000
# Biologi                                            86.000000
# Ekonomi                                            85.211111
# Geografi                                           84.793706
# Sosiologi                                          85.695971
# Sejarah                                            84.000000
#
#             Teknologi Industri Pertanian - IPB (IPA)  \
# Matematika                                 85.410699
# Inggris                                    84.775000
# Indonesia                                  86.789540
# Fisika                                     85.810345
# Kimia                                      84.825000
# Biologi                                    86.391667
# Ekonomi                                    84.961490
# Geografi                                   83.645000
# Sosiologi                                        NaN
# Sejarah                                    85.088235
#
#             Teknologi Informasi - UGM (IPA)  Teknologi Pangan - IPB (IPA)  \
# Matematika                        92.000000                     92.000000
# Inggris                           90.000000                     88.000000
# Indonesia                         93.000000                     86.000000
# Fisika                            89.000000                     92.000000
# Kimia                             89.000000                     85.000000
# Biologi                           93.000000                     86.000000
# Ekonomi                           89.837895                     85.845960
# Geografi                          88.094322                     87.250000
# Sosiologi                         90.363636                           NaN
# Sejarah                           91.000000                     85.916667
#
#             Televisi & Film - UNPAD (IPS)  Tin - IPB (IPA)  Tip - UGM (IPA)  \
# Matematika                      85.000000            90.00        87.000000
# Inggris                         85.500000            83.00        94.000000
# Indonesia                       86.500000            89.00        80.000000
# Fisika                          84.584430            88.00        86.000000
# Kimia                           84.592411            88.00        87.000000
# Biologi                         83.879942            89.00        86.000000
# Ekonomi                         86.000000            83.00        89.837895
# Geografi                        86.500000            87.25        88.094322
# Sosiologi                       85.500000              NaN        90.363636
# Sejarah                         86.500000            88.00        88.650538
#
#             Tv & Film - UNPAD (IPS)
# Matematika                85.000000
# Inggris                   85.000000
# Indonesia                 84.000000
# Fisika                    84.584430
# Kimia                     84.592411
# Biologi                   83.879942
# Ekonomi                   86.000000
# Geografi                  87.000000
# Sosiologi                 85.000000
# Sejarah                   85.000000
#
# [10 rows x 162 columns]

# %%
tabel_alternatif.to_csv("Tabel Alternatif.csv", encoding="utf-8")
